# %%
import argparse
import torch

from tqdm import tqdm

from utils import load_cached_activations

# %%
import torch.nn.functional as F

def topK_activation(x: torch.Tensor, k: int) -> torch.Tensor:
    """
    Apply top-k activation to the input tensor.

    Args:
        x: (BATCH_SIZE, D_EMBED, D_MODEL) input tensor to apply top-k activation on.
        k: Number of top activations to keep.

    Returns:
        torch.Tensor: Tensor with only the top k activations preserved,and others
        set to zero.

    This function performs the following steps:
    1. Find the top k values and their indices in the input tensor.
    2. Apply ReLU activation to these top k values.
    3. Create a new tensor of zeros with the same shape as the input.
    4. Scatter the activated top k values back into their original positions.
    """
    topk = torch.topk(x, k=k, dim=-1, sorted=False)
    values = F.relu(topk.values)
    result = torch.zeros_like(x)
    result.scatter_(-1, topk.indices, values)
    return result

# %%
import sys
sys.path.append('../../')
sys.path.append('../../plm_circuits')
from helpers.utils import (
    clear_memory,
    load_esm,
    load_sae_prot,
    mask_flanks_segment,
    patching_metric,
    cleanup_cuda,
    set_seed
)
# Out:
# In IPython
# Set autoreload

# %%
main_layers = [4, 8, 12, 16, 20, 24, 28]
saes = []
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
for layer in main_layers:
    sae_model = load_sae_prot(ESM_DIM=1280, SAE_DIM=4096, LAYER=layer, device=device)
    saes.append(sae_model)
    print(sae_model.k)
# Out:
# 128
# 128
# 128
# 128
# 128
# 128
# 128

# %%
tmp = load_cached_activations("/project/pi_annagreen_umass_edu/jatin/plm_circuits/acts")
summarized_activations = torch.zeros(len(tmp.metadata['proteins']), len(tmp.layers)*4096)
print(summarized_activations.shape)
print("-"*100)
k = 128
for protein_ix in tqdm(range(summarized_activations.shape[0])):
    cur_ptn = tmp.load_protein_activations_original_format(protein_ix)
    for l in tmp.layers:
        print(f"Original activations shape: {cur_ptn['activations'][l].shape}")
        print(f"Number of nonzero elements in original: {torch.count_nonzero(cur_ptn['activations'][l])}")
        latents = topK_activation(cur_ptn['activations'][l], k=k)
        print(f"Latents shape: {latents.shape}")
        print(f"Number of nonzero elements in latents: {torch.count_nonzero(latents)}")
    break
# Out:
# Loaded cache with 10000 proteins
# torch.Size([10000, 28672])
# ----------------------------------------------------------------------------------------------------
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Original activations shape: torch.Size([267, 4096])
# Number of nonzero elements in original: 34176
# Latents shape: torch.Size([267, 4096])
# Number of nonzero elements in latents: 34176
# Original activations shape: torch.Size([267, 4096])
# Number of nonzero elements in original: 34176
# Latents shape: torch.Size([267, 4096])
# Number of nonzero elements in latents: 34176
# Original activations shape: torch.Size([267, 4096])
# Number of nonzero elements in original: 34176
# Latents shape: torch.Size([267, 4096])
# Number of nonzero elements in latents: 34176
# Original activations shape: torch.Size([267, 4096])
# Number of nonzero elements in original: 34176
# Latents shape: torch.Size([267, 4096])
# Number of nonzero elements in latents: 34176
# Original activations shape: torch.Size([267, 4096])
# Number of nonzero elements in original: 34176
# Latents shape: torch.Size([267, 4096])
# Number of nonzero elements in latents: 34176
# Original activations shape: torch.Size([267, 4096])
# Number of nonzero elements in original: 34176
# Latents shape: torch.Size([267, 4096])
# Number of nonzero elements in latents: 34176
# Original activations shape: torch.Size([267, 4096])
# Number of nonzero elements in original: 34176
# Latents shape: torch.Size([267, 4096])
# Number of nonzero elements in latents: 34176

# %%
import sys
import os
import json
import torch

import pandas as pd
import numpy as np

from scipy.sparse import csr_matrix, save_npz, load_npz
from scipy.stats import mannwhitneyu

# %%
interpro_annotations_nonzero = pd.read_csv("metadata/interpro_entry_list_mapping_nonzero.csv")
ptn_fam_nonzero_tensor = torch.load("metadata/ptn_fam_tensor_nonzero.pt")

# latents_family_effect_size = torch.load("metadata/latents_property_top_q_effect_size.pt")
# latents_family_pvals = torch.load("metadata/latents_property_top_q_pvals.pt")
latents_family_effect_size = torch.load("data/latents_property_og_two_top_q_effect_size.pt") #torch.load("data/latents_property_2pkea_top_q_effect_size.pt")
latents_family_pvals = torch.load("data/latents_property_og_two_top_q_pvals.pt")
latents_family_stats = torch.load("data/latents_property_og_two_top_q_statistic.pt")
latents_n_neg = torch.load("data/latents_property_og_two_top_q_n_neg.pt")
latents_n_pos = torch.load("data/latents_property_og_two_top_q_n_pos.pt")
latents_auc = torch.load("data/latents_property_og_two_top_q_auc.pt")
# Out:
# /tmp/ipykernel_3091521/2512606895.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ptn_fam_nonzero_tensor = torch.load("metadata/ptn_fam_tensor_nonzero.pt")
# /tmp/ipykernel_3091521/2512606895.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   latents_family_effect_size = torch.load("data/latents_property_og_two_top_q_effect_size.pt") #torch.load("data/latents_property_2pkea_top_q_effect_size.pt")
# /tmp/ipykernel_3091521/2512606895.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   latents_family_pvals = torch.load("data/latents_property_og_two_top_q_pvals.pt")
# /tmp/ipykernel_3091521/2512606895.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   latents_family_stats = torch.load("data/latents_property_og_two_top_q_statistic.pt")
# /tmp/ipykernel_3091521/2512606895.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   latents_n_neg = torch.load("data/latents_property_og_two_top_q_n_neg.pt")
# /tmp/ipykernel_3091521/2512606895.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   latents_n_pos = torch.load("data/latents_property_og_two_top_q_n_pos.pt")
# /tmp/ipykernel_3091521/2512606895.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   latents_auc = torch.load("data/latents_property_og_two_top_q_auc.pt")

# %%
latents_auc.shape
# Out:
# torch.Size([383, 10096])

# %%
print(f"Interpro Annotations: {interpro_annotations_nonzero.shape}")
print(f"ptn_fam_nonzero_tensor: {ptn_fam_nonzero_tensor.shape}")
print(f"Effect sizes: {latents_family_effect_size.shape}")
print(f"MWU pvals: {latents_family_pvals.shape}")
print(f"MWU stats: {latents_family_stats.shape}")
# Out:
# Interpro Annotations: (10096, 3)
# ptn_fam_nonzero_tensor: torch.Size([10000, 10096])
# Effect sizes: torch.Size([383, 10096, 4])
# MWU pvals: torch.Size([383, 10096])
# MWU stats: torch.Size([383, 10096])

# %%
interpro_annotations_nonzero.head()
# Out:
#     ENTRY_AC   ENTRY_TYPE                                         ENTRY_NAME
# 0  IPR000126  Active_site    Serine proteases, V8 family, serine active site
# 1  IPR000169  Active_site           Cysteine peptidase, cysteine active site
# 2  IPR000189  Active_site          Prokaryotic transglycosylase, active site
# 3  IPR001252  Active_site                  Malate dehydrogenase, active site
# 4  IPR001345  Active_site  Phosphoglycerate/bisphosphoglycerate mutase, a...

# %%
interpro_annotations_nonzero[interpro_annotations_nonzero['ENTRY_NAME'].str.contains("SAM")]
# Out:
#        ENTRY_AC              ENTRY_TYPE  \
# 324   IPR018063          Conserved_site
# 949   IPR001678                  Domain
# 1287  IPR004107                  Domain
# 1545  IPR006638                  Domain
# 1601  IPR007197                  Domain
# 2467  IPR022642                  Domain
# 2714  IPR030382                  Domain
# 3034  IPR037635                  Domain
# 3247  IPR042650                  Domain
# 3401  IPR047238                  Domain
# 3555  IPR049560                  Domain
# 4441  IPR002935                  Family
# 6704  IPR023867                  Family
# 7921  IPR050377                  Family
# 8357  IPR051631                  Family
# 8424  IPR052085                  Family
# 8494  IPR053105                  Family
# 8504  IPR053384                  Family
# 8934  IPR023404  Homologous_superfamily
#
#                                              ENTRY_NAME
# 324   SAM-dependent methyltransferase RsmI, conserve...
# 949   SAM-dependent methyltransferase RsmB-F/NOP2-ty...
# 1287                    Integrase, SAM-like, N-terminal
# 1545       Elp3/MiaA/NifB-like, radical SAM core domain
# 1601                                        Radical SAM
# 2467  MCP methyltransferase, CheR-type, SAM-binding ...
# 2714     SAM-dependent methyltransferase TRM5/TYW2-type
# 3034                                   VTS1, SAM domain
# 3247                                   ASZ1, SAM domain
# 3401  Ankyrin repeat and SAM domain-containing prote...
# 3555  SAM-dependent methyltransferase RsmB-F/NOP2-ty...
# 4441     Class I-like SAM-dependent O-methyltransferase
# 6704         Anaerobic sulphatase maturase, radical SAM
# 7921  Radical SAM PqqA peptide cyclase/Mycofactocin ...
# 8357  Ankyrin repeat and KH/SAM domain-containing pr...
# 8424         WD repeat, SAM and U-box domain-containing
# 8494  Class V-like SAM-binding domain-containing pro...
# 8504                    SAM-dependent methyltransferase
# 8934                  Radical SAM, alpha/beta horseshoe

# %%
interpro_ids_for_manual = {"top2": ["IPR001757", # HATPase
                                    "IPR006086", # XPG-I domain
                                    "IPR001752"  # Kinesin
                                   ],
                           "metx":  [
                               "IPR029058", # Alpha/Beta hydrolase fold
                               "",
                               "",
                           ]}

# %%
with open("/work/pi_jensen_umass_edu/jnainani_umass_edu/plm_circuits/results/layer_latent_dicts/layer_latent_dict_MetXA_0.70.json", 'r') as file:
    metx_latents = json.load(file)

with open("/work/pi_jensen_umass_edu/jnainani_umass_edu/plm_circuits/results/layer_latent_dicts/layer_latent_dict_Top2_0.70.json", 'r') as file:
    top2_latents = json.load(file)

with open("/work/pi_jensen_umass_edu/jnainani_umass_edu/plm_circuits/results/layer_latent_dicts/layer_latent_dict_2PKEA_0.70.json", 'r') as file:
    pkea_latents = json.load(file)

# %%
offsets = {k: i*4096 for i,k in enumerate(metx_latents.keys())}
full_indices_metx = [j+offsets[layer_id] for layer_id in metx_latents.keys() for j in metx_latents[layer_id]]
full_indices_top2 = [j+offsets[layer_id] for layer_id in top2_latents.keys() for j in top2_latents[layer_id]]
full_indices_pkea = [j+offsets[layer_id] for layer_id in pkea_latents.keys() for j in pkea_latents[layer_id]]
latent_ids_both_proteins = list(set(full_indices_top2+full_indices_metx))
# latent_ids_both_proteins = list(set(full_indices_pkea))
latent_ids_both_proteins.sort()
len(latent_ids_both_proteins) # yes, only 383 unique
# Out:
# 383

# %%
latent_ids_both_proteins[0:10]
# Out:
# [100, 181, 237, 340, 443, 495, 527, 601, 794, 798]

# %%
n_tests = 28672*10096

# %%
n_tests
# Out:
# 289472512

# %%
np.argmin(latents_family_pvals[0])
# Out:
# tensor(8787)

# %%
import numpy as np
from scipy.stats import mannwhitneyu

try:
    import torch
except Exception:
    torch = None

def to_numpy_1d(a):
    # Convert numpy/torch/list to 1D numpy and drop NaNs/Infs
    if torch is not None and isinstance(a, torch.Tensor):
        a = a.detach().cpu().numpy()
    else:
        a = np.asarray(a)
    a = np.ravel(a)
    if a.size == 0:
        return a
    mask = np.isfinite(a)
    return a[mask]

# %%
import pickle

all_acts = torch.load("data/summarized_acts_top_q.pt")
all_properties = torch.load("metadata/ptn_fam_tensor_nonzero.pt")
with open("metadata/list_of_desired_latents_2pkea.pkl", 'rb') as f:
    subset_list = list(set(pickle.load(f)))
    subset_list.sort()
all_acts = all_acts[:,subset_list]
# Out:
# /tmp/ipykernel_3495194/26409442.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   all_acts = torch.load("data/summarized_acts_top_q.pt")
# /tmp/ipykernel_3495194/26409442.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   all_properties = torch.load("metadata/ptn_fam_tensor_nonzero.pt")

# %%
annotated_latents = []
results_df_dict = {}
for latent_i in range(latents_family_pvals.shape[0]):
    for family_j in range(latents_family_pvals.shape[1]):
        if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
            # x_raw = all_acts[all_properties[:, family_j] != 0, latent_i]
            # y_raw = all_acts[all_properties[:, family_j] == 0, latent_i]

            # x = to_numpy_1d(x_raw)
            # y = to_numpy_1d(y_raw)

            n_pos, n_neg = latents_n_pos[latent_i,family_j], latents_n_neg[latent_i,family_j]
            
            if n_pos == 0 or n_neg == 0:
                print(f"Property j={j}: one of the groups is empty (n_pos={n_pos}, n_neg={n_neg}); skipping.\n")
                continue
            # auc = latents_family_stats[latent_i,family_j] / (n_pos*n_neg)
            auc = latents_auc[latent_i,family_j]
            if auc > 0.95 or auc < 0.05:
                df_id = str(latent_i)+"_"+str(family_j)
                annotated_latents += [latent_ids_both_proteins[latent_i]]
                cur_lat_id = latent_ids_both_proteins[latent_i]
                layer_id = ((cur_lat_id // 4096) + 1) * 4
                lat_id = int(cur_lat_id % 4096)
                l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/ (latents_family_effect_size[latent_i,family_j,1]+0.00001))
                case_ptn = "MetX"
                if latent_ids_both_proteins[latent_i] in full_indices_top2:
                    case_ptn="Top2"
                results_df_dict[df_id] = {
                        "Case": case_ptn,
                        "Layer": layer_id,
                        "Latent_ID": lat_id,
                        "AUC": float(auc),
                        "InterPro ID": interpro_annotations_nonzero.iloc[family_j]["ENTRY_AC"],
                        "InterPro Name": interpro_annotations_nonzero.iloc[family_j]["ENTRY_NAME"],
                        "A_in": float(latents_family_effect_size[latent_i,family_j,0]),
                        "A_out": float(latents_family_effect_size[latent_i,family_j,1]),
                        "Delta_In_Out": float(latents_family_effect_size[latent_i,family_j,0]-latents_family_effect_size[latent_i,family_j,1]),
                        "L2FC": float(l2fc),
                        "Bonferroni adj. p-value": float(latents_family_pvals[latent_i,family_j]*n_tests)
                    }

# %%
import pandas as pd
from pathlib import Path

# Build DataFrame from your dict
df = pd.DataFrame.from_dict(results_df_dict, orient='index')

# Column ordering
cols = ['Case', 'Layer', 'Latent_ID', 'AUC', 'InterPro ID', 'InterPro Name', 
        'A_in', 'A_out', 'Delta_In_Out', 'L2FC', 'Bonferroni adj. p-value']
df = df[cols]
df.head()
# Out:
#         Case  Layer  Latent_ID       AUC InterPro ID  \
# 0_8560  Top2      4        100  0.956818   IPR008930
# 9_339   MetX      4        798  0.951780   IPR018102
# 9_4210  MetX      4        798  0.955919   IPR001971
# 9_6262  MetX      4        798  0.978647   IPR019981
# 9_9605  MetX      4        798  0.955919   IPR036967
#
#                                             InterPro Name      A_in     A_out  \
# 0_8560  Terpenoid cyclases/protein prenyltransferase a...  5.153020  3.690708
# 9_339   Small ribosomal subunit protein uS11, conserve...  8.440607  2.349753
# 9_4210               Small ribosomal subunit protein uS11  8.667236  2.347987
# 9_6262  Small ribosomal subunit protein uS11, bacteria...  9.537890  2.348775
# 9_9605   Small ribosomal subunit protein uS11 superfamily  8.667236  2.347987
#
#         Delta_In_Out      L2FC  Bonferroni adj. p-value
# 0_8560      1.462312  0.481517                 0.036786
# 9_339       6.090854  1.844831                 0.000033
# 9_4210      6.319250  1.884142                 0.000002
# 9_6262      7.189116  2.021756                 0.000018
# 9_9605      6.319250  1.884142                 0.000002

# %%
# Output paths (absolute)
out_dir = Path('/work/pi_jensen_umass_edu/jnainani_umass_edu/plm_circuits/results/domain_correlation_results/topq')
out_dir.mkdir(parents=True, exist_ok=True)

csv_path = out_dir / 'annotated_latents_results_og_two.csv'
txt_path = out_dir / 'annotated_latents_results_og_two.txt'

# Save as CSV (good for spreadsheets)
df.to_csv(csv_path, index=False)

# Save as plain text (fixed-width table)
with open(txt_path, 'w') as f:
    f.write(df.to_string(index=False))

print(f'Wrote CSV to: {csv_path}')
print(f'Wrote TXT to: {txt_path}')
# Out:
# Wrote CSV to: /work/pi_jensen_umass_edu/jnainani_umass_edu/plm_circuits/results/domain_correlation_results/topq/annotated_latents_results_og_two.csv
# Wrote TXT to: /work/pi_jensen_umass_edu/jnainani_umass_edu/plm_circuits/results/domain_correlation_results/topq/annotated_latents_results_og_two.txt

# %%
len(set(annotated_latents))
# Out:
# 163

# %%
163/188
# Out:
# 0.8670212765957447

# %%
set(annotated_latents)
# Out:
# {1509,
#  2487,
#  3501,
#  4232,
#  8456,
#  8579,
#  8684,
#  8758,
#  8882,
#  8913,
#  9464,
#  9577,
#  9738,
#  10046,
#  10152,
#  10161,
#  10670,
#  10743,
#  10852,
#  10971,
#  11366,
#  11521,
#  11522,
#  11700,
#  11713,
#  11749,
#  11796,
#  11832,
#  11851,
#  11865,
#  11874,
#  11943,
#  12334,
#  12454,
#  12537,
#  12675,
#  12749,
#  12835,
#  12845,
#  12968,
#  13088,
#  13177,
#  13219,
#  13233,
#  13304,
#  13312,
#  13363,
#  13489,
#  13524,
#  13542,
#  13658,
#  13687,
#  13690,
#  13753,
#  13791,
#  13887,
#  13986,
#  14037,
#  14156,
#  14184,
#  14282,
#  14436,
#  14628,
#  14759,
#  14934,
#  14965,
#  15021,
#  15194,
#  15240,
#  15361,
#  15396,
#  15491,
#  15597,
#  15615,
#  15680,
#  15740,
#  15742,
#  15797,
#  15953,
#  15954,
#  15967,
#  16110,
#  16130,
#  16167,
#  16192,
#  16226,
#  16277,
#  16278,
#  16337,
#  16406,
#  16479,
#  16501,
#  16758,
#  16834,
#  16846,
#  16872,
#  16986,
#  17183,
#  17214,
#  17665,
#  17778,
#  18128,
#  18130,
#  18183,
#  18201,
#  18405,
#  18407,
#  18586,
#  18706,
#  18711,
#  18785,
#  18810,
#  19285,
#  19351,
#  19360,
#  19372,
#  19751,
#  19789,
#  19845,
#  19846,
#  19891,
#  19964,
#  20000,
#  20061,
#  20116,
#  20155,
#  20384,
#  20442,
#  20463,
#  20910,
#  21085,
#  21493,
#  21605,
#  21629,
#  21770,
#  21901,
#  21907,
#  22349,
#  22397,
#  22530,
#  22543,
#  22609,
#  22689,
#  22829,
#  22900,
#  22915,
#  23011,
#  23112,
#  23212,
#  23477,
#  23651,
#  23864,
#  24255,
#  24439,
#  25393,
#  25438,
#  25472,
#  26712,
#  26978,
#  27715,
#  28331,
#  28571,
#  28597}

# %%
annotated_latents = []
for latent_i in range(latents_family_pvals.shape[0]):
    for family_j in range(latents_family_pvals.shape[1]):
        if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
            if latents_family_effect_size[latent_i,family_j,1] < 0.5:
                l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/ (latents_family_effect_size[latent_i,family_j,1]+0.00001))
                if l2fc >= 4:  # latents_family_effect_size[latent_i,family_j,0] > 1.05: #
                    annotated_latents += [latent_ids_both_proteins[latent_i]]
                    print(f"Latent {latent_ids_both_proteins[latent_i]} is sig assoc w family {family_j}")
                    print(f"    Family {interpro_annotations_nonzero.iloc[family_j]['ENTRY_NAME']}")
                    print(f"    Mean in-family: {latents_family_effect_size[latent_i,family_j,0]}")
                    print(f"    Mean out-of-family: {latents_family_effect_size[latent_i,family_j,1]}")
                    print(f"    Log2FC: {np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])}")
# Out:
# Latent 3717 is sig assoc w family 128
#     Family Metallothionein, vertebrate, metal binding site
#     Mean in-family: 1.982421875
#     Mean out-of-family: 0.05706040561199188
#     Log2FC: 5.1186299324035645
# Latent 3717 is sig assoc w family 604
#     Family Dehydrin, conserved site
#     Mean in-family: 1.9475911855697632
#     Mean out-of-family: 0.0572599433362484
#     Log2FC: 5.0880208015441895
# Latent 3717 is sig assoc w family 1441
#     Family YSIRK Gram-positive signal peptide
#     Mean in-family: 1.2471354007720947
#     Mean out-of-family: 0.05728105828166008
#     Log2FC: 4.444416046142578
# Latent 3717 is sig assoc w family 1652
#     Family ASXL, HARE-HTH domain
#     Mean in-family: 2.6171875
#     Mean out-of-family: 0.0571260005235672
#     Log2FC: 5.517725944519043
# Latent 3717 is sig assoc w family 1732
#     Family Regulator of ribonuclease activity B domain
#     Mean in-family: 1.2705078125
#     Mean out-of-family: 0.057395391166210175
#     Log2FC: 4.468326568603516
# Latent 3717 is sig assoc w family 1825
#     Family Fibrinogen-binding domain 2
#     Mean in-family: 1.2471354007720947
#     Mean out-of-family: 0.05728105828166008
#     Log2FC: 4.444416046142578
# Latent 3717 is sig assoc w family 2341
#     Family LPXTG cell wall anchor domain
#     Mean in-family: 0.935351550579071
#     Mean out-of-family: 0.05728678032755852
#     Log2FC: 4.029234409332275
# Latent 3717 is sig assoc w family 2643
#     Family Agouti domain
#     Mean in-family: 1.72216796875
#     Mean out-of-family: 0.05730504170060158
#     Log2FC: 4.909420013427734
# Latent 3717 is sig assoc w family 3031
#     Family Hepatitis delta antigen (HDAg) domain
#     Mean in-family: 2.3154296875
#     Mean out-of-family: 0.05718636512756348
#     Log2FC: 5.339465141296387
# Latent 3717 is sig assoc w family 3139
#     Family SDR-like Ig domain
#     Mean in-family: 1.2471354007720947
#     Mean out-of-family: 0.05728105828166008
#     Log2FC: 4.444416046142578
# Latent 3717 is sig assoc w family 3589
#     Family Glabrous enhancer-binding protein-like, DBD domain
#     Mean in-family: 1.3250324726104736
#     Mean out-of-family: 0.05738447979092598
#     Log2FC: 4.529223442077637
# Latent 3717 is sig assoc w family 3590
#     Family Glabrous enhancer-binding protein-like, C-terminal domain
#     Mean in-family: 1.3250324726104736
#     Mean out-of-family: 0.05738447979092598
#     Log2FC: 4.529223442077637
# Latent 3717 is sig assoc w family 3724
#     Family Metallothionein, vertebrate
#     Mean in-family: 1.982421875
#     Mean out-of-family: 0.05706040561199188
#     Log2FC: 5.1186299324035645
# Latent 3717 is sig assoc w family 3755
#     Family Dehydrin
#     Mean in-family: 1.9475911855697632
#     Mean out-of-family: 0.0572599433362484
#     Log2FC: 5.0880208015441895
# Latent 3717 is sig assoc w family 3767
#     Family Protamine P1
#     Mean in-family: 1.5597097873687744
#     Mean out-of-family: 0.05658581852912903
#     Log2FC: 4.784693241119385
# Latent 3717 is sig assoc w family 3824
#     Family Large ribosomal subunit protein bL36
#     Mean in-family: 1.4433051347732544
#     Mean out-of-family: 0.055139314383268356
#     Log2FC: 4.710151195526123
# Latent 3717 is sig assoc w family 4202
#     Family Scorpion short chain toxin, potassium channel inhibitor
#     Mean in-family: 0.9527994990348816
#     Mean out-of-family: 0.05736938491463661
#     Log2FC: 4.05381965637207
# Latent 3717 is sig assoc w family 4341
#     Family Keratin-associated protein
#     Mean in-family: 2.8180336952209473
#     Mean out-of-family: 0.05708581954240799
#     Log2FC: 5.625412464141846
# Latent 3717 is sig assoc w family 4344
#     Family Hepatitis delta virus delta antigen
#     Mean in-family: 2.3154296875
#     Mean out-of-family: 0.05718636512756348
#     Log2FC: 5.339465141296387
# Latent 3717 is sig assoc w family 4363
#     Family Photosystem I PsaJ, reaction centre subunit IX
#     Mean in-family: 1.51806640625
#     Mean out-of-family: 0.05734586715698242
#     Log2FC: 4.726401329040527
# Latent 3717 is sig assoc w family 5285
#     Family GLABROUS1 enhancer-binding protein-like
#     Mean in-family: 1.3250324726104736
#     Mean out-of-family: 0.05738447979092598
#     Log2FC: 4.529223442077637
# Latent 3717 is sig assoc w family 5300
#     Family Agouti
#     Mean in-family: 1.72216796875
#     Mean out-of-family: 0.05730504170060158
#     Log2FC: 4.909420013427734
# Latent 3717 is sig assoc w family 5309
#     Family Photosystem II PsbM
#     Mean in-family: 1.2054036855697632
#     Mean out-of-family: 0.05729357898235321
#     Log2FC: 4.394999027252197
# Latent 3717 is sig assoc w family 5853
#     Family Eukaryotic translation initiation factor 3 subunit J
#     Mean in-family: 1.501708984375
#     Mean out-of-family: 0.05734914168715477
#     Log2FC: 4.710689544677734
# Latent 3717 is sig assoc w family 6031
#     Family Regulator of ribonuclease activity B
#     Mean in-family: 1.2705078125
#     Mean out-of-family: 0.057395391166210175
#     Log2FC: 4.468326568603516
# Latent 3717 is sig assoc w family 6277
#     Family Secapin
#     Mean in-family: 0.951904296875
#     Mean out-of-family: 0.05745912343263626
#     Log2FC: 4.050208568572998
# Latent 3717 is sig assoc w family 6919
#     Family Protein of unknown function DUF4519
#     Mean in-family: 1.67236328125
#     Mean out-of-family: 0.057315003126859665
#     Log2FC: 4.8668317794799805
# Latent 3717 is sig assoc w family 6992
#     Family DNA-directed RNA polymerase subunit delta
#     Mean in-family: 2.6171875
#     Mean out-of-family: 0.0571260005235672
#     Log2FC: 5.517725944519043
# Latent 3717 is sig assoc w family 7042
#     Family Altered inheritance of mitochondria protein 3
#     Mean in-family: 1.67431640625
#     Mean out-of-family: 0.057314611971378326
#     Log2FC: 4.868525505065918
# Latent 3717 is sig assoc w family 7045
#     Family UPAR/Ly6 domain-containing protein Quiver-like
#     Mean in-family: 1.063232421875
#     Mean out-of-family: 0.057436853647232056
#     Log2FC: 4.210336685180664
# Latent 3717 is sig assoc w family 7615
#     Family Ribosomal protein L36, bacteria
#     Mean in-family: 1.327392578125
#     Mean out-of-family: 0.057129908353090286
#     Log2FC: 4.538205146789551
# Latent 3717 is sig assoc w family 8184
#     Family Collagen and Collagen-like Structural Proteins
#     Mean in-family: 2.068957567214966
#     Mean out-of-family: 0.05723566561937332
#     Log2FC: 5.175846099853516
# Latent 3717 is sig assoc w family 8199
#     Family Sleep homeostasis regulator
#     Mean in-family: 1.063232421875
#     Mean out-of-family: 0.057436853647232056
#     Log2FC: 4.210336685180664
# Latent 3717 is sig assoc w family 8570
#     Family Adhesion domain superfamily
#     Mean in-family: 1.2471354007720947
#     Mean out-of-family: 0.05728105828166008
#     Log2FC: 4.444416046142578
# Latent 3717 is sig assoc w family 8581
#     Family Electron transport accessory-like domain superfamily
#     Mean in-family: 1.32421875
#     Mean out-of-family: 0.05738464742898941
#     Log2FC: 4.528332710266113
# Latent 3717 is sig assoc w family 8684
#     Family Fibrogen-binding domain 1
#     Mean in-family: 1.2471354007720947
#     Mean out-of-family: 0.05728105828166008
#     Log2FC: 4.444416046142578
# Latent 3717 is sig assoc w family 8849
#     Family Metallothionein domain superfamily
#     Mean in-family: 1.982421875
#     Mean out-of-family: 0.05706040561199188
#     Log2FC: 5.1186299324035645
# Latent 3717 is sig assoc w family 8898
#     Family Eukaryotic translation initiation factor 3-like domain superfamily
#     Mean in-family: 1.501708984375
#     Mean out-of-family: 0.05734914168715477
#     Log2FC: 4.710689544677734
# Latent 3717 is sig assoc w family 8947
#     Family Metallothionein domain superfamily, vertebrate
#     Mean in-family: 1.982421875
#     Mean out-of-family: 0.05706040561199188
#     Log2FC: 5.1186299324035645
# Latent 3717 is sig assoc w family 9000
#     Family Delta antigen, N-terminal
#     Mean in-family: 2.3154296875
#     Mean out-of-family: 0.05718636512756348
#     Log2FC: 5.339465141296387
# Latent 3717 is sig assoc w family 9135
#     Family Large ribosomal subunit protein bL36 superfamily
#     Mean in-family: 1.4433051347732544
#     Mean out-of-family: 0.055139314383268356
#     Log2FC: 4.710151195526123
# Latent 3717 is sig assoc w family 9174
#     Family Photosystem I PsaJ, reaction centre subunit IX superfamily
#     Mean in-family: 1.51806640625
#     Mean out-of-family: 0.05734586715698242
#     Log2FC: 4.726401329040527
# Latent 3717 is sig assoc w family 9462
#     Family RraB-like superfamily
#     Mean in-family: 1.2705078125
#     Mean out-of-family: 0.057395391166210175
#     Log2FC: 4.468326568603516
# Latent 3717 is sig assoc w family 9522
#     Family Agouti domain superfamily
#     Mean in-family: 1.5159505605697632
#     Mean out-of-family: 0.05720038712024689
#     Log2FC: 4.728054046630859
# Latent 3717 is sig assoc w family 9706
#     Family Photosystem II PsbM superfamily
#     Mean in-family: 1.2054036855697632
#     Mean out-of-family: 0.05729357898235321
#     Log2FC: 4.394999027252197
# Latent 3717 is sig assoc w family 9731
#     Family DNA-directed RNA polymerase subunit delta, N-terminal domain superfamily
#     Mean in-family: 2.6171875
#     Mean out-of-family: 0.0571260005235672
#     Log2FC: 5.517725944519043
# Latent 3717 is sig assoc w family 10059
#     Family Fibronectin binding repeat
#     Mean in-family: 1.2471354007720947
#     Mean out-of-family: 0.05728105828166008
#     Log2FC: 4.444416046142578
# Latent 3717 is sig assoc w family 10065
#     Family Collagen triple helix repeat
#     Mean in-family: 1.0252374410629272
#     Mean out-of-family: 0.057057105004787445
#     Log2FC: 4.167407512664795
# Latent 4584 is sig assoc w family 9
#     Family Lipase, GDXG, putative histidine active site
#     Mean in-family: 5.215494632720947
#     Mean out-of-family: 0.037729643285274506
#     Log2FC: 7.1109619140625
# Latent 4584 is sig assoc w family 10
#     Family Peptidase S9, serine active site
#     Mean in-family: 3.7435824871063232
#     Mean out-of-family: 0.03787684813141823
#     Log2FC: 6.626959323883057
# Latent 4584 is sig assoc w family 57
#     Family Carboxylesterase type B, active site
#     Mean in-family: 1.8721842765808105
#     Mean out-of-family: 0.03769707679748535
#     Log2FC: 5.634125709533691
# Latent 4584 is sig assoc w family 64
#     Family Glyceraldehyde 3-phosphate dehydrogenase, active site
#     Mean in-family: 0.6408420205116272
#     Mean out-of-family: 0.037885647267103195
#     Log2FC: 4.080245494842529
# Latent 4584 is sig assoc w family 94
#     Family Ubiquitin-activating enzyme E1, Cys active site
#     Mean in-family: 1.809814453125
#     Mean out-of-family: 0.03807024657726288
#     Log2FC: 5.571033954620361
# Latent 4584 is sig assoc w family 100
#     Family Lipase, GDXG, putative serine active site
#     Mean in-family: 5.215494632720947
#     Mean out-of-family: 0.037729643285274506
#     Log2FC: 7.1109619140625
# Latent 4584 is sig assoc w family 102
#     Family Leu/Phe/Val dehydrogenases active site
#     Mean in-family: 0.70556640625
#     Mean out-of-family: 0.03818067908287048
#     Log2FC: 4.20786714553833
# Latent 4584 is sig assoc w family 157
#     Family Oxidoreductase, molybdopterin binding site
#     Mean in-family: 1.155029296875
#     Mean out-of-family: 0.03813573345541954
#     Log2FC: 4.920642375946045
# Latent 4584 is sig assoc w family 158
#     Family Porphobilinogen deaminase, dipyrromethane cofactor binding site
#     Mean in-family: 0.7127278447151184
#     Mean out-of-family: 0.0377749539911747
#     Log2FC: 4.237849235534668
# Latent 4584 is sig assoc w family 183
#     Family AB hydrolase 4, conserved site
#     Mean in-family: 4.200439453125
#     Mean out-of-family: 0.03741481155157089
#     Log2FC: 6.810786724090576
# Latent 4584 is sig assoc w family 239
#     Family Recombinase, conserved site
#     Mean in-family: 2.3385417461395264
#     Mean out-of-family: 0.037557121366262436
#     Log2FC: 5.960378646850586
# Latent 4584 is sig assoc w family 378
#     Family Large ribosomal subunit protein eL13, conserved site
#     Mean in-family: 1.34326171875
#     Mean out-of-family: 0.038116902112960815
#     Log2FC: 5.139165878295898
# Latent 4584 is sig assoc w family 463
#     Family Carboxylesterase type B, conserved site
#     Mean in-family: 1.0888671875
#     Mean out-of-family: 0.03814234584569931
#     Log2FC: 4.835290431976318
# Latent 4584 is sig assoc w family 624
#     Family Cutinase, aspartate and histidine active sites
#     Mean in-family: 1.071044921875
#     Mean out-of-family: 0.03804081678390503
#     Log2FC: 4.815327167510986
# Latent 4584 is sig assoc w family 625
#     Family Cutinase, serine active site
#     Mean in-family: 1.071044921875
#     Mean out-of-family: 0.03804081678390503
#     Log2FC: 4.815327167510986
# Latent 4584 is sig assoc w family 654
#     Family PurE domain
#     Mean in-family: 0.63720703125
#     Mean out-of-family: 0.03818751499056816
#     Log2FC: 4.06058931350708
# Latent 4584 is sig assoc w family 659
#     Family Alpha/beta hydrolase fold-1
#     Mean in-family: 3.5742106437683105
#     Mean out-of-family: 0.03258081153035164
#     Log2FC: 6.777458190917969
# Latent 4584 is sig assoc w family 745
#     Family THIF-type NAD/FAD binding fold
#     Mean in-family: 0.71038818359375
#     Mean out-of-family: 0.03797845542430878
#     Log2FC: 4.225354194641113
# Latent 4584 is sig assoc w family 778
#     Family MCP methyltransferase, CheR-type
#     Mean in-family: 0.88232421875
#     Mean out-of-family: 0.03816300258040428
#     Log2FC: 4.531062126159668
# Latent 4584 is sig assoc w family 844
#     Family Copper fist DNA-binding domain
#     Mean in-family: 1.0234375
#     Mean out-of-family: 0.03814889118075371
#     Log2FC: 4.745637893676758
# Latent 4584 is sig assoc w family 904
#     Family Peptidase S9, prolyl oligopeptidase, catalytic domain
#     Mean in-family: 2.7841694355010986
#     Mean out-of-family: 0.0371486134827137
#     Log2FC: 6.227794647216797
# Latent 4584 is sig assoc w family 956
#     Family Methyl-CpG DNA binding
#     Mean in-family: 0.7679443359375
#     Mean out-of-family: 0.03817444294691086
#     Log2FC: 4.330322742462158
# Latent 4584 is sig assoc w family 1007
#     Family Carboxylesterase, type B
#     Mean in-family: 0.953906238079071
#     Mean out-of-family: 0.038064248859882355
#     Log2FC: 4.6473388671875
# Latent 4584 is sig assoc w family 1050
#     Family Dipeptidylpeptidase IV, N-terminal domain
#     Mean in-family: 2.464365005493164
#     Mean out-of-family: 0.037519365549087524
#     Log2FC: 6.037436485290527
# Latent 4584 is sig assoc w family 1124
#     Family Dienelactone hydrolase
#     Mean in-family: 4.73291015625
#     Mean out-of-family: 0.03730830177664757
#     Log2FC: 6.987087249755859
# Latent 4584 is sig assoc w family 1157
#     Family Phospholipase/carboxylesterase/thioesterase
#     Mean in-family: 4.51025390625
#     Mean out-of-family: 0.037800174206495285
#     Log2FC: 6.898672103881836
# Latent 4584 is sig assoc w family 1168
#     Family Proteasome activator PA28, N-terminal domain
#     Mean in-family: 0.6181640625
#     Mean out-of-family: 0.038189422339200974
#     Log2FC: 4.016744613647461
# Latent 4584 is sig assoc w family 1169
#     Family Proteasome activator PA28, C-terminal domain
#     Mean in-family: 0.6181640625
#     Mean out-of-family: 0.038189422339200974
#     Log2FC: 4.016744613647461
# Latent 4584 is sig assoc w family 1363
#     Family NADPH-dependent FMN reductase-like domain
#     Mean in-family: 0.724609375
#     Mean out-of-family: 0.037972766906023026
#     Log2FC: 4.254166603088379
# Latent 4584 is sig assoc w family 1365
#     Family Moybdenum cofactor oxidoreductase, dimerisation
#     Mean in-family: 1.155029296875
#     Mean out-of-family: 0.03813573345541954
#     Log2FC: 4.920642375946045
# Latent 4584 is sig assoc w family 1419
#     Family Serine hydrolase domain
#     Mean in-family: 4.0849609375
#     Mean out-of-family: 0.03784270957112312
#     Log2FC: 6.7541632652282715
# Latent 4584 is sig assoc w family 1467
#     Family Glutamate/phenylalanine/leucine/valine/L-tryptophan dehydrogenase, C-terminal
#     Mean in-family: 0.70556640625
#     Mean out-of-family: 0.03818067908287048
#     Log2FC: 4.20786714553833
# Latent 4584 is sig assoc w family 1468
#     Family Glutamate/phenylalanine/leucine/valine/L-tryptophan dehydrogenase, dimerisation domain
#     Mean in-family: 0.70556640625
#     Mean out-of-family: 0.03818067908287048
#     Log2FC: 4.20786714553833
# Latent 4584 is sig assoc w family 1473
#     Family Resolvase, N-terminal catalytic domain
#     Mean in-family: 2.091552734375
#     Mean out-of-family: 0.03742576763033867
#     Log2FC: 5.804398536682129
# Latent 4584 is sig assoc w family 1474
#     Family Resolvase, HTH domain
#     Mean in-family: 2.3385417461395264
#     Mean out-of-family: 0.037557121366262436
#     Log2FC: 5.960378646850586
# Latent 4584 is sig assoc w family 1513
#     Family Methyltransferase FkbM
#     Mean in-family: 1.1416015625
#     Mean out-of-family: 0.03813707083463669
#     Log2FC: 4.903721332550049
# Latent 4584 is sig assoc w family 1655
#     Family Methyltransferase small domain
#     Mean in-family: 0.6884223818778992
#     Mean out-of-family: 0.03785707801580429
#     Log2FC: 4.184659004211426
# Latent 4584 is sig assoc w family 1684
#     Family Flavodoxin/nitric oxide synthase
#     Mean in-family: 0.7867431640625
#     Mean out-of-family: 0.03779805079102516
#     Log2FC: 4.379508972167969
# Latent 4584 is sig assoc w family 1791
#     Family Poly-beta-hydroxybutyrate polymerase, N-terminal domain
#     Mean in-family: 2.2281901836395264
#     Mean out-of-family: 0.038028404116630554
#     Log2FC: 5.872651100158691
# Latent 4584 is sig assoc w family 1945
#     Family Alpha/beta hydrolase fold-3
#     Mean in-family: 4.9095048904418945
#     Mean out-of-family: 0.037272971123456955
#     Log2FC: 7.041304111480713
# Latent 4584 is sig assoc w family 1951
#     Family Histidine biosynthesis HisG, C-terminal
#     Mean in-family: 0.9277614951133728
#     Mean out-of-family: 0.037713389843702316
#     Log2FC: 4.620604991912842
# Latent 4584 is sig assoc w family 1982
#     Family Methyltransferase type 12
#     Mean in-family: 0.6663411259651184
#     Mean out-of-family: 0.03818460553884506
#     Log2FC: 4.125197887420654
# Latent 4584 is sig assoc w family 2029
#     Family Methyltransferase small, N-terminal
#     Mean in-family: 0.6884223818778992
#     Mean out-of-family: 0.03785707801580429
#     Log2FC: 4.184659004211426
# Latent 4584 is sig assoc w family 2057
#     Family Lipase
#     Mean in-family: 0.6852925419807434
#     Mean out-of-family: 0.03798850253224373
#     Log2FC: 4.1730852127075195
# Latent 4584 is sig assoc w family 2059
#     Family ATP phosphoribosyltransferase, catalytic domain
#     Mean in-family: 0.6958211064338684
#     Mean out-of-family: 0.037720937281847
#     Log2FC: 4.2052788734436035
# Latent 4584 is sig assoc w family 2131
#     Family E2 binding
#     Mean in-family: 1.809814453125
#     Mean out-of-family: 0.03807024657726288
#     Log2FC: 5.571033954620361
# Latent 4584 is sig assoc w family 2212
#     Family ProQ/FinO domain
#     Mean in-family: 0.61376953125
#     Mean out-of-family: 0.03818986192345619
#     Log2FC: 4.006435394287109
# Latent 4584 is sig assoc w family 2216
#     Family Dockerin domain
#     Mean in-family: 2.0751953125
#     Mean out-of-family: 0.038043707609176636
#     Log2FC: 5.769445419311523
# Latent 4584 is sig assoc w family 2389
#     Family Glyceraldehyde 3-phosphate dehydrogenase, NAD(P) binding domain
#     Mean in-family: 0.6408420205116272
#     Mean out-of-family: 0.037885647267103195
#     Log2FC: 4.080245494842529
# Latent 4584 is sig assoc w family 2390
#     Family Glyceraldehyde 3-phosphate dehydrogenase, catalytic domain
#     Mean in-family: 0.6408420205116272
#     Mean out-of-family: 0.037885647267103195
#     Log2FC: 4.080245494842529
# Latent 4584 is sig assoc w family 2448
#     Family Porphobilinogen deaminase, N-terminal
#     Mean in-family: 0.7127278447151184
#     Mean out-of-family: 0.0377749539911747
#     Log2FC: 4.237849235534668
# Latent 4584 is sig assoc w family 2449
#     Family Porphobilinogen deaminase, C-terminal
#     Mean in-family: 0.7127278447151184
#     Mean out-of-family: 0.0377749539911747
#     Log2FC: 4.237849235534668
# Latent 4584 is sig assoc w family 2466
#     Family Chemotaxis receptor methyltransferase CheR, N-terminal
#     Mean in-family: 0.88232421875
#     Mean out-of-family: 0.03816300258040428
#     Log2FC: 4.531062126159668
# Latent 4584 is sig assoc w family 2467
#     Family MCP methyltransferase, CheR-type, SAM-binding domain, C-terminal
#     Mean in-family: 0.88232421875
#     Mean out-of-family: 0.03816300258040428
#     Log2FC: 4.531062126159668
# Latent 4584 is sig assoc w family 2487
#     Family Serine aminopeptidase, S33
#     Mean in-family: 5.759521484375
#     Mean out-of-family: 0.03595799207687378
#     Log2FC: 7.323492527008057
# Latent 4584 is sig assoc w family 2501
#     Family Peptidase S9A, N-terminal domain
#     Mean in-family: 3.7435824871063232
#     Mean out-of-family: 0.03787684813141823
#     Log2FC: 6.626959323883057
# Latent 4584 is sig assoc w family 2672
#     Family Glycosyltransferase subfamily 4-like, N-terminal domain
#     Mean in-family: 0.6494954824447632
#     Mean out-of-family: 0.03812514990568161
#     Log2FC: 4.0905046463012695
# Latent 4584 is sig assoc w family 2720
#     Family NEDD8-activating enzyme E1 catalytic subunit, N-terminal domain
#     Mean in-family: 1.809814453125
#     Mean out-of-family: 0.03807024657726288
#     Log2FC: 5.571033954620361
# Latent 4584 is sig assoc w family 2888
#     Family Lipase, N-terminal
#     Mean in-family: 0.9137234091758728
#     Mean out-of-family: 0.037984699010849
#     Log2FC: 4.5882673263549805
# Latent 4584 is sig assoc w family 2891
#     Family NAD(P) binding domain of glutamate dehydrogenase
#     Mean in-family: 0.70556640625
#     Mean out-of-family: 0.03818067908287048
#     Log2FC: 4.20786714553833
# Latent 4584 is sig assoc w family 2973
#     Family RNA chaperone ProQ, C-terminal
#     Mean in-family: 0.61376953125
#     Mean out-of-family: 0.03818986192345619
#     Log2FC: 4.006435394287109
# Latent 4584 is sig assoc w family 3551
#     Family BD-FAE-like domain
#     Mean in-family: 3.708740234375
#     Mean out-of-family: 0.03788033127784729
#     Log2FC: 6.613336563110352
# Latent 4584 is sig assoc w family 3614
#     Family 4-O-methyl-glucuronoyl methylesterase-like domain
#     Mean in-family: 2.0751953125
#     Mean out-of-family: 0.038043707609176636
#     Log2FC: 5.769445419311523
# Latent 4584 is sig assoc w family 3861
#     Family Epoxide hydrolase-like
#     Mean in-family: 2.1500651836395264
#     Mean out-of-family: 0.03803621977567673
#     Log2FC: 5.820862770080566
# Latent 4584 is sig assoc w family 3874
#     Family Cutinase/acetylxylan esterase
#     Mean in-family: 1.071044921875
#     Mean out-of-family: 0.03804081678390503
#     Log2FC: 4.815327167510986
# Latent 4584 is sig assoc w family 3891
#     Family Triacylglycerol lipase family
#     Mean in-family: 0.6852925419807434
#     Mean out-of-family: 0.03798850253224373
#     Log2FC: 4.1730852127075195
# Latent 4584 is sig assoc w family 3911
#     Family Esterase-like
#     Mean in-family: 4.185546875
#     Mean out-of-family: 0.03783264756202698
#     Log2FC: 6.789640426635742
# Latent 4584 is sig assoc w family 3927
#     Family Porphobilinogen deaminase
#     Mean in-family: 0.7127278447151184
#     Mean out-of-family: 0.0377749539911747
#     Log2FC: 4.237849235534668
# Latent 4584 is sig assoc w family 3963
#     Family Cholinesterase
#     Mean in-family: 1.0888671875
#     Mean out-of-family: 0.03814234584569931
#     Log2FC: 4.835290431976318
# Latent 4584 is sig assoc w family 4047
#     Family ATP phosphoribosyltransferase HisG
#     Mean in-family: 0.6958211064338684
#     Mean out-of-family: 0.037720937281847
#     Log2FC: 4.2052788734436035
# Latent 4584 is sig assoc w family 4054
#     Family Large ribosomal subunit protein eL13
#     Mean in-family: 1.34326171875
#     Mean out-of-family: 0.038116902112960815
#     Log2FC: 5.139165878295898
# Latent 4584 is sig assoc w family 4162
#     Family Small GTPase
#     Mean in-family: 1.01434326171875
#     Mean out-of-family: 0.036683160811662674
#     Log2FC: 4.7892842292785645
# Latent 4584 is sig assoc w family 4261
#     Family Lumazine/riboflavin synthase
#     Mean in-family: 0.9625244140625
#     Mean out-of-family: 0.03750740736722946
#     Log2FC: 4.681575775146484
# Latent 4584 is sig assoc w family 4303
#     Family Vespid venom allergen phospholipase A1
#     Mean in-family: 0.7471787929534912
#     Mean out-of-family: 0.038034677505493164
#     Log2FC: 4.2960662841796875
# Latent 4584 is sig assoc w family 4336
#     Family Peptidase S9A, prolyl oligopeptidase
#     Mean in-family: 3.7435824871063232
#     Mean out-of-family: 0.03787684813141823
#     Log2FC: 6.626959323883057
# Latent 4584 is sig assoc w family 4337
#     Family Palmitoyl protein thioesterase
#     Mean in-family: 3.3147785663604736
#     Mean out-of-family: 0.03791972994804382
#     Log2FC: 6.449820041656494
# Latent 4584 is sig assoc w family 4364
#     Family UDPGP family
#     Mean in-family: 0.6744791269302368
#     Mean out-of-family: 0.038120146840810776
#     Log2FC: 4.145148277282715
# Latent 4584 is sig assoc w family 4515
#     Family Sugar-phosphate isomerase, RpiB/LacA/LacB family
#     Mean in-family: 1.00830078125
#     Mean out-of-family: 0.0378592424094677
#     Log2FC: 4.73513650894165
# Latent 4584 is sig assoc w family 4526
#     Family Small GTPase Rho
#     Mean in-family: 1.1951904296875
#     Mean out-of-family: 0.037784457206726074
#     Log2FC: 4.983304023742676
# Latent 4584 is sig assoc w family 4633
#     Family NDRG
#     Mean in-family: 3.4635417461395264
#     Mean out-of-family: 0.037904854863882065
#     Log2FC: 6.513721466064453
# Latent 4584 is sig assoc w family 4771
#     Family L-threonine 3-dehydrogenase
#     Mean in-family: 0.6552734375
#     Mean out-of-family: 0.03818570822477341
#     Log2FC: 4.100992202758789
# Latent 4584 is sig assoc w family 4822
#     Family Galactose-6-phosphate isomerase subunit LacB
#     Mean in-family: 1.3444010019302368
#     Mean out-of-family: 0.03785545378923416
#     Log2FC: 5.150318622589111
# Latent 4584 is sig assoc w family 4842
#     Family Lipoprotein NlpA family
#     Mean in-family: 0.77197265625
#     Mean out-of-family: 0.038174040615558624
#     Log2FC: 4.337885856628418
# Latent 4584 is sig assoc w family 5089
#     Family Glutamate/phenylalanine/leucine/valine/L-tryptophan dehydrogenase
#     Mean in-family: 0.70556640625
#     Mean out-of-family: 0.03818067908287048
#     Log2FC: 4.20786714553833
# Latent 4584 is sig assoc w family 5159
#     Family Phosphoglycolate phosphatase
#     Mean in-family: 0.875244140625
#     Mean out-of-family: 0.038079988211393356
#     Log2FC: 4.522580623626709
# Latent 4584 is sig assoc w family 5164
#     Family D-erythrose-4-phosphate dehydrogenase
#     Mean in-family: 0.9296875
#     Mean out-of-family: 0.03815826401114464
#     Log2FC: 4.606678485870361
# Latent 4584 is sig assoc w family 5165
#     Family Glyceraldehyde-3-phosphate dehydrogenase, type I
#     Mean in-family: 0.9612630009651184
#     Mean out-of-family: 0.037878066301345825
#     Log2FC: 4.665496826171875
# Latent 4584 is sig assoc w family 5186
#     Family Small GTPase superfamily, SAR1-type
#     Mean in-family: 1.5107421875
#     Mean out-of-family: 0.03810015320777893
#     Log2FC: 5.309317111968994
# Latent 4584 is sig assoc w family 5187
#     Family Small GTPase superfamily, ARF/SAR type
#     Mean in-family: 1.54248046875
#     Mean out-of-family: 0.03764548897743225
#     Log2FC: 5.356631278991699
# Latent 4584 is sig assoc w family 5188
#     Family Uncharacterised protein family UPF0229
#     Mean in-family: 0.932373046875
#     Mean out-of-family: 0.03797909989953041
#     Log2FC: 4.617629528045654
# Latent 4584 is sig assoc w family 5358
#     Family Homoserine/serine acetyltransferase MetX-like
#     Mean in-family: 3.5375163555145264
#     Mean out-of-family: 0.036847151815891266
#     Log2FC: 6.585040092468262
# Latent 4584 is sig assoc w family 5372
#     Family Eukaryotic molybdopterin oxidoreductase
#     Mean in-family: 1.155029296875
#     Mean out-of-family: 0.03813573345541954
#     Log2FC: 4.920642375946045
# Latent 4584 is sig assoc w family 5407
#     Family Peptidase S28
#     Mean in-family: 1.321874976158142
#     Mean out-of-family: 0.03811904788017273
#     Log2FC: 5.11592960357666
# Latent 4584 is sig assoc w family 5419
#     Family TPMT family
#     Mean in-family: 0.9939778447151184
#     Mean out-of-family: 0.037960611283779144
#     Log2FC: 4.710638523101807
# Latent 4584 is sig assoc w family 5423
#     Family Uncharacterised protein family UPF0227/Esterase YqiA
#     Mean in-family: 6.7109375
#     Mean out-of-family: 0.03691261634230614
#     Log2FC: 7.506256580352783
# Latent 4584 is sig assoc w family 5429
#     Family Proteasome activator PA28
#     Mean in-family: 0.6181640625
#     Mean out-of-family: 0.038189422339200974
#     Log2FC: 4.016744613647461
# Latent 4584 is sig assoc w family 5516
#     Family Flavodoxin, long chain
#     Mean in-family: 1.4072265625
#     Mean out-of-family: 0.038110505789518356
#     Log2FC: 5.206521987915039
# Latent 4584 is sig assoc w family 5517
#     Family Flavoprotein WrbA-like
#     Mean in-family: 1.44921875
#     Mean out-of-family: 0.03796516731381416
#     Log2FC: 5.254455089569092
# Latent 4584 is sig assoc w family 5525
#     Family Esterase, PHB depolymerase
#     Mean in-family: 2.8216145038604736
#     Mean out-of-family: 0.03796905279159546
#     Log2FC: 6.215553283691406
# Latent 4584 is sig assoc w family 5575
#     Family Esterase FrsA-like
#     Mean in-family: 2.8937175273895264
#     Mean out-of-family: 0.03739052265882492
#     Log2FC: 6.274107456207275
# Latent 4584 is sig assoc w family 5605
#     Family Poly(R)-hydroxyalkanoic acid synthase, class I
#     Mean in-family: 2.2281901836395264
#     Mean out-of-family: 0.038028404116630554
#     Log2FC: 5.872651100158691
# Latent 4584 is sig assoc w family 5616
#     Family Cutinase, monofunctional
#     Mean in-family: 1.071044921875
#     Mean out-of-family: 0.03804081678390503
#     Log2FC: 4.815327167510986
# Latent 4584 is sig assoc w family 5720
#     Family AB hydrolase 4 family
#     Mean in-family: 4.200439453125
#     Mean out-of-family: 0.03741481155157089
#     Log2FC: 6.810786724090576
# Latent 4584 is sig assoc w family 5750
#     Family Esterase/lipase
#     Mean in-family: 5.9208984375
#     Mean out-of-family: 0.03765909746289253
#     Log2FC: 7.296673774719238
# Latent 4584 is sig assoc w family 5874
#     Family S-formylglutathione hydrolase
#     Mean in-family: 4.185546875
#     Mean out-of-family: 0.03783264756202698
#     Log2FC: 6.789640426635742
# Latent 4584 is sig assoc w family 5888
#     Family Glutamate dehydrogenase
#     Mean in-family: 0.70556640625
#     Mean out-of-family: 0.03818067908287048
#     Log2FC: 4.20786714553833
# Latent 4584 is sig assoc w family 6030
#     Family Platelet-activating factor acetylhydrolase-like, eukaryote
#     Mean in-family: 2.9996745586395264
#     Mean out-of-family: 0.03795124590396881
#     Log2FC: 6.3045148849487305
# Latent 4584 is sig assoc w family 6086
#     Family Methyl-CpG binding protein MeCP2
#     Mean in-family: 0.7679443359375
#     Mean out-of-family: 0.03817444294691086
#     Log2FC: 4.330322742462158
# Latent 4584 is sig assoc w family 6123
#     Family 2-hydroxy-6-oxo-6-phenylhexa-2,4-dienoate hydrolase, BphD
#     Mean in-family: 3.8310546875
#     Mean out-of-family: 0.03786810114979744
#     Log2FC: 6.660614967346191
# Latent 4584 is sig assoc w family 6305
#     Family ATP phosphoribosyltransferase HisG, long form
#     Mean in-family: 0.9277614951133728
#     Mean out-of-family: 0.037713389843702316
#     Log2FC: 4.620604991912842
# Latent 4584 is sig assoc w family 6316
#     Family Glyceraldehyde/Erythrose phosphate dehydrogenase family
#     Mean in-family: 0.6408420205116272
#     Mean out-of-family: 0.037885647267103195
#     Log2FC: 4.080245494842529
# Latent 4584 is sig assoc w family 6317
#     Family Small GTPase, Ras-type
#     Mean in-family: 1.24267578125
#     Mean out-of-family: 0.0380064882338047
#     Log2FC: 5.031060218811035
# Latent 4584 is sig assoc w family 6393
#     Family Thiopurine S-methyltransferase, Se/Te detoxification
#     Mean in-family: 0.9939778447151184
#     Mean out-of-family: 0.037960611283779144
#     Log2FC: 4.710638523101807
# Latent 4584 is sig assoc w family 6500
#     Family Uncharacterised protein family UPF0227
#     Mean in-family: 6.7109375
#     Mean out-of-family: 0.03691261634230614
#     Log2FC: 7.506256580352783
# Latent 4584 is sig assoc w family 6590
#     Family Haloalkane dehalogenase, subfamily 1
#     Mean in-family: 2.1500651836395264
#     Mean out-of-family: 0.03803621977567673
#     Log2FC: 5.820862770080566
# Latent 4584 is sig assoc w family 6600
#     Family Acetyl esterase
#     Mean in-family: 5.215494632720947
#     Mean out-of-family: 0.037729643285274506
#     Log2FC: 7.1109619140625
# Latent 4584 is sig assoc w family 6610
#     Family RNA chaperone ProQ
#     Mean in-family: 0.61376953125
#     Mean out-of-family: 0.03818986192345619
#     Log2FC: 4.006435394287109
# Latent 4584 is sig assoc w family 6616
#     Family rRNA small subunit methyltransferase C
#     Mean in-family: 0.6884223818778992
#     Mean out-of-family: 0.03785707801580429
#     Log2FC: 4.184659004211426
# Latent 4584 is sig assoc w family 6646
#     Family NAD-dependent malic enzyme, proteobacteria
#     Mean in-family: 0.8023437261581421
#     Mean out-of-family: 0.03817100450396538
#     Log2FC: 4.39367151260376
# Latent 4584 is sig assoc w family 6736
#     Family Small GTPase superfamily, ARF type
#     Mean in-family: 1.5380859375
#     Mean out-of-family: 0.0379473902285099
#     Log2FC: 5.340991497039795
# Latent 4584 is sig assoc w family 6793
#     Family Thiopurine S-methyltransferase
#     Mean in-family: 0.9939778447151184
#     Mean out-of-family: 0.037960611283779144
#     Log2FC: 4.710638523101807
# Latent 4584 is sig assoc w family 6799
#     Family Chemotaxis protein methyltransferase CheR
#     Mean in-family: 0.88232421875
#     Mean out-of-family: 0.03816300258040428
#     Log2FC: 4.531062126159668
# Latent 4584 is sig assoc w family 7150
#     Family Deoxyuridine 5'-triphosphate nucleotidohydrolase
#     Mean in-family: 0.6725260615348816
#     Mean out-of-family: 0.03818398714065552
#     Log2FC: 4.138550758361816
# Latent 4584 is sig assoc w family 7157
#     Family Lumazine synthase
#     Mean in-family: 0.9625244140625
#     Mean out-of-family: 0.03750740736722946
#     Log2FC: 4.681575775146484
# Latent 4584 is sig assoc w family 7180
#     Family NAD(P)H dehydrogenase (quinone), prokaryotic
#     Mean in-family: 1.44921875
#     Mean out-of-family: 0.03796516731381416
#     Log2FC: 5.254455089569092
# Latent 4584 is sig assoc w family 7198
#     Family Cdc42
#     Mean in-family: 1.3828125
#     Mean out-of-family: 0.03811294957995415
#     Log2FC: 5.181180477142334
# Latent 4584 is sig assoc w family 7204
#     Family Ras-related protein Rap1
#     Mean in-family: 1.1611328125
#     Mean out-of-family: 0.038135118782520294
#     Log2FC: 4.928268909454346
# Latent 4584 is sig assoc w family 7264
#     Family Pyridinium-3,5-biscarboxylic acid mononucleotide synthase
#     Mean in-family: 0.63720703125
#     Mean out-of-family: 0.03818751499056816
#     Log2FC: 4.06058931350708
# Latent 4584 is sig assoc w family 7281
#     Family UDP-sugar pyrophosphorylase
#     Mean in-family: 0.6744791269302368
#     Mean out-of-family: 0.038120146840810776
#     Log2FC: 4.145148277282715
# Latent 4584 is sig assoc w family 7354
#     Family Rab33A/B
#     Mean in-family: 1.05078125
#     Mean out-of-family: 0.03814615681767464
#     Log2FC: 4.783780574798584
# Latent 4584 is sig assoc w family 7398
#     Family Esterase FrsA
#     Mean in-family: 2.8937175273895264
#     Mean out-of-family: 0.03739052265882492
#     Log2FC: 6.274107456207275
# Latent 4584 is sig assoc w family 7448
#     Family ADP-ribosylation factor-like protein 2/3
#     Mean in-family: 1.5830078125
#     Mean out-of-family: 0.03809292986989021
#     Log2FC: 5.3770012855529785
# Latent 4584 is sig assoc w family 7526
#     Family Methyl-CpG binding protein MeCP2/MBD4
#     Mean in-family: 0.7679443359375
#     Mean out-of-family: 0.03817444294691086
#     Log2FC: 4.330322742462158
# Latent 4584 is sig assoc w family 7569
#     Family ADP-ribosylation factor 1-5
#     Mean in-family: 1.5888671875
#     Mean out-of-family: 0.038092344999313354
#     Log2FC: 5.382353782653809
# Latent 4584 is sig assoc w family 7570
#     Family ThiF/MoeB/HesA family
#     Mean in-family: 0.71038818359375
#     Mean out-of-family: 0.03797845542430878
#     Log2FC: 4.225354194641113
# Latent 4584 is sig assoc w family 7571
#     Family Methylesterase/Alpha-hydroxynitrile lyase
#     Mean in-family: 5.14501953125
#     Mean out-of-family: 0.037225861102342606
#     Log2FC: 7.110727310180664
# Latent 4584 is sig assoc w family 7585
#     Family rRNA (guanine-N(2)-)-methyltransferase RsmC/RlmG
#     Mean in-family: 0.6884223818778992
#     Mean out-of-family: 0.03785707801580429
#     Log2FC: 4.184659004211426
# Latent 4584 is sig assoc w family 7631
#     Family IS607 transposase
#     Mean in-family: 1.3505859375
#     Mean out-of-family: 0.03811617195606232
#     Log2FC: 5.147038459777832
# Latent 4584 is sig assoc w family 7783
#     Family Glycosyltransferase group 1
#     Mean in-family: 0.6494954824447632
#     Mean out-of-family: 0.03812514990568161
#     Log2FC: 4.0905046463012695
# Latent 4584 is sig assoc w family 7812
#     Family Ras-related protein Rab
#     Mean in-family: 1.2236328125
#     Mean out-of-family: 0.038128867745399475
#     Log2FC: 5.004143238067627
# Latent 4584 is sig assoc w family 7839
#     Family FrsA esterase
#     Mean in-family: 2.9111328125
#     Mean out-of-family: 0.037097807973623276
#     Log2FC: 6.294102668762207
# Latent 4584 is sig assoc w family 7843
#     Family AB hydrolase superfamily
#     Mean in-family: 3.77587890625
#     Mean out-of-family: 0.03749974071979523
#     Log2FC: 6.653788089752197
# Latent 4584 is sig assoc w family 7853
#     Family Serine protease S9B/DPPIV
#     Mean in-family: 2.464365005493164
#     Mean out-of-family: 0.037519365549087524
#     Log2FC: 6.037436485290527
# Latent 4584 is sig assoc w family 7868
#     Family GDXG lipolytic enzyme
#     Mean in-family: 4.4621171951293945
#     Mean out-of-family: 0.037362467497587204
#     Log2FC: 6.899994850158691
# Latent 4584 is sig assoc w family 7872
#     Family Small GTPase superfamily, Rab
#     Mean in-family: 1.294189453125
#     Mean out-of-family: 0.03799618035554886
#     Log2FC: 5.09005069732666
# Latent 4584 is sig assoc w family 7875
#     Family Type-B Carboxylesterase/Lipase
#     Mean in-family: 0.953906238079071
#     Mean out-of-family: 0.038064248859882355
#     Log2FC: 4.6473388671875
# Latent 4584 is sig assoc w family 7961
#     Family Polyketide synthase
#     Mean in-family: 0.6663411259651184
#     Mean out-of-family: 0.03818460553884506
#     Log2FC: 4.125197887420654
# Latent 4584 is sig assoc w family 7973
#     Family Diverse Carboxylesterases and Gibberellin Receptors
#     Mean in-family: 4.603515625
#     Mean out-of-family: 0.037790849804878235
#     Log2FC: 6.928555011749268
# Latent 4584 is sig assoc w family 7998
#     Family Methyltransferase Superfamily
#     Mean in-family: 0.8876953125
#     Mean out-of-family: 0.0381624661386013
#     Log2FC: 4.5398383140563965
# Latent 4584 is sig assoc w family 8030
#     Family Acyl-protein thioesterase 1-2/Carboxylesterase-like
#     Mean in-family: 4.51025390625
#     Mean out-of-family: 0.037800174206495285
#     Log2FC: 6.898672103881836
# Latent 4584 is sig assoc w family 8042
#     Family Lovastatin nonaketide synthase thioesterase
#     Mean in-family: 4.0849609375
#     Mean out-of-family: 0.03784270957112312
#     Log2FC: 6.7541632652282715
# Latent 4584 is sig assoc w family 8056
#     Family Flavodoxin
#     Mean in-family: 1.4072265625
#     Mean out-of-family: 0.038110505789518356
#     Log2FC: 5.206521987915039
# Latent 4584 is sig assoc w family 8064
#     Family Site-specific recombinase resolvase
#     Mean in-family: 2.3385417461395264
#     Mean out-of-family: 0.037557121366262436
#     Log2FC: 5.960378646850586
# Latent 4584 is sig assoc w family 8174
#     Family Bacterial Chemotaxis Protein Methyltransferase
#     Mean in-family: 0.88232421875
#     Mean out-of-family: 0.03816300258040428
#     Log2FC: 4.531062126159668
# Latent 4584 is sig assoc w family 8189
#     Family Plant Biomass Hydrolyzing Esterase
#     Mean in-family: 2.8216145038604736
#     Mean out-of-family: 0.03796905279159546
#     Log2FC: 6.215553283691406
# Latent 4584 is sig assoc w family 8192
#     Family AB hydrolase superfamily, subfamily 4
#     Mean in-family: 4.200439453125
#     Mean out-of-family: 0.03741481155157089
#     Log2FC: 6.810786724090576
# Latent 4584 is sig assoc w family 8226
#     Family Monoacylglycerol and Diacylglycerol Lipase
#     Mean in-family: 5.5419921875
#     Mean out-of-family: 0.03714644908905029
#     Log2FC: 7.221036434173584
# Latent 4584 is sig assoc w family 8229
#     Family Dienelactone hydrolase-like enzyme
#     Mean in-family: 5.103515625
#     Mean out-of-family: 0.03774084150791168
#     Log2FC: 7.079221248626709
# Latent 4584 is sig assoc w family 8264
#     Family Prolyl oligopeptidase and macrocyclase
#     Mean in-family: 3.7435824871063232
#     Mean out-of-family: 0.03787684813141823
#     Log2FC: 6.626959323883057
# Latent 4584 is sig assoc w family 8300
#     Family Polyhydroxyalkanoate Synthase
#     Mean in-family: 2.2281901836395264
#     Mean out-of-family: 0.038028404116630554
#     Log2FC: 5.872651100158691
# Latent 4584 is sig assoc w family 8306
#     Family Haloalkane Dehalogenase Enzyme
#     Mean in-family: 2.1500651836395264
#     Mean out-of-family: 0.03803621977567673
#     Log2FC: 5.820862770080566
# Latent 4584 is sig assoc w family 8330
#     Family Site-specific recombinase/transposase-related
#     Mean in-family: 1.3505859375
#     Mean out-of-family: 0.03811617195606232
#     Log2FC: 5.147038459777832
# Latent 4584 is sig assoc w family 8337
#     Family Diverse Ester Hydrolysis Enzymes
#     Mean in-family: 2.0751953125
#     Mean out-of-family: 0.038043707609176636
#     Log2FC: 5.769445419311523
# Latent 4584 is sig assoc w family 8351
#     Family Serine protease/Carboxylesterase S33
#     Mean in-family: 0.944531261920929
#     Mean out-of-family: 0.03815678134560585
#     Log2FC: 4.629587173461914
# Latent 4584 is sig assoc w family 8353
#     Family Zinc-Containing ADH Family: Quinone Oxidoreductase/CCCR
#     Mean in-family: 0.6341145634651184
#     Mean out-of-family: 0.03818782791495323
#     Log2FC: 4.053558826446533
# Latent 4584 is sig assoc w family 8383
#     Family Copper Homeostasis Regulator
#     Mean in-family: 1.0234375
#     Mean out-of-family: 0.03814889118075371
#     Log2FC: 4.745637893676758
# Latent 4584 is sig assoc w family 8441
#     Family Small GTPase RasD
#     Mean in-family: 1.30712890625
#     Mean out-of-family: 0.03812051936984062
#     Log2FC: 5.099689960479736
# Latent 4584 is sig assoc w family 8496
#     Family FkbM Methyltransferase
#     Mean in-family: 1.1416015625
#     Mean out-of-family: 0.03813707083463669
#     Log2FC: 4.903721332550049
# Latent 4584 is sig assoc w family 8686
#     Family Nitrogen regulatory PII-like, alpha/beta
#     Mean in-family: 0.6185076236724854
#     Mean out-of-family: 0.03772471472620964
#     Log2FC: 4.035209655761719
# Latent 4584 is sig assoc w family 8912
#     Family Ubiquitin activating enzyme, alpha domain superfamily
#     Mean in-family: 1.809814453125
#     Mean out-of-family: 0.03807024657726288
#     Log2FC: 5.571033954620361
# Latent 4584 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 2.730806589126587
#     Mean out-of-family: 0.02117674984037876
#     Log2FC: 7.010702133178711
# Latent 4584 is sig assoc w family 9140
#     Family Ubiquitin-activating enzyme-like
#     Mean in-family: 0.71038818359375
#     Mean out-of-family: 0.03797845542430878
#     Log2FC: 4.225354194641113
# Latent 4584 is sig assoc w family 9222
#     Family Resolvase-like, N-terminal catalytic domain superfamily
#     Mean in-family: 2.091552734375
#     Mean out-of-family: 0.03742576763033867
#     Log2FC: 5.804398536682129
# Latent 4584 is sig assoc w family 9259
#     Family Proteasome activator superfamily
#     Mean in-family: 0.6181640625
#     Mean out-of-family: 0.038189422339200974
#     Log2FC: 4.016744613647461
# Latent 4584 is sig assoc w family 9326
#     Family Copper fist DNA-binding domain superfamily
#     Mean in-family: 1.0234375
#     Mean out-of-family: 0.03814889118075371
#     Log2FC: 4.745637893676758
# Latent 4584 is sig assoc w family 9353
#     Family Dockerin domain superfamily
#     Mean in-family: 2.0751953125
#     Mean out-of-family: 0.038043707609176636
#     Log2FC: 5.769445419311523
# Latent 4584 is sig assoc w family 9356
#     Family ProQ/FinO domain superfamily
#     Mean in-family: 0.61376953125
#     Mean out-of-family: 0.03818986192345619
#     Log2FC: 4.006435394287109
# Latent 4584 is sig assoc w family 9370
#     Family Lumazine/riboflavin synthase superfamily
#     Mean in-family: 0.9625244140625
#     Mean out-of-family: 0.03750740736722946
#     Log2FC: 4.681575775146484
# Latent 4584 is sig assoc w family 9404
#     Family Sugar-phosphate isomerase, RpiB/LacA/LacB superfamily
#     Mean in-family: 1.00830078125
#     Mean out-of-family: 0.0378592424094677
#     Log2FC: 4.73513650894165
# Latent 4584 is sig assoc w family 9507
#     Family Porphobilinogen deaminase, C-terminal domain superfamily
#     Mean in-family: 0.7127278447151184
#     Mean out-of-family: 0.0377749539911747
#     Log2FC: 4.237849235534668
# Latent 4584 is sig assoc w family 9508
#     Family Chemotaxis receptor methyltransferase CheR, N-terminal domain superfamily
#     Mean in-family: 0.88232421875
#     Mean out-of-family: 0.03816300258040428
#     Log2FC: 4.531062126159668
# Latent 4584 is sig assoc w family 9619
#     Family Proteasome activator PA28, N-terminal domain superfamily
#     Mean in-family: 0.6181640625
#     Mean out-of-family: 0.038189422339200974
#     Log2FC: 4.016744613647461
# Latent 4584 is sig assoc w family 9620
#     Family Proteasome activator PA28, C-terminal domain superfamily
#     Mean in-family: 0.6181640625
#     Mean out-of-family: 0.038189422339200974
#     Log2FC: 4.016744613647461
# Latent 4584 is sig assoc w family 10048
#     Family Dockerin type I repeat
#     Mean in-family: 2.0751953125
#     Mean out-of-family: 0.038043707609176636
#     Log2FC: 5.769445419311523
# Latent 7480 is sig assoc w family 220
#     Family Ubiquitin interacting motif
#     Mean in-family: 4.3538408279418945
#     Mean out-of-family: 0.23631730675697327
#     Log2FC: 4.203491687774658
# Latent 7480 is sig assoc w family 376
#     Family DnaJ domain, conserved site
#     Mean in-family: 4.992560863494873
#     Mean out-of-family: 0.22748112678527832
#     Log2FC: 4.455961227416992
# Latent 7480 is sig assoc w family 838
#     Family Beta/gamma crystallin
#     Mean in-family: 5.154296875
#     Mean out-of-family: 0.23599699139595032
#     Log2FC: 4.448935031890869
# Latent 7480 is sig assoc w family 892
#     Family Heat shock protein DnaJ, cysteine-rich domain
#     Mean in-family: 6.114568710327148
#     Mean out-of-family: 0.2273673713207245
#     Log2FC: 4.7491536140441895
# Latent 7480 is sig assoc w family 936
#     Family DnaJ domain
#     Mean in-family: 4.133791446685791
#     Mean out-of-family: 0.22624166309833527
#     Log2FC: 4.191528797149658
# Latent 7480 is sig assoc w family 1129
#     Family Chaperone DnaJ, C-terminal
#     Mean in-family: 5.792749404907227
#     Mean out-of-family: 0.2273901253938675
#     Log2FC: 4.671006679534912
# Latent 7480 is sig assoc w family 1441
#     Family YSIRK Gram-positive signal peptide
#     Mean in-family: 7.3768229484558105
#     Mean out-of-family: 0.23582202196121216
#     Log2FC: 4.96722936630249
# Latent 7480 is sig assoc w family 1825
#     Family Fibrinogen-binding domain 2
#     Mean in-family: 7.3768229484558105
#     Mean out-of-family: 0.23582202196121216
#     Log2FC: 4.96722936630249
# Latent 7480 is sig assoc w family 3139
#     Family SDR-like Ig domain
#     Mean in-family: 7.3768229484558105
#     Mean out-of-family: 0.23582202196121216
#     Log2FC: 4.96722936630249
# Latent 7480 is sig assoc w family 5773
#     Family Chaperone DnaJ
#     Mean in-family: 6.114568710327148
#     Mean out-of-family: 0.2273673713207245
#     Log2FC: 4.7491536140441895
# Latent 7480 is sig assoc w family 7831
#     Family Beta/Gamma-Crystallin
#     Mean in-family: 5.154296875
#     Mean out-of-family: 0.23599699139595032
#     Log2FC: 4.448935031890869
# Latent 7480 is sig assoc w family 8570
#     Family Adhesion domain superfamily
#     Mean in-family: 7.3768229484558105
#     Mean out-of-family: 0.23582202196121216
#     Log2FC: 4.96722936630249
# Latent 7480 is sig assoc w family 8573
#     Family HSP40/DnaJ peptide-binding
#     Mean in-family: 5.792749404907227
#     Mean out-of-family: 0.2273901253938675
#     Log2FC: 4.671006679534912
# Latent 7480 is sig assoc w family 8650
#     Family Gamma-crystallin-like
#     Mean in-family: 5.154296875
#     Mean out-of-family: 0.23599699139595032
#     Log2FC: 4.448935031890869
# Latent 7480 is sig assoc w family 8684
# ...
# Latent 13454 is sig assoc w family 2370
#     Family Heat shock protein Hsp90, N-terminal
#     Mean in-family: 18.453998565673828
#     Mean out-of-family: 0.30356937646865845
#     Log2FC: 5.9257636070251465
# Latent 13454 is sig assoc w family 4065
#     Family Heat shock protein Hsp90 family
#     Mean in-family: 18.453998565673828
#     Mean out-of-family: 0.30356937646865845
#     Log2FC: 5.9257636070251465
# Latent 13454 is sig assoc w family 4238
#     Family DNA mismatch repair protein MutL/Mlh/PMS
#     Mean in-family: 10.364322662353516
#     Mean out-of-family: 0.3130641281604767
#     Log2FC: 5.049023628234863
# Latent 13454 is sig assoc w family 6308
#     Family DNA mismatch repair protein, MutL
#     Mean in-family: 10.364322662353516
#     Mean out-of-family: 0.3130641281604767
#     Log2FC: 5.049023628234863
# Latent 13454 is sig assoc w family 7213
#     Family DNA mismatch repair protein MutL/Mlh/Pms-like
#     Mean in-family: 10.364322662353516
#     Mean out-of-family: 0.3130641281604767
#     Log2FC: 5.049023628234863
# Latent 13454 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 9.598411560058594
#     Mean out-of-family: 0.2892312705516815
#     Log2FC: 5.052500247955322
# Latent 13454 is sig assoc w family 9682
#     Family HSP90, C-terminal domain
#     Mean in-family: 18.519969940185547
#     Mean out-of-family: 0.305339515209198
#     Log2FC: 5.922523498535156
# Latent 13454 is sig assoc w family 9684
#     Family MutL, C-terminal domain superfamily
#     Mean in-family: 10.364322662353516
#     Mean out-of-family: 0.3130641281604767
#     Log2FC: 5.049023628234863
# Latent 13454 is sig assoc w family 9897
#     Family MutL, C-terminal domain, dimerisation subdomain
#     Mean in-family: 10.364322662353516
#     Mean out-of-family: 0.3130641281604767
#     Log2FC: 5.049023628234863
# Latent 13454 is sig assoc w family 9898
#     Family MutL, C-terminal domain, regulatory subdomain
#     Mean in-family: 10.364322662353516
#     Mean out-of-family: 0.3130641281604767
#     Log2FC: 5.049023628234863
# Latent 13568 is sig assoc w family 274
#     Family DNA mismatch repair, conserved site
#     Mean in-family: 20.480730056762695
#     Mean out-of-family: 0.23116931319236755
#     Log2FC: 6.469173431396484
# Latent 13568 is sig assoc w family 457
#     Family Heat shock protein Hsp90, conserved site
#     Mean in-family: 20.25584602355957
#     Mean out-of-family: 0.22727413475513458
#     Log2FC: 6.4777607917785645
# Latent 13568 is sig assoc w family 2000
#     Family DNA mismatch repair protein, S5 domain 2-like
#     Mean in-family: 20.480730056762695
#     Mean out-of-family: 0.23116931319236755
#     Log2FC: 6.469173431396484
# Latent 13568 is sig assoc w family 2113
#     Family MutL, C-terminal, dimerisation
#     Mean in-family: 20.480730056762695
#     Mean out-of-family: 0.23116931319236755
#     Log2FC: 6.469173431396484
# Latent 13568 is sig assoc w family 2370
#     Family Heat shock protein Hsp90, N-terminal
#     Mean in-family: 20.398344039916992
#     Mean out-of-family: 0.2251555621623993
#     Log2FC: 6.5013861656188965
# Latent 13568 is sig assoc w family 4065
#     Family Heat shock protein Hsp90 family
#     Mean in-family: 20.398344039916992
#     Mean out-of-family: 0.2251555621623993
#     Log2FC: 6.5013861656188965
# Latent 13568 is sig assoc w family 4238
#     Family DNA mismatch repair protein MutL/Mlh/PMS
#     Mean in-family: 20.480730056762695
#     Mean out-of-family: 0.23116931319236755
#     Log2FC: 6.469173431396484
# Latent 13568 is sig assoc w family 6308
#     Family DNA mismatch repair protein, MutL
#     Mean in-family: 20.480730056762695
#     Mean out-of-family: 0.23116931319236755
#     Log2FC: 6.469173431396484
# Latent 13568 is sig assoc w family 7213
#     Family DNA mismatch repair protein MutL/Mlh/Pms-like
#     Mean in-family: 20.480730056762695
#     Mean out-of-family: 0.23116931319236755
#     Log2FC: 6.469173431396484
# Latent 13568 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 11.05267333984375
#     Mean out-of-family: 0.20767460763454437
#     Log2FC: 5.733926773071289
# Latent 13568 is sig assoc w family 9682
#     Family HSP90, C-terminal domain
#     Mean in-family: 21.42232894897461
#     Mean out-of-family: 0.22645699977874756
#     Log2FC: 6.563734531402588
# Latent 13568 is sig assoc w family 9684
#     Family MutL, C-terminal domain superfamily
#     Mean in-family: 20.480730056762695
#     Mean out-of-family: 0.23116931319236755
#     Log2FC: 6.469173431396484
# Latent 13568 is sig assoc w family 9897
#     Family MutL, C-terminal domain, dimerisation subdomain
#     Mean in-family: 20.480730056762695
#     Mean out-of-family: 0.23116931319236755
#     Log2FC: 6.469173431396484
# Latent 13568 is sig assoc w family 9898
#     Family MutL, C-terminal domain, regulatory subdomain
#     Mean in-family: 20.480730056762695
#     Mean out-of-family: 0.23116931319236755
#     Log2FC: 6.469173431396484
# Latent 14016 is sig assoc w family 9076
#     Family Leucine-rich repeat domain superfamily
#     Mean in-family: 5.0822672843933105
#     Mean out-of-family: 0.2882714867591858
#     Log2FC: 4.13997220993042
# Latent 14016 is sig assoc w family 10045
#     Family Leucine-rich repeat
#     Mean in-family: 5.10562801361084
#     Mean out-of-family: 0.2901417911052704
#     Log2FC: 4.137258529663086
# Latent 14016 is sig assoc w family 10056
#     Family Leucine-rich repeat, typical subtype
#     Mean in-family: 5.203310489654541
#     Mean out-of-family: 0.29435423016548157
#     Log2FC: 4.143804550170898
# Latent 16053 is sig assoc w family 161
#     Family Cytochrome c oxidase, subunit I, copper-binding site
#     Mean in-family: 8.241275787353516
#     Mean out-of-family: 0.4171334207057953
#     Log2FC: 4.304286956787109
# Latent 16053 is sig assoc w family 1063
#     Family Cytochrome c assembly protein
#     Mean in-family: 9.048828125
#     Mean out-of-family: 0.41664862632751465
#     Log2FC: 4.4408278465271
# Latent 16053 is sig assoc w family 2513
#     Family Cytochrome c oxidase-like, subunit I domain
#     Mean in-family: 8.241275787353516
#     Mean out-of-family: 0.4171334207057953
#     Log2FC: 4.304286956787109
# Latent 16053 is sig assoc w family 3935
#     Family Cytochrome c oxidase subunit I
#     Mean in-family: 8.241275787353516
#     Mean out-of-family: 0.4171334207057953
#     Log2FC: 4.304286956787109
# Latent 16053 is sig assoc w family 4116
#     Family Phosphatidylglycerol--prolipoprotein diacylglyceryl transferase Lgt
#     Mean in-family: 8.098214149475098
#     Mean out-of-family: 0.41645073890686035
#     Log2FC: 4.281385898590088
# Latent 16053 is sig assoc w family 4594
#     Family Undecaprenyl-diphosphatase UppP
#     Mean in-family: 7.337740421295166
#     Mean out-of-family: 0.4128255844116211
#     Log2FC: 4.151731491088867
# Latent 16053 is sig assoc w family 9583
#     Family Cytochrome c oxidase-like, subunit I superfamily
#     Mean in-family: 8.241275787353516
#     Mean out-of-family: 0.4171334207057953
#     Log2FC: 4.304286956787109
# Latent 17043 is sig assoc w family 4754
#     Family Outer membrane lipoprotein LolB
#     Mean in-family: 7.857747554779053
#     Mean out-of-family: 0.4559526741504669
#     Log2FC: 4.107159614562988
# Latent 17043 is sig assoc w family 9052
#     Family Lipoprotein localisation LolA/LolB/LppX
#     Mean in-family: 9.566939353942871
#     Mean out-of-family: 0.45036551356315613
#     Log2FC: 4.408889293670654
# Latent 17660 is sig assoc w family 659
#     Family Alpha/beta hydrolase fold-1
#     Mean in-family: 6.300508975982666
#     Mean out-of-family: 0.3463914394378662
#     Log2FC: 4.184993267059326
# Latent 17660 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 5.34006404876709
#     Mean out-of-family: 0.32431885600090027
#     Log2FC: 4.041372299194336
# Latent 18350 is sig assoc w family 669
#     Family GNAT domain
#     Mean in-family: 9.628588676452637
#     Mean out-of-family: 0.2605372965335846
#     Log2FC: 5.207762718200684
# Latent 18350 is sig assoc w family 1529
#     Family TLDc domain
#     Mean in-family: 4.612890243530273
#     Mean out-of-family: 0.2696073353290558
#     Log2FC: 4.096739292144775
# Latent 18350 is sig assoc w family 4544
#     Family NAD(+) synthetase
#     Mean in-family: 5.013857841491699
#     Mean out-of-family: 0.268932044506073
#     Log2FC: 4.220607757568359
# Latent 18350 is sig assoc w family 4765
#     Family Leucyl/phenylalanyl-tRNA-protein transferase
#     Mean in-family: 12.568359375
#     Mean out-of-family: 0.261933833360672
#     Log2FC: 5.5844502449035645
# Latent 18350 is sig assoc w family 6472
#     Family NH(3)-dependent NAD(+) synthetase
#     Mean in-family: 4.955468654632568
#     Mean out-of-family: 0.26943597197532654
#     Log2FC: 4.201006889343262
# Latent 18350 is sig assoc w family 8834
#     Family Acyl-CoA N-acyltransferase
#     Mean in-family: 11.163222312927246
#     Mean out-of-family: 0.2444821298122406
#     Log2FC: 5.512880802154541
# Latent 18350 is sig assoc w family 9910
#     Family Leucyl/phenylalanyl-tRNA-protein transferase, C-terminal
#     Mean in-family: 12.568359375
#     Mean out-of-family: 0.261933833360672
#     Log2FC: 5.5844502449035645
# Latent 18350 is sig assoc w family 9912
#     Family Leucyl/phenylalanyl-tRNA-protein transferase, N-terminal
#     Mean in-family: 12.524553298950195
#     Mean out-of-family: 0.26319605112075806
#     Log2FC: 5.572477340698242
# Latent 18695 is sig assoc w family 457
#     Family Heat shock protein Hsp90, conserved site
#     Mean in-family: 21.97588539123535
#     Mean out-of-family: 0.4374622702598572
#     Log2FC: 5.650619029998779
# Latent 18695 is sig assoc w family 2370
#     Family Heat shock protein Hsp90, N-terminal
#     Mean in-family: 22.053768157958984
#     Mean out-of-family: 0.4352443516254425
#     Log2FC: 5.663055896759033
# Latent 18695 is sig assoc w family 4065
#     Family Heat shock protein Hsp90 family
#     Mean in-family: 22.053768157958984
#     Mean out-of-family: 0.4352443516254425
#     Log2FC: 5.663055896759033
# Latent 18695 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 12.313361167907715
#     Mean out-of-family: 0.41565626859664917
#     Log2FC: 4.888689994812012
# Latent 18695 is sig assoc w family 9682
#     Family HSP90, C-terminal domain
#     Mean in-family: 22.193145751953125
#     Mean out-of-family: 0.4373100697994232
#     Log2FC: 5.665313720703125
# Latent 20356 is sig assoc w family 274
#     Family DNA mismatch repair, conserved site
#     Mean in-family: 20.917709350585938
#     Mean out-of-family: 0.28388261795043945
#     Log2FC: 6.203286647796631
# Latent 20356 is sig assoc w family 457
#     Family Heat shock protein Hsp90, conserved site
#     Mean in-family: 25.101428985595703
#     Mean out-of-family: 0.2768222689628601
#     Log2FC: 6.5026655197143555
# Latent 20356 is sig assoc w family 2000
#     Family DNA mismatch repair protein, S5 domain 2-like
#     Mean in-family: 20.917709350585938
#     Mean out-of-family: 0.28388261795043945
#     Log2FC: 6.203286647796631
# Latent 20356 is sig assoc w family 2113
#     Family MutL, C-terminal, dimerisation
#     Mean in-family: 20.917709350585938
#     Mean out-of-family: 0.28388261795043945
#     Log2FC: 6.203286647796631
# Latent 20356 is sig assoc w family 2370
#     Family Heat shock protein Hsp90, N-terminal
#     Mean in-family: 25.36316680908203
#     Mean out-of-family: 0.2741282880306244
#     Log2FC: 6.531739711761475
# Latent 20356 is sig assoc w family 4065
#     Family Heat shock protein Hsp90 family
#     Mean in-family: 25.36316680908203
#     Mean out-of-family: 0.2741282880306244
#     Log2FC: 6.531739711761475
# Latent 20356 is sig assoc w family 4238
#     Family DNA mismatch repair protein MutL/Mlh/PMS
#     Mean in-family: 20.917709350585938
#     Mean out-of-family: 0.28388261795043945
#     Log2FC: 6.203286647796631
# Latent 20356 is sig assoc w family 6308
#     Family DNA mismatch repair protein, MutL
#     Mean in-family: 20.917709350585938
#     Mean out-of-family: 0.28388261795043945
#     Log2FC: 6.203286647796631
# Latent 20356 is sig assoc w family 7213
#     Family DNA mismatch repair protein MutL/Mlh/Pms-like
#     Mean in-family: 20.917709350585938
#     Mean out-of-family: 0.28388261795043945
#     Log2FC: 6.203286647796631
# Latent 20356 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 12.88416862487793
#     Mean out-of-family: 0.2550492286682129
#     Log2FC: 5.658679962158203
# Latent 20356 is sig assoc w family 9682
#     Family HSP90, C-terminal domain
#     Mean in-family: 26.67732048034668
#     Mean out-of-family: 0.2757183909416199
#     Log2FC: 6.596274375915527
# Latent 20356 is sig assoc w family 9684
#     Family MutL, C-terminal domain superfamily
#     Mean in-family: 20.917709350585938
#     Mean out-of-family: 0.28388261795043945
#     Log2FC: 6.203286647796631
# Latent 20356 is sig assoc w family 9897
#     Family MutL, C-terminal domain, dimerisation subdomain
#     Mean in-family: 20.917709350585938
#     Mean out-of-family: 0.28388261795043945
#     Log2FC: 6.203286647796631
# Latent 20356 is sig assoc w family 9898
#     Family MutL, C-terminal domain, regulatory subdomain
#     Mean in-family: 20.917709350585938
#     Mean out-of-family: 0.28388261795043945
#     Log2FC: 6.203286647796631
# Latent 20379 is sig assoc w family 38
#     Family Serine carboxypeptidase, serine active site
#     Mean in-family: 9.556071281433105
#     Mean out-of-family: 0.2616489827632904
#     Log2FC: 5.190712928771973
# Latent 20379 is sig assoc w family 92
#     Family Serine carboxypeptidases, histidine active site
#     Mean in-family: 9.696510314941406
#     Mean out-of-family: 0.2643684446811676
#     Log2FC: 5.19684362411499
# Latent 20379 is sig assoc w family 282
#     Family Phosphoenolpyruvate carboxykinase (ATP), conserved site
#     Mean in-family: 4.336197853088379
#     Mean out-of-family: 0.26664280891418457
#     Log2FC: 4.0234503746032715
# Latent 20379 is sig assoc w family 1698
#     Family Propeptide, carboxypeptidase Y
#     Mean in-family: 9.4375
#     Mean out-of-family: 0.2654156982898712
#     Log2FC: 5.152079105377197
# Latent 20379 is sig assoc w family 2057
#     Family Lipase
#     Mean in-family: 4.537841796875
#     Mean out-of-family: 0.2673763334751129
#     Log2FC: 4.085062503814697
# Latent 20379 is sig assoc w family 3891
#     Family Triacylglycerol lipase family
#     Mean in-family: 4.537841796875
#     Mean out-of-family: 0.2673763334751129
#     Log2FC: 4.085062503814697
# Latent 20379 is sig assoc w family 3985
#     Family GDSL lipase/esterase
#     Mean in-family: 5.323893070220947
#     Mean out-of-family: 0.2670617997646332
#     Log2FC: 4.317235946655273
# Latent 20379 is sig assoc w family 4029
#     Family Phosphoenolpyruvate carboxykinase, ATP-utilising
#     Mean in-family: 4.336197853088379
#     Mean out-of-family: 0.26664280891418457
#     Log2FC: 4.0234503746032715
# Latent 20379 is sig assoc w family 4096
#     Family Peptidase S10, serine carboxypeptidase
#     Mean in-family: 9.708293914794922
#     Mean out-of-family: 0.259635865688324
#     Log2FC: 5.224656105041504
# Latent 20379 is sig assoc w family 5358
#     Family Homoserine/serine acetyltransferase MetX-like
#     Mean in-family: 5.5625
#     Mean out-of-family: 0.266966313123703
#     Log2FC: 4.3810038566589355
# Latent 20379 is sig assoc w family 8548
#     Family Phosphoenolpyruvate carboxykinase, N-terminal
#     Mean in-family: 4.254648685455322
#     Mean out-of-family: 0.26509496569633484
#     Log2FC: 4.004458904266357
# Latent 20379 is sig assoc w family 8720
#     Family Phosphoenolpyruvate carboxykinase, C-terminal
#     Mean in-family: 4.254648685455322
#     Mean out-of-family: 0.26509496569633484
#     Log2FC: 4.004458904266357
# Latent 20379 is sig assoc w family 8797
#     Family Acyl transferase/acyl hydrolase/lysophospholipase
#     Mean in-family: 9.4435453414917
#     Mean out-of-family: 0.2654132843017578
#     Log2FC: 5.153016090393066
# Latent 20379 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 4.5938005447387695
#     Mean out-of-family: 0.24166607856750488
#     Log2FC: 4.24860143661499
# Latent 20379 is sig assoc w family 9382
#     Family SGNH hydrolase superfamily
#     Mean in-family: 4.425765037536621
#     Mean out-of-family: 0.26700514554977417
#     Log2FC: 4.050987243652344

# %%
for latent_i in range(latents_family_pvals.shape[0]):
    cur_lat_id = latent_ids_both_proteins[latent_i]
    layer_id = ((cur_lat_id // 4096)+1)*4
    lat_id = cur_lat_id % 4096
    print(f"Latent {latent_i}-{cur_lat_id} is in layer {layer_id} with latent ID {lat_id}")
    for family_j in range(latents_family_pvals.shape[1]):
        if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
            if latents_family_effect_size[latent_i,family_j,1] < latents_family_effect_size[latent_i,family_j,0]:
                l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/ (latents_family_effect_size[latent_i,family_j,1]+0.00001))
                # if l2fc >= 4:  # latents_family_effect_size[latent_i,family_j,0] > 1.05: #
                annotated_latents += [latent_ids_both_proteins[latent_i]]
                print(f"Latent {latent_ids_both_proteins[latent_i]} is sig assoc w family {family_j}")
                print(f"    Family {interpro_annotations_nonzero.iloc[family_j]['ENTRY_NAME']}")
                print(f"    Mean in-family: {latents_family_effect_size[latent_i,family_j,0]}")
                print(f"    Mean out-of-family: {latents_family_effect_size[latent_i,family_j,1]}")
                print(f"    Log2FC: {np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])}")
# Out:
# Latent 0-100 is in layer 4 with latent ID 100
# Latent 1-181 is in layer 4 with latent ID 181
# Latent 2-237 is in layer 4 with latent ID 237
# Latent 3-340 is in layer 4 with latent ID 340
# Latent 4-443 is in layer 4 with latent ID 443
# Latent 5-495 is in layer 4 with latent ID 495
# Latent 6-527 is in layer 4 with latent ID 527
# Latent 7-601 is in layer 4 with latent ID 601
# Latent 8-794 is in layer 4 with latent ID 794
# Latent 9-798 is in layer 4 with latent ID 798
# Latent 10-963 is in layer 4 with latent ID 963
# Latent 11-1096 is in layer 4 with latent ID 1096
# Latent 12-1196 is in layer 4 with latent ID 1196
# Latent 13-1297 is in layer 4 with latent ID 1297
# Latent 14-1374 is in layer 4 with latent ID 1374
# Latent 15-1468 is in layer 4 with latent ID 1468
# Latent 16-1474 is in layer 4 with latent ID 1474
# Latent 17-1509 is in layer 4 with latent ID 1509
# Latent 18-1682 is in layer 4 with latent ID 1682
# Latent 19-1690 is in layer 4 with latent ID 1690
# Latent 20-1712 is in layer 4 with latent ID 1712
# Latent 21-1807 is in layer 4 with latent ID 1807
# Latent 22-1949 is in layer 4 with latent ID 1949
# Latent 23-2005 is in layer 4 with latent ID 2005
# Latent 24-2112 is in layer 4 with latent ID 2112
# Latent 25-2277 is in layer 4 with latent ID 2277
# Latent 26-2311 is in layer 4 with latent ID 2311
# Latent 27-2340 is in layer 4 with latent ID 2340
# Latent 28-2443 is in layer 4 with latent ID 2443
# Latent 29-2511 is in layer 4 with latent ID 2511
# Latent 30-2850 is in layer 4 with latent ID 2850
# Latent 31-2929 is in layer 4 with latent ID 2929
# Latent 32-2947 is in layer 4 with latent ID 2947
# Latent 33-2983 is in layer 4 with latent ID 2983
# Latent 34-3069 is in layer 4 with latent ID 3069
# Latent 35-3153 is in layer 4 with latent ID 3153
# Latent 36-3170 is in layer 4 with latent ID 3170
# Latent 37-3177 is in layer 4 with latent ID 3177
# Latent 38-3229 is in layer 4 with latent ID 3229
# Latent 39-3326 is in layer 4 with latent ID 3326
# Latent 40-3351 is in layer 4 with latent ID 3351
# Latent 41-3544 is in layer 4 with latent ID 3544
# Latent 42-3612 is in layer 4 with latent ID 3612
# Latent 43-3634 is in layer 4 with latent ID 3634
# Latent 44-3651 is in layer 4 with latent ID 3651
# Latent 45-3701 is in layer 4 with latent ID 3701
# Latent 46-3717 is in layer 4 with latent ID 3717
# Latent 47-3764 is in layer 4 with latent ID 3764
# Latent 48-3788 is in layer 4 with latent ID 3788
# Latent 49-3832 is in layer 4 with latent ID 3832
# Latent 50-4527 is in layer 8 with latent ID 431
# Latent 51-4584 is in layer 8 with latent ID 488
# Latent 52-5671 is in layer 8 with latent ID 1575
# Latent 53-6262 is in layer 8 with latent ID 2166
# Latent 54-6582 is in layer 8 with latent ID 2486
# Latent 55-6758 is in layer 8 with latent ID 2662
# Latent 56-6773 is in layer 8 with latent ID 2677
# Latent 57-6871 is in layer 8 with latent ID 2775
# Latent 58-7415 is in layer 8 with latent ID 3319
# Latent 59-7480 is in layer 8 with latent ID 3384
# Latent 60-8017 is in layer 8 with latent ID 3921
# Latent 61-8403 is in layer 12 with latent ID 211
# Latent 62-8531 is in layer 12 with latent ID 339
# Latent 63-8757 is in layer 12 with latent ID 565
# Latent 64-8859 is in layer 12 with latent ID 667
# Latent 65-8861 is in layer 12 with latent ID 669
# Latent 66-8990 is in layer 12 with latent ID 798
# Latent 67-8995 is in layer 12 with latent ID 803
# Latent 68-9091 is in layer 12 with latent ID 899
# Latent 69-9096 is in layer 12 with latent ID 904
# Latent 70-9274 is in layer 12 with latent ID 1082
# Latent 71-9313 is in layer 12 with latent ID 1121
# Latent 72-9396 is in layer 12 with latent ID 1204
# Latent 73-9448 is in layer 12 with latent ID 1256
# Latent 74-9569 is in layer 12 with latent ID 1377
# Latent 75-9606 is in layer 12 with latent ID 1414
# Latent 76-9710 is in layer 12 with latent ID 1518
# Latent 77-9988 is in layer 12 with latent ID 1796
# Latent 78-10010 is in layer 12 with latent ID 1818
# Latent 79-10249 is in layer 12 with latent ID 2057
# Latent 80-10304 is in layer 12 with latent ID 2112
# Latent 81-10342 is in layer 12 with latent ID 2150
# Latent 82-10494 is in layer 12 with latent ID 2302
# Latent 83-10664 is in layer 12 with latent ID 2472
# Latent 84-10666 is in layer 12 with latent ID 2474
# Latent 85-10669 is in layer 12 with latent ID 2477
# Latent 86-10670 is in layer 12 with latent ID 2478
# Latent 87-10704 is in layer 12 with latent ID 2512
# Latent 88-10820 is in layer 12 with latent ID 2628
# Latent 89-10989 is in layer 12 with latent ID 2797
# Latent 90-11037 is in layer 12 with latent ID 2845
# Latent 91-11227 is in layer 12 with latent ID 3035
# Latent 92-11431 is in layer 12 with latent ID 3239
# Latent 93-11690 is in layer 12 with latent ID 3498
# Latent 94-11728 is in layer 12 with latent ID 3536
# Latent 95-11735 is in layer 12 with latent ID 3543
# Latent 96-11749 is in layer 12 with latent ID 3557
# Latent 97-11790 is in layer 12 with latent ID 3598
# Latent 98-11818 is in layer 12 with latent ID 3626
# Latent 99-11943 is in layer 12 with latent ID 3751
# Latent 100-11986 is in layer 12 with latent ID 3794
# Latent 101-12000 is in layer 12 with latent ID 3808
# Latent 102-12041 is in layer 12 with latent ID 3849
# Latent 103-12135 is in layer 12 with latent ID 3943
# Latent 104-12152 is in layer 12 with latent ID 3960
# Latent 105-12211 is in layer 12 with latent ID 4019
# Latent 106-12236 is in layer 12 with latent ID 4044
# Latent 107-12334 is in layer 16 with latent ID 46
# Latent 108-12445 is in layer 16 with latent ID 157
# Latent 109-12645 is in layer 16 with latent ID 357
# Latent 110-12675 is in layer 16 with latent ID 387
# Latent 111-12679 is in layer 16 with latent ID 391
# Latent 112-12768 is in layer 16 with latent ID 480
# Latent 113-12894 is in layer 16 with latent ID 606
# Latent 114-12919 is in layer 16 with latent ID 631
# Latent 115-12996 is in layer 16 with latent ID 708
# Latent 116-13025 is in layer 16 with latent ID 737
# Latent 117-13088 is in layer 16 with latent ID 800
# Latent 118-13099 is in layer 16 with latent ID 811
# Latent 119-13146 is in layer 16 with latent ID 858
# Latent 120-13216 is in layer 16 with latent ID 928
# Latent 121-13356 is in layer 16 with latent ID 1068
# Latent 122-13363 is in layer 16 with latent ID 1075
# Latent 123-13454 is in layer 16 with latent ID 1166
# Latent 124-13491 is in layer 16 with latent ID 1203
# Latent 125-13497 is in layer 16 with latent ID 1209
# Latent 126-13524 is in layer 16 with latent ID 1236
# Latent 127-13568 is in layer 16 with latent ID 1280
# Latent 128-13641 is in layer 16 with latent ID 1353
# Latent 129-13668 is in layer 16 with latent ID 1380
# Latent 130-13676 is in layer 16 with latent ID 1388
# Latent 131-13687 is in layer 16 with latent ID 1399
# Latent 132-13735 is in layer 16 with latent ID 1447
# Latent 133-13737 is in layer 16 with latent ID 1449
# Latent 134-13740 is in layer 16 with latent ID 1452
# Latent 135-13748 is in layer 16 with latent ID 1460
# Latent 136-13792 is in layer 16 with latent ID 1504
# Latent 137-13801 is in layer 16 with latent ID 1513
# Latent 138-13885 is in layer 16 with latent ID 1597
# Latent 139-14016 is in layer 16 with latent ID 1728
# Latent 140-14076 is in layer 16 with latent ID 1788
# Latent 141-14124 is in layer 16 with latent ID 1836
# Latent 142-14128 is in layer 16 with latent ID 1840
# Latent 143-14168 is in layer 16 with latent ID 1880
# Latent 144-14215 is in layer 16 with latent ID 1927
# Latent 145-14463 is in layer 16 with latent ID 2175
# Latent 146-14511 is in layer 16 with latent ID 2223
# Latent 147-14629 is in layer 16 with latent ID 2341
# Latent 148-14700 is in layer 16 with latent ID 2412
# Latent 149-14734 is in layer 16 with latent ID 2446
# Latent 150-14738 is in layer 16 with latent ID 2450
# Latent 151-14824 is in layer 16 with latent ID 2536
# Latent 152-14837 is in layer 16 with latent ID 2549
# Latent 153-14876 is in layer 16 with latent ID 2588
# Latent 154-15124 is in layer 16 with latent ID 2836
# Latent 155-15166 is in layer 16 with latent ID 2878
# Latent 156-15380 is in layer 16 with latent ID 3092
# Latent 157-15395 is in layer 16 with latent ID 3107
# Latent 158-15429 is in layer 16 with latent ID 3141
# Latent 159-15553 is in layer 16 with latent ID 3265
# Latent 160-15585 is in layer 16 with latent ID 3297
# Latent 161-15681 is in layer 16 with latent ID 3393
# Latent 162-15742 is in layer 16 with latent ID 3454
# Latent 163-15746 is in layer 16 with latent ID 3458
# Latent 164-15801 is in layer 16 with latent ID 3513
# Latent 165-15851 is in layer 16 with latent ID 3563
# Latent 166-15953 is in layer 16 with latent ID 3665
# Latent 167-15954 is in layer 16 with latent ID 3666
# Latent 168-15967 is in layer 16 with latent ID 3679
# Latent 169-16051 is in layer 16 with latent ID 3763
# Latent 170-16053 is in layer 16 with latent ID 3765
# Latent 171-16167 is in layer 16 with latent ID 3879
# Latent 172-16282 is in layer 16 with latent ID 3994
# Latent 173-16443 is in layer 20 with latent ID 59
# Latent 174-16470 is in layer 20 with latent ID 86
# Latent 175-16520 is in layer 20 with latent ID 136
# Latent 176-16521 is in layer 20 with latent ID 137
# Latent 177-16526 is in layer 20 with latent ID 142
# Latent 178-16571 is in layer 20 with latent ID 187
# Latent 179-16816 is in layer 20 with latent ID 432
# Latent 180-16825 is in layer 20 with latent ID 441
# Latent 181-16846 is in layer 20 with latent ID 462
# Latent 182-16880 is in layer 20 with latent ID 496
# Latent 183-16978 is in layer 20 with latent ID 594
# Latent 184-17043 is in layer 20 with latent ID 659
# Latent 185-17106 is in layer 20 with latent ID 722
# Latent 186-17138 is in layer 20 with latent ID 754
# Latent 187-17173 is in layer 20 with latent ID 789
# Latent 188-17214 is in layer 20 with latent ID 830
# Latent 189-17222 is in layer 20 with latent ID 838
# Latent 190-17235 is in layer 20 with latent ID 851
# Latent 191-17249 is in layer 20 with latent ID 865
# Latent 192-17262 is in layer 20 with latent ID 878
# Latent 193-17282 is in layer 20 with latent ID 898
# Latent 194-17292 is in layer 20 with latent ID 908
# Latent 195-17314 is in layer 20 with latent ID 930
# Latent 196-17396 is in layer 20 with latent ID 1012
# Latent 197-17492 is in layer 20 with latent ID 1108
# Latent 198-17651 is in layer 20 with latent ID 1267
# Latent 199-17660 is in layer 20 with latent ID 1276
# Latent 200-17689 is in layer 20 with latent ID 1305
# Latent 201-17779 is in layer 20 with latent ID 1395
# Latent 202-17889 is in layer 20 with latent ID 1505
# Latent 203-17917 is in layer 20 with latent ID 1533
# Latent 204-17924 is in layer 20 with latent ID 1540
# Latent 205-18128 is in layer 20 with latent ID 1744
# Latent 206-18140 is in layer 20 with latent ID 1756
# Latent 207-18144 is in layer 20 with latent ID 1760
# Latent 208-18147 is in layer 20 with latent ID 1763
# Latent 209-18167 is in layer 20 with latent ID 1783
# Latent 210-18183 is in layer 20 with latent ID 1799
# Latent 211-18184 is in layer 20 with latent ID 1800
# Latent 212-18191 is in layer 20 with latent ID 1807
# Latent 213-18344 is in layer 20 with latent ID 1960
# Latent 214-18350 is in layer 20 with latent ID 1966
# Latent 215-18359 is in layer 20 with latent ID 1975
# Latent 216-18405 is in layer 20 with latent ID 2021
# Latent 217-18407 is in layer 20 with latent ID 2023
# Latent 218-18587 is in layer 20 with latent ID 2203
# Latent 219-18645 is in layer 20 with latent ID 2261
# Latent 220-18695 is in layer 20 with latent ID 2311
# Latent 221-18706 is in layer 20 with latent ID 2322
# Latent 222-18708 is in layer 20 with latent ID 2324
# Latent 223-18711 is in layer 20 with latent ID 2327
# Latent 224-18750 is in layer 20 with latent ID 2366
# Latent 225-18785 is in layer 20 with latent ID 2401
# Latent 226-18879 is in layer 20 with latent ID 2495
# Latent 227-18884 is in layer 20 with latent ID 2500
# Latent 228-18922 is in layer 20 with latent ID 2538
# Latent 229-19016 is in layer 20 with latent ID 2632
# Latent 230-19105 is in layer 20 with latent ID 2721
# Latent 231-19107 is in layer 20 with latent ID 2723
# Latent 232-19122 is in layer 20 with latent ID 2738
# Latent 233-19145 is in layer 20 with latent ID 2761
# Latent 234-19332 is in layer 20 with latent ID 2948
# Latent 235-19351 is in layer 20 with latent ID 2967
# Latent 236-19428 is in layer 20 with latent ID 3044
# Latent 237-19780 is in layer 20 with latent ID 3396
# Latent 238-19794 is in layer 20 with latent ID 3410
# Latent 239-19846 is in layer 20 with latent ID 3462
# Latent 240-19874 is in layer 20 with latent ID 3490
# Latent 241-19951 is in layer 20 with latent ID 3567
# Latent 242-19964 is in layer 20 with latent ID 3580
# Latent 243-19981 is in layer 20 with latent ID 3597
# Latent 244-19999 is in layer 20 with latent ID 3615
# Latent 245-20000 is in layer 20 with latent ID 3616
# Latent 246-20023 is in layer 20 with latent ID 3639
# Latent 247-20061 is in layer 20 with latent ID 3677
# Latent 248-20112 is in layer 20 with latent ID 3728
# Latent 249-20116 is in layer 20 with latent ID 3732
# Latent 250-20159 is in layer 20 with latent ID 3775
# Latent 251-20171 is in layer 20 with latent ID 3787
# Latent 252-20308 is in layer 20 with latent ID 3924
# Latent 253-20336 is in layer 20 with latent ID 3952
# Latent 254-20338 is in layer 20 with latent ID 3954
# Latent 255-20356 is in layer 20 with latent ID 3972
# Latent 256-20379 is in layer 20 with latent ID 3995
# Latent 257-20384 is in layer 20 with latent ID 4000
# Latent 258-20442 is in layer 20 with latent ID 4058
# Latent 259-20444 is in layer 20 with latent ID 4060
# Latent 260-20494 is in layer 24 with latent ID 14
# Latent 261-20521 is in layer 24 with latent ID 41
# Latent 262-20558 is in layer 24 with latent ID 78
# Latent 263-20568 is in layer 24 with latent ID 88
# Latent 264-20590 is in layer 24 with latent ID 110
# Latent 265-20660 is in layer 24 with latent ID 180
# Latent 266-20700 is in layer 24 with latent ID 220
# Latent 267-20711 is in layer 24 with latent ID 231
# Latent 268-20808 is in layer 24 with latent ID 328
# Latent 269-20910 is in layer 24 with latent ID 430
# Latent 270-20926 is in layer 24 with latent ID 446
# Latent 271-20951 is in layer 24 with latent ID 471
# Latent 272-20971 is in layer 24 with latent ID 491
# Latent 273-21085 is in layer 24 with latent ID 605
# Latent 274-21164 is in layer 24 with latent ID 684
# Latent 275-21211 is in layer 24 with latent ID 731
# Latent 276-21378 is in layer 24 with latent ID 898
# Latent 277-21409 is in layer 24 with latent ID 929
# Latent 278-21430 is in layer 24 with latent ID 950
# Latent 279-21452 is in layer 24 with latent ID 972
# Latent 280-21456 is in layer 24 with latent ID 976
# Latent 281-21476 is in layer 24 with latent ID 996
# Latent 282-21493 is in layer 24 with latent ID 1013
# Latent 283-21524 is in layer 24 with latent ID 1044
# Latent 284-21549 is in layer 24 with latent ID 1069
# Latent 285-21555 is in layer 24 with latent ID 1075
# Latent 286-21577 is in layer 24 with latent ID 1097
# Latent 287-21629 is in layer 24 with latent ID 1149
# Latent 288-21635 is in layer 24 with latent ID 1155
# Latent 289-21743 is in layer 24 with latent ID 1263
# Latent 290-21780 is in layer 24 with latent ID 1300
# Latent 291-21879 is in layer 24 with latent ID 1399
# Latent 292-21887 is in layer 24 with latent ID 1407
# Latent 293-21901 is in layer 24 with latent ID 1421
# Latent 294-21907 is in layer 24 with latent ID 1427
# Latent 295-21985 is in layer 24 with latent ID 1505
# Latent 296-22174 is in layer 24 with latent ID 1694
# Latent 297-22302 is in layer 24 with latent ID 1822
# Latent 298-22308 is in layer 24 with latent ID 1828
# Latent 299-22338 is in layer 24 with latent ID 1858
# Latent 300-22345 is in layer 24 with latent ID 1865
# Latent 301-22373 is in layer 24 with latent ID 1893
# Latent 302-22389 is in layer 24 with latent ID 1909
# Latent 303-22401 is in layer 24 with latent ID 1921
# Latent 304-22528 is in layer 24 with latent ID 2048
# Latent 305-22530 is in layer 24 with latent ID 2050
# Latent 306-22533 is in layer 24 with latent ID 2053
# Latent 307-22543 is in layer 24 with latent ID 2063
# Latent 308-22686 is in layer 24 with latent ID 2206
# Latent 309-22689 is in layer 24 with latent ID 2209
# Latent 310-22733 is in layer 24 with latent ID 2253
# Latent 311-22734 is in layer 24 with latent ID 2254
# Latent 312-22801 is in layer 24 with latent ID 2321
# Latent 313-22829 is in layer 24 with latent ID 2349
# Latent 314-22830 is in layer 24 with latent ID 2350
# Latent 315-22878 is in layer 24 with latent ID 2398
# Latent 316-22915 is in layer 24 with latent ID 2435
# Latent 317-23013 is in layer 24 with latent ID 2533
# Latent 318-23025 is in layer 24 with latent ID 2545
# Latent 319-23066 is in layer 24 with latent ID 2586
# Latent 320-23089 is in layer 24 with latent ID 2609
# Latent 321-23107 is in layer 24 with latent ID 2627
# Latent 322-23112 is in layer 24 with latent ID 2632
# Latent 323-23133 is in layer 24 with latent ID 2653
# Latent 324-23219 is in layer 24 with latent ID 2739
# Latent 325-23226 is in layer 24 with latent ID 2746
# Latent 326-23264 is in layer 24 with latent ID 2784
# Latent 327-23328 is in layer 24 with latent ID 2848
# Latent 328-23478 is in layer 24 with latent ID 2998
# Latent 329-23496 is in layer 24 with latent ID 3016
# Latent 330-23532 is in layer 24 with latent ID 3052
# Latent 331-23545 is in layer 24 with latent ID 3065
# Latent 332-23546 is in layer 24 with latent ID 3066
# Latent 333-23597 is in layer 24 with latent ID 3117
# Latent 334-23651 is in layer 24 with latent ID 3171
# Latent 335-23676 is in layer 24 with latent ID 3196
# Latent 336-23744 is in layer 24 with latent ID 3264
# Latent 337-23782 is in layer 24 with latent ID 3302
# Latent 338-23807 is in layer 24 with latent ID 3327
# Latent 339-23810 is in layer 24 with latent ID 3330
# Latent 340-23838 is in layer 24 with latent ID 3358
# Latent 341-23917 is in layer 24 with latent ID 3437
# Latent 342-23919 is in layer 24 with latent ID 3439
# Latent 343-23940 is in layer 24 with latent ID 3460
# Latent 344-24098 is in layer 24 with latent ID 3618
# Latent 345-24113 is in layer 24 with latent ID 3633
# Latent 346-24159 is in layer 24 with latent ID 3679
# Latent 347-24187 is in layer 24 with latent ID 3707
# Latent 348-24266 is in layer 24 with latent ID 3786
# Latent 349-24337 is in layer 24 with latent ID 3857
# Latent 350-24345 is in layer 24 with latent ID 3865
# Latent 351-24352 is in layer 24 with latent ID 3872
# Latent 352-24375 is in layer 24 with latent ID 3895
# Latent 353-24426 is in layer 24 with latent ID 3946
# Latent 354-24439 is in layer 24 with latent ID 3959
# Latent 355-24476 is in layer 24 with latent ID 3996
# Latent 356-24548 is in layer 24 with latent ID 4068
# Latent 357-24692 is in layer 28 with latent ID 116
# Latent 358-24745 is in layer 28 with latent ID 169
# Latent 359-24789 is in layer 28 with latent ID 213
# Latent 360-24910 is in layer 28 with latent ID 334
# Latent 361-25063 is in layer 28 with latent ID 487
# Latent 362-25234 is in layer 28 with latent ID 658
# Latent 363-25238 is in layer 28 with latent ID 662
# Latent 364-25306 is in layer 28 with latent ID 730
# Latent 365-25393 is in layer 28 with latent ID 817
# Latent 366-25438 is in layer 28 with latent ID 862
# Latent 367-25472 is in layer 28 with latent ID 896
# Latent 368-25642 is in layer 28 with latent ID 1066
# Latent 369-25671 is in layer 28 with latent ID 1095
# Latent 370-25998 is in layer 28 with latent ID 1422
# Latent 371-26455 is in layer 28 with latent ID 1879
# Latent 372-26468 is in layer 28 with latent ID 1892
# Latent 373-26546 is in layer 28 with latent ID 1970
# Latent 374-26607 is in layer 28 with latent ID 2031
# Latent 375-27528 is in layer 28 with latent ID 2952
# Latent 376-27895 is in layer 28 with latent ID 3319
# Latent 377-28023 is in layer 28 with latent ID 3447
# Latent 378-28331 is in layer 28 with latent ID 3755
# Latent 379-28482 is in layer 28 with latent ID 3906
# Latent 380-28526 is in layer 28 with latent ID 3950
# Latent 381-28597 is in layer 28 with latent ID 4021
# Latent 382-28651 is in layer 28 with latent ID 4075

# %%
metx_manual_latents = {8: [488, 2677, 2775, 2166], 12: [2112, 3035, 3536, 3794, 1256, 2797]}

def to_flattened_id(layer_id: int, lat_id: int) -> int:
    if layer_id % 4 != 0:
        raise ValueError("layer_id must be a multiple of 4 (e.g., 4, 8, 12, ...)")
    if not (0 <= lat_id < 4096):
        raise ValueError("lat_id must be in [0, 4096)")
    return ((layer_id // 4) - 1) * 4096 + lat_id

# %%
0.05/n_tests
# Out:
# 1.7272797218134482e-10

# %%
for layer, latents in metx_manual_latents.items():
    for lat_id in latents:
        print("="*100)
        print(layer, lat_id)
        flattened_id = to_flattened_id(int(layer), int(lat_id))
        latent_i = latent_ids_both_proteins.index(flattened_id)

        for family_j in range(latents_family_pvals.shape[1]):
            if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
                if latents_family_effect_size[latent_i,family_j,1] < latents_family_effect_size[latent_i,family_j,0]:
                    l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/ (latents_family_effect_size[latent_i,family_j,1]+0.00001))

                    print(f"    Family {interpro_annotations_nonzero.iloc[family_j]['ENTRY_NAME']}")
                    print(f"    Mean in-family: {latents_family_effect_size[latent_i,family_j,0]}")
                    print(f"    Mean out-of-family: {latents_family_effect_size[latent_i,family_j,1]}")
                    print(f"    Log2FC: {np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])}")
# Out:
# ====================================================================================================
# 8 488
#     Family Serine carboxypeptidase, serine active site
#     Mean in-family: 0.41482341289520264
#     Mean out-of-family: 0.03794591873884201
#     Log2FC: 3.4504806995391846
#     Family Carboxylesterase type B, active site
#     Mean in-family: 1.8721842765808105
#     Mean out-of-family: 0.03769707679748535
#     Log2FC: 5.634125709533691
#     Family Glyceraldehyde 3-phosphate dehydrogenase, active site
#     Mean in-family: 0.6408420205116272
#     Mean out-of-family: 0.037885647267103195
#     Log2FC: 4.080245494842529
#     Family Serine carboxypeptidases, histidine active site
#     Mean in-family: 0.37188151478767395
#     Mean out-of-family: 0.038080520927906036
#     Log2FC: 3.287717819213867
#     Family Porphobilinogen deaminase, dipyrromethane cofactor binding site
#     Mean in-family: 0.7127278447151184
#     Mean out-of-family: 0.0377749539911747
#     Log2FC: 4.237849235534668
#     Family AB hydrolase 4, conserved site
#     Mean in-family: 4.200439453125
#     Mean out-of-family: 0.03741481155157089
#     Log2FC: 6.810786724090576
#     Family DNA methylase, N-6 adenine-specific, conserved site
#     Mean in-family: 0.5920937657356262
#     Mean out-of-family: 0.03752648085355759
#     Log2FC: 3.979844808578491
#     Family Recombinase, conserved site
#     Mean in-family: 2.3385417461395264
#     Mean out-of-family: 0.037557121366262436
#     Log2FC: 5.960378646850586
#     Family Malic enzyme, conserved site
#     Mean in-family: 0.4471679627895355
#     Mean out-of-family: 0.03808378800749779
#     Log2FC: 3.553567886352539
#     Family Alpha-D-phosphohexomutase, conserved site
#     Mean in-family: 0.15471334755420685
#     Mean out-of-family: 0.03804909065365791
#     Log2FC: 2.0236637592315674
#     Family ATP phosphoribosyltransferase, conserved site
#     Mean in-family: 0.5463402271270752
#     Mean out-of-family: 0.037891507148742676
#     Log2FC: 3.849853277206421
#     Family Glutamyl-tRNA reductase, conserved site
#     Mean in-family: 0.3387180268764496
#     Mean out-of-family: 0.037886422127485275
#     Log2FC: 3.160331964492798
#     Family Tetrahydrofolate dehydrogenase/cyclohydrolase, conserved site
#     Mean in-family: 0.43464425206184387
#     Mean out-of-family: 0.037810903042554855
#     Log2FC: 3.522960901260376
#     Family Tr-type G domain, conserved site
#     Mean in-family: 0.1343076527118683
#     Mean out-of-family: 0.03770645335316658
#     Log2FC: 1.8326581716537476
#     Family Cutinase, aspartate and histidine active sites
#     Mean in-family: 1.071044921875
#     Mean out-of-family: 0.03804081678390503
#     Log2FC: 4.815327167510986
#     Family Cutinase, serine active site
#     Mean in-family: 1.071044921875
#     Mean out-of-family: 0.03804081678390503
#     Log2FC: 4.815327167510986
#     Family Ribosomal RNA large subunit methyltransferase K/L-like, conserved site
#     Mean in-family: 0.5455635786056519
#     Mean out-of-family: 0.03799363598227501
#     Log2FC: 3.8439176082611084
#     Family Alpha/beta hydrolase fold-1
#     Mean in-family: 3.5742106437683105
#     Mean out-of-family: 0.03258081153035164
#     Log2FC: 6.777458190917969
#     Family Ribosomal RNA large subunit methyltransferase K/L-like, methyltransferase domain
#     Mean in-family: 0.5044410228729248
#     Mean out-of-family: 0.037967532873153687
#     Log2FC: 3.7318475246429443
#     Family THIF-type NAD/FAD binding fold
#     Mean in-family: 0.71038818359375
#     Mean out-of-family: 0.03797845542430878
#     Log2FC: 4.225354194641113
#     Family Translational (tr)-type GTP-binding domain
#     Mean in-family: 0.10941319167613983
#     Mean out-of-family: 0.037745747715234756
#     Log2FC: 1.5354007482528687
#     Family Glycosyl transferase, family 1
#     Mean in-family: 0.300360769033432
#     Mean out-of-family: 0.03793250769376755
#     Log2FC: 2.98518967628479
#     Family Peptidase S9, prolyl oligopeptidase, catalytic domain
#     Mean in-family: 2.7841694355010986
#     Mean out-of-family: 0.0371486134827137
#     Log2FC: 6.227794647216797
#     Family Carboxylesterase, type B
#     Mean in-family: 0.953906238079071
#     Mean out-of-family: 0.038064248859882355
#     Log2FC: 4.6473388671875
#     Family Dipeptidylpeptidase IV, N-terminal domain
#     Mean in-family: 2.464365005493164
#     Mean out-of-family: 0.037519365549087524
#     Log2FC: 6.037436485290527
#     Family Dienelactone hydrolase
#     Mean in-family: 4.73291015625
#     Mean out-of-family: 0.03730830177664757
#     Log2FC: 6.987087249755859
#     Family Translation elongation factor EFTu/EF1A, C-terminal
#     Mean in-family: 0.34693285822868347
#     Mean out-of-family: 0.03769078478217125
#     Log2FC: 3.2023727893829346
#     Family Translation elongation factor EFTu-like, domain 2
#     Mean in-family: 0.1320798546075821
#     Mean out-of-family: 0.03772848844528198
#     Log2FC: 1.8076841831207275
#     Family Small GTP-binding domain
#     Mean in-family: 0.28440719842910767
#     Mean out-of-family: 0.03505571931600571
#     Log2FC: 3.0202362537384033
#     Family Alpha-D-phosphohexomutase, C-terminal
#     Mean in-family: 0.15471334755420685
#     Mean out-of-family: 0.03804909065365791
#     Log2FC: 2.0236637592315674
#     Family Alpha-D-phosphohexomutase, alpha/beta/alpha domain I
#     Mean in-family: 0.1461181640625
#     Mean out-of-family: 0.03805290162563324
#     Log2FC: 1.9410572052001953
#     Family Alpha-D-phosphohexomutase, alpha/beta/alpha domain II
#     Mean in-family: 0.1643829345703125
#     Mean out-of-family: 0.03804527968168259
#     Log2FC: 2.1112711429595947
#     Family Alpha-D-phosphohexomutase, alpha/beta/alpha domain III
#     Mean in-family: 0.1643829345703125
#     Mean out-of-family: 0.03804527968168259
#     Log2FC: 2.1112711429595947
#     Family GTP binding domain
#     Mean in-family: 0.20224033296108246
#     Mean out-of-family: 0.03722432255744934
#     Log2FC: 2.441753387451172
#     Family Resolvase, N-terminal catalytic domain
#     Mean in-family: 2.091552734375
#     Mean out-of-family: 0.03742576763033867
#     Log2FC: 5.804398536682129
#     Family Resolvase, HTH domain
#     Mean in-family: 2.3385417461395264
#     Mean out-of-family: 0.037557121366262436
#     Log2FC: 5.960378646850586
#     Family Quinate/shikimate 5-dehydrogenase/glutamyl-tRNA reductase
#     Mean in-family: 0.21392716467380524
#     Mean out-of-family: 0.037912990897893906
#     Log2FC: 2.4963555335998535
#     Family Methyltransferase small domain
#     Mean in-family: 0.6884223818778992
#     Mean out-of-family: 0.03785707801580429
#     Log2FC: 4.184659004211426
#     Family Flavodoxin/nitric oxide synthase
#     Mean in-family: 0.7867431640625
#     Mean out-of-family: 0.03779805079102516
#     Log2FC: 4.379508972167969
#     Family Propeptide, carboxypeptidase Y
#     Mean in-family: 0.34980469942092896
#     Mean out-of-family: 0.0381227470934391
#     Log2FC: 3.1978256702423096
#     Family Malic enzyme, N-terminal domain
#     Mean in-family: 0.4471679627895355
#     Mean out-of-family: 0.03808378800749779
#     Log2FC: 3.553567886352539
#     Family Malic enzyme, NAD-binding
#     Mean in-family: 0.4471679627895355
#     Mean out-of-family: 0.03808378800749779
#     Log2FC: 3.553567886352539
#     Family Alpha/beta hydrolase fold-3
#     Mean in-family: 4.9095048904418945
#     Mean out-of-family: 0.037272971123456955
#     Log2FC: 7.041304111480713
#     Family Histidine biosynthesis HisG, C-terminal
#     Mean in-family: 0.9277614951133728
#     Mean out-of-family: 0.037713389843702316
#     Log2FC: 4.620604991912842
#     Family Starch synthase, catalytic domain
#     Mean in-family: 0.25614869594573975
#     Mean out-of-family: 0.03805113583803177
#     Log2FC: 2.7509701251983643
#     Family Methyltransferase small, N-terminal
#     Mean in-family: 0.6884223818778992
#     Mean out-of-family: 0.03785707801580429
#     Log2FC: 4.184659004211426
#     Family Lipase
#     Mean in-family: 0.6852925419807434
#     Mean out-of-family: 0.03798850253224373
#     Log2FC: 4.1730852127075195
#     Family ATP phosphoribosyltransferase, catalytic domain
#     Mean in-family: 0.6958211064338684
#     Mean out-of-family: 0.037720937281847
#     Log2FC: 4.2052788734436035
#     Family Glutamyl-tRNA reductase, N-terminal
#     Mean in-family: 0.3126627802848816
#     Mean out-of-family: 0.03789021819829941
#     Log2FC: 3.044710159301758
#     Family Tetrapyrrole biosynthesis, glutamyl-tRNA reductase, dimerisation domain
#     Mean in-family: 0.3126627802848816
#     Mean out-of-family: 0.03789021819829941
#     Log2FC: 3.044710159301758
#     Family S-adenosylmethionine-dependent methyltransferase
#     Mean in-family: 0.3096400499343872
#     Mean out-of-family: 0.038138821721076965
#     Log2FC: 3.0212600231170654
#     Family Tetrahydrofolate dehydrogenase/cyclohydrolase, catalytic domain
#     Mean in-family: 0.3290303349494934
#     Mean out-of-family: 0.03778142109513283
#     Log2FC: 3.122471809387207
#     Family Tetrahydrofolate dehydrogenase/cyclohydrolase, NAD(P)-binding domain
#     Mean in-family: 0.3290303349494934
#     Mean out-of-family: 0.03778142109513283
#     Log2FC: 3.122471809387207
#     Family Glyceraldehyde 3-phosphate dehydrogenase, NAD(P) binding domain
#     Mean in-family: 0.6408420205116272
#     Mean out-of-family: 0.037885647267103195
#     Log2FC: 4.080245494842529
#     Family Glyceraldehyde 3-phosphate dehydrogenase, catalytic domain
#     Mean in-family: 0.6408420205116272
#     Mean out-of-family: 0.037885647267103195
#     Log2FC: 4.080245494842529
#     Family Porphobilinogen deaminase, N-terminal
#     Mean in-family: 0.7127278447151184
#     Mean out-of-family: 0.0377749539911747
#     Log2FC: 4.237849235534668
#     Family Porphobilinogen deaminase, C-terminal
#     Mean in-family: 0.7127278447151184
#     Mean out-of-family: 0.0377749539911747
#     Log2FC: 4.237849235534668
#     Family Serine aminopeptidase, S33
#     Mean in-family: 5.759521484375
#     Mean out-of-family: 0.03595799207687378
#     Log2FC: 7.323492527008057
#     Family DNA translocase FtsK, 4TM region
#     Mean in-family: 0.1475306898355484
#     Mean out-of-family: 0.038225557655096054
#     Log2FC: 1.9484056234359741
#     Family Glycosyltransferase subfamily 4-like, N-terminal domain
#     Mean in-family: 0.6494954824447632
#     Mean out-of-family: 0.03812514990568161
#     Log2FC: 4.0905046463012695
#     Family EngB-type guanine nucleotide-binding (G) domain
#     Mean in-family: 0.5705344676971436
#     Mean out-of-family: 0.03766125813126564
#     Log2FC: 3.921160936355591
#     Family EngA-type guanine nucleotide-binding (G) domain
#     Mean in-family: 0.3259721100330353
#     Mean out-of-family: 0.037930574268102646
#     Log2FC: 3.1033153533935547
#     Family GTPase Der, C-terminal KH-domain-like
#     Mean in-family: 0.3259721100330353
#     Mean out-of-family: 0.037930574268102646
#     Log2FC: 3.1033153533935547
#     Family Elongation factor Tu, domain 2
#     Mean in-family: 0.34693285822868347
#     Mean out-of-family: 0.03769078478217125
#     Log2FC: 3.2023727893829346
#     Family Lipase, N-terminal
#     Mean in-family: 0.9137234091758728
#     Mean out-of-family: 0.037984699010849
#     Log2FC: 4.5882673263549805
#     Family Elongation factor Tu (EF-Tu), GTP-binding domain
#     Mean in-family: 0.34693285822868347
#     Mean out-of-family: 0.03769078478217125
#     Log2FC: 3.2023727893829346
#     Family RlmL, ferredoxin-like domain
#     Mean in-family: 0.3096400499343872
#     Mean out-of-family: 0.038138821721076965
#     Log2FC: 3.0212600231170654
#     Family GTP-eEF1A, C-terminal domain
#     Mean in-family: 0.23134765028953552
#     Mean out-of-family: 0.03815082088112831
#     Log2FC: 2.600276470184326
#     Family Glutamyl-tRNA reductase
#     Mean in-family: 0.3126627802848816
#     Mean out-of-family: 0.03789021819829941
#     Log2FC: 3.044710159301758
#     Family Tetrahydrofolate dehydrogenase/cyclohydrolase
#     Mean in-family: 0.3290303349494934
#     Mean out-of-family: 0.03778142109513283
#     Log2FC: 3.122471809387207
#     Family Cutinase/acetylxylan esterase
#     Mean in-family: 1.071044921875
#     Mean out-of-family: 0.03804081678390503
#     Log2FC: 4.815327167510986
#     Family Triacylglycerol lipase family
#     Mean in-family: 0.6852925419807434
#     Mean out-of-family: 0.03798850253224373
#     Log2FC: 4.1730852127075195
#     Family Porphobilinogen deaminase
#     Mean in-family: 0.7127278447151184
#     Mean out-of-family: 0.0377749539911747
#     Log2FC: 4.237849235534668
#     Family ATP phosphoribosyltransferase HisG
#     Mean in-family: 0.6958211064338684
#     Mean out-of-family: 0.037720937281847
#     Log2FC: 4.2052788734436035
#     Family Peptidase S10, serine carboxypeptidase
#     Mean in-family: 0.4322981834411621
#     Mean out-of-family: 0.037852976471185684
#     Log2FC: 3.5135481357574463
#     Family Small GTPase
#     Mean in-family: 1.01434326171875
#     Mean out-of-family: 0.036683160811662674
#     Log2FC: 4.7892842292785645
#     Family Glycosyl transferase, family 20
#     Mean in-family: 0.535400390625
#     Mean out-of-family: 0.03814796730875969
#     Log2FC: 3.8109400272369385
#     Family Malic oxidoreductase
#     Mean in-family: 0.4471679627895355
#     Mean out-of-family: 0.03808378800749779
#     Log2FC: 3.553567886352539
#     Family Phosphopantetheine adenylyltransferase
#     Mean in-family: 0.4722764790058136
#     Mean out-of-family: 0.03746476024389267
#     Log2FC: 3.6560256481170654
#     Family Lumazine/riboflavin synthase
#     Mean in-family: 0.9625244140625
#     Mean out-of-family: 0.03750740736722946
#     Log2FC: 4.681575775146484
#     Family UDPGP family
#     Mean in-family: 0.6744791269302368
#     Mean out-of-family: 0.038120146840810776
#     Log2FC: 4.145148277282715
#     Family Sugar-phosphate isomerase, RpiB/LacA/LacB family
#     Mean in-family: 1.00830078125
#     Mean out-of-family: 0.0378592424094677
#     Log2FC: 4.73513650894165
#     Family Small GTPase Rho
#     Mean in-family: 1.1951904296875
#     Mean out-of-family: 0.037784457206726074
#     Log2FC: 4.983304023742676
#     Family Translation elongation factor EFTu/EF1A, bacterial/organelle
#     Mean in-family: 0.34693285822868347
#     Mean out-of-family: 0.03769078478217125
#     Log2FC: 3.2023727893829346
#     Family Galactose-6-phosphate isomerase subunit LacB
#     Mean in-family: 1.3444010019302368
#     Mean out-of-family: 0.03785545378923416
#     Log2FC: 5.150318622589111
#     Family Alpha-D-phosphohexomutase superfamily
#     Mean in-family: 0.1643829345703125
#     Mean out-of-family: 0.03804527968168259
#     Log2FC: 2.1112711429595947
#     Family Phosphoglucosamine mutase, bacterial type
#     Mean in-family: 0.1878662109375
#     Mean out-of-family: 0.03803766146302223
#     Log2FC: 2.3042051792144775
#     Family Phosphoglycolate phosphatase
#     Mean in-family: 0.875244140625
#     Mean out-of-family: 0.038079988211393356
#     Log2FC: 4.522580623626709
#     Family Glyceraldehyde-3-phosphate dehydrogenase, type I
#     Mean in-family: 0.9612630009651184
#     Mean out-of-family: 0.037878066301345825
#     Log2FC: 4.665496826171875
#     Family Small GTPase superfamily, ARF/SAR type
#     Mean in-family: 1.54248046875
#     Mean out-of-family: 0.03764548897743225
#     Log2FC: 5.356631278991699
#     Family Uncharacterised protein family UPF0229
#     Mean in-family: 0.932373046875
#     Mean out-of-family: 0.03797909989953041
#     Log2FC: 4.617629528045654
#     Family Homoserine/serine acetyltransferase MetX-like
#     Mean in-family: 3.5375163555145264
#     Mean out-of-family: 0.036847151815891266
#     Log2FC: 6.585040092468262
#     Family TPMT family
#     Mean in-family: 0.9939778447151184
#     Mean out-of-family: 0.037960611283779144
#     Log2FC: 4.710638523101807
#     Family Uncharacterised protein family UPF0227/Esterase YqiA
#     Mean in-family: 6.7109375
#     Mean out-of-family: 0.03691261634230614
#     Log2FC: 7.506256580352783
#     Family Flavoprotein WrbA-like
#     Mean in-family: 1.44921875
#     Mean out-of-family: 0.03796516731381416
#     Log2FC: 5.254455089569092
#     Family Esterase FrsA-like
#     Mean in-family: 2.8937175273895264
#     Mean out-of-family: 0.03739052265882492
#     Log2FC: 6.274107456207275
#     Family Cutinase, monofunctional
#     Mean in-family: 1.071044921875
#     Mean out-of-family: 0.03804081678390503
#     Log2FC: 4.815327167510986
#     Family Bacterial/plant glycogen synthase
#     Mean in-family: 0.25614869594573975
#     Mean out-of-family: 0.03805113583803177
#     Log2FC: 2.7509701251983643
#     Family AB hydrolase 4 family
#     Mean in-family: 4.200439453125
#     Mean out-of-family: 0.03741481155157089
#     Log2FC: 6.810786724090576
#     Family GTPase Der
#     Mean in-family: 0.3259721100330353
#     Mean out-of-family: 0.037930574268102646
#     Log2FC: 3.1033153533935547
#     Family Ribosomal RNA large subunit methyltransferase K/L
#     Mean in-family: 0.3096400499343872
#     Mean out-of-family: 0.038138821721076965
#     Log2FC: 3.0212600231170654
#     Family GTP-binding protein, ribosome biogenesis, YsxC
#     Mean in-family: 0.5705344676971436
#     Mean out-of-family: 0.03766125813126564
#     Log2FC: 3.921160936355591
#     Family ATP phosphoribosyltransferase HisG, long form
#     Mean in-family: 0.9277614951133728
#     Mean out-of-family: 0.037713389843702316
#     Log2FC: 4.620604991912842
#     Family Glyceraldehyde/Erythrose phosphate dehydrogenase family
#     Mean in-family: 0.6408420205116272
#     Mean out-of-family: 0.037885647267103195
#     Log2FC: 4.080245494842529
#     Family Small GTPase, Ras-type
#     Mean in-family: 1.24267578125
#     Mean out-of-family: 0.0380064882338047
#     Log2FC: 5.031060218811035
#     Family Thiopurine S-methyltransferase, Se/Te detoxification
#     Mean in-family: 0.9939778447151184
#     Mean out-of-family: 0.037960611283779144
#     Log2FC: 4.710638523101807
#     Family Uncharacterised protein family UPF0227
#     Mean in-family: 6.7109375
#     Mean out-of-family: 0.03691261634230614
#     Log2FC: 7.506256580352783
#     Family rRNA small subunit methyltransferase C
#     Mean in-family: 0.6884223818778992
#     Mean out-of-family: 0.03785707801580429
#     Log2FC: 4.184659004211426
#     Family Small GTPase superfamily, ARF type
#     Mean in-family: 1.5380859375
#     Mean out-of-family: 0.0379473902285099
#     Log2FC: 5.340991497039795
#     Family Thiopurine S-methyltransferase
#     Mean in-family: 0.9939778447151184
#     Mean out-of-family: 0.037960611283779144
#     Log2FC: 4.710638523101807
#     Family Lumazine synthase
#     Mean in-family: 0.9625244140625
#     Mean out-of-family: 0.03750740736722946
#     Log2FC: 4.681575775146484
#     Family NAD(P)H dehydrogenase (quinone), prokaryotic
#     Mean in-family: 1.44921875
#     Mean out-of-family: 0.03796516731381416
#     Log2FC: 5.254455089569092
#     Family UDP-sugar pyrophosphorylase
#     Mean in-family: 0.6744791269302368
#     Mean out-of-family: 0.038120146840810776
#     Log2FC: 4.145148277282715
#     Family Esterase FrsA
#     Mean in-family: 2.8937175273895264
#     Mean out-of-family: 0.03739052265882492
#     Log2FC: 6.274107456207275
#     Family ThiF/MoeB/HesA family
#     Mean in-family: 0.71038818359375
#     Mean out-of-family: 0.03797845542430878
#     Log2FC: 4.225354194641113
#     Family Methylesterase/Alpha-hydroxynitrile lyase
#     Mean in-family: 5.14501953125
#     Mean out-of-family: 0.037225861102342606
#     Log2FC: 7.110727310180664
#     Family rRNA (guanine-N(2)-)-methyltransferase RsmC/RlmG
#     Mean in-family: 0.6884223818778992
#     Mean out-of-family: 0.03785707801580429
#     Log2FC: 4.184659004211426
#     Family Elongation factor Tu GTPase
#     Mean in-family: 0.34693285822868347
#     Mean out-of-family: 0.03769078478217125
#     Log2FC: 3.2023727893829346
#     Family Phosphoglucosamine mutase
#     Mean in-family: 0.1878662109375
#     Mean out-of-family: 0.03803766146302223
#     Log2FC: 2.3042051792144775
#     Family Translation factor GTPase superfamily members
#     Mean in-family: 0.23134765028953552
#     Mean out-of-family: 0.03815082088112831
#     Log2FC: 2.600276470184326
#     Family Zinc-containing alcohol dehydrogenase
#     Mean in-family: 0.566162109375
#     Mean out-of-family: 0.03814181312918663
#     Log2FC: 3.8917698860168457
#     Family Glycosyltransferase group 1
#     Mean in-family: 0.6494954824447632
#     Mean out-of-family: 0.03812514990568161
#     Log2FC: 4.0905046463012695
#     Family FrsA esterase
#     Mean in-family: 2.9111328125
#     Mean out-of-family: 0.037097807973623276
#     Log2FC: 6.294102668762207
#     Family AB hydrolase superfamily
#     Mean in-family: 3.77587890625
#     Mean out-of-family: 0.03749974071979523
#     Log2FC: 6.653788089752197
#     Family Serine protease S9B/DPPIV
#     Mean in-family: 2.464365005493164
#     Mean out-of-family: 0.037519365549087524
#     Log2FC: 6.037436485290527
#     Family GDXG lipolytic enzyme
#     Mean in-family: 4.4621171951293945
#     Mean out-of-family: 0.037362467497587204
#     Log2FC: 6.899994850158691
#     Family Small GTPase superfamily, Rab
#     Mean in-family: 1.294189453125
#     Mean out-of-family: 0.03799618035554886
#     Log2FC: 5.09005069732666
#     Family Type-B Carboxylesterase/Lipase
#     Mean in-family: 0.953906238079071
#     Mean out-of-family: 0.038064248859882355
#     Log2FC: 4.6473388671875
#     Family Site-specific recombinase resolvase
#     Mean in-family: 2.3385417461395264
#     Mean out-of-family: 0.037557121366262436
#     Log2FC: 5.960378646850586
#     Family AB hydrolase superfamily, subfamily 4
#     Mean in-family: 4.200439453125
#     Mean out-of-family: 0.03741481155157089
#     Log2FC: 6.810786724090576
#     Family Monoacylglycerol and Diacylglycerol Lipase
#     Mean in-family: 5.5419921875
#     Mean out-of-family: 0.03714644908905029
#     Log2FC: 7.221036434173584
#     Family Translation protein, beta-barrel domain superfamily
#     Mean in-family: 0.07112476974725723
#     Mean out-of-family: 0.03789518401026726
#     Log2FC: 0.9083375334739685
#     Family Translation elongation factor EF1A/initiation factor IF2gamma, C-terminal
#     Mean in-family: 0.3218056559562683
#     Mean out-of-family: 0.03759373351931572
#     Log2FC: 3.097625732421875
#     Family Nitrogen regulatory PII-like, alpha/beta
#     Mean in-family: 0.6185076236724854
#     Mean out-of-family: 0.03772471472620964
#     Log2FC: 4.035209655761719
#     Family Nitrogen regulatory protein PII/ATP phosphoribosyltransferase, C-terminal
#     Mean in-family: 0.5566568374633789
#     Mean out-of-family: 0.03772849217057228
#     Log2FC: 3.8830618858337402
#     Family Alpha-D-phosphohexomutase, alpha/beta/alpha I/II/III
#     Mean in-family: 0.1461181640625
#     Mean out-of-family: 0.03805290162563324
#     Log2FC: 1.9410572052001953
#     Family P-loop containing nucleoside triphosphate hydrolase
#     Mean in-family: 0.0744059830904007
#     Mean out-of-family: 0.03572545200586319
#     Log2FC: 1.0584664344787598
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 2.730806589126587
#     Mean out-of-family: 0.02117674984037876
#     Log2FC: 7.010702133178711
#     Family S-adenosyl-L-methionine-dependent methyltransferase superfamily
#     Mean in-family: 0.08907242119312286
#     Mean out-of-family: 0.0373210683465004
#     Log2FC: 1.2549885511398315
#     Family Ubiquitin-activating enzyme-like
#     Mean in-family: 0.71038818359375
#     Mean out-of-family: 0.03797845542430878
#     Log2FC: 4.225354194641113
#     Family Resolvase-like, N-terminal catalytic domain superfamily
#     Mean in-family: 2.091552734375
#     Mean out-of-family: 0.03742576763033867
#     Log2FC: 5.804398536682129
#     Family NAD(P)-binding domain superfamily
#     Mean in-family: 0.08746680617332458
#     Mean out-of-family: 0.037212178111076355
#     Log2FC: 1.2329607009887695
#     Family Glutamyl-tRNA reductase, N-terminal domain superfamily
#     Mean in-family: 0.3126627802848816
#     Mean out-of-family: 0.03789021819829941
#     Log2FC: 3.044710159301758
#     Family Glutamyl tRNA-reductase dimerization domain superfamily
#     Mean in-family: 0.22895507514476776
#     Mean out-of-family: 0.038056518882513046
#     Log2FC: 2.5888490676879883
#     Family Lumazine/riboflavin synthase superfamily
#     Mean in-family: 0.9625244140625
#     Mean out-of-family: 0.03750740736722946
#     Log2FC: 4.681575775146484
#     Family Sugar-phosphate isomerase, RpiB/LacA/LacB superfamily
#     Mean in-family: 1.00830078125
#     Mean out-of-family: 0.0378592424094677
#     Log2FC: 4.73513650894165
#     Family Porphobilinogen deaminase, C-terminal domain superfamily
#     Mean in-family: 0.7127278447151184
#     Mean out-of-family: 0.0377749539911747
#     Log2FC: 4.237849235534668
#     Family Alpha-D-phosphohexomutase, C-terminal domain superfamily
#     Mean in-family: 0.1461181640625
#     Mean out-of-family: 0.03805290162563324
#     Log2FC: 1.9410572052001953
#     Family Malic enzyme, N-terminal domain superfamily
#     Mean in-family: 0.4471679627895355
#     Mean out-of-family: 0.03808378800749779
#     Log2FC: 3.553567886352539
#     Family Aminoacid dehydrogenase-like, N-terminal domain superfamily
#     Mean in-family: 0.2586241364479065
#     Mean out-of-family: 0.037584301084280014
#     Log2FC: 2.7826547622680664
# ====================================================================================================
# 8 2677
#     Family Heat shock protein 70, conserved site
#     Mean in-family: 4.134421348571777
#     Mean out-of-family: 1.9783005714416504
#     Log2FC: 1.063423752784729
#     Family Short-chain dehydrogenase/reductase, conserved site
#     Mean in-family: 11.591758728027344
#     Mean out-of-family: 1.9664652347564697
#     Log2FC: 2.559422731399536
#     Family Alpha/beta hydrolase fold-1
#     Mean in-family: 9.378202438354492
#     Mean out-of-family: 1.9709765911102295
#     Log2FC: 2.2504007816314697
#     Family Phosphoribosyltransferase domain
#     Mean in-family: 3.0704846382141113
#     Mean out-of-family: 1.977033019065857
#     Log2FC: 0.635129451751709
#     Family Lactate/malate dehydrogenase, N-terminal
#     Mean in-family: 8.138652801513672
#     Mean out-of-family: 1.971727967262268
#     Log2FC: 2.0453293323516846
#     Family Metallo-beta-lactamase
#     Mean in-family: 6.316902160644531
#     Mean out-of-family: 1.9680421352386475
#     Log2FC: 1.682456135749817
#     Family AAA+ ATPase domain
#     Mean in-family: 1.9862903356552124
#     Mean out-of-family: 1.9827667474746704
#     Log2FC: 0.0025614702608436346
#     Family Mur ligase, C-terminal
#     Mean in-family: 7.0930352210998535
#     Mean out-of-family: 1.9700210094451904
#     Log2FC: 1.8481920957565308
#     Family Quinate/shikimate 5-dehydrogenase/glutamyl-tRNA reductase
#     Mean in-family: 9.853370666503906
#     Mean out-of-family: 1.9678457975387573
#     Log2FC: 2.324000120162964
#     Family Elp3/MiaA/NifB-like, radical SAM core domain
#     Mean in-family: 2.2586863040924072
#     Mean out-of-family: 1.981107473373413
#     Log2FC: 0.18917681276798248
#     Family Radical SAM
#     Mean in-family: 2.296903610229492
#     Mean out-of-family: 1.9806143045425415
#     Log2FC: 0.21374234557151794
#     Family Mur ligase, central
#     Mean in-family: 7.0930352210998535
#     Mean out-of-family: 1.9700210094451904
#     Log2FC: 1.8481920957565308
#     Family Thioredoxin domain
#     Mean in-family: 4.202579975128174
#     Mean out-of-family: 1.9774881601333618
#     Log2FC: 1.0876061916351318
#     Family Glutamine amidotransferase
#     Mean in-family: 4.229537010192871
#     Mean out-of-family: 1.97674560546875
#     Log2FC: 1.0973725318908691
#     Family Lactate/malate dehydrogenase, C-terminal
#     Mean in-family: 8.138652801513672
#     Mean out-of-family: 1.971727967262268
#     Log2FC: 2.0453293323516846
#     Family FAD/NAD(P)-binding domain
#     Mean in-family: 14.035085678100586
#     Mean out-of-family: 1.9647226333618164
#     Log2FC: 2.8366403579711914
#     Family MnmG, N-terminal domain
#     Mean in-family: 9.211478233337402
#     Mean out-of-family: 1.971243977546692
#     Log2FC: 2.2243263721466064
#     Family L-lactate/malate dehydrogenase
#     Mean in-family: 8.386756896972656
#     Mean out-of-family: 1.9719229936599731
#     Log2FC: 2.0885097980499268
#     Family Small ribosomal subunit protein uS11
#     Mean in-family: 3.32568359375
#     Mean out-of-family: 1.9795976877212524
#     Log2FC: 0.7484436631202698
#     Family tRNA uridine 5-carboxymethylaminomethyl modification enzyme MnmG-related
#     Mean in-family: 9.211478233337402
#     Mean out-of-family: 1.971243977546692
#     Log2FC: 2.2243263721466064
#     Family Short-chain dehydrogenase/reductase SDR
#     Mean in-family: 11.401981353759766
#     Mean out-of-family: 1.9582747220993042
#     Log2FC: 2.5416295528411865
#     Family Heat shock protein 70 family
#     Mean in-family: 4.102802753448486
#     Mean out-of-family: 1.9781540632247925
#     Log2FC: 1.052454948425293
#     Family Uracil phosphoribosyltransferase/Adenine phosphoribosyltransferase
#     Mean in-family: 3.1895909309387207
#     Mean out-of-family: 1.9796826839447021
#     Log2FC: 0.6881021857261658
#     Family 6-phosphogluconate dehydrogenase-like, C-terminal domain superfamily
#     Mean in-family: 8.2460355758667
#     Mean out-of-family: 1.9633516073226929
#     Log2FC: 2.0703821182250977
#     Family Lactate dehydrogenase/glycoside hydrolase, family 4, C-terminal
#     Mean in-family: 8.010313987731934
#     Mean out-of-family: 1.9713541269302368
#     Log2FC: 2.022671937942505
#     Family Pre-ATP-grasp domain superfamily
#     Mean in-family: 4.457016468048096
#     Mean out-of-family: 1.9773731231689453
#     Log2FC: 1.1724931001663208
#     Family P-loop containing nucleoside triphosphate hydrolase
#     Mean in-family: 2.146221876144409
#     Mean out-of-family: 1.971432089805603
#     Log2FC: 0.1225551888346672
#     Family Nucleotide-diphospho-sugar transferases
#     Mean in-family: 3.8650124073028564
#     Mean out-of-family: 1.9733699560165405
#     Log2FC: 0.9698115587234497
#     Family Heat shock protein 70kD, peptide-binding domain superfamily
#     Mean in-family: 4.134421348571777
#     Mean out-of-family: 1.9783005714416504
#     Log2FC: 1.063423752784729
#     Family Heat shock protein 70kD, C-terminal domain superfamily
#     Mean in-family: 4.1104583740234375
#     Mean out-of-family: 1.9785643815994263
#     Log2FC: 1.0548452138900757
#     Family Phosphoribosyltransferase-like
#     Mean in-family: 3.0704846382141113
#     Mean out-of-family: 1.977033019065857
#     Log2FC: 0.635129451751709
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 9.109944343566895
#     Mean out-of-family: 1.9376429319381714
#     Log2FC: 2.2331395149230957
#     Family Class I glutamine amidotransferase-like
#     Mean in-family: 4.22108268737793
#     Mean out-of-family: 1.9727106094360352
#     Log2FC: 1.0974336862564087
#     Family S-adenosyl-L-methionine-dependent methyltransferase superfamily
#     Mean in-family: 7.255128860473633
#     Mean out-of-family: 1.8867340087890625
#     Log2FC: 1.9431102275848389
#     Family FAD/NAD(P)-binding domain superfamily
#     Mean in-family: 10.539289474487305
#     Mean out-of-family: 1.9181698560714722
#     Log2FC: 2.457975149154663
#     Family Thioredoxin-like superfamily
#     Mean in-family: 3.711564779281616
#     Mean out-of-family: 1.9750137329101562
#     Log2FC: 0.9101648330688477
#     Family NAD(P)-binding domain superfamily
#     Mean in-family: 8.735453605651855
#     Mean out-of-family: 1.8407983779907227
#     Log2FC: 2.246551036834717
#     Family Mur-like, catalytic domain superfamily
#     Mean in-family: 6.949898719787598
#     Mean out-of-family: 1.969880223274231
#     Log2FC: 1.818884015083313
#     Family Mur ligase, C-terminal domain superfamily
#     Mean in-family: 6.949898719787598
#     Mean out-of-family: 1.969880223274231
#     Log2FC: 1.818884015083313
#     Family Ribonuclease Z/Hydroxyacylglutathione hydrolase-like
#     Mean in-family: 6.272021770477295
#     Mean out-of-family: 1.9677633047103882
#     Log2FC: 1.67237389087677
#     Family Small ribosomal subunit protein uS11 superfamily
#     Mean in-family: 3.32568359375
#     Mean out-of-family: 1.9795976877212524
#     Log2FC: 0.7484436631202698
#     Family ATPase, nucleotide binding domain
#     Mean in-family: 3.4580459594726562
#     Mean out-of-family: 1.968679428100586
#     Log2FC: 0.8127288222312927
#     Family Aminoacid dehydrogenase-like, N-terminal domain superfamily
#     Mean in-family: 8.176102638244629
#     Mean out-of-family: 1.9641926288604736
#     Log2FC: 2.057476758956909
# ====================================================================================================
# 8 2775
#     Family ABC transporter-like, conserved site
#     Mean in-family: 5.03361177444458
#     Mean out-of-family: 2.8674464225769043
#     Log2FC: 0.8118273615837097
#     Family Small ribosomal subunit protein uS2, conserved site
#     Mean in-family: 6.902622699737549
#     Mean out-of-family: 2.8730642795562744
#     Log2FC: 1.2645543813705444
#     Family Methylthiotransferase, conserved site
#     Mean in-family: 6.876631259918213
#     Mean out-of-family: 2.8735203742980957
#     Log2FC: 1.258882761001587
#     Family Phosphoribosyltransferase domain
#     Mean in-family: 7.596765518188477
#     Mean out-of-family: 2.85640287399292
#     Log2FC: 1.4111857414245605
#     Family Aspartate/glutamate/uridylate kinase
#     Mean in-family: 7.42474889755249
#     Mean out-of-family: 2.8655693531036377
#     Log2FC: 1.3735204935073853
#     Family Metallo-beta-lactamase
#     Mean in-family: 5.831618785858154
#     Mean out-of-family: 2.871462106704712
#     Log2FC: 1.022110939025879
#     Family Tryptophan synthase beta chain-like, PALP domain
#     Mean in-family: 8.055435180664062
#     Mean out-of-family: 2.873753786087036
#     Log2FC: 1.4870260953903198
#     Family TRAM domain
#     Mean in-family: 6.442000865936279
#     Mean out-of-family: 2.8733184337615967
#     Log2FC: 1.1647909879684448
#     Family ABC transporter-like, ATP-binding domain
#     Mean in-family: 5.0054850578308105
#     Mean out-of-family: 2.8671998977661133
#     Log2FC: 0.8038673996925354
#     Family AAA+ ATPase domain
#     Mean in-family: 4.963393211364746
#     Mean out-of-family: 2.844444751739502
#     Log2FC: 0.8031797409057617
#     Family Mur ligase, C-terminal
#     Mean in-family: 8.47465991973877
#     Mean out-of-family: 2.8675084114074707
#     Log2FC: 1.5633577108383179
#     Family Cytidyltransferase-like domain
#     Mean in-family: 8.033729553222656
#     Mean out-of-family: 2.8623924255371094
#     Log2FC: 1.488848328590393
#     Family Small GTP-binding domain
#     Mean in-family: 3.8441922664642334
#     Mean out-of-family: 2.869044542312622
#     Log2FC: 0.42211008071899414
#     Family Aspartate/ornithine carbamoyltransferase, Asp/Orn-binding domain
#     Mean in-family: 7.2439494132995605
#     Mean out-of-family: 2.8740975856781006
#     Log2FC: 1.333667516708374
#     Family Aspartate/ornithine carbamoyltransferase, carbamoyl-P binding
#     Mean in-family: 7.2439494132995605
#     Mean out-of-family: 2.8740975856781006
#     Log2FC: 1.333667516708374
#     Family Elp3/MiaA/NifB-like, radical SAM core domain
#     Mean in-family: 5.940580368041992
#     Mean out-of-family: 2.8624420166015625
#     Log2FC: 1.0533573627471924
#     Family Radical SAM
#     Mean in-family: 5.77379846572876
#     Mean out-of-family: 2.861138105392456
#     Log2FC: 1.0129315853118896
#     Family Mur ligase, central
#     Mean in-family: 8.47465991973877
#     Mean out-of-family: 2.8675084114074707
#     Log2FC: 1.5633577108383179
#     Family Thioredoxin domain
#     Mean in-family: 7.59880256652832
#     Mean out-of-family: 2.870177984237671
#     Log2FC: 1.4046318531036377
#     Family Methylthiotransferase, N-terminal
#     Mean in-family: 6.906198501586914
#     Mean out-of-family: 2.8738651275634766
#     Log2FC: 1.2648993730545044
#     Family Glutamine amidotransferase
#     Mean in-family: 6.322723388671875
#     Mean out-of-family: 2.8722097873687744
#     Log2FC: 1.1383849382400513
#     Family Small ribosomal subunit protein uS2
#     Mean in-family: 6.921075820922852
#     Mean out-of-family: 2.872619867324829
#     Log2FC: 1.2686291933059692
#     Family Phosphopantetheine adenylyltransferase
#     Mean in-family: 8.733073234558105
#     Mean out-of-family: 2.870974540710449
#     Log2FC: 1.604948878288269
#     Family RNA methyltransferase RlmH
#     Mean in-family: 7.709635257720947
#     Mean out-of-family: 2.8728201389312744
#     Log2FC: 1.4241950511932373
#     Family Methylthiotransferase
#     Mean in-family: 6.906198501586914
#     Mean out-of-family: 2.8738651275634766
#     Log2FC: 1.2648993730545044
#     Family Histidine biosynthesis protein
#     Mean in-family: 6.75653076171875
#     Mean out-of-family: 2.869086980819702
#     Log2FC: 1.235690951347351
#     Family Aspartate/ornithine carbamoyltransferase
#     Mean in-family: 7.2439494132995605
#     Mean out-of-family: 2.8740975856781006
#     Log2FC: 1.333667516708374
#     Family Histidine biosynthesis, HisA-like
#     Mean in-family: 7.104275226593018
#     Mean out-of-family: 2.8739116191864014
#     Log2FC: 1.3056716918945312
#     Family Uracil phosphoribosyltransferase/Adenine phosphoribosyltransferase
#     Mean in-family: 7.607172012329102
#     Mean out-of-family: 2.8692078590393066
#     Log2FC: 1.4067076444625854
#     Family 6-phosphogluconate dehydrogenase-like, C-terminal domain superfamily
#     Mean in-family: 6.1679792404174805
#     Mean out-of-family: 2.8713066577911377
#     Log2FC: 1.103090524673462
#     Family Ribulose-phosphate binding barrel
#     Mean in-family: 6.938671588897705
#     Mean out-of-family: 2.8504557609558105
#     Log2FC: 1.2834668159484863
#     Family Aldolase-type TIM barrel
#     Mean in-family: 6.357929229736328
#     Mean out-of-family: 2.794215440750122
#     Log2FC: 1.1861135959625244
#     Family ATP-grasp fold, subdomain 1
#     Mean in-family: 5.554652214050293
#     Mean out-of-family: 2.871868133544922
#     Log2FC: 0.9517070651054382
#     Family Rossmann-like alpha/beta/alpha sandwich fold
#     Mean in-family: 5.259191513061523
#     Mean out-of-family: 2.8178062438964844
#     Log2FC: 0.9002686142921448
#     Family Pyridoxal phosphate-dependent transferase, major domain
#     Mean in-family: 5.184420585632324
#     Mean out-of-family: 2.860377550125122
#     Log2FC: 0.8579772114753723
#     Family Pyridoxal phosphate-dependent transferase, small domain
#     Mean in-family: 5.114117622375488
#     Mean out-of-family: 2.8632946014404297
#     Log2FC: 0.8368092179298401
#     Family Pyridoxal phosphate-dependent transferase
#     Mean in-family: 5.184420585632324
#     Mean out-of-family: 2.860377550125122
#     Log2FC: 0.8579772114753723
#     Family Pyruvate/Phosphoenolpyruvate kinase-like domain superfamily
#     Mean in-family: 6.630572319030762
#     Mean out-of-family: 2.8728837966918945
#     Log2FC: 1.2066336870193481
#     Family Radical SAM, alpha/beta horseshoe
#     Mean in-family: 6.868741035461426
#     Mean out-of-family: 2.873135805130005
#     Log2FC: 1.257419466972351
#     Family Small ribosomal subunit protein uS2, flavodoxin-like domain superfamily
#     Mean in-family: 6.921075820922852
#     Mean out-of-family: 2.872619867324829
#     Log2FC: 1.2686291933059692
#     Family P-loop containing nucleoside triphosphate hydrolase
#     Mean in-family: 4.658633708953857
#     Mean out-of-family: 2.757577657699585
#     Log2FC: 0.7565054297447205
#     Family tRNA (guanine-N1-)-methyltransferase, N-terminal
#     Mean in-family: 6.572365760803223
#     Mean out-of-family: 2.8670756816864014
#     Log2FC: 1.1968327760696411
#     Family Alpha/beta knot methyltransferases
#     Mean in-family: 6.572365760803223
#     Mean out-of-family: 2.8670756816864014
#     Log2FC: 1.1968327760696411
#     Family Nucleotide-diphospho-sugar transferases
#     Mean in-family: 4.814451217651367
#     Mean out-of-family: 2.8718132972717285
#     Log2FC: 0.745409369468689
#     Family Phosphoribosyltransferase-like
#     Mean in-family: 7.596765518188477
#     Mean out-of-family: 2.85640287399292
#     Log2FC: 1.4111857414245605
#     Family Thiamin diphosphate-binding fold
#     Mean in-family: 6.761059761047363
#     Mean out-of-family: 2.8702430725097656
#     Log2FC: 1.2360765933990479
#     Family Class I glutamine amidotransferase-like
#     Mean in-family: 6.053867816925049
#     Mean out-of-family: 2.8671863079071045
#     Log2FC: 1.0782215595245361
#     Family S-adenosyl-L-methionine-dependent methyltransferase superfamily
#     Mean in-family: 5.50318717956543
#     Mean out-of-family: 2.8337433338165283
#     Log2FC: 0.957558274269104
#     Family Tryptophan synthase beta chain-like, PALP domain superfamily
#     Mean in-family: 8.055435180664062
#     Mean out-of-family: 2.873753786087036
#     Log2FC: 1.4870260953903198
#     Family Thioredoxin-like superfamily
#     Mean in-family: 6.120921611785889
#     Mean out-of-family: 2.8668832778930664
#     Log2FC: 1.0942656993865967
#     Family NAD(P)-binding domain superfamily
#     Mean in-family: 5.243727207183838
#     Mean out-of-family: 2.8318417072296143
#     Log2FC: 0.8888520002365112
#     Family Acetylglutamate kinase-like superfamily
#     Mean in-family: 7.42474889755249
#     Mean out-of-family: 2.8655693531036377
#     Log2FC: 1.3735204935073853
#     Family Mur-like, catalytic domain superfamily
#     Mean in-family: 8.441620826721191
#     Mean out-of-family: 2.867032527923584
#     Log2FC: 1.5579618215560913
#     Family Mur ligase, C-terminal domain superfamily
#     Mean in-family: 8.441620826721191
#     Mean out-of-family: 2.867032527923584
#     Log2FC: 1.5579618215560913
#     Family Ribonuclease Z/Hydroxyacylglutathione hydrolase-like
#     Mean in-family: 5.87445068359375
#     Mean out-of-family: 2.87101411819458
#     Log2FC: 1.0328935384750366
#     Family Aspartate/ornithine carbamoyltransferase superfamily
#     Mean in-family: 7.2439494132995605
#     Mean out-of-family: 2.8740975856781006
#     Log2FC: 1.333667516708374
#     Family Methylthiotransferase, N-terminal domain superfamily
#     Mean in-family: 6.906198501586914
#     Mean out-of-family: 2.8738651275634766
#     Log2FC: 1.2648993730545044
#     Family SIS domain superfamily
#     Mean in-family: 7.147165775299072
#     Mean out-of-family: 2.8704071044921875
#     Log2FC: 1.3161158561706543
# ====================================================================================================
# 8 2166
#     Family Serine/threonine-protein kinase, active site
#     Mean in-family: 1.3517621755599976
#     Mean out-of-family: 0.5172113180160522
#     Log2FC: 1.3860156536102295
#     Family ATPase, alpha/beta subunit, nucleotide-binding domain, active site
#     Mean in-family: 1.423757553100586
#     Mean out-of-family: 0.5178367495536804
#     Log2FC: 1.4591343402862549
#     Family Protein kinase, ATP binding site
#     Mean in-family: 1.2808244228363037
#     Mean out-of-family: 0.5178122520446777
#     Log2FC: 1.3065717220306396
#     Family Large ribosomal subunit protein uL3, conserved site
#     Mean in-family: 3.0605249404907227
#     Mean out-of-family: 0.5177368521690369
#     Log2FC: 2.563488245010376
#     Family Large ribosomal subunit protein uL14, conserved site
#     Mean in-family: 2.2298827171325684
#     Mean out-of-family: 0.517269492149353
#     Log2FC: 2.1079797744750977
#     Family ATPase, F1/V1/A1 complex, alpha/beta subunit, nucleotide-binding domain
#     Mean in-family: 1.423757553100586
#     Mean out-of-family: 0.5178367495536804
#     Log2FC: 1.4591343402862549
#     Family Protein kinase domain
#     Mean in-family: 1.273966670036316
#     Mean out-of-family: 0.5167807936668396
#     Log2FC: 1.3017030954360962
#     Family ATP synthase, alpha subunit, C-terminal
#     Mean in-family: 1.388952612876892
#     Mean out-of-family: 0.5194642543792725
#     Log2FC: 1.418900966644287
#     Family ATPase, F1/V1/A1 complex, alpha/beta subunit, N-terminal domain
#     Mean in-family: 1.4509449005126953
#     Mean out-of-family: 0.5178185105323792
#     Log2FC: 1.4864742755889893
#     Family Cytochrome b/b6, N-terminal domain
#     Mean in-family: 1.2392795085906982
#     Mean out-of-family: 0.5193913578987122
#     Log2FC: 1.2546076774597168
#     Family Cytochrome b/b6, C-terminal
#     Mean in-family: 1.252267837524414
#     Mean out-of-family: 0.5193523168563843
#     Log2FC: 1.269757628440857
#     Family tRNA methyltransferase TRMD/TRM10-type domain
#     Mean in-family: 1.8672637939453125
#     Mean out-of-family: 0.5193943977355957
#     Log2FC: 1.8460233211517334
#     Family ATP synthase, F1 complex, alpha subunit nucleotide-binding domain
#     Mean in-family: 1.388952612876892
#     Mean out-of-family: 0.5194642543792725
#     Log2FC: 1.418900966644287
#     Family Cytochrome b/b6, N-terminal domain, eukaryotic/bacterial
#     Mean in-family: 1.268532156944275
#     Mean out-of-family: 0.5193784832954407
#     Log2FC: 1.2883018255233765
#     Family Cytochrome b/b6, C-terminal domain, eukaryotic/bacterial
#     Mean in-family: 1.252267837524414
#     Mean out-of-family: 0.5193523168563843
#     Log2FC: 1.269757628440857
#     Family Large ribosomal subunit protein uL14
#     Mean in-family: 2.1444265842437744
#     Mean out-of-family: 0.5169942378997803
#     Log2FC: 2.0523719787597656
#     Family Large ribosomal subunit protein uL3
#     Mean in-family: 3.0121257305145264
#     Mean out-of-family: 0.5175597071647644
#     Log2FC: 2.540984869003296
#     Family tRNA (guanine-N1-)-methyltransferase TrmD
#     Mean in-family: 1.8672637939453125
#     Mean out-of-family: 0.5193943977355957
#     Log2FC: 1.8460233211517334
#     Family RNA methyltransferase RlmH
#     Mean in-family: 3.0227863788604736
#     Mean out-of-family: 0.5170406103134155
#     Log2FC: 2.547529458999634
#     Family ATP synthase, F1 complex, alpha subunit
#     Mean in-family: 1.388952612876892
#     Mean out-of-family: 0.5194642543792725
#     Log2FC: 1.418900966644287
#     Family Ribosomal protein uS12, bacterial-type
#     Mean in-family: 1.95849609375
#     Mean out-of-family: 0.5183827877044678
#     Log2FC: 1.9176565408706665
#     Family Large ribosomal subunit protein uL14, bacterial-type
#     Mean in-family: 2.1589627265930176
#     Mean out-of-family: 0.5171180963516235
#     Log2FC: 2.061772584915161
#     Family Large ribosomal subunit protein uL13
#     Mean in-family: 3.172476053237915
#     Mean out-of-family: 0.518100380897522
#     Log2FC: 2.6143057346343994
#     Family Large ribosomal subunit protein uL13, bacterial-type
#     Mean in-family: 3.172476053237915
#     Mean out-of-family: 0.518100380897522
#     Log2FC: 2.6143057346343994
#     Family Small ribosomal subunit protein uS12
#     Mean in-family: 1.791090726852417
#     Mean out-of-family: 0.5182416439056396
#     Log2FC: 1.7891415357589722
#     Family Large ribosomal subunit protein uL23-like
#     Mean in-family: 2.780707359313965
#     Mean out-of-family: 0.5174772143363953
#     Log2FC: 2.42588472366333
#     Family Large ribosomal subunit protein uL3, bacterial/organelle-type
#     Mean in-family: 3.1085286140441895
#     Mean out-of-family: 0.5176647305488586
#     Log2FC: 2.58614182472229
#     Family Large ribosomal subunit protein uL5, bacterial-type
#     Mean in-family: 2.6990017890930176
#     Mean out-of-family: 0.51762455701828
#     Log2FC: 2.3824479579925537
#     Family Translation protein SH3-like domain superfamily
#     Mean in-family: 1.1600072383880615
#     Mean out-of-family: 0.5177618265151978
#     Log2FC: 1.1637732982635498
#     Family Protein kinase-like domain superfamily
#     Mean in-family: 1.1187905073165894
#     Mean out-of-family: 0.5168559551239014
#     Log2FC: 1.1141058206558228
#     Family Nucleic acid-binding, OB-fold
#     Mean in-family: 0.8794291019439697
#     Mean out-of-family: 0.5129384994506836
#     Log2FC: 0.7777814269065857
#     Family Nucleotide-binding alpha-beta plait domain superfamily
#     Mean in-family: 1.5213758945465088
#     Mean out-of-family: 0.5168296098709106
#     Log2FC: 1.5576159954071045
#     Family Ribosomal protein uL23/eL15/eS24 core domain superfamily
#     Mean in-family: 2.684107780456543
#     Mean out-of-family: 0.5174343585968018
#     Log2FC: 2.374994993209839
#     Family Large ribosomal subunit protein uL2, domain 2
#     Mean in-family: 1.2999457120895386
#     Mean out-of-family: 0.518032431602478
#     Log2FC: 1.3273370265960693
#     Family Di-haem cytochrome, transmembrane
#     Mean in-family: 1.2392795085906982
#     Mean out-of-family: 0.5193913578987122
#     Log2FC: 1.2546076774597168
#     Family tRNA (guanine-N(1)-)-methyltransferase, C-terminal domain superfamily
#     Mean in-family: 1.8672637939453125
#     Mean out-of-family: 0.5193943977355957
#     Log2FC: 1.8460233211517334
#     Family ATP synthase subunit alpha, N-terminal domain-like superfamily
#     Mean in-family: 1.3721643686294556
#     Mean out-of-family: 0.5192481279373169
#     Log2FC: 1.4019572734832764
#     Family Cytochrome b/b6-like domain superfamily
#     Mean in-family: 1.2392795085906982
#     Mean out-of-family: 0.5193913578987122
#     Log2FC: 1.2546076774597168
#     Family P-loop containing nucleoside triphosphate hydrolase
#     Mean in-family: 0.618075430393219
#     Mean out-of-family: 0.5148186087608337
#     Log2FC: 0.2637186348438263
#     Family tRNA (guanine-N1-)-methyltransferase, N-terminal
#     Mean in-family: 2.197509765625
#     Mean out-of-family: 0.5149891972541809
# ...
#     Mean out-of-family: 0.45163363218307495
#     Log2FC: 2.5528550148010254
#     Family Triosephosphate isomerase
#     Mean in-family: 6.161783695220947
#     Mean out-of-family: 0.4467986226081848
#     Log2FC: 3.785651445388794
#     Family Large ribosomal subunit protein uL6-like
#     Mean in-family: 2.533900737762451
#     Mean out-of-family: 0.452457070350647
#     Log2FC: 2.4855072498321533
#     Family Enolase
#     Mean in-family: 1.0234607458114624
#     Mean out-of-family: 0.4541756510734558
#     Log2FC: 1.1721335649490356
#     Family L-lactate/malate dehydrogenase
#     Mean in-family: 1.1742159128189087
#     Mean out-of-family: 0.45414701104164124
#     Log2FC: 1.3704664707183838
#     Family Peptidase S10, serine carboxypeptidase
#     Mean in-family: 4.24091911315918
#     Mean out-of-family: 0.451581746339798
#     Log2FC: 3.2313179969787598
#     Family Phosphoglycerate kinase
#     Mean in-family: 3.706026554107666
#     Mean out-of-family: 0.45113974809646606
#     Log2FC: 3.038226842880249
#     Family Transaldolase/Fructose-6-phosphate aldolase
#     Mean in-family: 2.911724805831909
#     Mean out-of-family: 0.45266613364219666
#     Log2FC: 2.685354709625244
#     Family Small GTPase
#     Mean in-family: 4.126373291015625
#     Mean out-of-family: 0.4494880735874176
#     Log2FC: 3.198519468307495
#     Family Large ribosomal subunit protein uL29
#     Mean in-family: 2.8797433376312256
#     Mean out-of-family: 0.45197221636772156
#     Log2FC: 2.6716341972351074
#     Family Dehydroquinase, class II
#     Mean in-family: 3.0680043697357178
#     Mean out-of-family: 0.4524940252304077
#     Log2FC: 2.7613298892974854
#     Family Tryptophan synthase, alpha chain
#     Mean in-family: 7.285908222198486
#     Mean out-of-family: 0.4492180645465851
#     Log2FC: 4.019620895385742
#     Family UDP-glucuronosyl/UDP-glucosyltransferase
#     Mean in-family: 4.966090679168701
#     Mean out-of-family: 0.4490472078323364
#     Log2FC: 3.4671716690063477
#     Family DapA-like
#     Mean in-family: 6.103515625
#     Mean out-of-family: 0.44461917877197266
#     Log2FC: 3.778998374938965
#     Family Short-chain dehydrogenase/reductase SDR
#     Mean in-family: 1.1174441576004028
#     Mean out-of-family: 0.4536451995372772
#     Log2FC: 1.300566554069519
#     Family NAD kinase
#     Mean in-family: 2.018791913986206
#     Mean out-of-family: 0.4534927308559418
#     Log2FC: 2.1543407440185547
#     Family Biotin synthase/Biotin biosynthesis bifunctional protein BioAB
#     Mean in-family: 2.943250894546509
#     Mean out-of-family: 0.4516336917877197
#     Log2FC: 2.7041854858398438
#     Family Ribosomal RNA small subunit methyltransferase H
#     Mean in-family: 1.5611546039581299
#     Mean out-of-family: 0.4537099599838257
#     Log2FC: 1.7827712297439575
#     Family Translation elongation factor EFTu/EF1A, bacterial/organelle
#     Mean in-family: 1.6785165071487427
#     Mean out-of-family: 0.4531655013561249
#     Log2FC: 1.8890767097473145
#     Family 4-hydroxy-3-methylbut-2-en-1-yl diphosphate synthase, bacterial-type
#     Mean in-family: 2.473325729370117
#     Mean out-of-family: 0.45314890146255493
#     Log2FC: 2.448395252227783
#     Family Tetrapyrrole biosynthesis, glutamate-1-semialdehyde aminotransferase
#     Mean in-family: 1.54400634765625
#     Mean out-of-family: 0.4538448452949524
#     Log2FC: 1.7664076089859009
#     Family Histidine biosynthesis, HisF
#     Mean in-family: 8.535993576049805
#     Mean out-of-family: 0.4440423548221588
#     Log2FC: 4.264790058135986
#     Family tRNA-guanine transglycosylase
#     Mean in-family: 4.379828453063965
#     Mean out-of-family: 0.45065605640411377
#     Log2FC: 3.280775785446167
#     Family 4-hydroxy-tetrahydrodipicolinate synthase, DapA
#     Mean in-family: 6.126736164093018
#     Mean out-of-family: 0.44514426589012146
#     Log2FC: 3.782773733139038
#     Family Small ribosomal subunit protein uS15, bacterial-type
#     Mean in-family: 2.711087703704834
#     Mean out-of-family: 0.4524348974227905
#     Log2FC: 2.583089590072632
#     Family Aminotransferase class-III
#     Mean in-family: 1.5643788576126099
#     Mean out-of-family: 0.452814519405365
#     Log2FC: 1.788597822189331
#     Family Methylthiotransferase
#     Mean in-family: 1.5604312419891357
#     Mean out-of-family: 0.4532674551010132
#     Log2FC: 1.7835102081298828
#     Family Histidine biosynthesis protein
#     Mean in-family: 8.824951171875
#     Mean out-of-family: 0.42850250005722046
#     Log2FC: 4.364212989807129
#     Family HisA, bacterial
#     Mean in-family: 9.157551765441895
#     Mean out-of-family: 0.44491592049598694
#     Log2FC: 4.3633575439453125
#     Family NADH-ubiquinone oxidoreductase, 20 Kd subunit
#     Mean in-family: 3.125278949737549
#     Mean out-of-family: 0.4516279697418213
#     Log2FC: 2.790778160095215
#     Family Uroporphyrinogen decarboxylase HemE
#     Mean in-family: 4.08751106262207
#     Mean out-of-family: 0.45100733637809753
#     Log2FC: 3.179999828338623
#     Family GTP-binding protein Obg/CgtA
#     Mean in-family: 1.5133215188980103
#     Mean out-of-family: 0.4539940059185028
#     Log2FC: 1.7369734048843384
#     Family Orotidine 5'-phosphate decarboxylase
#     Mean in-family: 5.525405406951904
#     Mean out-of-family: 0.4497879445552826
#     Log2FC: 3.6187634468078613
#     Family 4-hydroxy-3-methylbut-2-en-1-yl diphosphate synthase, bacterial
#     Mean in-family: 2.473325729370117
#     Mean out-of-family: 0.45314890146255493
#     Log2FC: 2.448395252227783
#     Family GTPase Der
#     Mean in-family: 2.4222300052642822
#     Mean out-of-family: 0.4532051682472229
#     Log2FC: 2.4180996417999268
#     Family Hydroxyacylglutathione hydrolase
#     Mean in-family: 2.5722951889038086
#     Mean out-of-family: 0.4530399441719055
#     Log2FC: 2.5053460597991943
#     Family Large ribosomal subunit protein uL6, bacterial-type
#     Mean in-family: 2.573317289352417
#     Mean out-of-family: 0.4526141881942749
#     Log2FC: 2.5072755813598633
#     Family Ribulose bisphosphate carboxylase large subunit, type I
#     Mean in-family: 3.1711668968200684
#     Mean out-of-family: 0.45265260338783264
#     Log2FC: 2.808537721633911
#     Family Triosephosphate isomerase, bacterial/eukaryotic
#     Mean in-family: 6.1578545570373535
#     Mean out-of-family: 0.44737643003463745
#     Log2FC: 3.7828667163848877
#     Family HisA/PriA
#     Mean in-family: 9.203584671020508
#     Mean out-of-family: 0.44047385454177856
#     Log2FC: 4.385067462921143
#     Family Biotin synthase
#     Mean in-family: 2.943250894546509
#     Mean out-of-family: 0.4516336917877197
#     Log2FC: 2.7041854858398438
#     Family RuBisCO
#     Mean in-family: 2.9295437335968018
#     Mean out-of-family: 0.4521505534648895
#     Log2FC: 2.69580078125
#     Family Thiamine phosphate synthase
#     Mean in-family: 6.226345539093018
#     Mean out-of-family: 0.4501725435256958
#     Log2FC: 3.7898356914520264
#     Family Histidine biosynthesis, HisA-like
#     Mean in-family: 9.04969596862793
#     Mean out-of-family: 0.43987342715263367
#     Log2FC: 4.362709045410156
#     Family OBG-type GTPase
#     Mean in-family: 1.5133215188980103
#     Mean out-of-family: 0.4539940059185028
#     Log2FC: 1.7369734048843384
#     Family Indole-3-glycerol phosphate synthase
#     Mean in-family: 6.777929782867432
#     Mean out-of-family: 0.4490422010421753
#     Log2FC: 3.915921688079834
#     Family Elongation factor Tu GTPase
#     Mean in-family: 1.6785165071487427
#     Mean out-of-family: 0.4531655013561249
#     Log2FC: 1.8890767097473145
#     Family Universal ribosomal protein uL29
#     Mean in-family: 2.8797433376312256
#     Mean out-of-family: 0.45197221636772156
#     Log2FC: 2.6716341972351074
#     Family Imidazole glycerol phosphate synthase HisA/HisF
#     Mean in-family: 8.441536903381348
#     Mean out-of-family: 0.4433738887310028
#     Log2FC: 4.250909805297852
#     Family Dihydroorotate dehydrogenase
#     Mean in-family: 5.987926006317139
#     Mean out-of-family: 0.4492786228656769
#     Log2FC: 3.7363741397857666
#     Family Archaeosine Synthase Type 1/Queuine TRNA-Ribosyltransferase
#     Mean in-family: 4.379828453063965
#     Mean out-of-family: 0.45065605640411377
#     Log2FC: 3.280775785446167
#     Family Isoprenoid synthase domain superfamily
#     Mean in-family: 0.8308607935905457
#     Mean out-of-family: 0.4545809030532837
#     Log2FC: 0.870069682598114
#     Family Translation protein, beta-barrel domain superfamily
#     Mean in-family: 0.6772748827934265
#     Mean out-of-family: 0.4529937207698822
#     Log2FC: 0.5802503824234009
#     Family Translation elongation factor EF1A/initiation factor IF2gamma, C-terminal
#     Mean in-family: 1.607651948928833
#     Mean out-of-family: 0.452714741230011
#     Log2FC: 1.8282809257507324
#     Family uS15/NS1, RNA-binding domain superfamily
#     Mean in-family: 2.5029296875
#     Mean out-of-family: 0.4516788423061371
#     Log2FC: 2.4702484607696533
#     Family Dihydropteroate synthase-like superfamily
#     Mean in-family: 2.4429657459259033
#     Mean out-of-family: 0.45298317074775696
#     Log2FC: 2.4311041831970215
#     Family Ribulose-phosphate binding barrel
#     Mean in-family: 7.3291754722595215
#     Mean out-of-family: 0.40273013710975647
#     Log2FC: 4.185765743255615
#     Family Aldolase-type TIM barrel
#     Mean in-family: 5.073848247528076
#     Mean out-of-family: 0.3393765687942505
#     Log2FC: 3.9021215438842773
#     Family Pyridoxal phosphate-dependent transferase, major domain
#     Mean in-family: 1.2282105684280396
#     Mean out-of-family: 0.4482736885547638
#     Log2FC: 1.4541062116622925
#     Family Pyridoxal phosphate-dependent transferase, small domain
#     Mean in-family: 1.2358076572418213
#     Mean out-of-family: 0.44899797439575195
#     Log2FC: 1.4606733322143555
#     Family Pyridoxal phosphate-dependent transferase
#     Mean in-family: 1.2282105684280396
#     Mean out-of-family: 0.4482736885547638
#     Log2FC: 1.4541062116622925
#     Family Pyruvate/Phosphoenolpyruvate kinase-like domain superfamily
#     Mean in-family: 3.1910579204559326
#     Mean out-of-family: 0.44906455278396606
#     Log2FC: 2.829040050506592
#     Family Phosphoglycerate kinase, N-terminal
#     Mean in-family: 3.706026554107666
#     Mean out-of-family: 0.45113974809646606
#     Log2FC: 3.038226842880249
#     Family Lactate dehydrogenase/glycoside hydrolase, family 4, C-terminal
#     Mean in-family: 1.161717414855957
#     Mean out-of-family: 0.4540265202522278
#     Log2FC: 1.3554106950759888
#     Family ATP-NAD kinase, PpnK-type, C-terminal
#     Mean in-family: 2.018791913986206
#     Mean out-of-family: 0.4534927308559418
#     Log2FC: 2.1543407440185547
#     Family Glycoside hydrolase superfamily
#     Mean in-family: 2.0864226818084717
#     Mean out-of-family: 0.4470101296901703
#     Log2FC: 2.2226521968841553
#     Family S-adenosyl-L-methionine-dependent methyltransferase, MraW, recognition domain superfamily
#     Mean in-family: 1.5611546039581299
#     Mean out-of-family: 0.4537099599838257
#     Log2FC: 1.7827712297439575
#     Family Radical SAM, alpha/beta horseshoe
#     Mean in-family: 1.5354852676391602
#     Mean out-of-family: 0.4530981481075287
#     Log2FC: 1.7607991695404053
#     Family P-loop containing nucleoside triphosphate hydrolase
#     Mean in-family: 0.6139196157455444
#     Mean out-of-family: 0.44431281089782715
#     Log2FC: 0.46647408604621887
#     Family Enolase-like, N-terminal
#     Mean in-family: 1.13134765625
#     Mean out-of-family: 0.4535410702228546
#     Log2FC: 1.318737268447876
#     Family Flavoprotein-like superfamily
#     Mean in-family: 4.552018642425537
#     Mean out-of-family: 0.44962772727012634
#     Log2FC: 3.3397035598754883
#     Family Ribokinase-like
#     Mean in-family: 1.290959119796753
#     Mean out-of-family: 0.4539482295513153
#     Log2FC: 1.5078436136245728
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 3.8248589038848877
#     Mean out-of-family: 0.43400871753692627
#     Log2FC: 3.139610767364502
#     Family Class I glutamine amidotransferase-like
#     Mean in-family: 2.0915963649749756
#     Mean out-of-family: 0.4479748606681824
#     Log2FC: 2.2231147289276123
#     Family S-adenosyl-L-methionine-dependent methyltransferase superfamily
#     Mean in-family: 0.9695432186126709
#     Mean out-of-family: 0.44599974155426025
#     Log2FC: 1.1202623844146729
#     Family Metal-dependent hydrolase
#     Mean in-family: 1.534903645515442
#     Mean out-of-family: 0.4525569677352905
#     Log2FC: 1.761976718902588
#     Family EF-G domain III/V-like
#     Mean in-family: 0.8340902328491211
#     Mean out-of-family: 0.4540409445762634
#     Log2FC: 0.8773810267448425
#     Family Triosephosphate isomerase superfamily
#     Mean in-family: 6.161783695220947
#     Mean out-of-family: 0.4467986226081848
#     Log2FC: 3.785651445388794
#     Family Phosphoglycerate kinase superfamily
#     Mean in-family: 3.706026554107666
#     Mean out-of-family: 0.45113974809646606
#     Log2FC: 3.038226842880249
#     Family Large ribosomal subunit protein uL29 superfamily
#     Mean in-family: 2.8797433376312256
#     Mean out-of-family: 0.45197221636772156
#     Log2FC: 2.6716341972351074
#     Family FAD/NAD(P)-binding domain superfamily
#     Mean in-family: 0.8465721011161804
#     Mean out-of-family: 0.4524149000644684
#     Log2FC: 0.9039865136146545
#     Family Thiamin phosphate synthase superfamily
#     Mean in-family: 6.226345539093018
#     Mean out-of-family: 0.4501725435256958
#     Log2FC: 3.7898356914520264
#     Family Xylose isomerase-like superfamily
#     Mean in-family: 2.73376202583313
#     Mean out-of-family: 0.4519484341144562
#     Log2FC: 2.5966575145721436
#     Family NAD(P)-binding domain superfamily
#     Mean in-family: 0.47978878021240234
#     Mean out-of-family: 0.4548575282096863
#     Log2FC: 0.07698468863964081
#     Family Ribulose bisphosphate carboxylase, large subunit, C-terminal domain superfamily
#     Mean in-family: 3.1736724376678467
#     Mean out-of-family: 0.45210522413253784
#     Log2FC: 2.811422824859619
#     Family Winged helix-like DNA-binding domain superfamily
#     Mean in-family: 0.5938863158226013
#     Mean out-of-family: 0.4534328579902649
#     Log2FC: 0.38929787278175354
#     Family Winged helix DNA-binding domain superfamily
#     Mean in-family: 0.5699114203453064
#     Mean out-of-family: 0.45405030250549316
#     Log2FC: 0.3278855085372925
#     Family Dehydroquinase, class II superfamily
#     Mean in-family: 3.0680043697357178
#     Mean out-of-family: 0.4524940252304077
#     Log2FC: 2.7613298892974854
#     Family Queuine tRNA-ribosyltransferase-like
#     Mean in-family: 4.3313798904418945
#     Mean out-of-family: 0.45032575726509094
#     Log2FC: 3.2657859325408936
#     Family Mur-like, catalytic domain superfamily
#     Mean in-family: 0.8310660123825073
#     Mean out-of-family: 0.4543917775154114
#     Log2FC: 0.8710263967514038
#     Family Mur ligase, C-terminal domain superfamily
#     Mean in-family: 0.8310660123825073
#     Mean out-of-family: 0.4543917775154114
#     Log2FC: 0.8710263967514038
#     Family GTP1/OBG domain superfamily
#     Mean in-family: 1.5133215188980103
#     Mean out-of-family: 0.4539940059185028
#     Log2FC: 1.7369734048843384
#     Family Large ribosomal subunit protein uL6-like, alpha-beta domain superfamily
#     Mean in-family: 2.533900737762451
#     Mean out-of-family: 0.452457070350647
#     Log2FC: 2.4855072498321533
#     Family Enolase-like, C-terminal domain superfamily
#     Mean in-family: 1.13134765625
#     Mean out-of-family: 0.4535410702228546
#     Log2FC: 1.318737268447876
#     Family Ribonuclease Z/Hydroxyacylglutathione hydrolase-like
#     Mean in-family: 2.4611599445343018
#     Mean out-of-family: 0.4483262300491333
#     Log2FC: 2.4567177295684814
#     Family Uracil-DNA glycosylase-like domain superfamily
#     Mean in-family: 1.5740443468093872
#     Mean out-of-family: 0.45380276441574097
#     Log2FC: 1.7943389415740967
#     Family UROD/MetE-like superfamily
#     Mean in-family: 3.8339779376983643
#     Mean out-of-family: 0.4506343901157379
#     Log2FC: 3.0888125896453857
#     Family Methylthiotransferase, N-terminal domain superfamily
#     Mean in-family: 1.5604312419891357
#     Mean out-of-family: 0.4532674551010132
#     Log2FC: 1.7835102081298828
#     Family Pyruvate kinase-like domain superfamily
#     Mean in-family: 4.04038667678833
#     Mean out-of-family: 0.44890648126602173
#     Log2FC: 3.170006513595581

# %%
import numpy as np
import pandas as pd
import torch

EPS = 1e-9  # tiny epsilon for ratios

def as_numpy(x):
    if isinstance(x, torch.Tensor):
        return x.detach().cpu().numpy()
    return np.asarray(x)

def build_top3_table(metx_manual_latents, k=3, alpha=0.05):
    rows = []
    bonf = alpha / n_tests

    # Ensure these big tensors/arrays are NumPy
    P = as_numpy(latents_family_pvals)                   # [n_latents, n_families]
    E = as_numpy(latents_family_effect_size)             # [:, :, 0]=mean_in, [:, :, 1]=mean_out

    for layer, latents in metx_manual_latents.items():
        for lat_id in latents:
            flattened_id = to_flattened_id(int(layer), int(lat_id))
            latent_i = latent_ids_both_proteins.index(flattened_id)

            pvals    = P[latent_i, :]
            mean_in  = E[latent_i, :, 0]
            mean_out = E[latent_i, :, 1]

            # numeric hygiene
            ratio = (mean_in + EPS) / (mean_out + EPS)
            mask = np.isfinite(ratio) & (pvals < bonf) & (mean_in > mean_out)
            idx = np.where(mask)[0]
            if idx.size == 0:
                continue

            # DESC sort without [::-1] to avoid the "step must be > 0" issue
            order = np.argsort(-ratio[idx])  # minus sign = descending
            top = idx[order[:k]]

            for j in top:
                rows.append({
                    "Layer": layer,
                    "Latent": lat_id,
                    "Family_ID": int(j),
                    "Family": interpro_annotations_nonzero.iloc[int(j)]["ENTRY_NAME"], #[:30],
                    "pval": float(pvals[j]),
                    "mean_in": float(mean_in[j]),
                    "mean_out": float(mean_out[j]),
                    "ratio_in_out": float(ratio[j]),
                })

    if not rows:
        return pd.DataFrame(columns=["Layer","Latent","Family_ID","Family","pval",
                                     "mean_in","mean_out","ratio_in_out"])

    df = pd.DataFrame(rows)#.sort_values(
        # ["ratio_in_out", "pval"], ascending=[False, True], ignore_index=True
    # )
    # Nice display tweaks
    df.insert(0, "LatentID", df["Layer"].astype(str)+":"+df["Latent"].astype(str))
    df["pval_fmt"] = df["pval"].map(lambda x: f"{x:.2e}")
    df["mean_in"] = df["mean_in"].map(lambda x: round(x, 3))
    df["mean_out"] = df["mean_out"].map(lambda x: round(x, 3))
    df["ratio_in_out"] = df["ratio_in_out"].map(lambda x: round(x, 3))

    cols = ["LatentID","Family","pval_fmt","mean_in","mean_out","ratio_in_out","Family_ID"]
    return df[cols]
    return df

# run
df_top3 = build_top3_table(metx_manual_latents, k=3, alpha=0.05)
print(df_top3.head(30).to_string(index=False))
# Out:
# LatentID                                                                                    Family pval_fmt  mean_in  mean_out  ratio_in_out  Family_ID
#    8:488                                                    Uncharacterised protein family UPF0227 1.45e-14    6.711     0.037       181.806       6500
#    8:488                                      Uncharacterised protein family UPF0227/Esterase YqiA 1.45e-14    6.711     0.037       181.806       5423
#    8:488                                                                Serine aminopeptidase, S33 1.57e-27    5.760     0.036       160.174       2487
#   8:2677                                                                 FAD/NAD(P)-binding domain 2.04e-11   14.035     1.965         7.144       2515
#   8:2677                                       Short-chain dehydrogenase/reductase, conserved site 1.40e-12   11.592     1.966         5.895        536
#   8:2677                                                   Short-chain dehydrogenase/reductase SDR 2.06e-18   11.402     1.958         5.822       4311
#   8:2775                                                    Phosphopantetheine adenylyltransferase 4.63e-13    8.733     2.871         3.042       4213
#   8:2775                                                                       Mur ligase, central 3.32e-17    8.475     2.868         2.955       1983
#   8:2775                                                                    Mur ligase, C-terminal 3.32e-17    8.475     2.868         2.955       1284
#   8:2166                                      Large ribosomal subunit protein uL13, bacterial-type 3.59e-11    3.172     0.518         6.123       5008
#   8:2166                                          Large ribosomal subunit protein uL13 superfamily 3.59e-11    3.172     0.518         6.123       9565
#   8:2166                                                      Large ribosomal subunit protein uL13 3.59e-11    3.172     0.518         6.123       5007
#  12:2112                                                                 Alpha/Beta hydrolase fold 0.00e+00   11.973     0.204        58.672       9059
#  12:2112                                                               Alpha/beta hydrolase fold-1 1.16e-22   12.314     0.259        47.557        659
#  12:2112                                                    Peptidase S10, serine carboxypeptidase 1.06e-14   11.646     0.267        43.644       4096
#  12:3035                                                              PAC1/LIS1-like, WD-40 repeat 1.55e-16   10.343     0.633        16.346      10082
#  12:3035                                                               WD40 repeat, conserved site 6.12e-20   10.226     0.628        16.278        448
#  12:3035                                                                               WD40 repeat 9.26e-31    9.475     0.616        15.382      10047
#  12:3536 S-adenosyl-L-methionine-dependent methyltransferase, MraW, recognition domain superfamily 5.58e-12   12.410     1.148        10.808       8930
#  12:3536                                           Ribosomal RNA small subunit methyltransferase H 5.58e-12   12.410     1.148        10.808       4433
#  12:3536                           S-adenosyl-L-methionine-dependent methyltransferase superfamily 0.00e+00    8.075     1.039         7.770       9063
#  12:3794                                   Ribosomal RNA adenine methylase transferase, N-terminal 7.80e-12   11.245     0.846        13.296       2374
#  12:3794                                          Ribosomal RNA adenine methyltransferase KsgA/Erm 7.80e-12   11.245     0.846        13.296       4148
#  12:3794                               Ribosomal RNA adenine methylase transferase, conserved site 7.80e-12   11.245     0.846        13.296        505
#  12:1256                                       P-loop containing nucleoside triphosphate hydrolase 0.00e+00    9.336     1.221         7.645       9005
#  12:1256                                                                              Small GTPase 3.54e-12   11.940     1.734         6.886       4162
#  12:1256                                                                        GTP binding domain 2.26e-42   11.624     1.689         6.883       1458
#  12:2797                                                                                 HisA/PriA 1.43e-19    9.204     0.440        20.895       6510
#  12:2797                                                            Histidine biosynthesis protein 2.40e-35    8.825     0.429        20.595       5086
#  12:2797                                                                           HisA, bacterial 2.94e-14    9.158     0.445        20.583       5087

# %%
# Build table
df_top3 = build_top3_table(metx_manual_latents, k=3, alpha=0.05)

# ===== CSV for Google Sheets =====
csv_path = "../../data/top3_latent_domain_hits.csv"
df_top3.to_csv(csv_path, index=False)
print(f"Saved CSV -> {csv_path}")

# Quick copy/paste alternative (optional; needs clipboard support on your OS):
# df_top3.to_clipboard(index=False)

# ===== LaTeX table (with visible column boundaries) =====
# Minimal grid-style table (use \usepackage{array} in your preamble)
latex_path = "../../data/top3_latent_domain_hits.tex"
latex_tabular = df_top3[["LatentID","Family","pval_fmt","mean_in","mean_out","ratio_in_out"]].to_latex(
    index=False,
    escape=True,  # escapes underscores etc. in Family names
    column_format="|l|l|l|r|r|r|",  # vertical lines = visible boundaries
    header=["Latent","Family","p-value","Mean (in)","Mean (out)","Ratio (in/out)"]
)
# Add horizontal lines at top/bottom and between header/body
latex_tabular = latex_tabular.replace("\\toprule", "\\hline").replace("\\midrule", "\\hline").replace("\\bottomrule", "\\hline")
with open(latex_path, "w") as f:
    f.write(latex_tabular)
print(f"Saved LaTeX -> {latex_path}")
# Out:
# Saved CSV -> ../../data/top3_latent_domain_hits.csv
# Saved LaTeX -> ../../data/top3_latent_domain_hits.tex

# %%
k = 5  # Get top 5 lowest p-values
latent_i = 56
top_k_indices = np.argsort(latents_family_pvals[latent_i])[:k]
print(f"Top {k} indices with lowest p-values:", top_k_indices)
print(f"Corresponding p-values:", latents_family_pvals[latent_i][top_k_indices])
# Out:
# Top 5 indices with lowest p-values: tensor([9235, 9063, 9278, 9005, 9059])
# Corresponding p-values: tensor([0.0000e+00, 0.0000e+00, 0.0000e+00, 1.5414e-44, 1.3737e-39])

# %%
family_j = 9278
print(latents_family_effect_size[latent_i,family_j,0], latents_family_effect_size[latent_i,family_j,1])
# Out:
# tensor(8.7355) tensor(1.8408)

# %%
np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])
# Out:
# tensor(2.2466)

# %%
ann_latents_list = list(set(annotated_latents))

# %%
len(ann_latents_list)
# Out:
# 24

# %%
len(set(full_indices_metx))
# Out:
# 273

# %%
len(set(full_indices_metx).intersection(ann_latents_list))
# Out:
# 11

# %%
len(set(full_indices_top2))
# Out:
# 134

# %%
len(set(full_indices_top2).intersection(ann_latents_list))
# Out:
# 27

# %%
# For a table:
# Layer | Latent ID (#) | IntroPro ID | InterPro Name | out-of-family | in-family | Bonf p-value

# %%
metx_results_df_dict = {}
for latent_i in range(latents_family_pvals.shape[0]):
    for family_j in range(latents_family_pvals.shape[1]):
        if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
            if latents_family_effect_size[latent_i,family_j,1] != 0:
                l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/(latents_family_effect_size[latent_i,family_j,1]+0.00001))
                if l2fc >= 4:  # latents_family_effect_size[latent_i,family_j,0] > 1.05:

                    df_id = str(latent_i)+"_"+str(family_j)
                    cur_lat_id = latent_ids_both_proteins[latent_i]
                    layer_id = ((cur_lat_id // 4096)+1)*4
                    lat_id = cur_lat_id % 4096

                    case_ptn = "MetX"
                    if latent_ids_both_proteins[latent_i] in full_indices_top2:
                        case_ptn="Top2"

                    metx_results_df_dict[df_id] = {
                        "Case": case_ptn,
                        "Layer": layer_id,
                        "Latent_ID": lat_id,
                        "InterPro ID": interpro_annotations_nonzero.iloc[family_j]["ENTRY_AC"],
                        "InterPro Name": interpro_annotations_nonzero.iloc[family_j]["ENTRY_NAME"],
                        "A_in": float(latents_family_effect_size[latent_i,family_j,0]),
                        "A_out": float(latents_family_effect_size[latent_i,family_j,1]),
                        "L2FC": float(l2fc),
                        "Bonferroni adj. p-value": float(latents_family_pvals[latent_i,family_j]*n_tests)
                    }
# Out:
# /tmp/ipykernel_3056120/3099770789.py:6: RuntimeWarning: divide by zero encountered in log2
#   l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/(latents_family_effect_size[latent_i,family_j,1]+0.00001))

# %%
0.05/n_tests
# Out:
# 1.7272797218134482e-10

# %%
df_metx_results = pd.DataFrame.from_dict(metx_results_df_dict, orient='index')
df_metx_results.tail(50)
# Out:
#            Case  Layer  Latent_ID InterPro ID  \
# 177_9990   MetX     20        142   IPR045851
# 184_9052   Top2     20        659   IPR029046
# 192_21     MetX     20        878   IPR008271
# 192_126    MetX     20        878   IPR017441
# 192_767    MetX     20        878   IPR000719
# 192_8644   MetX     20        878   IPR011009
# 195_9076   MetX     20        930   IPR032675
# 195_10045  MetX     20        930   IPR001611
# 197_9559   Top2     20       1108   IPR036890
# 199_659    MetX     20       1276   IPR000073
# 199_9059   MetX     20       1276   IPR029058
# 214_669    Top2     20       1966   IPR000182
# 214_4765   Top2     20       1966   IPR004616
# 214_8834   Top2     20       1966   IPR016181
# 214_9910   Top2     20       1966   IPR042203
# 214_9912   Top2     20       1966   IPR042221
# 220_9559   Top2     20       2311   IPR036890
# 227_448    MetX     20       2500   IPR019775
# 227_8787   MetX     20       2500   IPR015943
# 227_9289   MetX     20       2500   IPR036322
# 227_10047  MetX     20       2500   IPR001680
# 227_10082  MetX     20       2500   IPR020472
# 229_659    MetX     20       2632   IPR000073
# 229_9059   MetX     20       2632   IPR029058
# 241_9076   MetX     20       3567   IPR032675
# 241_10045  MetX     20       3567   IPR001611
# 241_10056  MetX     20       3567   IPR003591
# 244_659    MetX     20       3615   IPR000073
# 244_9059   MetX     20       3615   IPR029058
# 245_659    MetX     20       3616   IPR000073
# 245_9059   MetX     20       3616   IPR029058
# 255_9559   Top2     20       3972   IPR036890
# 256_38     MetX     20       3995   IPR018202
# 256_4096   MetX     20       3995   IPR001563
# 256_8548   MetX     20       3995   IPR008210
# 256_8720   MetX     20       3995   IPR013035
# 256_9059   MetX     20       3995   IPR029058
# 261_9263   MetX     24         41   IPR036259
# 297_21     MetX     24       1822   IPR008271
# 297_126    MetX     24       1822   IPR017441
# 297_767    MetX     24       1822   IPR000719
# 297_8644   MetX     24       1822   IPR011009
# 299_9076   MetX     24       1858   IPR032675
# 299_10045  MetX     24       1858   IPR001611
# 299_10056  MetX     24       1858   IPR003591
# 315_9488   MetX     24       2398   IPR036770
# 315_10049  MetX     24       2398   IPR002110
# 322_9076   MetX     24       2632   IPR032675
# 322_10045  MetX     24       2632   IPR001611
# 347_10043  MetX     24       3707   IPR001451
#
#                                                InterPro Name       A_in  \
# 177_9990   AMP-binding enzyme, C-terminal domain superfamily  18.365587
# 184_9052             Lipoprotein localisation LolA/LolB/LppX   9.566939
# 192_21          Serine/threonine-protein kinase, active site  18.476511
# 192_126                     Protein kinase, ATP binding site  17.910606
# 192_767                                Protein kinase domain  18.215298
# 192_8644              Protein kinase-like domain superfamily  15.110942
# 195_9076              Leucine-rich repeat domain superfamily  22.808462
# 195_10045                                Leucine-rich repeat  22.871658
# 197_9559      Histidine kinase/HSP90-like ATPase superfamily  14.924856
# 199_659                          Alpha/beta hydrolase fold-1   6.300509
# 199_9059                           Alpha/Beta hydrolase fold   5.340064
# 214_669                                          GNAT domain   9.628589
# 214_4765        Leucyl/phenylalanyl-tRNA-protein transferase  12.568359
# 214_8834                          Acyl-CoA N-acyltransferase  11.163222
# 214_9910   Leucyl/phenylalanyl-tRNA-protein transferase, ...  12.568359
# 214_9912   Leucyl/phenylalanyl-tRNA-protein transferase, ...  12.524553
# 220_9559      Histidine kinase/HSP90-like ATPase superfamily  12.313361
# 227_448                          WD40 repeat, conserved site  17.588116
# 227_8787   WD40/YVTN repeat-like-containing domain superf...  17.427538
# 227_9289           WD40-repeat-containing domain superfamily  17.386154
# 227_10047                                        WD40 repeat  17.575191
# 227_10082                       PAC1/LIS1-like, WD-40 repeat  17.628004
# 229_659                          Alpha/beta hydrolase fold-1  19.105957
# 229_9059                           Alpha/Beta hydrolase fold  14.053987
# 241_9076              Leucine-rich repeat domain superfamily  24.414482
# 241_10045                                Leucine-rich repeat  23.779814
# 241_10056               Leucine-rich repeat, typical subtype  26.624117
# 244_659                          Alpha/beta hydrolase fold-1  17.210402
# 244_9059                           Alpha/Beta hydrolase fold  15.129910
# 245_659                          Alpha/beta hydrolase fold-1  14.252125
# 245_9059                           Alpha/Beta hydrolase fold  13.807409
# 255_9559      Histidine kinase/HSP90-like ATPase superfamily  12.884169
# 256_38           Serine carboxypeptidase, serine active site   9.556071
# 256_4096              Peptidase S10, serine carboxypeptidase   9.708294
# 256_8548       Phosphoenolpyruvate carboxykinase, N-terminal   4.254649
# 256_8720       Phosphoenolpyruvate carboxykinase, C-terminal   4.254649
# 256_9059                           Alpha/Beta hydrolase fold   4.593801
# 261_9263                         MFS transporter superfamily  17.502260
# 297_21          Serine/threonine-protein kinase, active site  22.696062
# 297_126                     Protein kinase, ATP binding site  22.015697
# 297_767                                Protein kinase domain  22.332542
# 297_8644              Protein kinase-like domain superfamily  18.661913
# 299_9076              Leucine-rich repeat domain superfamily  25.423765
# 299_10045                                Leucine-rich repeat  24.941114
# 299_10056               Leucine-rich repeat, typical subtype  28.223133
# 315_9488        Ankyrin repeat-containing domain superfamily  19.536869
# 315_10049                                     Ankyrin repeat  20.023464
# 322_9076              Leucine-rich repeat domain superfamily  23.370811
# 322_10045                                Leucine-rich repeat  22.555536
# 347_10043                                 Hexapeptide repeat  10.799130
#
#               A_out      L2FC  Bonferroni adj. p-value
# 177_9990   0.789571  4.539774             1.508712e-02
# 184_9052   0.450366  4.408857             1.078425e-02
# 192_21     0.629554  4.875196             7.512202e-32
# 192_126    0.637721  4.811722             1.557397e-29
# 192_767    0.611454  4.896739             0.000000e+00
# 192_8644   0.609245  4.632404             0.000000e+00
# 195_9076   1.028491  4.470954             8.131812e-11
# 195_10045  1.037083  4.462944             2.587965e-07
# 197_9559   0.686570  4.442146             2.595448e-16
# 199_659    0.346391  4.184951             4.424463e-08
# 199_9059   0.324319  4.041327             0.000000e+00
# 214_669    0.260537  5.207707             5.503000e-09
# 214_4765   0.261934  5.584395             1.015718e-03
# 214_8834   0.244482  5.512822             2.926562e-26
# 214_9910   0.261934  5.584395             1.015718e-03
# 214_9912   0.263196  5.572423             2.241299e-02
# 220_9559   0.415656  4.888655             1.326085e-15
# 227_448    0.676018  4.701374             1.241839e-13
# 227_8787   0.625911  4.799243             2.028187e-36
# 227_9289   0.651395  4.738241             5.122524e-25
# 227_10047  0.648898  4.759383             8.372437e-26
# 227_10082  0.684405  4.686854             7.844719e-10
# 229_659    0.742551  4.685369             1.291789e-04
# 229_9059   0.687725  4.352983             5.804832e-21
# 241_9076   0.652376  5.225868             4.488991e-13
# 241_10045  0.663301  5.163908             1.206944e-09
# 241_10056  0.680431  5.290121             4.518913e-03
# 244_659    0.806727  4.415039             2.156198e-04
# 244_9059   0.742331  4.349177             4.056374e-37
# 245_659    0.816588  4.125408             4.887528e-05
# 245_9059   0.755860  4.191161             0.000000e+00
# 255_9559   0.255049  5.658623             4.314035e-19
# 256_38     0.261649  5.190658             3.900829e-03
# 256_4096   0.259636  5.224600             1.132700e-05
# 256_8548   0.265095  4.004404             1.936652e-05
# 256_8720   0.265095  4.004404             1.936652e-05
# 256_9059   0.241666  4.248541             0.000000e+00
# 261_9263   1.065919  4.037357             1.382558e-26
# 297_21     1.111773  4.351495             8.653562e-28
# 297_126    1.121630  4.294851             1.020680e-25
# 297_767    1.090184  4.356490             4.178065e-35
# 297_8644   1.086926  4.101758             0.000000e+00
# 299_9076   0.892874  4.831562             2.483594e-11
# 299_10045  0.903772  4.786407             7.847721e-08
# 299_10056  0.921162  4.937264             3.435506e-02
# 315_9488   0.991314  4.300698             2.779549e-08
# 315_10049  0.992149  4.334977             1.342176e-07
# 322_9076   1.284030  4.185946             6.514982e-11
# 322_10045  1.294681  4.122801             5.670966e-06
# 347_10043  0.663827  4.023942             7.158106e-14

# %%
df_metx_results.query("Case == 'MetX' and Latent_ID != 488").head(50)#.sort_values(by="Bonferroni adj. p-value")
# Out:
#           Case  Layer  Latent_ID InterPro ID  \
# 59_376    MetX      8       3384   IPR018253
# 59_892    MetX      8       3384   IPR001305
# 59_936    MetX      8       3384   IPR001623
# 59_1129   MetX      8       3384   IPR002939
# 59_5773   MetX      8       3384   IPR012724
# 59_8573   MetX      8       3384   IPR008971
# 59_9337   MetX      8       3384   IPR036410
# 59_9543   MetX      8       3384   IPR036869
# 80_38     MetX     12       2112   IPR018202
# 80_659    MetX     12       2112   IPR000073
# 80_4096   MetX     12       2112   IPR001563
# 80_9059   MetX     12       2112   IPR029058
# 82_526    MetX     12       2302   IPR020845
# 82_797    MetX     12       2302   IPR000873
# 82_2569   MetX     12       2302   IPR025110
# 82_5515   MetX     12       2302   IPR010084
# 82_5813   MetX     12       2302   IPR013114
# 82_9068   MetX     12       2302   IPR029069
# 82_9881   MetX     12       2302   IPR042099
# 82_9990   MetX     12       2302   IPR045851
# 89_39     MetX     12       2797   IPR018204
# 89_4224   MetX     12       2797   IPR002028
# 89_4784   MetX     12       2797   IPR004651
# 89_5086   MetX     12       2797   IPR006062
# 89_5087   MetX     12       2797   IPR006063
# 89_6510   MetX     12       2797   IPR023016
# 89_7440   MetX     12       2797   IPR044524
# 89_7667   MetX     12       2797   IPR050064
# 89_8673   MetX     12       2797   IPR011060
# 91_448    MetX     12       3035   IPR019775
# 91_10082  MetX     12       3035   IPR020472
# 104_307   MetX     12       3960   IPR017972
# 104_3998  MetX     12       3960   IPR001128
# 104_4319  MetX     12       3960   IPR002401
# 104_7720  MetX     12       3960   IPR050121
# 104_9327  MetX     12       3960   IPR036396
# 106_2145  MetX     12       4044   IPR015273
# 106_2348  MetX     12       4044   IPR020058
# 106_2820  MetX     12       4044   IPR032678
# 106_2862  MetX     12       4044   IPR033708
# 106_2889  MetX     12       4044   IPR033910
# 106_2890  MetX     12       4044   IPR033911
# 106_3227  MetX     12       4044   IPR041872
# 106_3337  MetX     12       4044   IPR045462
# 106_3686  MetX     12       4044   IPR056411
# 106_3943  MetX     12       4044   IPR000924
# 106_4284  MetX     12       4044   IPR002301
# 106_4590  MetX     12       4044   IPR003815
# 106_4731  MetX     12       4044   IPR004527
# 106_5911  MetX     12       4044   IPR014758
#
#                                               InterPro Name       A_in  \
# 59_376                          DnaJ domain, conserved site   4.992561
# 59_892        Heat shock protein DnaJ, cysteine-rich domain   6.114569
# 59_936                                          DnaJ domain   4.133791
# 59_1129                          Chaperone DnaJ, C-terminal   5.792749
# 59_5773                                      Chaperone DnaJ   6.114569
# 59_8573                          HSP40/DnaJ peptide-binding   5.792749
# 59_9337   Heat shock protein DnaJ, cysteine-rich domain ...   6.114569
# 59_9543                      Chaperone J-domain superfamily   3.976351
# 80_38           Serine carboxypeptidase, serine active site  11.515869
# 80_659                          Alpha/beta hydrolase fold-1  12.313834
# 80_4096              Peptidase S10, serine carboxypeptidase  11.645741
# 80_9059                           Alpha/Beta hydrolase fold  11.973055
# 82_526                          AMP-binding, conserved site   4.837448
# 82_797               AMP-dependent synthetase/ligase domain   4.838560
# 82_2569               AMP-binding enzyme, C-terminal domain   4.955524
# 82_5515   Beta-hydroxyacyl-(acyl-carrier-protein) dehydr...  11.321875
# 82_5813   Beta-hydroxydecanoyl thiol ester dehydrase, Fa...  11.862380
# 82_9068                           HotDog domain superfamily  10.446072
# 82_9881                              ANL, N-terminal domain   4.812712
# 82_9990   AMP-binding enzyme, C-terminal domain superfamily   4.838560
# 89_39         Tryptophan synthase, alpha chain, active site   7.285908
# 89_4224                    Tryptophan synthase, alpha chain   7.285908
# 89_4784                        Histidine biosynthesis, HisF   8.535994
# 89_5086                      Histidine biosynthesis protein   8.824951
# 89_5087                                     HisA, bacterial   9.157552
# 89_6510                                           HisA/PriA   9.203585
# 89_7440                   Histidine biosynthesis, HisA-like   9.049696
# 89_7667     Imidazole glycerol phosphate synthase HisA/HisF   8.441537
# 89_8673                   Ribulose-phosphate binding barrel   7.329175
# 91_448                          WD40 repeat, conserved site  10.225831
# 91_10082                       PAC1/LIS1-like, WD-40 repeat  10.342903
# 104_307                     Cytochrome P450, conserved site  12.228394
# 104_3998                                    Cytochrome P450  12.632799
# 104_4319                  Cytochrome P450, E-class, group I  13.161021
# 104_7720                      Cytochrome P450 monooxygenase  10.063725
# 104_9327                        Cytochrome P450 superfamily  12.632799
# 106_2145          Cysteinyl-tRNA synthetase, class Ia, DALR   1.884910
# 106_2348  Glutamyl/glutaminyl-tRNA synthetase, class Ib,...   1.781835
# 106_2820         tRNA synthetases class I, catalytic domain   1.880568
# 106_2862  Isoleucyl tRNA synthetase type 1, anticodon-bi...   2.131802
# 106_2889                           Glutamyl-tRNA synthetase   1.932336
# 106_2890            Methioninyl-tRNA synthetase core domain   1.768682
# 106_3227  Methionyl-tRNA synthetase, anticodon-binding d...   1.779560
# 106_3337  Aminoacyl-tRNA synthetase, class I, anticodon-...   1.932336
# 106_3686    Cysteinyl-tRNA ligase, anticodon binding domain   1.876160
# 106_3943                Glutamyl/glutaminyl-tRNA synthetase   1.781835
# 106_4284                             Isoleucine-tRNA ligase   2.131802
# 106_4590                     S-ribosylhomocysteinase (LuxS)   1.930542
# 106_4731     Glutamate-tRNA ligase, bacterial/mitochondrial   1.932336
# 106_5911                          Methionyl-tRNA synthetase   1.768682
#
#              A_out      L2FC  Bonferroni adj. p-value
# 59_376    0.227481  4.455898             1.846045e-20
# 59_892    0.227367  4.749090             8.616593e-22
# 59_936    0.226242  4.191465             8.413398e-23
# 59_1129   0.227390  4.670943             8.346652e-20
# 59_5773   0.227367  4.749090             8.616593e-22
# 59_8573   0.227390  4.670943             8.346652e-20
# 59_9337   0.227367  4.749090             8.616593e-22
# 59_9543   0.225963  4.137222             2.916018e-25
# 80_38     0.269216  5.418662             1.379683e-03
# 80_659    0.258925  5.571544             3.343802e-14
# 80_4096   0.266834  5.447660             3.073600e-06
# 80_9059   0.204069  5.874523             0.000000e+00
# 82_526    0.210435  4.522730             2.091408e-05
# 82_797    0.209507  4.529438             1.179699e-07
# 82_2569   0.210305  4.558414             2.069738e-05
# 82_5515   0.204407  5.791451             2.301300e-04
# 82_5813   0.200364  5.887553             8.952758e-08
# 82_9068   0.197077  5.727987             2.092150e-13
# 82_9881   0.210002  4.518310             1.578390e-06
# 82_9990   0.209507  4.529438             1.179699e-07
# 89_39     0.449218  4.019589             2.267569e-02
# 89_4224   0.449218  4.019589             2.267569e-02
# 89_4784   0.444042  4.264758             7.439777e-08
# 89_5086   0.428503  4.364179             6.944129e-27
# 89_5087   0.444916  4.363325             8.514643e-06
# 89_6510   0.440474  4.385035             4.126888e-11
# 89_7440   0.439873  4.362676             3.888092e-12
# 89_7667   0.443374  4.250877             6.724912e-09
# 89_8673   0.402730  4.185730             0.000000e+00
# 91_448    0.628181  4.024872             1.771169e-11
# 91_10082  0.632732  4.030880             4.485788e-08
# 104_307   0.489067  4.644030             1.888902e-20
# 104_3998  0.482728  4.709790             1.669560e-23
# 104_4319  0.492055  4.741280             1.108502e-16
# 104_7720  0.519876  4.274826             3.931387e-02
# 104_9327  0.482728  4.709790             1.669560e-23
# 106_2145  0.110191  4.096290             5.231187e-12
# 106_2348  0.109310  4.026737             5.512194e-21
# 106_2820  0.109309  4.104549             7.181245e-20
# 106_2862  0.109894  4.277756             2.151137e-12
# 106_2889  0.110499  4.128116             6.500488e-09
# 106_2890  0.109998  4.006992             6.389857e-15
# 106_3227  0.110150  4.013846             2.211541e-13
# 106_3337  0.110499  4.128116             6.500488e-09
# 106_3686  0.110908  4.080215             1.103969e-05
# 106_3943  0.109310  4.026737             5.512194e-21
# 106_4284  0.109894  4.277756             2.151137e-12
# 106_4590  0.110865  4.122005             9.645525e-06
# 106_4731  0.110499  4.128116             6.500488e-09
# 106_5911  0.109998  4.006992             6.389857e-15

# %%
df_metx_results.query("Case == 'Top2'")#.sort_values(by="Bonferroni adj. p-value")
# Out:
#           Case  Layer  Latent ID InterPro ID  \
# 46_9135   Top2      4       3717   IPR035977
# 46_3824   Top2      4       3717   IPR000473
# 72_781    Top2     12       1204   IPR000793
# 72_672    Top2     12       1204   IPR000194
# 72_58     Top2     12       1204   IPR020003
# ...        ...    ...        ...         ...
# 214_9912  Top2     20       1966   IPR042221
# 214_1058  Top2     20       1966   IPR002500
# 84_669    Top2     12       2474   IPR000182
# 214_1909  Top2     20       1966   IPR012795
# 214_5728  Top2     20       1966   IPR012094
#
#                                               InterPro Name  \
# 46_9135    Large ribosomal subunit protein bL36 superfamily
# 46_3824                Large ribosomal subunit protein bL36
# 72_781              ATP synthase, alpha subunit, C-terminal
# 72_672    ATPase, F1/V1/A1 complex, alpha/beta subunit, ...
# 72_58     ATPase, alpha/beta subunit, nucleotide-binding...
# ...                                                     ...
# 214_9912  Leucyl/phenylalanyl-tRNA-protein transferase, ...
# 214_1058  Phosphoadenosine phosphosulphate reductase domain
# 84_669                                          GNAT domain
# 214_1909            tRNA(Ile)-lysidine synthase, N-terminal
# 214_5728                        tRNA(Ile)-lysidine synthase
#
#           Activation w/ domain  Activation w/o domain      L2FC  \
# 46_9135               0.082034               0.001080  6.234466
# 46_3824               0.082034               0.001080  6.234466
# 72_781                0.297229               0.004520  6.036056
# 72_672                0.276573               0.004105  6.070641
# 72_58                 0.276573               0.004105  6.070641
# ...                        ...                    ...       ...
# 214_9912              6.532168               0.023353  8.127212
# 214_1058              1.451269               0.026912  5.752396
# 84_669                1.381740               0.022060  5.968279
# 214_1909              0.617451               0.027496  4.488513
# 214_5728              0.617451               0.027496  4.488513
#
#           Bonferroni adj. p-value
# 46_9135                  0.000000
# 46_3824                  0.000000
# 72_781                   0.000000
# 72_672                   0.000000
# 72_58                    0.000000
# ...                           ...
# 214_9912                 0.021919
# 214_1058                 0.028800
# 84_669                   0.034206
# 214_1909                 0.042795
# 214_5728                 0.042795
#
# [218 rows x 9 columns]

# %%
df_metx_results.to_csv('circuit_domain_detectors.csv', index=False)

# %%
print(df_metx_results.query("Case == 'Top2'").drop("Case", axis=1).to_latex(
    index=False, float_format="{:.2g}".format))
# Out:
# \begin{tabular}{rrllrrr}
# \toprule
# Layer & Latent ID & InterPro ID & InterPro Name & Activation w/ domain & Activation w/o domain & Bonferroni adj. p-value \\
# \midrule
# 12 & 1204 & IPR014762 & DNA mismatch repair, conserved site & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR019805 & Heat shock protein Hsp90, conserved site & 1.5 & 0.0042 & 2.9e-13 \\
# 12 & 1204 & IPR013507 & DNA mismatch repair protein, S5 domain 2-like & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR014790 & MutL, C-terminal, dimerisation & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR020575 & Heat shock protein Hsp90, N-terminal & 1.4 & 0.0041 & 3.9e-16 \\
# 12 & 1204 & IPR001404 & Heat shock protein Hsp90 family & 1.4 & 0.0041 & 3.9e-16 \\
# 12 & 1204 & IPR002099 & DNA mismatch repair protein MutL/Mlh/PMS & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR020667 & DNA mismatch repair protein, MutL & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR038973 & DNA mismatch repair protein MutL/Mlh/Pms-like & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR037196 & HSP90, C-terminal domain & 1.2 & 0.0044 & 3e-13 \\
# 12 & 1204 & IPR037198 & MutL, C-terminal domain superfamily & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR042120 & MutL, C-terminal domain, dimerisation subdomain & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR042121 & MutL, C-terminal domain, regulatory subdomain & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1796 & IPR019805 & Heat shock protein Hsp90, conserved site & 1.6 & 0.0081 & 9e-05 \\
# 12 & 1796 & IPR003661 & Signal transduction histidine kinase, dimerisation/phosphoacceptor domain & 1.7 & 0.0082 & 0.004 \\
# 12 & 1796 & IPR004358 & Signal transduction histidine kinase-related protein, C-terminal & 1.8 & 0.008 & 8.2e-05 \\
# 12 & 1796 & IPR005467 & Histidine kinase domain & 1.8 & 0.008 & 8.2e-05 \\
# 12 & 1796 & IPR020575 & Heat shock protein Hsp90, N-terminal & 1.6 & 0.008 & 1.9e-06 \\
# 12 & 1796 & IPR001404 & Heat shock protein Hsp90 family & 1.6 & 0.008 & 1.9e-06 \\
# 12 & 1796 & IPR036097 & Signal transduction histidine kinase, dimerisation/phosphoacceptor domain superfamily & 1.8 & 0.008 & 8.2e-05 \\
# 12 & 1796 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.7 & 0.0041 & 0 \\
# 12 & 1796 & IPR037196 & HSP90, C-terminal domain & 1.3 & 0.0083 & 9.3e-05 \\
# 12 & 2474 & IPR000182 & GNAT domain & 1.4 & 0.022 & 0.034 \\
# 12 & 2474 & IPR016181 & Acyl-CoA N-acyltransferase & 1.7 & 0.02 & 3.6e-12 \\
# 16 & 737 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.8 & 0.021 & 4.6e-06 \\
# 16 & 1166 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.5 & 0.011 & 1e-20 \\
# 16 & 1280 & IPR020575 & Heat shock protein Hsp90, N-terminal & 5.7 & 0.012 & 0.017 \\
# 16 & 1280 & IPR001404 & Heat shock protein Hsp90 family & 5.7 & 0.012 & 0.017 \\
# 16 & 1280 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 3.1 & 0.007 & 1.7e-12 \\
# 20 & 659 & IPR020097 & Pseudouridine synthase I, TruA, alpha/beta domain & 1.1 & 0.028 & 5e-06 \\
# 20 & 659 & IPR001406 & Pseudouridine synthase I, TruA & 1.1 & 0.028 & 5e-06 \\
# 20 & 659 & IPR020095 & Pseudouridine synthase I, TruA, C-terminal & 1.1 & 0.028 & 5e-06 \\
# 20 & 659 & IPR029046 & Lipoprotein localisation LolA/LolB/LppX & 2.1 & 0.027 & 0.011 \\
# 20 & 865 & IPR013025 & Large ribosomal subunit protein uL23-like & 1.1 & 0.046 & 2e-05 \\
# 20 & 865 & IPR012678 & Ribosomal protein uL23/eL15/eS24 core domain superfamily & 1.1 & 0.046 & 1.6e-05 \\
# 20 & 1966 & IPR000182 & GNAT domain & 3.2 & 0.024 & 5.7e-09 \\
# 20 & 1966 & IPR002500 & Phosphoadenosine phosphosulphate reductase domain & 1.5 & 0.027 & 0.029 \\
# 20 & 1966 & IPR004616 & Leucyl/phenylalanyl-tRNA-protein transferase & 6.5 & 0.023 & 0.001 \\
# 20 & 1966 & IPR008210 & Phosphoenolpyruvate carboxykinase, N-terminal & 1.1 & 0.027 & 3.3e-06 \\
# 20 & 1966 & IPR013035 & Phosphoenolpyruvate carboxykinase, C-terminal & 1.1 & 0.027 & 3.3e-06 \\
# 20 & 1966 & IPR016181 & Acyl-CoA N-acyltransferase & 4.7 & 0.016 & 3e-26 \\
# 20 & 1966 & IPR042203 & Leucyl/phenylalanyl-tRNA-protein transferase, C-terminal & 6.5 & 0.023 & 0.001 \\
# 20 & 1966 & IPR042221 & Leucyl/phenylalanyl-tRNA-protein transferase, N-terminal & 6.5 & 0.023 & 0.022 \\
# 20 & 2311 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 2.1 & 0.016 & 1.7e-15 \\
# 20 & 3972 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 3.4 & 0.0069 & 2.5e-19 \\
# 24 & 2998 & IPR029044 & Nucleotide-diphospho-sugar transferases & 1.7 & 0.043 & 1.6e-23 \\
# \bottomrule
# \end{tabular}

# %%
print(df_metx_results.query("Case == 'MetX'").drop("Case", axis=1).to_latex(
    index=False, float_format="{:.2g}".format))
# Out:
# \begin{tabular}{rrllrrr}
# \toprule
# Layer & Latent ID & InterPro ID & InterPro Name & Activation w/ domain & Activation w/o domain & Bonferroni adj. p-value \\
# \midrule
# 16 & 1504 & IPR000073 & Alpha/beta hydrolase fold-1 & 1.3 & 0.026 & 8.7e-06 \\
# 16 & 1504 & IPR029058 & Alpha/Beta hydrolase fold & 1.3 & 0.02 & 0 \\
# 16 & 2175 & IPR029058 & Alpha/Beta hydrolase fold & 1.6 & 0.023 & 0 \\
# 16 & 2836 & IPR029058 & Alpha/Beta hydrolase fold & 1.3 & 0.045 & 3e-35 \\
# 16 & 3765 & IPR003824 & Undecaprenyl-diphosphatase UppP & 1.1 & 0.033 & 2e-06 \\
# 20 & 142 & IPR000873 & AMP-dependent synthetase/ligase domain & 2.9 & 0.044 & 0.015 \\
# 20 & 142 & IPR015590 & Aldehyde dehydrogenase domain & 2.5 & 0.043 & 1.4e-07 \\
# 20 & 142 & IPR016161 & Aldehyde/histidinol dehydrogenase & 2.5 & 0.042 & 1.7e-10 \\
# 20 & 142 & IPR016162 & Aldehyde dehydrogenase, N-terminal & 2.5 & 0.043 & 1.4e-07 \\
# 20 & 142 & IPR016163 & Aldehyde dehydrogenase, C-terminal & 2.5 & 0.043 & 1.4e-07 \\
# 20 & 142 & IPR045851 & AMP-binding enzyme, C-terminal domain superfamily & 2.9 & 0.044 & 0.015 \\
# 20 & 838 & IPR020846 & Major facilitator superfamily domain & 1.1 & 0.026 & 8.6e-19 \\
# 20 & 838 & IPR036259 & MFS transporter superfamily & 1.1 & 0.025 & 1.5e-29 \\
# 20 & 878 & IPR008271 & Serine/threonine-protein kinase, active site & 1.1 & 0.018 & 4.8e-32 \\
# 20 & 1276 & IPR029058 & Alpha/Beta hydrolase fold & 1.1 & 0.012 & 0 \\
# 20 & 2632 & IPR000073 & Alpha/beta hydrolase fold-1 & 3.3 & 0.035 & 0.00013 \\
# 20 & 2632 & IPR029058 & Alpha/Beta hydrolase fold & 2.1 & 0.027 & 6.1e-21 \\
# 20 & 3615 & IPR000073 & Alpha/beta hydrolase fold-1 & 2.3 & 0.041 & 0.00022 \\
# 20 & 3615 & IPR029058 & Alpha/Beta hydrolase fold & 2.1 & 0.031 & 4.1e-37 \\
# 20 & 3995 & IPR018202 & Serine carboxypeptidase, serine active site & 2.2 & 0.018 & 0.0041 \\
# 20 & 3995 & IPR001563 & Peptidase S10, serine carboxypeptidase & 2.4 & 0.017 & 1.2e-05 \\
# 20 & 3995 & IPR029058 & Alpha/Beta hydrolase fold & 1.1 & 0.013 & 0 \\
# 24 & 41 & IPR020846 & Major facilitator superfamily domain & 2.1 & 0.045 & 1.2e-16 \\
# 24 & 41 & IPR011701 & Major facilitator superfamily & 2 & 0.047 & 3.1e-11 \\
# 24 & 41 & IPR036259 & MFS transporter superfamily & 2.4 & 0.04 & 1.9e-26 \\
# 24 & 471 & IPR029044 & Nucleotide-diphospho-sugar transferases & 1.3 & 0.042 & 2.3e-26 \\
# 24 & 898 & IPR012338 & Beta-lactamase/transpeptidase-like & 1.6 & 0.049 & 0.00021 \\
# 24 & 1822 & IPR008271 & Serine/threonine-protein kinase, active site & 1.7 & 0.035 & 8.1e-28 \\
# 24 & 1822 & IPR017441 & Protein kinase, ATP binding site & 1.5 & 0.036 & 9.8e-26 \\
# 24 & 1822 & IPR000719 & Protein kinase domain & 1.6 & 0.034 & 4.1e-35 \\
# 24 & 1822 & IPR011009 & Protein kinase-like domain superfamily & 1.4 & 0.033 & 0 \\
# 24 & 3065 & IPR029058 & Alpha/Beta hydrolase fold & 1.4 & 0.047 & 1.7e-21 \\
# 24 & 3066 & IPR000073 & Alpha/beta hydrolase fold-1 & 1.4 & 0.032 & 0.00023 \\
# 24 & 3066 & IPR029058 & Alpha/Beta hydrolase fold & 1.7 & 0.024 & 0 \\
# 24 & 3196 & IPR033704 & dUTPase, trimeric & 1.1 & 0.037 & 0.00013 \\
# 24 & 3196 & IPR036157 & dUTPase-like superfamily & 1.1 & 0.037 & 0.00013 \\
# \bottomrule
# \end{tabular}
