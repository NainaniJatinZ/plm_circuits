# %%
import sys
import os
import json
import torch

import pandas as pd
import numpy as np

from scipy.sparse import csr_matrix, save_npz, load_npz
from scipy.stats import mannwhitneyu

# %%
interpro_annotations_nonzero = pd.read_csv("metadata/interpro_entry_list_mapping_nonzero.csv")
ptn_fam_nonzero_tensor = torch.load("metadata/ptn_fam_tensor_nonzero.pt")

latents_family_effect_size = torch.load("latents_family_effect_size_circuit.pt")
latents_family_pvals = torch.load("latents_family_pvals_circuit.pt")

# %%
print(f"Interpro Annotations: {interpro_annotations_nonzero.shape}")
print(f"ptn_fam_nonzero_tensor: {ptn_fam_nonzero_tensor.shape}")
print(f"Effect sizes: {latents_family_effect_size.shape}")
print(f"MWU pvals: {latents_family_pvals.shape}")
# Out:
# Interpro Annotations: (10096, 3)
# ptn_fam_nonzero_tensor: torch.Size([10000, 10096])
# Effect sizes: torch.Size([383, 10096, 4])
# MWU pvals: torch.Size([383, 10096])

# %%
interpro_annotations_nonzero.head()
# Out:
#     ENTRY_AC   ENTRY_TYPE                                         ENTRY_NAME
# 0  IPR000126  Active_site    Serine proteases, V8 family, serine active site
# 1  IPR000169  Active_site           Cysteine peptidase, cysteine active site
# 2  IPR000189  Active_site          Prokaryotic transglycosylase, active site
# 3  IPR001252  Active_site                  Malate dehydrogenase, active site
# 4  IPR001345  Active_site  Phosphoglycerate/bisphosphoglycerate mutase, a...

# %%
interpro_annotations_nonzero[interpro_annotations_nonzero['ENTRY_NAME'].str.contains("SAM")]
# Out:
#        ENTRY_AC              ENTRY_TYPE  \
# 324   IPR018063          Conserved_site
# 949   IPR001678                  Domain
# 1287  IPR004107                  Domain
# 1545  IPR006638                  Domain
# 1601  IPR007197                  Domain
# 2467  IPR022642                  Domain
# 2714  IPR030382                  Domain
# 3034  IPR037635                  Domain
# 3247  IPR042650                  Domain
# 3401  IPR047238                  Domain
# 3555  IPR049560                  Domain
# 4441  IPR002935                  Family
# 6704  IPR023867                  Family
# 7921  IPR050377                  Family
# 8357  IPR051631                  Family
# 8424  IPR052085                  Family
# 8494  IPR053105                  Family
# 8504  IPR053384                  Family
# 8934  IPR023404  Homologous_superfamily
#
#                                              ENTRY_NAME
# 324   SAM-dependent methyltransferase RsmI, conserve...
# 949   SAM-dependent methyltransferase RsmB-F/NOP2-ty...
# 1287                    Integrase, SAM-like, N-terminal
# 1545       Elp3/MiaA/NifB-like, radical SAM core domain
# 1601                                        Radical SAM
# 2467  MCP methyltransferase, CheR-type, SAM-binding ...
# 2714     SAM-dependent methyltransferase TRM5/TYW2-type
# 3034                                   VTS1, SAM domain
# 3247                                   ASZ1, SAM domain
# 3401  Ankyrin repeat and SAM domain-containing prote...
# 3555  SAM-dependent methyltransferase RsmB-F/NOP2-ty...
# 4441     Class I-like SAM-dependent O-methyltransferase
# 6704         Anaerobic sulphatase maturase, radical SAM
# 7921  Radical SAM PqqA peptide cyclase/Mycofactocin ...
# 8357  Ankyrin repeat and KH/SAM domain-containing pr...
# 8424         WD repeat, SAM and U-box domain-containing
# 8494  Class V-like SAM-binding domain-containing pro...
# 8504                    SAM-dependent methyltransferase
# 8934                  Radical SAM, alpha/beta horseshoe

# %%
interpro_ids_for_manual = {"top2": ["IPR001757", # HATPase
                                    "IPR006086", # XPG-I domain
                                    "IPR001752"  # Kinesin
                                   ],
                           "metx":  [
                               "IPR029058", # Alpha/Beta hydrolase fold
                               "",
                               "",
                           ]}

# %%
with open("../../jatin/plm_circuits/layer_latent_dict_metx.json", 'r') as file:
    metx_latents = json.load(file)

with open("../../jatin/plm_circuits/layer_latent_dict_top2.json", 'r') as file:
    top2_latents = json.load(file)

# %%
offsets = {k: i*4096 for i,k in enumerate(metx_latents.keys())}
full_indices_metx = [j+offsets[layer_id] for layer_id in metx_latents.keys() for j in metx_latents[layer_id]]
full_indices_top2 = [j+offsets[layer_id] for layer_id in top2_latents.keys() for j in top2_latents[layer_id]]
latent_ids_both_proteins = list(set(full_indices_top2+full_indices_metx))
latent_ids_both_proteins.sort()
len(latent_ids_both_proteins) # yes, only 383 unique
# Out:
# 383

# %%
latent_ids_both_proteins[0:10]
# Out:
# [100, 181, 237, 340, 443, 495, 527, 601, 794, 798]

# %%
n_tests = 28672*10096

# %%
n_tests
# Out:
# 289472512

# %%
np.argmin(latents_family_pvals[0])
# Out:
# tensor(8760)

# %%
annotated_latents = []
for latent_i in range(latents_family_pvals.shape[0]):
    for family_j in range(latents_family_pvals.shape[1]):
        if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
            if latents_family_effect_size[latent_i,family_j,1] < 0.05:
                l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/ (latents_family_effect_size[latent_i,family_j,1]+0.00001))
                if l2fc >= 4:  # latents_family_effect_size[latent_i,family_j,0] > 1.05: #
                    annotated_latents += [latent_ids_both_proteins[latent_i]]
                    print(f"Latent {latent_ids_both_proteins[latent_i]} is sig assoc w family {family_j}")
                    print(f"    Family {interpro_annotations_nonzero.iloc[family_j]["ENTRY_NAME"]}")
                    print(f"    Mean in-family: {latents_family_effect_size[latent_i,family_j,0]}")
                    print(f"    Mean out-of-family: {latents_family_effect_size[latent_i,family_j,1]}")
                    print(f"    Log2FC: {np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])}")
# Out:
# /tmp/ipykernel_331029/1747811902.py:6: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/ (latents_family_effect_size[latent_i,family_j,1]+0.001))
# Latent 1297 is sig assoc w family 3824
#     Family Large ribosomal subunit protein bL36
#     Mean in-family: 0.07311572134494781
#     Mean out-of-family: 0.0033203079365193844
#     Log2FC: 4.460792541503906
# Latent 1297 is sig assoc w family 9135
#     Family Large ribosomal subunit protein bL36 superfamily
#     Mean in-family: 0.07311572134494781
#     Mean out-of-family: 0.0033203079365193844
#     Log2FC: 4.460792541503906
# /tmp/ipykernel_331029/1747811902.py:13: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"    Log2FC: {np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])}")
# Latent 3717 is sig assoc w family 128
#     Family Metallothionein, vertebrate, metal binding site
#     Mean in-family: 0.04005880653858185
#     Mean out-of-family: 0.0012135858414694667
#     Log2FC: 5.044771194458008
# Latent 3717 is sig assoc w family 3724
#     Family Metallothionein, vertebrate
#     Mean in-family: 0.04005880653858185
#     Mean out-of-family: 0.0012135858414694667
#     Log2FC: 5.044771194458008
# Latent 3717 is sig assoc w family 3767
#     Family Protamine P1
#     Mean in-family: 0.04811539128422737
#     Mean out-of-family: 0.0011923930142074823
#     Log2FC: 5.334566593170166
# Latent 3717 is sig assoc w family 3824
#     Family Large ribosomal subunit protein bL36
#     Mean in-family: 0.08203448355197906
#     Mean out-of-family: 0.001079520327039063
#     Log2FC: 6.247768402099609
# Latent 3717 is sig assoc w family 8849
#     Family Metallothionein domain superfamily
#     Mean in-family: 0.04005880653858185
#     Mean out-of-family: 0.0012135858414694667
#     Log2FC: 5.044771194458008
# Latent 3717 is sig assoc w family 8947
#     Family Metallothionein domain superfamily, vertebrate
#     Mean in-family: 0.04005880653858185
#     Mean out-of-family: 0.0012135858414694667
#     Log2FC: 5.044771194458008
# Latent 3717 is sig assoc w family 9135
#     Family Large ribosomal subunit protein bL36 superfamily
#     Mean in-family: 0.08203448355197906
#     Mean out-of-family: 0.001079520327039063
#     Log2FC: 6.247768402099609
# Latent 4584 is sig assoc w family 183
#     Family AB hydrolase 4, conserved site
#     Mean in-family: 0.0477968230843544
#     Mean out-of-family: 0.0003813161456491798
#     Log2FC: 6.969783306121826
# Latent 4584 is sig assoc w family 659
#     Family Alpha/beta hydrolase fold-1
#     Mean in-family: 0.037126462906599045
#     Mean out-of-family: 0.00033192799310199916
#     Log2FC: 6.805433750152588
# Latent 4584 is sig assoc w family 904
#     Family Peptidase S9, prolyl oligopeptidase, catalytic domain
#     Mean in-family: 0.025766363367438316
#     Mean out-of-family: 0.0003806449531111866
#     Log2FC: 6.080899238586426
# Latent 4584 is sig assoc w family 1050
#     Family Dipeptidylpeptidase IV, N-terminal domain
#     Mean in-family: 0.022861696779727936
#     Mean out-of-family: 0.00038405595114454627
#     Log2FC: 5.895472049713135
# Latent 4584 is sig assoc w family 1124
#     Family Dienelactone hydrolase
#     Mean in-family: 0.061854057013988495
#     Mean out-of-family: 0.00037850416265428066
#     Log2FC: 7.352415084838867
# Latent 4584 is sig assoc w family 1945
#     Family Alpha/beta hydrolase fold-3
#     Mean in-family: 0.0684899166226387
#     Mean out-of-family: 0.0003771767078433186
#     Log2FC: 7.504507064819336
# Latent 4584 is sig assoc w family 2487
#     Family Serine aminopeptidase, S33
#     Mean in-family: 0.10242367535829544
#     Mean out-of-family: 0.0003499697777442634
#     Log2FC: 8.193102836608887
# Latent 4584 is sig assoc w family 5187
#     Family Small GTPase superfamily, ARF/SAR type
#     Mean in-family: 0.023908471688628197
#     Mean out-of-family: 0.0003813884104602039
#     Log2FC: 5.970117092132568
# Latent 4584 is sig assoc w family 5358
#     Family Homoserine/serine acetyltransferase MetX-like
#     Mean in-family: 0.03243804723024368
#     Mean out-of-family: 0.00037797525874339044
#     Log2FC: 6.423251152038574
# Latent 4584 is sig assoc w family 5423
#     Family Uncharacterised protein family UPF0227/Esterase YqiA
#     Mean in-family: 0.05371907353401184
#     Mean out-of-family: 0.000380131445126608
#     Log2FC: 7.142792224884033
# Latent 4584 is sig assoc w family 5575
#     Family Esterase FrsA-like
#     Mean in-family: 0.029372386634349823
#     Mean out-of-family: 0.0003821021819021553
#     Log2FC: 6.264358043670654
# Latent 4584 is sig assoc w family 5720
#     Family AB hydrolase 4 family
#     Mean in-family: 0.0477968230843544
#     Mean out-of-family: 0.0003813161456491798
#     Log2FC: 6.969783306121826
# Latent 4584 is sig assoc w family 6500
#     Family Uncharacterised protein family UPF0227
#     Mean in-family: 0.05371907353401184
#     Mean out-of-family: 0.000380131445126608
#     Log2FC: 7.142792224884033
# Latent 4584 is sig assoc w family 6736
#     Family Small GTPase superfamily, ARF type
#     Mean in-family: 0.025640472769737244
#     Mean out-of-family: 0.0003857483097817749
#     Log2FC: 6.054619312286377
# Latent 4584 is sig assoc w family 7398
#     Family Esterase FrsA
#     Mean in-family: 0.029372386634349823
#     Mean out-of-family: 0.0003821021819021553
#     Log2FC: 6.264358043670654
# Latent 4584 is sig assoc w family 7571
#     Family Methylesterase/Alpha-hydroxynitrile lyase
#     Mean in-family: 0.06598692387342453
#     Mean out-of-family: 0.00037767741014249623
#     Log2FC: 7.44888162612915
# Latent 4584 is sig assoc w family 7839
#     Family FrsA esterase
#     Mean in-family: 0.031198536977171898
#     Mean out-of-family: 0.00037847121711820364
#     Log2FC: 6.3651509284973145
# Latent 4584 is sig assoc w family 7843
#     Family AB hydrolase superfamily
#     Mean in-family: 0.02945972979068756
#     Mean out-of-family: 0.00038498430512845516
#     Log2FC: 6.257800579071045
# Latent 4584 is sig assoc w family 7853
#     Family Serine protease S9B/DPPIV
#     Mean in-family: 0.022861696779727936
#     Mean out-of-family: 0.00038405595114454627
#     Log2FC: 5.895472049713135
# Latent 4584 is sig assoc w family 7868
#     Family GDXG lipolytic enzyme
#     Mean in-family: 0.055552296340465546
#     Mean out-of-family: 0.00037976473686285317
#     Log2FC: 7.192596912384033
# Latent 4584 is sig assoc w family 7872
#     Family Small GTPase superfamily, Rab
#     Mean in-family: 0.023199325427412987
#     Mean out-of-family: 0.00038623667205683887
#     Log2FC: 5.908453941345215
# Latent 4584 is sig assoc w family 8192
#     Family AB hydrolase superfamily, subfamily 4
#     Mean in-family: 0.0477968230843544
#     Mean out-of-family: 0.0003813161456491798
#     Log2FC: 6.969783306121826
# Latent 4584 is sig assoc w family 8226
#     Family Monoacylglycerol and Diacylglycerol Lipase
#     Mean in-family: 0.05502624437212944
#     Mean out-of-family: 0.0003798700054176152
#     Log2FC: 7.178470134735107
# Latent 4584 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 0.03214840963482857
#     Mean out-of-family: 0.00018945785996038467
#     Log2FC: 7.406726837158203
# Latent 7480 is sig assoc w family 3767
#     Family Protamine P1
#     Mean in-family: 0.13014566898345947
#     Mean out-of-family: 0.005366102792322636
#     Log2FC: 4.600108623504639
# Latent 7480 is sig assoc w family 10065
#     Family Collagen triple helix repeat
#     Mean in-family: 0.15829811990261078
#     Mean out-of-family: 0.005361686926335096
#     Log2FC: 4.883813381195068
# Latent 8757 is sig assoc w family 41
#     Family ClpP, Ser active site
#     Mean in-family: 0.7668513059616089
#     Mean out-of-family: 0.04502340406179428
#     Log2FC: 4.090199947357178
# Latent 8757 is sig assoc w family 99
#     Family ClpP, histidine active site
#     Mean in-family: 0.7635300755500793
#     Mean out-of-family: 0.04502806439995766
#     Log2FC: 4.083788871765137
# Latent 8757 is sig assoc w family 4192
#     Family ATP-dependent Clp protease proteolytic subunit
#     Mean in-family: 0.7633147835731506
#     Mean out-of-family: 0.04488447681069374
#     Log2FC: 4.087989807128906
# Latent 8757 is sig assoc w family 6623
#     Family Clp protease proteolytic subunit /Translocation-enhancing protein TepA
#     Mean in-family: 0.7633147835731506
#     Mean out-of-family: 0.04488447681069374
#     Log2FC: 4.087989807128906
# Latent 8757 is sig assoc w family 8847
#     Family Alkaline-phosphatase-like, core domain superfamily
#     Mean in-family: 0.7370474338531494
#     Mean out-of-family: 0.04499588534235954
#     Log2FC: 4.033892631530762
# Latent 8757 is sig assoc w family 9051
#     Family ClpP/crotonase-like domain superfamily
#     Mean in-family: 0.8375989198684692
#     Mean out-of-family: 0.04293477535247803
#     Log2FC: 4.286041259765625
# /tmp/ipykernel_331029/1747811902.py:6: RuntimeWarning: divide by zero encountered in log2
#   l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/ (latents_family_effect_size[latent_i,family_j,1]+0.001))
# Latent 9274 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 0.12935441732406616
#     Mean out-of-family: 0.00605860585346818
#     Log2FC: 4.416199684143066
# Latent 9313 is sig assoc w family 536
#     Family Short-chain dehydrogenase/reductase, conserved site
#     Mean in-family: 0.7055881023406982
#     Mean out-of-family: 0.035321809351444244
#     Log2FC: 4.320195198059082
# Latent 9313 is sig assoc w family 4311
#     Family Short-chain dehydrogenase/reductase SDR
#     Mean in-family: 0.6978220343589783
#     Mean out-of-family: 0.0347372405230999
#     Log2FC: 4.328303813934326
# Latent 9396 is sig assoc w family 58
#     Family ATPase, alpha/beta subunit, nucleotide-binding domain, active site
#     Mean in-family: 0.2765734791755676
#     Mean out-of-family: 0.004104959778487682
#     Log2FC: 6.074151039123535
# Latent 9396 is sig assoc w family 274
#     Family DNA mismatch repair, conserved site
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 457
#     Family Heat shock protein Hsp90, conserved site
#     Mean in-family: 1.4559404850006104
#     Mean out-of-family: 0.00420586671680212
#     Log2FC: 8.435332298278809
# Latent 9396 is sig assoc w family 499
#     Family DNA recombination/repair protein RecA, conserved site
#     Mean in-family: 0.2642000913619995
#     Mean out-of-family: 0.004962843842804432
#     Log2FC: 5.734320163726807
# Latent 9396 is sig assoc w family 672
#     Family ATPase, F1/V1/A1 complex, alpha/beta subunit, nucleotide-binding domain
#     Mean in-family: 0.2765734791755676
#     Mean out-of-family: 0.004104959778487682
#     Log2FC: 6.074151039123535
# Latent 9396 is sig assoc w family 780
#     Family Transcription regulator LuxR, C-terminal
#     Mean in-family: 0.10673874616622925
#     Mean out-of-family: 0.005150969140231609
#     Log2FC: 4.373096466064453
# Latent 9396 is sig assoc w family 781
#     Family ATP synthase, alpha subunit, C-terminal
#     Mean in-family: 0.29722923040390015
#     Mean out-of-family: 0.004519577603787184
#     Log2FC: 6.039244174957275
# Latent 9396 is sig assoc w family 1283
#     Family ATPase, F1/V1/A1 complex, alpha/beta subunit, N-terminal domain
#     Mean in-family: 0.2754667401313782
#     Mean out-of-family: 0.00413676118478179
#     Log2FC: 6.057232856750488
# Latent 9396 is sig assoc w family 2000
#     Family DNA mismatch repair protein, S5 domain 2-like
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 2113
#     Family MutL, C-terminal, dimerisation
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 2370
#     Family Heat shock protein Hsp90, N-terminal
#     Mean in-family: 1.4246454238891602
#     Mean out-of-family: 0.004085632972419262
#     Log2FC: 8.44582748413086
# Latent 9396 is sig assoc w family 2372
#     Family DNA recombination and repair protein RecA, monomer-monomer interface
#     Mean in-family: 0.23690299689769745
#     Mean out-of-family: 0.0048972731456160545
#     Log2FC: 5.5961737632751465
# Latent 9396 is sig assoc w family 2373
#     Family DNA recombination and repair protein RecA-like, ATP-binding domain
#     Mean in-family: 0.21057526767253876
#     Mean out-of-family: 0.004892989061772823
#     Log2FC: 5.427475929260254
# Latent 9396 is sig assoc w family 2871
#     Family ATP synthase, F1 complex, alpha subunit nucleotide-binding domain
#     Mean in-family: 0.29722923040390015
#     Mean out-of-family: 0.004519577603787184
#     Log2FC: 6.039244174957275
# Latent 9396 is sig assoc w family 3527
#     Family RecA-like, C-terminal
#     Mean in-family: 0.2711515426635742
#     Mean out-of-family: 0.004902581684291363
#     Log2FC: 5.789413928985596
# Latent 9396 is sig assoc w family 3545
#     Family RecA-like, N-terminal
#     Mean in-family: 0.2711515426635742
#     Mean out-of-family: 0.004902581684291363
#     Log2FC: 5.789413928985596
# Latent 9396 is sig assoc w family 3639
#     Family ATP synthase A/B type, C-terminal domain
#     Mean in-family: 0.24741239845752716
#     Mean out-of-family: 0.004809655714780092
#     Log2FC: 5.684840202331543
# Latent 9396 is sig assoc w family 4065
#     Family Heat shock protein Hsp90 family
#     Mean in-family: 1.4246454238891602
#     Mean out-of-family: 0.004085632972419262
#     Log2FC: 8.44582748413086
# Latent 9396 is sig assoc w family 4238
#     Family DNA mismatch repair protein MutL/Mlh/PMS
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 4895
#     Family ATP synthase, F1 complex, alpha subunit
#     Mean in-family: 0.29722923040390015
#     Mean out-of-family: 0.004519577603787184
#     Log2FC: 6.039244174957275
# Latent 9396 is sig assoc w family 4971
#     Family ATP synthase, F1 complex, beta subunit
#     Mean in-family: 0.23636092245578766
#     Mean out-of-family: 0.004921209067106247
#     Log2FC: 5.585834980010986
# Latent 9396 is sig assoc w family 5846
#     Family DNA recombination and repair protein RecA
#     Mean in-family: 0.2711515426635742
#     Mean out-of-family: 0.004902581684291363
#     Log2FC: 5.789413928985596
# Latent 9396 is sig assoc w family 6308
#     Family DNA mismatch repair protein, MutL
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 7213
#     Family DNA mismatch repair protein MutL/Mlh/Pms-like
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 7656
#     Family ATPase alpha/beta chains
#     Mean in-family: 0.23636092245578766
#     Mean out-of-family: 0.004921209067106247
#     Log2FC: 5.585834980010986
# Latent 9396 is sig assoc w family 8756
#     Family Small ribosomal subunit protein uS5 domain 2-type fold, subgroup
#     Mean in-family: 0.1322544366121292
#     Mean out-of-family: 0.004068406764417887
#     Log2FC: 5.022708415985107
# Latent 9396 is sig assoc w family 8865
#     Family Ribosomal protein uS5 domain 2-type superfamily
#     Mean in-family: 0.15220856666564941
#     Mean out-of-family: 0.0031955030281096697
#     Log2FC: 5.573862552642822
# Latent 9396 is sig assoc w family 8921
#     Family ATP synthase subunit alpha, N-terminal domain-like superfamily
#     Mean in-family: 0.2805522084236145
#     Mean out-of-family: 0.004476677160710096
#     Log2FC: 5.969696998596191
# Latent 9396 is sig assoc w family 8932
#     Family DNA recombination and repair protein RecA, C-terminal, superfamily
#     Mean in-family: 0.2711515426635742
#     Mean out-of-family: 0.004902581684291363
#     Log2FC: 5.789413928985596
# Latent 9396 is sig assoc w family 8958
#     Family ATPase, F1/V1 complex, beta/alpha subunit, C-terminal
#     Mean in-family: 0.234273299574852
#     Mean out-of-family: 0.0048779877834022045
#     Log2FC: 5.5857625007629395
# Latent 9396 is sig assoc w family 9204
#     Family ATPase, F1/V1/A1 complex, alpha/beta subunit, N-terminal domain superfamily
#     Mean in-family: 0.27175676822662354
#     Mean out-of-family: 0.004205385688692331
#     Log2FC: 6.013934135437012
# Latent 9396 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 0.8115893602371216
#     Mean out-of-family: 0.002714569214731455
#     Log2FC: 8.223882675170898
# Latent 9396 is sig assoc w family 9682
#     Family HSP90, C-terminal domain
#     Mean in-family: 1.2057727575302124
#     Mean out-of-family: 0.004381106235086918
#     Log2FC: 8.104447364807129
# Latent 9396 is sig assoc w family 9684
#     Family MutL, C-terminal domain superfamily
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 9784
#     Family ATP synthase, alpha subunit, C-terminal domain superfamily
#     Mean in-family: 0.29722923040390015
#     Mean out-of-family: 0.004519577603787184
#     Log2FC: 6.039244174957275
# Latent 9396 is sig assoc w family 9897
#     Family MutL, C-terminal domain, dimerisation subdomain
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 9898
#     Family MutL, C-terminal domain, regulatory subdomain
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9988 is sig assoc w family 457
#     Family Heat shock protein Hsp90, conserved site
#     Mean in-family: 1.5989656448364258
#     Mean out-of-family: 0.008104116655886173
#     Log2FC: 7.624268054962158
# Latent 9988 is sig assoc w family 669
#     Family GNAT domain
#     Mean in-family: 0.4696122407913208
#     Mean out-of-family: 0.00866458285599947
#     Log2FC: 5.760195732116699
# Latent 9988 is sig assoc w family 1229
#     Family Signal transduction histidine kinase, dimerisation/phosphoacceptor domain
#     Mean in-family: 1.7447575330734253
#     Mean out-of-family: 0.008175770752131939
#     Log2FC: 7.737456321716309
# Latent 9988 is sig assoc w family 1324
#     Family Signal transduction histidine kinase-related protein, C-terminal
#     Mean in-family: 1.785921335220337
#     Mean out-of-family: 0.007973155938088894
#     Log2FC: 7.807301998138428
# Latent 9988 is sig assoc w family 1401
#     Family Histidine kinase domain
#     Mean in-family: 1.785921335220337
#     Mean out-of-family: 0.007973155938088894
#     Log2FC: 7.807301998138428
# Latent 9988 is sig assoc w family 2370
#     Family Heat shock protein Hsp90, N-terminal
#     Mean in-family: 1.5625734329223633
#     Mean out-of-family: 0.007974040694534779
#     Log2FC: 7.6143975257873535
# Latent 9988 is sig assoc w family 4065
#     Family Heat shock protein Hsp90 family
#     Mean in-family: 1.5625734329223633
#     Mean out-of-family: 0.007974040694534779
#     Log2FC: 7.6143975257873535
# Latent 9988 is sig assoc w family 4765
#     Family Leucyl/phenylalanyl-tRNA-protein transferase
#     Mean in-family: 0.21765664219856262
#     Mean out-of-family: 0.00905083492398262
#     Log2FC: 4.587859153747559
# Latent 9988 is sig assoc w family 4991
#     Family Uracil phosphoribosyl transferase
#     Mean in-family: 0.3435714542865753
#     Mean out-of-family: 0.008748967200517654
#     Log2FC: 5.295353412628174
# Latent 9988 is sig assoc w family 7126
#     Family Uracil phosphoribosyltransferase, bacterial-type
#     Mean in-family: 0.3435714542865753
#     Mean out-of-family: 0.008748967200517654
#     Log2FC: 5.295353412628174
# Latent 9988 is sig assoc w family 7657
#     Family Uracil phosphoribosyltransferase/Adenine phosphoribosyltransferase
#     Mean in-family: 0.2080070972442627
#     Mean out-of-family: 0.00869951955974102
#     Log2FC: 4.579553127288818
# Latent 9988 is sig assoc w family 8834
#     Family Acyl-CoA N-acyltransferase
#     Mean in-family: 0.3485409617424011
#     Mean out-of-family: 0.008367285132408142
#     Log2FC: 5.380424976348877
# Latent 9988 is sig assoc w family 9193
#     Family Signal transduction histidine kinase, dimerisation/phosphoacceptor domain superfamily
#     Mean in-family: 1.785921335220337
#     Mean out-of-family: 0.007973155938088894
#     Log2FC: 7.807301998138428
# Latent 9988 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 1.6556663513183594
#     Mean out-of-family: 0.004097857512533665
#     Log2FC: 8.658326148986816
# Latent 9988 is sig assoc w family 9682
#     Family HSP90, C-terminal domain
#     Mean in-family: 1.2926454544067383
#     Mean out-of-family: 0.00831869151443243
#     Log2FC: 7.279754161834717
# Latent 9988 is sig assoc w family 9910
#     Family Leucyl/phenylalanyl-tRNA-protein transferase, C-terminal
#     Mean in-family: 0.21765664219856262
#     Mean out-of-family: 0.00905083492398262
#     Log2FC: 4.587859153747559
# Latent 9988 is sig assoc w family 9912
#     Family Leucyl/phenylalanyl-tRNA-protein transferase, N-terminal
#     Mean in-family: 0.21809335052967072
#     Mean out-of-family: 0.009071404114365578
#     Log2FC: 4.5874762535095215
# Latent 10304 is sig assoc w family 38
#     Family Serine carboxypeptidase, serine active site
#     Mean in-family: 0.4119054675102234
#     Mean out-of-family: 0.008394940756261349
#     Log2FC: 5.616649150848389
# Latent 10304 is sig assoc w family 338
#     Family Translation elongation factor Ts, conserved site
#     Mean in-family: 0.24861522018909454
#     Mean out-of-family: 0.00838142167776823
#     Log2FC: 4.890575885772705
# Latent 10304 is sig assoc w family 492
#     Family Amidase, conserved site
#     Mean in-family: 0.17381229996681213
#     Mean out-of-family: 0.008453174494206905
#     Log2FC: 4.361893177032471
# Latent 10304 is sig assoc w family 659
#     Family Alpha/beta hydrolase fold-1
#     Mean in-family: 0.6045286059379578
#     Mean out-of-family: 0.007762924302369356
#     Log2FC: 6.283066749572754
# Latent 10304 is sig assoc w family 2100
#     Family Translation elongation factor EFTs/EF1B, dimerisation
#     Mean in-family: 0.23409047722816467
#     Mean out-of-family: 0.00837918184697628
#     Log2FC: 4.804112911224365
# Latent 10304 is sig assoc w family 2514
#     Family Amidase signature domain
#     Mean in-family: 0.17461837828159332
#     Mean out-of-family: 0.008435237221419811
#     Log2FC: 4.371633052825928
# Latent 10304 is sig assoc w family 3746
#     Family Amidase
#     Mean in-family: 0.17461837828159332
#     Mean out-of-family: 0.008435237221419811
#     Log2FC: 4.371633052825928
# Latent 10304 is sig assoc w family 4096
#     Family Peptidase S10, serine carboxypeptidase
#     Mean in-family: 0.42072170972824097
#     Mean out-of-family: 0.008305331692099571
#     Log2FC: 5.662684440612793
# Latent 10304 is sig assoc w family 4164
#     Family Translation elongation factor EFTs/EF1B
#     Mean in-family: 0.23409047722816467
#     Mean out-of-family: 0.00837918184697628
#     Log2FC: 4.804112911224365
# Latent 10304 is sig assoc w family 4684
#     Family Glutamyl-tRNA(Gln) amidotransferase A subunit
#     Mean in-family: 0.17498797178268433
#     Mean out-of-family: 0.008451289497315884
#     Log2FC: 4.371940612792969
# Latent 10304 is sig assoc w family 4990
#     Family Adenine phosphoribosyl transferase
#     Mean in-family: 0.16906781494617462
#     Mean out-of-family: 0.008525097742676735
#     Log2FC: 4.309741973876953
# Latent 10304 is sig assoc w family 8611
#     Family UBA-like superfamily
#     Mean in-family: 0.1755678504705429
#     Mean out-of-family: 0.008383380249142647
#     Log2FC: 4.388352870941162
# Latent 10304 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 0.5598078966140747
#     Mean out-of-family: 0.0052238693460822105
#     Log2FC: 6.743669033050537
# Latent 10304 is sig assoc w family 9332
#     Family Elongation factor Ts, dimerisation domain superfamily
#     Mean in-family: 0.23409047722816467
#     Mean out-of-family: 0.00837918184697628
#     Log2FC: 4.804112911224365
# Latent 10304 is sig assoc w family 9584
#     Family Amidase signature (AS) superfamily
#     Mean in-family: 0.17461837828159332
#     Mean out-of-family: 0.008435237221419811
#     Log2FC: 4.371633052825928
# Latent 10494 is sig assoc w family 1002
#     Family Enolpyruvate transferase domain
#     Mean in-family: 0.18132133781909943
#     Mean out-of-family: 0.0031945074442774057
#     Log2FC: 5.82681131362915
# Latent 10494 is sig assoc w family 4984
#     Family UDP-N-acetylglucosamine 1-carboxyvinyltransferase
#     Mean in-family: 0.20380496978759766
#     Mean out-of-family: 0.003281226148828864
#     Log2FC: 5.956810474395752
# Latent 10494 is sig assoc w family 5515
#     Family Beta-hydroxyacyl-(acyl-carrier-protein) dehydratase FabZ
#     Mean in-family: 0.5495408773422241
#     Mean out-of-family: 0.002915071789175272
#     Log2FC: 7.558551788330078
# Latent 10494 is sig assoc w family 5813
#     Family Beta-hydroxydecanoyl thiol ester dehydrase, FabA/FabZ
#     Mean in-family: 0.5653337836265564
#     Mean out-of-family: 0.0027303132228553295
#     Log2FC: 7.693892478942871
# Latent 10494 is sig assoc w family 7671
#     Family UDP-N-acetylglucosamine 1-carboxyvinyltransferase MurA subfamily
#     Mean in-family: 0.20380496978759766
#     Mean out-of-family: 0.003281226148828864
#     Log2FC: 5.956810474395752
# Latent 10494 is sig assoc w family 8741
#     Family RNA 3'-terminal phosphate cyclase/enolpyruvate transferase, alpha/beta
#     Mean in-family: 0.16998878121376038
#     Mean out-of-family: 0.0031948271207511425
#     Log2FC: 5.73355770111084
# Latent 10494 is sig assoc w family 9068
#     Family HotDog domain superfamily
#     Mean in-family: 0.4656863808631897
#     Mean out-of-family: 0.0026281927712261677
#     Log2FC: 7.469143867492676
# Latent 10494 is sig assoc w family 9606
#     Family Enolpyruvate transferase domain superfamily
#     Mean in-family: 0.18132133781909943
#     Mean out-of-family: 0.0031945074442774057
#     Log2FC: 5.82681131362915
# Latent 10664 is sig assoc w family 187
#     Family Large ribosomal subunit protein uL15, conserved site
#     Mean in-family: 0.3599565029144287
#     Mean out-of-family: 0.016906971111893654
#     Log2FC: 4.412132263183594
# Latent 10664 is sig assoc w family 472
#     Family Large ribosomal subunit protein uL3, conserved site
#     Mean in-family: 0.2882368862628937
#     Mean out-of-family: 0.016911640763282776
#     Log2FC: 4.0911664962768555
# Latent 10664 is sig assoc w family 499
#     Family DNA recombination/repair protein RecA, conserved site
#     Mean in-family: 0.6835445165634155
#     Mean out-of-family: 0.016651736572384834
#     Log2FC: 5.359290599822998
# Latent 10664 is sig assoc w family 540
#     Family Large ribosomal subunit protein bL34, conserved site
#     Mean in-family: 0.3871017396450043
#     Mean out-of-family: 0.0166518185287714
#     Log2FC: 4.538960933685303
# Latent 10664 is sig assoc w family 2372
#     Family DNA recombination and repair protein RecA, monomer-monomer interface
#     Mean in-family: 0.6666694283485413
#     Mean out-of-family: 0.016408264636993408
#     Log2FC: 5.34447717666626
# Latent 10664 is sig assoc w family 2373
#     Family DNA recombination and repair protein RecA-like, ATP-binding domain
#     Mean in-family: 0.5993033051490784
#     Mean out-of-family: 0.016385961323976517
#     Log2FC: 5.19275426864624
# Latent 10664 is sig assoc w family 2404
#     Family Large ribosomal subunit protein uL15/eL18
#     Mean in-family: 0.31519854068756104
#     Mean out-of-family: 0.016811372712254524
#     Log2FC: 4.2287516593933105
# Latent 10664 is sig assoc w family 2473
#     Family Large ribosomal subunit protein uL2, RNA-binding domain
#     Mean in-family: 0.4788550138473511
#     Mean out-of-family: 0.016902873292565346
#     Log2FC: 4.824248313903809
# Latent 10664 is sig assoc w family 2474
#     Family Large ribosomal subunit protein uL2, C-terminal
#     Mean in-family: 0.4788550138473511
#     Mean out-of-family: 0.016902873292565346
#     Log2FC: 4.824248313903809
# Latent 10664 is sig assoc w family 3527
#     Family RecA-like, C-terminal
#     Mean in-family: 0.6794419288635254
#     Mean out-of-family: 0.016523128375411034
#     Log2FC: 5.361791610717773
# Latent 10664 is sig assoc w family 3545
#     Family RecA-like, N-terminal
#     Mean in-family: 0.6794419288635254
#     Mean out-of-family: 0.016523128375411034
#     Log2FC: 5.361791610717773
# Latent 10664 is sig assoc w family 3784
#     Family Large ribosomal subunit protein bL34
#     Mean in-family: 0.3871017396450043
#     Mean out-of-family: 0.0166518185287714
#     Log2FC: 4.538960933685303
# Latent 10664 is sig assoc w family 3852
#     Family Large ribosomal subunit protein uL3
#     Mean in-family: 0.28634577989578247
#     Mean out-of-family: 0.016887495294213295
#     Log2FC: 4.083731174468994
# Latent 10664 is sig assoc w family 4162
#     Family Small GTPase
#     Mean in-family: 0.3096520006656647
#     Mean out-of-family: 0.016850145533680916
#     Log2FC: 4.199814796447754
# Latent 10664 is sig assoc w family 4257
#     Family Large ribosomal subunit protein uL2
#     Mean in-family: 0.4788550138473511
#     Mean out-of-family: 0.016902873292565346
#     Log2FC: 4.824248313903809
# Latent 10664 is sig assoc w family 4983
#     Family Large ribosomal subunit protein uL15, bacterial-type
#     Mean in-family: 0.31594932079315186
#     Mean out-of-family: 0.016840053722262383
#     Log2FC: 4.229724407196045
# Latent 10664 is sig assoc w family 5026
#     Family Large ribosomal subunit protein uL2, bacterial/organellar-type
#     Mean in-family: 0.4788550138473511
#     Mean out-of-family: 0.016902873292565346
#     Log2FC: 4.824248313903809
# Latent 10664 is sig assoc w family 5846
#     Family DNA recombination and repair protein RecA
#     Mean in-family: 0.6794419288635254
#     Mean out-of-family: 0.016523128375411034
#     Log2FC: 5.361791610717773
# Latent 10664 is sig assoc w family 7023
#     Family Large ribosomal subunit protein uL15
#     Mean in-family: 0.32131946086883545
#     Mean out-of-family: 0.016800949349999428
#     Log2FC: 4.257393836975098
# Latent 10664 is sig assoc w family 8759
#     Family Large ribosomal subunit protein uL2, domain 3
#     Mean in-family: 0.4788550138473511
#     Mean out-of-family: 0.016902873292565346
#     Log2FC: 4.824248313903809
# Latent 10664 is sig assoc w family 8932
#     Family DNA recombination and repair protein RecA, C-terminal, superfamily
#     Mean in-family: 0.6794419288635254
#     Mean out-of-family: 0.016523128375411034
#     Log2FC: 5.361791610717773
# Latent 10664 is sig assoc w family 9251
#     Family Large ribosomal subunit protein uL15/eL18 superfamily
#     Mean in-family: 0.3065423369407654
#     Mean out-of-family: 0.016797088086605072
#     Log2FC: 4.189803123474121
# Latent 10666 is sig assoc w family 669
#     Family GNAT domain
#     Mean in-family: 1.381739616394043
#     Mean out-of-family: 0.02205962873995304
#     Log2FC: 5.968933582305908
# Latent 10666 is sig assoc w family 1799
#     Family tRNA(Ile)-lysidine/2-thiocytidine synthase, N-terminal
#     Mean in-family: 0.4430710971355438
#     Mean out-of-family: 0.023103289306163788
#     Log2FC: 4.2613677978515625
# Latent 10666 is sig assoc w family 6166
#     Family Queuosine biosynthesis protein QueC
#     Mean in-family: 0.47157222032546997
#     Mean out-of-family: 0.023108238354325294
#     Log2FC: 4.350999355316162
# Latent 10666 is sig assoc w family 8834
#     Family Acyl-CoA N-acyltransferase
#     Mean in-family: 1.6904847621917725
#     Mean out-of-family: 0.019513817504048347
#     Log2FC: 6.436797142028809
# Latent 10669 is sig assoc w family 448
#     Family WD40 repeat, conserved site
#     Mean in-family: 0.22784112393856049
#     Mean out-of-family: 0.0072798398323357105
#     Log2FC: 4.967977523803711
# Latent 10669 is sig assoc w family 8787
#     Family WD40/YVTN repeat-like-containing domain superfamily
#     Mean in-family: 0.2077755481004715
#     Mean out-of-family: 0.006729392800480127
#     Log2FC: 4.948405742645264
# Latent 10669 is sig assoc w family 9289
#     Family WD40-repeat-containing domain superfamily
#     Mean in-family: 0.2122894674539566
#     Mean out-of-family: 0.007013195659965277
#     Log2FC: 4.919816970825195
# Latent 10669 is sig assoc w family 10047
#     Family WD40 repeat
#     Mean in-family: 0.2116236388683319
#     Mean out-of-family: 0.006995454430580139
#     Log2FC: 4.918939113616943
# Latent 10669 is sig assoc w family 10082
#     Family PAC1/LIS1-like, WD-40 repeat
#     Mean in-family: 0.2295394390821457
#     Mean out-of-family: 0.007386620156466961
#     Log2FC: 4.95768404006958
# Latent 10989 is sig assoc w family 2496
#     Family Thiamine phosphate synthase/TenI
#     Mean in-family: 0.09344660490751266
#     Mean out-of-family: 0.0043544284999370575
#     Log2FC: 4.423586845397949
# Latent 10989 is sig assoc w family 4784
#     Family Histidine biosynthesis, HisF
#     Mean in-family: 0.09286059439182281
#     Mean out-of-family: 0.004310641437768936
#     Log2FC: 4.429091930389404
# Latent 10989 is sig assoc w family 5086
#     Family Histidine biosynthesis protein
#     Mean in-family: 0.0945085808634758
#     Mean out-of-family: 0.004145449493080378
#     Log2FC: 4.510844707489014
# Latent 10989 is sig assoc w family 5087
#     Family HisA, bacterial
#     Mean in-family: 0.09476497024297714
#     Mean out-of-family: 0.00432608462870121
#     Log2FC: 4.453220367431641
# Latent 10989 is sig assoc w family 6510
#     Family HisA/PriA
#     Mean in-family: 0.09623750299215317
#     Mean out-of-family: 0.004278280772268772
#     Log2FC: 4.4914960861206055
# Latent 10989 is sig assoc w family 7124
#     Family Thiamine phosphate synthase
#     Mean in-family: 0.09344660490751266
#     Mean out-of-family: 0.0043544284999370575
#     Log2FC: 4.423586845397949
# Latent 10989 is sig assoc w family 7440
#     Family Histidine biosynthesis, HisA-like
#     Mean in-family: 0.09579034894704819
#     Mean out-of-family: 0.004269874654710293
#     Log2FC: 4.487614631652832
# Latent 10989 is sig assoc w family 7667
#     Family Imidazole glycerol phosphate synthase HisA/HisF
#     Mean in-family: 0.09219323843717575
#     Mean out-of-family: 0.004302775487303734
#     Log2FC: 4.421321392059326
# Latent 10989 is sig assoc w family 8673
#     Family Ribulose-phosphate binding barrel
#     Mean in-family: 0.07949548959732056
#     Mean out-of-family: 0.0038597802631556988
#     Log2FC: 4.364282608032227
# Latent 10989 is sig assoc w family 9243
#     Family Thiamin phosphate synthase superfamily
#     Mean in-family: 0.09344660490751266
#     Mean out-of-family: 0.0043544284999370575
#     Log2FC: 4.423586845397949
# Latent 11227 is sig assoc w family 448
#     Family WD40 repeat, conserved site
#     Mean in-family: 0.3776521384716034
#     Mean out-of-family: 0.022417519241571426
#     Log2FC: 4.07435941696167
# Latent 11227 is sig assoc w family 1501
#     Family RNA-binding domain, S1, IF1 type
#     Mean in-family: 0.5106582641601562
#     Mean out-of-family: 0.022497963160276413
#     Log2FC: 4.504491806030273
# Latent 11227 is sig assoc w family 4666
#     Family Translation initiation factor IF-1
#     Mean in-family: 0.535741925239563
#     Mean out-of-family: 0.022606952115893364
#     Log2FC: 4.566699981689453
# Latent 11227 is sig assoc w family 10082
#     Family PAC1/LIS1-like, WD-40 repeat
#     Mean in-family: 0.3855274021625519
#     Mean out-of-family: 0.02257816679775715
#     Log2FC: 4.093832969665527
# Latent 12135 is sig assoc w family 1687
#     Family 4'-phosphopantetheinyl transferase domain
#     Mean in-family: 0.2575828433036804
#     Mean out-of-family: 0.007906307466328144
#     Log2FC: 5.025888442993164
# Latent 12135 is sig assoc w family 8654
#     Family GroES-like superfamily
#     Mean in-family: 0.4841662049293518
#     Mean out-of-family: 0.007277109194546938
#     Log2FC: 6.05599308013916
# Latent 12135 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 0.2702530324459076
#     Mean out-of-family: 0.007416092790663242
#     Log2FC: 5.187507629394531
# Latent 12135 is sig assoc w family 9664
#     Family 4'-phosphopantetheinyl transferase domain superfamily
#     Mean in-family: 0.2575828433036804
#     Mean out-of-family: 0.007906307466328144
#     Log2FC: 5.025888442993164
# Latent 12152 is sig assoc w family 307
#     Family Cytochrome P450, conserved site
#     Mean in-family: 0.4007573425769806
#     Mean out-of-family: 0.01201742421835661
#     Log2FC: 5.0595293045043945
# Latent 12152 is sig assoc w family 2230
#     Family GPCR, rhodopsin-like, 7TM
#     Mean in-family: 0.31294336915016174
#     Mean out-of-family: 0.01224416121840477
#     Log2FC: 4.675735950469971
# Latent 12152 is sig assoc w family 3785
#     Family G protein-coupled receptor, rhodopsin-like
#     Mean in-family: 0.3160342276096344
#     Mean out-of-family: 0.012293046340346336
#     Log2FC: 4.684166431427002
# Latent 12152 is sig assoc w family 3998
#     Family Cytochrome P450
#     Mean in-family: 0.42661333084106445
#     Mean out-of-family: 0.011757465079426765
#     Log2FC: 5.181280136108398
# Latent 12152 is sig assoc w family 4319
#     Family Cytochrome P450, E-class, group I
#     Mean in-family: 0.4557350277900696
#     Mean out-of-family: 0.012041437439620495
#     Log2FC: 5.2421159744262695
# Latent 12152 is sig assoc w family 7720
#     Family Cytochrome P450 monooxygenase
#     Mean in-family: 0.34195923805236816
#     Mean out-of-family: 0.0130221638828516
#     Log2FC: 4.714783191680908
# Latent 12152 is sig assoc w family 9327
#     Family Cytochrome P450 superfamily
#     Mean in-family: 0.42661333084106445
#     Mean out-of-family: 0.011757465079426765
#     Log2FC: 5.181280136108398
# Latent 12236 is sig assoc w family 2862
#     Family Isoleucyl tRNA synthetase type 1, anticodon-binding domain
#     Mean in-family: 0.047675687819719315
#     Mean out-of-family: 0.0012220806675031781
#     Log2FC: 5.285842418670654
# Latent 12236 is sig assoc w family 4284
#     Family Isoleucine-tRNA ligase
#     Mean in-family: 0.047675687819719315
#     Mean out-of-family: 0.0012220806675031781
#     Log2FC: 5.285842418670654
# Latent 12236 is sig assoc w family 6625
#     Family Isoleucine-tRNA ligase, type 1
#     Mean in-family: 0.047675687819719315
#     Mean out-of-family: 0.0012220806675031781
#     Log2FC: 5.285842418670654
# Latent 12236 is sig assoc w family 7683
#     Family Isoleucine--tRNA ligase
#     Mean in-family: 0.047675687819719315
#     Mean out-of-family: 0.0012220806675031781
#     Log2FC: 5.285842418670654
# Latent 12768 is sig assoc w family 395
#     Family Small ribosomal subunit protein uS3, conserved site
#     Mean in-family: 0.639503538608551
#     Mean out-of-family: 0.03638039156794548
#     Log2FC: 4.135719299316406
# Latent 12768 is sig assoc w family 896
#     Family Small ribosomal subunit protein uS3, C-terminal
#     Mean in-family: 0.639503538608551
#     Mean out-of-family: 0.03638039156794548
#     Log2FC: 4.135719299316406
# Latent 12768 is sig assoc w family 4959
#     Family Small ribosomal subunit protein uS3, bacterial-type
#     Mean in-family: 0.639503538608551
#     Mean out-of-family: 0.03638039156794548
#     Log2FC: 4.135719299316406
# Latent 12768 is sig assoc w family 9341
#     Family Ribosomal protein S3, C-terminal domain superfamily
#     Mean in-family: 0.639503538608551
#     Mean out-of-family: 0.03638039156794548
#     Log2FC: 4.135719299316406
# Latent 12919 is sig assoc w family 387
#     Family Small ribosomal subunit protein uS10, conserved site
#     Mean in-family: 0.33709436655044556
#     Mean out-of-family: 0.014466116204857826
#     Log2FC: 4.542403221130371
# Latent 12919 is sig assoc w family 669
#     Family GNAT domain
#     Mean in-family: 0.6747000217437744
#     Mean out-of-family: 0.014125105924904346
#     Log2FC: 5.5779128074646
# Latent 12919 is sig assoc w family 2657
#     Family Small ribosomal subunit protein uS10 domain
#     Mean in-family: 0.33553439378738403
#     Mean out-of-family: 0.01430746540427208
#     Log2FC: 4.5516204833984375
# Latent 12919 is sig assoc w family 4174
#     Family Small ribosomal subunit protein uS10
#     Mean in-family: 0.33553439378738403
#     Mean out-of-family: 0.01430746540427208
#     Log2FC: 4.5516204833984375
# Latent 12919 is sig assoc w family 8834
#     Family Acyl-CoA N-acyltransferase
#     Mean in-family: 0.7470805644989014
#     Mean out-of-family: 0.013082800433039665
#     Log2FC: 5.8355207443237305
# Latent 12919 is sig assoc w family 9524
#     Family Small ribosomal subunit protein uS10 domain superfamily
#     Mean in-family: 0.33553439378738403
#     Mean out-of-family: 0.01430746540427208
#     Log2FC: 4.5516204833984375
# Latent 12919 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 0.8603730201721191
#     Mean out-of-family: 0.012288734316825867
#     Log2FC: 6.129554271697998
# Latent 12996 is sig assoc w family 448
#     Family WD40 repeat, conserved site
#     Mean in-family: 0.3190717399120331
#     Mean out-of-family: 0.018587451428174973
#     Log2FC: 4.101480007171631
# Latent 12996 is sig assoc w family 476
#     Family Small ribosomal subunit protein uS17, conserved site
#     Mean in-family: 0.34171387553215027
#     Mean out-of-family: 0.01881754770874977
#     Log2FC: 4.182638168334961
# Latent 12996 is sig assoc w family 3781
#     Family Small ribosomal subunit protein uS17
#     Mean in-family: 0.33893945813179016
#     Mean out-of-family: 0.01869422011077404
#     Log2FC: 4.180363178253174
# Latent 12996 is sig assoc w family 4954
#     Family Ribosomal protein uS12, bacterial-type
#     Mean in-family: 0.4359339773654938
#     Mean out-of-family: 0.018480360507965088
#     Log2FC: 4.560044765472412
# Latent 12996 is sig assoc w family 5078
#     Family Small ribosomal subunit protein uS12
#     Mean in-family: 0.41410842537879944
#     Mean out-of-family: 0.01836983859539032
#     Log2FC: 4.494597911834717
# Latent 12996 is sig assoc w family 6265
#     Family Small ribosomal subunit protein uS17, bacteria/chloroplast
#     Mean in-family: 0.34027600288391113
#     Mean out-of-family: 0.0187234990298748
#     Log2FC: 4.183783531188965
# Latent 12996 is sig assoc w family 8787
#     Family WD40/YVTN repeat-like-containing domain superfamily
#     Mean in-family: 0.3259943127632141
#     Mean out-of-family: 0.01764114573597908
#     Log2FC: 4.207830429077148
# Latent 12996 is sig assoc w family 10082
#     Family PAC1/LIS1-like, WD-40 repeat
#     Mean in-family: 0.3162643313407898
#     Mean out-of-family: 0.01874421536922455
#     Log2FC: 4.076613426208496
# Latent 13025 is sig assoc w family 395
#     Family Small ribosomal subunit protein uS3, conserved site
#     Mean in-family: 0.4631943106651306
#     Mean out-of-family: 0.025567539036273956
#     Log2FC: 4.179232120513916
# Latent 13025 is sig assoc w family 548
#     Family S-adenosylmethionine synthetase, conserved site
#     Mean in-family: 0.5566028356552124
#     Mean out-of-family: 0.025204947218298912
#     Log2FC: 4.464869499206543
# Latent 13025 is sig assoc w family 896
#     Family Small ribosomal subunit protein uS3, C-terminal
#     Mean in-family: 0.4631943106651306
#     Mean out-of-family: 0.025567539036273956
#     Log2FC: 4.179232120513916
# Latent 13025 is sig assoc w family 2460
#     Family S-adenosylmethionine synthetase, N-terminal
#     Mean in-family: 0.5566028356552124
#     Mean out-of-family: 0.025204947218298912
#     Log2FC: 4.464869499206543
# Latent 13025 is sig assoc w family 2461
#     Family S-adenosylmethionine synthetase, central domain
#     Mean in-family: 0.5566028356552124
#     Mean out-of-family: 0.025204947218298912
#     Log2FC: 4.464869499206543
# Latent 13025 is sig assoc w family 2462
#     Family S-adenosylmethionine synthetase, C-terminal
#     Mean in-family: 0.5566028356552124
#     Mean out-of-family: 0.025204947218298912
#     Log2FC: 4.464869499206543
# Latent 13025 is sig assoc w family 4245
#     Family S-adenosylmethionine synthetase
#     Mean in-family: 0.5566028356552124
#     Mean out-of-family: 0.025204947218298912
#     Log2FC: 4.464869499206543
# Latent 13025 is sig assoc w family 4959
#     Family Small ribosomal subunit protein uS3, bacterial-type
#     Mean in-family: 0.4631943106651306
#     Mean out-of-family: 0.025567539036273956
#     Log2FC: 4.179232120513916
# Latent 13025 is sig assoc w family 8834
#     Family Acyl-CoA N-acyltransferase
#     Mean in-family: 0.8189588785171509
#     Mean out-of-family: 0.024281049147248268
#     Log2FC: 5.075888156890869
# Latent 13025 is sig assoc w family 8865
#     Family Ribosomal protein uS5 domain 2-type superfamily
#     Mean in-family: 0.3957386910915375
#     Mean out-of-family: 0.021173659712076187
#     Log2FC: 4.224205493927002
# Latent 13025 is sig assoc w family 8871
#     Family S-adenosylmethionine synthetase superfamily
#     Mean in-family: 0.5566028356552124
#     Mean out-of-family: 0.025204947218298912
#     Log2FC: 4.464869499206543
# Latent 13025 is sig assoc w family 9341
#     Family Ribosomal protein S3, C-terminal domain superfamily
#     Mean in-family: 0.4631943106651306
#     Mean out-of-family: 0.025567539036273956
#     Log2FC: 4.179232120513916
# Latent 13025 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 1.7811452150344849
#     Mean out-of-family: 0.020810704678297043
#     Log2FC: 6.41933536529541
# Latent 13099 is sig assoc w family 1300
#     Family Translation elongation factor EFTu/EF1A, C-terminal
#     Mean in-family: 0.4874235689640045
#     Mean out-of-family: 0.018069421872496605
#     Log2FC: 4.753553867340088
# Latent 13099 is sig assoc w family 2865
#     Family Elongation factor Tu, domain 2
#     Mean in-family: 0.4874235689640045
#     Mean out-of-family: 0.018069421872496605
#     Log2FC: 4.753553867340088
# Latent 13099 is sig assoc w family 3204
#     Family Elongation factor Tu (EF-Tu), GTP-binding domain
#     Mean in-family: 0.4874235689640045
#     Mean out-of-family: 0.018069421872496605
#     Log2FC: 4.753553867340088
# Latent 13099 is sig assoc w family 4741
#     Family Translation elongation factor EFTu/EF1A, bacterial/organelle
#     Mean in-family: 0.4874235689640045
#     Mean out-of-family: 0.018069421872496605
#     Log2FC: 4.753553867340088
# Latent 13099 is sig assoc w family 7658
#     Family Elongation factor Tu GTPase
#     Mean in-family: 0.4874235689640045
#     Mean out-of-family: 0.018069421872496605
#     Log2FC: 4.753553867340088
# Latent 13099 is sig assoc w family 8588
#     Family Translation elongation factor EF1A/initiation factor IF2gamma, C-terminal
#     Mean in-family: 0.4817850589752197
#     Mean out-of-family: 0.017847202718257904
#     Log2FC: 4.754619598388672
# Latent 13454 is sig assoc w family 669
#     Family GNAT domain
#     Mean in-family: 0.42641329765319824
#     Mean out-of-family: 0.014919137582182884
#     Log2FC: 4.837016582489014
# Latent 13454 is sig assoc w family 8834
#     Family Acyl-CoA N-acyltransferase
#     Mean in-family: 0.46634894609451294
#     Mean out-of-family: 0.014282764866948128
#     Log2FC: 5.029062747955322
# Latent 13454 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 1.5226376056671143
#     Mean out-of-family: 0.010726005770266056
#     Log2FC: 7.14931583404541
# Latent 13568 is sig assoc w family 2370
#     Family Heat shock protein Hsp90, N-terminal
#     Mean in-family: 5.7453508377075195
#     Mean out-of-family: 0.011984986253082752
#     Log2FC: 8.905022621154785
# Latent 13568 is sig assoc w family 4065
#     Family Heat shock protein Hsp90 family
#     Mean in-family: 5.7453508377075195
#     Mean out-of-family: 0.011984986253082752
#     Log2FC: 8.905022621154785
# Latent 13568 is sig assoc w family 8756
#     Family Small ribosomal subunit protein uS5 domain 2-type fold, subgroup
#     Mean in-family: 0.5613808631896973
#     Mean out-of-family: 0.011623866856098175
#     Log2FC: 5.593817710876465
# Latent 13568 is sig assoc w family 8865
#     Family Ribosomal protein uS5 domain 2-type superfamily
#     Mean in-family: 0.694469690322876
#     Mean out-of-family: 0.007225153502076864
#     Log2FC: 6.586739540100098
# Latent 13568 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 3.1017351150512695
#     Mean out-of-family: 0.0069779325276613235
#     Log2FC: 8.796060562133789
# Latent 13676 is sig assoc w family 386
#     Family Large ribosomal subunit protein bL35, conserved site
#     Mean in-family: 0.3710414469242096
#     Mean out-of-family: 0.022066116333007812
#     Log2FC: 4.071675777435303
# Latent 13676 is sig assoc w family 4137
#     Family Large ribosomal subunit protein bL35
#     Mean in-family: 0.3710414469242096
#     Mean out-of-family: 0.022066116333007812
#     Log2FC: 4.071675777435303
# Latent 13676 is sig assoc w family 6355
# ...
#     Mean in-family: 0.6078767776489258
#     Mean out-of-family: 0.022247377783060074
#     Log2FC: 4.772071838378906
# Latent 20000 is sig assoc w family 881
#     Family Exoribonuclease, phosphorolytic domain 1
#     Mean in-family: 0.3802396059036255
#     Mean out-of-family: 0.022253621369600296
#     Log2FC: 4.094796657562256
# Latent 20000 is sig assoc w family 2175
#     Family Exoribonuclease, phosphorolytic domain 2
#     Mean in-family: 0.3894028961658478
#     Mean out-of-family: 0.022340141236782074
#     Log2FC: 4.123553276062012
# Latent 20000 is sig assoc w family 4311
#     Family Short-chain dehydrogenase/reductase SDR
#     Mean in-family: 0.4458678662776947
#     Mean out-of-family: 0.02208254672586918
#     Log2FC: 4.33563756942749
# Latent 20000 is sig assoc w family 9001
#     Family PNPase/RNase PH domain superfamily
#     Mean in-family: 0.3802396059036255
#     Mean out-of-family: 0.022253621369600296
#     Log2FC: 4.094796657562256
# Latent 20000 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 0.5730864405632019
#     Mean out-of-family: 0.019698040559887886
#     Log2FC: 4.862628936767578
# Latent 20000 is sig assoc w family 9294
#     Family Exoribonuclease, PH domain 2 superfamily
#     Mean in-family: 0.3802396059036255
#     Mean out-of-family: 0.022253621369600296
#     Log2FC: 4.094796657562256
# Latent 20112 is sig assoc w family 4433
#     Family Ribosomal RNA small subunit methyltransferase H
#     Mean in-family: 0.6889240145683289
#     Mean out-of-family: 0.03980513662099838
#     Log2FC: 4.11331844329834
# Latent 20112 is sig assoc w family 8930
#     Family S-adenosyl-L-methionine-dependent methyltransferase, MraW, recognition domain superfamily
#     Mean in-family: 0.6889240145683289
#     Mean out-of-family: 0.03980513662099838
#     Log2FC: 4.11331844329834
# Latent 20336 is sig assoc w family 476
#     Family Small ribosomal subunit protein uS17, conserved site
#     Mean in-family: 0.5187437534332275
#     Mean out-of-family: 0.03066885471343994
#     Log2FC: 4.080175876617432
# Latent 20336 is sig assoc w family 3781
#     Family Small ribosomal subunit protein uS17
#     Mean in-family: 0.5144175887107849
#     Mean out-of-family: 0.030482733622193336
#     Log2FC: 4.076875686645508
# Latent 20336 is sig assoc w family 6265
#     Family Small ribosomal subunit protein uS17, bacteria/chloroplast
#     Mean in-family: 0.5261944532394409
#     Mean out-of-family: 0.030506443232297897
#     Log2FC: 4.108409881591797
# Latent 20356 is sig assoc w family 8548
#     Family Phosphoenolpyruvate carboxykinase, N-terminal
#     Mean in-family: 0.3887499272823334
#     Mean out-of-family: 0.01717735454440117
#     Log2FC: 4.50026273727417
# Latent 20356 is sig assoc w family 8720
#     Family Phosphoenolpyruvate carboxykinase, C-terminal
#     Mean in-family: 0.3887499272823334
#     Mean out-of-family: 0.01717735454440117
#     Log2FC: 4.50026273727417
# Latent 20356 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 3.437107801437378
#     Mean out-of-family: 0.00691533088684082
#     Log2FC: 8.957180976867676
# Latent 20379 is sig assoc w family 38
#     Family Serine carboxypeptidase, serine active site
#     Mean in-family: 2.240122079849243
#     Mean out-of-family: 0.018040232360363007
#     Log2FC: 6.956215858459473
# Latent 20379 is sig assoc w family 659
#     Family Alpha/beta hydrolase fold-1
#     Mean in-family: 0.38782161474227905
#     Mean out-of-family: 0.019228151068091393
#     Log2FC: 4.33410120010376
# Latent 20379 is sig assoc w family 4096
#     Family Peptidase S10, serine carboxypeptidase
#     Mean in-family: 2.3884708881378174
#     Mean out-of-family: 0.01744687557220459
#     Log2FC: 7.096974849700928
# Latent 20379 is sig assoc w family 8548
#     Family Phosphoenolpyruvate carboxykinase, N-terminal
#     Mean in-family: 0.7066150903701782
#     Mean out-of-family: 0.019130414351820946
#     Log2FC: 5.206984519958496
# Latent 20379 is sig assoc w family 8720
#     Family Phosphoenolpyruvate carboxykinase, C-terminal
#     Mean in-family: 0.7066150903701782
#     Mean out-of-family: 0.019130414351820946
#     Log2FC: 5.206984519958496
# Latent 20379 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 1.093358039855957
#     Mean out-of-family: 0.013011718168854713
#     Log2FC: 6.392810821533203
# Latent 20521 is sig assoc w family 2393
#     Family Major facilitator superfamily domain
#     Mean in-family: 2.061525583267212
#     Mean out-of-family: 0.04509911313652992
#     Log2FC: 5.514469623565674
# Latent 20521 is sig assoc w family 5666
#     Family Major facilitator superfamily
#     Mean in-family: 1.9933199882507324
#     Mean out-of-family: 0.04690127447247505
#     Log2FC: 5.409402370452881
# Latent 20521 is sig assoc w family 9263
#     Family MFS transporter superfamily
#     Mean in-family: 2.3734781742095947
#     Mean out-of-family: 0.04049167037010193
#     Log2FC: 5.873233795166016
# Latent 20951 is sig assoc w family 9050
#     Family Nucleotide-diphospho-sugar transferases
#     Mean in-family: 1.2871720790863037
#     Mean out-of-family: 0.04178468510508537
#     Log2FC: 4.94508695602417
# Latent 21211 is sig assoc w family 409
#     Family Hexapeptide transferase, conserved site
#     Mean in-family: 0.739273726940155
#     Mean out-of-family: 0.022155746817588806
#     Log2FC: 5.0603556632995605
# Latent 21211 is sig assoc w family 8640
#     Family Trimeric LpxA-like superfamily
#     Mean in-family: 0.6969022154808044
#     Mean out-of-family: 0.02101336047053337
#     Log2FC: 5.051577568054199
# Latent 21211 is sig assoc w family 10043
#     Family Hexapeptide repeat
#     Mean in-family: 0.7523244619369507
#     Mean out-of-family: 0.02139997109770775
#     Log2FC: 5.135673999786377
# Latent 21378 is sig assoc w family 8706
#     Family Beta-lactamase/transpeptidase-like
#     Mean in-family: 1.6190625429153442
#     Mean out-of-family: 0.04948509484529495
#     Log2FC: 5.0320210456848145
# Latent 21409 is sig assoc w family 4246
#     Family Large ribosomal subunit protein uL4
#     Mean in-family: 0.6273184418678284
#     Mean out-of-family: 0.03229612857103348
#     Log2FC: 4.279764652252197
# Latent 21409 is sig assoc w family 5807
#     Family Large ribosomal subunit protein uL4-like
#     Mean in-family: 0.6262902021408081
#     Mean out-of-family: 0.03241674229502678
#     Log2FC: 4.27202033996582
# Latent 21409 is sig assoc w family 8943
#     Family Large ribosomal subunit protein uL4 domain superfamily
#     Mean in-family: 0.6273184418678284
#     Mean out-of-family: 0.03229612857103348
#     Log2FC: 4.279764652252197
# Latent 21555 is sig assoc w family 538
#     Family Small ribosomal subunit protein uS19, conserved site
#     Mean in-family: 0.1703060418367386
#     Mean out-of-family: 0.008113380521535873
#     Log2FC: 4.3916826248168945
# Latent 21555 is sig assoc w family 4269
#     Family Small ribosomal subunit protein uS19
#     Mean in-family: 0.1703060418367386
#     Mean out-of-family: 0.008113380521535873
#     Log2FC: 4.3916826248168945
# Latent 21555 is sig assoc w family 4974
#     Family Small ribosomal subunit protein uS19, bacterial-type
#     Mean in-family: 0.1693945825099945
#     Mean out-of-family: 0.00813155248761177
#     Log2FC: 4.380712985992432
# Latent 21555 is sig assoc w family 8944
#     Family Small ribosomal subunit protein uS19, superfamily
#     Mean in-family: 0.1703060418367386
#     Mean out-of-family: 0.008113380521535873
#     Log2FC: 4.3916826248168945
# Latent 21577 is sig assoc w family 2393
#     Family Major facilitator superfamily domain
#     Mean in-family: 0.4553247392177582
#     Mean out-of-family: 0.022463997825980186
#     Log2FC: 4.341209411621094
# Latent 21577 is sig assoc w family 5666
#     Family Major facilitator superfamily
#     Mean in-family: 0.4868934154510498
#     Mean out-of-family: 0.02272576279938221
#     Log2FC: 4.421205520629883
# Latent 21577 is sig assoc w family 9263
#     Family MFS transporter superfamily
#     Mean in-family: 0.40163013339042664
#     Mean out-of-family: 0.022081268951296806
#     Log2FC: 4.184972286224365
# Latent 22302 is sig assoc w family 21
#     Family Serine/threonine-protein kinase, active site
#     Mean in-family: 1.740713357925415
#     Mean out-of-family: 0.034819893538951874
#     Log2FC: 5.643622875213623
# Latent 22302 is sig assoc w family 126
#     Family Protein kinase, ATP binding site
#     Mean in-family: 1.548477053642273
#     Mean out-of-family: 0.03628077730536461
#     Log2FC: 5.415500640869141
# Latent 22302 is sig assoc w family 767
#     Family Protein kinase domain
#     Mean in-family: 1.6119248867034912
#     Mean out-of-family: 0.03374802693724632
#     Log2FC: 5.5778374671936035
# Latent 22302 is sig assoc w family 4162
#     Family Small GTPase
#     Mean in-family: 0.7695377469062805
#     Mean out-of-family: 0.042527321726083755
#     Log2FC: 4.177530288696289
# Latent 22302 is sig assoc w family 8644
#     Family Protein kinase-like domain superfamily
#     Mean in-family: 1.3631665706634521
#     Mean out-of-family: 0.03331771492958069
#     Log2FC: 5.354528427124023
# Latent 22338 is sig assoc w family 9076
#     Family Leucine-rich repeat domain superfamily
#     Mean in-family: 0.5853737592697144
#     Mean out-of-family: 0.017818067222833633
#     Log2FC: 5.03794527053833
# Latent 22338 is sig assoc w family 10045
#     Family Leucine-rich repeat
#     Mean in-family: 0.5737512707710266
#     Mean out-of-family: 0.018071217462420464
#     Log2FC: 4.988659858703613
# Latent 22338 is sig assoc w family 10056
#     Family Leucine-rich repeat, typical subtype
#     Mean in-family: 0.7508118152618408
#     Mean out-of-family: 0.01834150031208992
#     Log2FC: 5.355267524719238
# Latent 22373 is sig assoc w family 2230
#     Family GPCR, rhodopsin-like, 7TM
#     Mean in-family: 0.3355243504047394
#     Mean out-of-family: 0.019241658970713615
#     Log2FC: 4.124112129211426
# Latent 22373 is sig assoc w family 3785
#     Family G protein-coupled receptor, rhodopsin-like
#     Mean in-family: 0.3320424556732178
#     Mean out-of-family: 0.019318079575896263
#     Log2FC: 4.103343963623047
# Latent 22878 is sig assoc w family 8697
#     Family Armadillo-like helical
#     Mean in-family: 0.5484892725944519
#     Mean out-of-family: 0.02006591483950615
#     Log2FC: 4.772644519805908
# Latent 22878 is sig assoc w family 8793
#     Family Armadillo-type fold
#     Mean in-family: 0.5099973082542419
#     Mean out-of-family: 0.020052578300237656
#     Log2FC: 4.668630123138428
# Latent 22878 is sig assoc w family 9488
#     Family Ankyrin repeat-containing domain superfamily
#     Mean in-family: 0.3890288174152374
#     Mean out-of-family: 0.02041749842464924
#     Log2FC: 4.2519989013671875
# Latent 22878 is sig assoc w family 10049
#     Family Ankyrin repeat
#     Mean in-family: 0.4018898606300354
#     Mean out-of-family: 0.020427372306585312
#     Log2FC: 4.298224449157715
# Latent 23066 is sig assoc w family 409
#     Family Hexapeptide transferase, conserved site
#     Mean in-family: 0.4226112961769104
#     Mean out-of-family: 0.018783029168844223
#     Log2FC: 4.491829872131348
# Latent 23066 is sig assoc w family 8640
#     Family Trimeric LpxA-like superfamily
#     Mean in-family: 0.3604845106601715
#     Mean out-of-family: 0.018277976661920547
#     Log2FC: 4.301758766174316
# Latent 23066 is sig assoc w family 10043
#     Family Hexapeptide repeat
#     Mean in-family: 0.42759761214256287
#     Mean out-of-family: 0.018364068120718002
#     Log2FC: 4.541296005249023
# Latent 23112 is sig assoc w family 9076
#     Family Leucine-rich repeat domain superfamily
#     Mean in-family: 0.9044533967971802
#     Mean out-of-family: 0.019289681687951088
#     Log2FC: 5.551145076751709
# Latent 23112 is sig assoc w family 10045
#     Family Leucine-rich repeat
#     Mean in-family: 0.8948426842689514
#     Mean out-of-family: 0.01966572180390358
#     Log2FC: 5.507879257202148
# Latent 23226 is sig assoc w family 8834
#     Family Acyl-CoA N-acyltransferase
#     Mean in-family: 0.7110255360603333
#     Mean out-of-family: 0.02958017587661743
#     Log2FC: 4.587198734283447
# Latent 23226 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 0.6048210263252258
#     Mean out-of-family: 0.029500294476747513
#     Log2FC: 4.3577070236206055
# Latent 23478 is sig assoc w family 409
#     Family Hexapeptide transferase, conserved site
#     Mean in-family: 0.819526195526123
#     Mean out-of-family: 0.04943011328577995
#     Log2FC: 4.051328182220459
# Latent 23478 is sig assoc w family 8640
#     Family Trimeric LpxA-like superfamily
#     Mean in-family: 1.0332179069519043
#     Mean out-of-family: 0.04726685956120491
#     Log2FC: 4.45017147064209
# Latent 23478 is sig assoc w family 9050
#     Family Nucleotide-diphospho-sugar transferases
#     Mean in-family: 1.6834858655929565
#     Mean out-of-family: 0.04261191189289093
#     Log2FC: 5.304050922393799
# Latent 23478 is sig assoc w family 10043
#     Family Hexapeptide repeat
#     Mean in-family: 0.8184228539466858
#     Mean out-of-family: 0.04866094887256622
#     Log2FC: 4.072010040283203
# Latent 23545 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 1.3932600021362305
#     Mean out-of-family: 0.046924397349357605
#     Log2FC: 4.891982555389404
# Latent 23546 is sig assoc w family 659
#     Family Alpha/beta hydrolase fold-1
#     Mean in-family: 1.384918212890625
#     Mean out-of-family: 0.0320814847946167
#     Log2FC: 5.431916236877441
# Latent 23546 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 1.7029019594192505
#     Mean out-of-family: 0.02366684004664421
#     Log2FC: 6.168984413146973
# Latent 23676 is sig assoc w family 2860
#     Family dUTPase, trimeric
#     Mean in-family: 1.088760256767273
#     Mean out-of-family: 0.03685624524950981
#     Log2FC: 4.884633541107178
# Latent 23676 is sig assoc w family 9220
#     Family dUTPase-like superfamily
#     Mean in-family: 1.088760256767273
#     Mean out-of-family: 0.03685624524950981
#     Log2FC: 4.884633541107178
# Latent 23782 is sig assoc w family 8697
#     Family Armadillo-like helical
#     Mean in-family: 0.6590232253074646
#     Mean out-of-family: 0.035368580371141434
#     Log2FC: 4.219789028167725
# Latent 23782 is sig assoc w family 8793
#     Family Armadillo-type fold
#     Mean in-family: 0.6162825226783752
#     Mean out-of-family: 0.035346370190382004
#     Log2FC: 4.123958110809326
# Latent 24187 is sig assoc w family 209
#     Family Large ribosomal subunit protein uL6, conserved site
#     Mean in-family: 0.344217449426651
#     Mean out-of-family: 0.01652410440146923
#     Log2FC: 4.38067626953125
# Latent 24187 is sig assoc w family 409
#     Family Hexapeptide transferase, conserved site
#     Mean in-family: 0.7382096648216248
#     Mean out-of-family: 0.015649495646357536
#     Log2FC: 5.559842586517334
# Latent 24187 is sig assoc w family 2344
#     Family Large ribosomal subunit protein uL6, alpha-beta domain
#     Mean in-family: 0.3430361747741699
#     Mean out-of-family: 0.016492944210767746
#     Log2FC: 4.378439903259277
# Latent 24187 is sig assoc w family 3881
#     Family Large ribosomal subunit protein uL6-like
#     Mean in-family: 0.3430361747741699
#     Mean out-of-family: 0.016492944210767746
#     Log2FC: 4.378439903259277
# Latent 24187 is sig assoc w family 6246
#     Family Large ribosomal subunit protein uL6, bacterial-type
#     Mean in-family: 0.344217449426651
#     Mean out-of-family: 0.01652410440146923
#     Log2FC: 4.38067626953125
# Latent 24187 is sig assoc w family 8640
#     Family Trimeric LpxA-like superfamily
#     Mean in-family: 0.6752702593803406
#     Mean out-of-family: 0.014571589417755604
#     Log2FC: 5.534235000610352
# Latent 24187 is sig assoc w family 9497
#     Family Large ribosomal subunit protein uL6-like, alpha-beta domain superfamily
#     Mean in-family: 0.3430361747741699
#     Mean out-of-family: 0.016492944210767746
#     Log2FC: 4.378439903259277
# Latent 24187 is sig assoc w family 10043
#     Family Hexapeptide repeat
#     Mean in-family: 0.7518470883369446
#     Mean out-of-family: 0.014886614866554737
#     Log2FC: 5.658351421356201
# Latent 24345 is sig assoc w family 8847
#     Family Alkaline-phosphatase-like, core domain superfamily
#     Mean in-family: 0.7316627502441406
#     Mean out-of-family: 0.03460899367928505
#     Log2FC: 4.4019598960876465

# %%
ann_latents_list = list(set(annotated_latents))

# %%
len(ann_latents_list)
# Out:
# 84

# %%
len(set(full_indices_metx))
# Out:
# 273

# %%
len(set(full_indices_metx).intersection(ann_latents_list))
# Out:
# 59

# %%
len(set(full_indices_top2))
# Out:
# 134

# %%
len(set(full_indices_top2).intersection(ann_latents_list))
# Out:
# 27

# %%
# For a table:
# Layer | Latent ID (#) | IntroPro ID | InterPro Name | out-of-family | in-family | Bonf p-value

# %%
metx_results_df_dict = {}
for latent_i in range(latents_family_pvals.shape[0]):
    for family_j in range(latents_family_pvals.shape[1]):
        if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
            if latents_family_effect_size[latent_i,family_j,1] < 0.05:
                l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/(latents_family_effect_size[latent_i,family_j,1]+0.00001))
                if l2fc >= 4:  # latents_family_effect_size[latent_i,family_j,0] > 1.05:

                    df_id = str(latent_i)+"_"+str(family_j)
                    cur_lat_id = latent_ids_both_proteins[latent_i]
                    layer_id = ((cur_lat_id // 4096)+1)*4
                    lat_id = cur_lat_id % 4096

                    case_ptn = "MetX"
                    if latent_ids_both_proteins[latent_i] in full_indices_top2:
                        case_ptn="Top2"

                    metx_results_df_dict[df_id] = {
                        "Case": case_ptn,
                        "Layer": layer_id,
                        "Latent ID": lat_id,
                        "InterPro ID": interpro_annotations_nonzero.iloc[family_j]["ENTRY_AC"],
                        "InterPro Name": interpro_annotations_nonzero.iloc[family_j]["ENTRY_NAME"],
                        "A_in": float(latents_family_effect_size[latent_i,family_j,0]),
                        "A_out": float(latents_family_effect_size[latent_i,family_j,1]),
                        "L2FC": float(l2fc),
                        "Bonferroni adj. p-value": float(latents_family_pvals[latent_i,family_j]*n_tests)
                    }
# Out:
# /tmp/ipykernel_331029/507448697.py:6: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/(latents_family_effect_size[latent_i,family_j,1]+0.00001))
# /tmp/ipykernel_331029/507448697.py:6: RuntimeWarning: divide by zero encountered in log2
#   l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/(latents_family_effect_size[latent_i,family_j,1]+0.00001))

# %%
df_metx_results = pd.DataFrame.from_dict(metx_results_df_dict, orient='index')
df_metx_results.head()
# Out:
#          Case  Layer  Latent ID InterPro ID  \
# 13_3824  Top2      4       1297   IPR000473
# 13_5069  Top2      4       1297   IPR005996
# 13_9135  Top2      4       1297   IPR035977
# 46_128   Top2      4       3717   IPR018064
# 46_540   Top2      4       3717   IPR020939
#
#                                              InterPro Name      A_in  \
# 13_3824               Large ribosomal subunit protein bL36  0.073116
# 13_5069  Large ribosomal subunit protein uL30, bacteria...  0.057346
# 13_9135   Large ribosomal subunit protein bL36 superfamily  0.073116
# 46_128     Metallothionein, vertebrate, metal binding site  0.040059
# 46_540   Large ribosomal subunit protein bL34, conserve...  0.019646
#
#             A_out      L2FC  Bonferroni adj. p-value
# 13_3824  0.003320  4.456454             6.988324e-07
# 13_5069  0.003392  4.075256             7.427055e-05
# 13_9135  0.003320  4.456454             6.988324e-07
# 46_128   0.001214  5.032932             5.300378e-05
# 46_540   0.001192  4.030718             6.362296e-09

# %%
df_metx_results.query("Case == 'MetX' and L2FC > 5 and A_in >= 0.5")#.sort_values(by="Bonferroni adj. p-value")
# Out:
#            Case  Layer  Latent ID InterPro ID  \
# 80_659     MetX     12       2112   IPR000073
# 80_9059    MetX     12       2112   IPR029058
# 82_5515    MetX     12       2302   IPR010084
# 82_5813    MetX     12       2302   IPR013114
# 136_659    MetX     16       1504   IPR000073
# 136_9059   MetX     16       1504   IPR029058
# 145_9059   MetX     16       2175   IPR029058
# 170_4594   MetX     16       3765   IPR003824
# 177_797    MetX     20        142   IPR000873
# 177_2169   MetX     20        142   IPR015590
# 177_8825   MetX     20        142   IPR016161
# 177_8826   MetX     20        142   IPR016162
# 177_8827   MetX     20        142   IPR016163
# 177_9990   MetX     20        142   IPR045851
# 189_2393   MetX     20        838   IPR020846
# 189_5666   MetX     20        838   IPR011701
# 189_9263   MetX     20        838   IPR036259
# 192_21     MetX     20        878   IPR008271
# 192_126    MetX     20        878   IPR017441
# 192_767    MetX     20        878   IPR000719
# 192_8644   MetX     20        878   IPR011009
# 199_659    MetX     20       1276   IPR000073
# 199_9059   MetX     20       1276   IPR029058
# 229_659    MetX     20       2632   IPR000073
# 229_9059   MetX     20       2632   IPR029058
# 238_409    MetX     20       3410   IPR018357
# 238_8640   MetX     20       3410   IPR011004
# 238_10043  MetX     20       3410   IPR001451
# 241_9076   MetX     20       3567   IPR032675
# 241_10045  MetX     20       3567   IPR001611
# 241_10056  MetX     20       3567   IPR003591
# 244_659    MetX     20       3615   IPR000073
# 244_9059   MetX     20       3615   IPR029058
# 256_38     MetX     20       3995   IPR018202
# 256_4096   MetX     20       3995   IPR001563
# 256_8548   MetX     20       3995   IPR008210
# 256_8720   MetX     20       3995   IPR013035
# 256_9059   MetX     20       3995   IPR029058
# 261_2393   MetX     24         41   IPR020846
# 261_5666   MetX     24         41   IPR011701
# 261_9263   MetX     24         41   IPR036259
# 275_409    MetX     24        731   IPR018357
# 275_8640   MetX     24        731   IPR011004
# 275_10043  MetX     24        731   IPR001451
# 276_8706   MetX     24        898   IPR012338
# 297_21     MetX     24       1822   IPR008271
# 297_126    MetX     24       1822   IPR017441
# 297_767    MetX     24       1822   IPR000719
# 297_8644   MetX     24       1822   IPR011009
# 299_9076   MetX     24       1858   IPR032675
# 299_10056  MetX     24       1858   IPR003591
# 322_9076   MetX     24       2632   IPR032675
# 322_10045  MetX     24       2632   IPR001611
# 332_659    MetX     24       3066   IPR000073
# 332_9059   MetX     24       3066   IPR029058
# 347_409    MetX     24       3707   IPR018357
# 347_8640   MetX     24       3707   IPR011004
# 347_10043  MetX     24       3707   IPR001451
#
#                                                InterPro Name      A_in  \
# 80_659                           Alpha/beta hydrolase fold-1  0.604529
# 80_9059                            Alpha/Beta hydrolase fold  0.559808
# 82_5515    Beta-hydroxyacyl-(acyl-carrier-protein) dehydr...  0.549541
# 82_5813    Beta-hydroxydecanoyl thiol ester dehydrase, Fa...  0.565334
# 136_659                          Alpha/beta hydrolase fold-1  1.283272
# 136_9059                           Alpha/Beta hydrolase fold  1.323345
# 145_9059                           Alpha/Beta hydrolase fold  1.561086
# 170_4594                     Undecaprenyl-diphosphatase UppP  1.132152
# 177_797               AMP-dependent synthetase/ligase domain  2.935064
# 177_2169                       Aldehyde dehydrogenase domain  2.456921
# 177_8825                   Aldehyde/histidinol dehydrogenase  2.455720
# 177_8826                  Aldehyde dehydrogenase, N-terminal  2.456921
# 177_8827                  Aldehyde dehydrogenase, C-terminal  2.456921
# 177_9990   AMP-binding enzyme, C-terminal domain superfamily  2.935064
# 189_2393                Major facilitator superfamily domain  1.100751
# 189_5666                       Major facilitator superfamily  1.029800
# 189_9263                         MFS transporter superfamily  1.119349
# 192_21          Serine/threonine-protein kinase, active site  1.067409
# 192_126                     Protein kinase, ATP binding site  0.960275
# 192_767                                Protein kinase domain  1.004173
# 192_8644              Protein kinase-like domain superfamily  0.833855
# 199_659                          Alpha/beta hydrolase fold-1  1.036726
# 199_9059                           Alpha/Beta hydrolase fold  1.106537
# 229_659                          Alpha/beta hydrolase fold-1  3.268316
# 229_9059                           Alpha/Beta hydrolase fold  2.097037
# 238_409              Hexapeptide transferase, conserved site  0.702238
# 238_8640                      Trimeric LpxA-like superfamily  0.645120
# 238_10043                                 Hexapeptide repeat  0.717845
# 241_9076              Leucine-rich repeat domain superfamily  0.646688
# 241_10045                                Leucine-rich repeat  0.638234
# 241_10056               Leucine-rich repeat, typical subtype  0.813662
# 244_659                          Alpha/beta hydrolase fold-1  2.274716
# 244_9059                           Alpha/Beta hydrolase fold  2.113031
# 256_38           Serine carboxypeptidase, serine active site  2.240122
# 256_4096              Peptidase S10, serine carboxypeptidase  2.388471
# 256_8548       Phosphoenolpyruvate carboxykinase, N-terminal  0.706615
# 256_8720       Phosphoenolpyruvate carboxykinase, C-terminal  0.706615
# 256_9059                           Alpha/Beta hydrolase fold  1.093358
# 261_2393                Major facilitator superfamily domain  2.061526
# 261_5666                       Major facilitator superfamily  1.993320
# 261_9263                         MFS transporter superfamily  2.373478
# 275_409              Hexapeptide transferase, conserved site  0.739274
# 275_8640                      Trimeric LpxA-like superfamily  0.696902
# 275_10043                                 Hexapeptide repeat  0.752324
# 276_8706                  Beta-lactamase/transpeptidase-like  1.619063
# 297_21          Serine/threonine-protein kinase, active site  1.740713
# 297_126                     Protein kinase, ATP binding site  1.548477
# 297_767                                Protein kinase domain  1.611925
# 297_8644              Protein kinase-like domain superfamily  1.363167
# 299_9076              Leucine-rich repeat domain superfamily  0.585374
# 299_10056               Leucine-rich repeat, typical subtype  0.750812
# 322_9076              Leucine-rich repeat domain superfamily  0.904453
# 322_10045                                Leucine-rich repeat  0.894843
# 332_659                          Alpha/beta hydrolase fold-1  1.384918
# 332_9059                           Alpha/Beta hydrolase fold  1.702902
# 347_409              Hexapeptide transferase, conserved site  0.738210
# 347_8640                      Trimeric LpxA-like superfamily  0.675270
# 347_10043                                 Hexapeptide repeat  0.751847
#
#               A_out      L2FC  Bonferroni adj. p-value
# 80_659     0.007763  6.281209             3.070172e-14
# 80_9059    0.005224  6.740910             0.000000e+00
# 82_5515    0.002915  7.553611             2.303711e-04
# 82_5813    0.002730  7.688618             8.962103e-08
# 136_659    0.026213  5.612868             8.708278e-06
# 136_9059   0.020013  6.046389             0.000000e+00
# 145_9059   0.022779  6.098062             0.000000e+00
# 170_4594   0.032733  5.111751             2.038676e-06
# 177_797    0.044304  6.049480             1.535564e-02
# 177_2169   0.043235  5.828182             1.386195e-07
# 177_8825   0.042270  5.860032             1.722333e-10
# 177_8826   0.043235  5.828182             1.386195e-07
# 177_8827   0.043235  5.828182             1.386195e-07
# 177_9990   0.044304  6.049480             1.535564e-02
# 189_2393   0.026312  5.386091             8.563810e-19
# 189_5666   0.027366  5.233326             7.136852e-13
# 189_9263   0.024599  5.507359             1.460178e-29
# 192_21     0.018165  5.875982             4.822177e-32
# 192_126    0.019009  5.657915             1.017561e-29
# 192_767    0.017405  5.849547             0.000000e+00
# 192_8644   0.017252  5.594130             0.000000e+00
# 199_659    0.017040  5.926127             6.427711e-08
# 199_9059   0.011774  6.553029             0.000000e+00
# 229_659    0.034831  6.551633             1.250094e-04
# 229_9059   0.026963  6.280706             6.118074e-21
# 238_409    0.018665  5.232786             5.400885e-06
# 238_8640   0.017636  5.192122             8.065174e-19
# 238_10043  0.017936  5.321970             3.390490e-13
# 241_9076   0.016151  5.322513             6.153167e-13
# 241_10045  0.016422  5.279501             1.267719e-09
# 241_10056  0.016754  5.600986             4.784869e-03
# 244_659    0.040920  5.796384             2.239325e-04
# 244_9059   0.031380  6.072880             4.056374e-37
# 256_38     0.018040  6.955416             4.092521e-03
# 256_4096   0.017447  7.096148             1.195451e-05
# 256_8548   0.019130  5.206231             1.899686e-05
# 256_8720   0.019130  5.206231             1.899686e-05
# 256_9059   0.013012  6.391702             0.000000e+00
# 261_2393   0.045099  5.514150             1.203750e-16
# 261_5666   0.046901  5.409095             3.062357e-11
# 261_9263   0.040492  5.872878             1.909631e-26
# 275_409    0.022156  5.059705             2.361393e-05
# 275_8640   0.021013  5.050891             1.279508e-17
# 275_10043  0.021400  5.135000             3.297988e-12
# 276_8706   0.049485  5.031730             2.095319e-04
# 297_21     0.034820  5.643209             8.078916e-28
# 297_126    0.036281  5.415103             9.803431e-26
# 297_767    0.033748  5.577410             4.096938e-35
# 297_8644   0.033318  5.354096             0.000000e+00
# 299_9076   0.017818  5.037136             2.989763e-11
# 299_10056  0.018342  5.354481             3.596360e-02
# 322_9076   0.019290  5.550397             7.063917e-11
# 322_10045  0.019666  5.507145             6.113173e-06
# 332_659    0.032081  5.431467             2.296502e-04
# 332_9059   0.023667  6.168375             0.000000e+00
# 347_409    0.015649  5.558921             1.806917e-06
# 347_8640   0.014572  5.533245             9.245827e-20
# 347_10043  0.014887  5.657383             6.261721e-14

# %%
df_metx_results.query("Case == 'Top2'")#.sort_values(by="Bonferroni adj. p-value")
# Out:
#           Case  Layer  Latent ID InterPro ID  \
# 46_9135   Top2      4       3717   IPR035977
# 46_3824   Top2      4       3717   IPR000473
# 72_781    Top2     12       1204   IPR000793
# 72_672    Top2     12       1204   IPR000194
# 72_58     Top2     12       1204   IPR020003
# ...        ...    ...        ...         ...
# 214_9912  Top2     20       1966   IPR042221
# 214_1058  Top2     20       1966   IPR002500
# 84_669    Top2     12       2474   IPR000182
# 214_1909  Top2     20       1966   IPR012795
# 214_5728  Top2     20       1966   IPR012094
#
#                                               InterPro Name  \
# 46_9135    Large ribosomal subunit protein bL36 superfamily
# 46_3824                Large ribosomal subunit protein bL36
# 72_781              ATP synthase, alpha subunit, C-terminal
# 72_672    ATPase, F1/V1/A1 complex, alpha/beta subunit, ...
# 72_58     ATPase, alpha/beta subunit, nucleotide-binding...
# ...                                                     ...
# 214_9912  Leucyl/phenylalanyl-tRNA-protein transferase, ...
# 214_1058  Phosphoadenosine phosphosulphate reductase domain
# 84_669                                          GNAT domain
# 214_1909            tRNA(Ile)-lysidine synthase, N-terminal
# 214_5728                        tRNA(Ile)-lysidine synthase
#
#           Activation w/ domain  Activation w/o domain      L2FC  \
# 46_9135               0.082034               0.001080  6.234466
# 46_3824               0.082034               0.001080  6.234466
# 72_781                0.297229               0.004520  6.036056
# 72_672                0.276573               0.004105  6.070641
# 72_58                 0.276573               0.004105  6.070641
# ...                        ...                    ...       ...
# 214_9912              6.532168               0.023353  8.127212
# 214_1058              1.451269               0.026912  5.752396
# 84_669                1.381740               0.022060  5.968279
# 214_1909              0.617451               0.027496  4.488513
# 214_5728              0.617451               0.027496  4.488513
#
#           Bonferroni adj. p-value
# 46_9135                  0.000000
# 46_3824                  0.000000
# 72_781                   0.000000
# 72_672                   0.000000
# 72_58                    0.000000
# ...                           ...
# 214_9912                 0.021919
# 214_1058                 0.028800
# 84_669                   0.034206
# 214_1909                 0.042795
# 214_5728                 0.042795
#
# [218 rows x 9 columns]

# %%
df_metx_results.to_csv('circuit_domain_detectors.csv', index=False)

# %%
print(df_metx_results.query("Case == 'Top2'").drop("Case", axis=1).to_latex(
    index=False, float_format="{:.2g}".format))
# Out:
# \begin{tabular}{rrllrrr}
# \toprule
# Layer & Latent ID & InterPro ID & InterPro Name & Activation w/ domain & Activation w/o domain & Bonferroni adj. p-value \\
# \midrule
# 12 & 1204 & IPR014762 & DNA mismatch repair, conserved site & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR019805 & Heat shock protein Hsp90, conserved site & 1.5 & 0.0042 & 2.9e-13 \\
# 12 & 1204 & IPR013507 & DNA mismatch repair protein, S5 domain 2-like & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR014790 & MutL, C-terminal, dimerisation & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR020575 & Heat shock protein Hsp90, N-terminal & 1.4 & 0.0041 & 3.9e-16 \\
# 12 & 1204 & IPR001404 & Heat shock protein Hsp90 family & 1.4 & 0.0041 & 3.9e-16 \\
# 12 & 1204 & IPR002099 & DNA mismatch repair protein MutL/Mlh/PMS & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR020667 & DNA mismatch repair protein, MutL & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR038973 & DNA mismatch repair protein MutL/Mlh/Pms-like & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR037196 & HSP90, C-terminal domain & 1.2 & 0.0044 & 3e-13 \\
# 12 & 1204 & IPR037198 & MutL, C-terminal domain superfamily & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR042120 & MutL, C-terminal domain, dimerisation subdomain & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1204 & IPR042121 & MutL, C-terminal domain, regulatory subdomain & 1.5 & 0.0045 & 1.6e-07 \\
# 12 & 1796 & IPR019805 & Heat shock protein Hsp90, conserved site & 1.6 & 0.0081 & 9e-05 \\
# 12 & 1796 & IPR003661 & Signal transduction histidine kinase, dimerisation/phosphoacceptor domain & 1.7 & 0.0082 & 0.004 \\
# 12 & 1796 & IPR004358 & Signal transduction histidine kinase-related protein, C-terminal & 1.8 & 0.008 & 8.2e-05 \\
# 12 & 1796 & IPR005467 & Histidine kinase domain & 1.8 & 0.008 & 8.2e-05 \\
# 12 & 1796 & IPR020575 & Heat shock protein Hsp90, N-terminal & 1.6 & 0.008 & 1.9e-06 \\
# 12 & 1796 & IPR001404 & Heat shock protein Hsp90 family & 1.6 & 0.008 & 1.9e-06 \\
# 12 & 1796 & IPR036097 & Signal transduction histidine kinase, dimerisation/phosphoacceptor domain superfamily & 1.8 & 0.008 & 8.2e-05 \\
# 12 & 1796 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.7 & 0.0041 & 0 \\
# 12 & 1796 & IPR037196 & HSP90, C-terminal domain & 1.3 & 0.0083 & 9.3e-05 \\
# 12 & 2474 & IPR000182 & GNAT domain & 1.4 & 0.022 & 0.034 \\
# 12 & 2474 & IPR016181 & Acyl-CoA N-acyltransferase & 1.7 & 0.02 & 3.6e-12 \\
# 16 & 737 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.8 & 0.021 & 4.6e-06 \\
# 16 & 1166 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.5 & 0.011 & 1e-20 \\
# 16 & 1280 & IPR020575 & Heat shock protein Hsp90, N-terminal & 5.7 & 0.012 & 0.017 \\
# 16 & 1280 & IPR001404 & Heat shock protein Hsp90 family & 5.7 & 0.012 & 0.017 \\
# 16 & 1280 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 3.1 & 0.007 & 1.7e-12 \\
# 20 & 659 & IPR020097 & Pseudouridine synthase I, TruA, alpha/beta domain & 1.1 & 0.028 & 5e-06 \\
# 20 & 659 & IPR001406 & Pseudouridine synthase I, TruA & 1.1 & 0.028 & 5e-06 \\
# 20 & 659 & IPR020095 & Pseudouridine synthase I, TruA, C-terminal & 1.1 & 0.028 & 5e-06 \\
# 20 & 659 & IPR029046 & Lipoprotein localisation LolA/LolB/LppX & 2.1 & 0.027 & 0.011 \\
# 20 & 865 & IPR013025 & Large ribosomal subunit protein uL23-like & 1.1 & 0.046 & 2e-05 \\
# 20 & 865 & IPR012678 & Ribosomal protein uL23/eL15/eS24 core domain superfamily & 1.1 & 0.046 & 1.6e-05 \\
# 20 & 1966 & IPR000182 & GNAT domain & 3.2 & 0.024 & 5.7e-09 \\
# 20 & 1966 & IPR002500 & Phosphoadenosine phosphosulphate reductase domain & 1.5 & 0.027 & 0.029 \\
# 20 & 1966 & IPR004616 & Leucyl/phenylalanyl-tRNA-protein transferase & 6.5 & 0.023 & 0.001 \\
# 20 & 1966 & IPR008210 & Phosphoenolpyruvate carboxykinase, N-terminal & 1.1 & 0.027 & 3.3e-06 \\
# 20 & 1966 & IPR013035 & Phosphoenolpyruvate carboxykinase, C-terminal & 1.1 & 0.027 & 3.3e-06 \\
# 20 & 1966 & IPR016181 & Acyl-CoA N-acyltransferase & 4.7 & 0.016 & 3e-26 \\
# 20 & 1966 & IPR042203 & Leucyl/phenylalanyl-tRNA-protein transferase, C-terminal & 6.5 & 0.023 & 0.001 \\
# 20 & 1966 & IPR042221 & Leucyl/phenylalanyl-tRNA-protein transferase, N-terminal & 6.5 & 0.023 & 0.022 \\
# 20 & 2311 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 2.1 & 0.016 & 1.7e-15 \\
# 20 & 3972 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 3.4 & 0.0069 & 2.5e-19 \\
# 24 & 2998 & IPR029044 & Nucleotide-diphospho-sugar transferases & 1.7 & 0.043 & 1.6e-23 \\
# \bottomrule
# \end{tabular}

# %%
print(df_metx_results.query("Case == 'MetX'").drop("Case", axis=1).to_latex(
    index=False, float_format="{:.2g}".format))
# Out:
# \begin{tabular}{rrllrrr}
# \toprule
# Layer & Latent ID & InterPro ID & InterPro Name & Activation w/ domain & Activation w/o domain & Bonferroni adj. p-value \\
# \midrule
# 16 & 1504 & IPR000073 & Alpha/beta hydrolase fold-1 & 1.3 & 0.026 & 8.7e-06 \\
# 16 & 1504 & IPR029058 & Alpha/Beta hydrolase fold & 1.3 & 0.02 & 0 \\
# 16 & 2175 & IPR029058 & Alpha/Beta hydrolase fold & 1.6 & 0.023 & 0 \\
# 16 & 2836 & IPR029058 & Alpha/Beta hydrolase fold & 1.3 & 0.045 & 3e-35 \\
# 16 & 3765 & IPR003824 & Undecaprenyl-diphosphatase UppP & 1.1 & 0.033 & 2e-06 \\
# 20 & 142 & IPR000873 & AMP-dependent synthetase/ligase domain & 2.9 & 0.044 & 0.015 \\
# 20 & 142 & IPR015590 & Aldehyde dehydrogenase domain & 2.5 & 0.043 & 1.4e-07 \\
# 20 & 142 & IPR016161 & Aldehyde/histidinol dehydrogenase & 2.5 & 0.042 & 1.7e-10 \\
# 20 & 142 & IPR016162 & Aldehyde dehydrogenase, N-terminal & 2.5 & 0.043 & 1.4e-07 \\
# 20 & 142 & IPR016163 & Aldehyde dehydrogenase, C-terminal & 2.5 & 0.043 & 1.4e-07 \\
# 20 & 142 & IPR045851 & AMP-binding enzyme, C-terminal domain superfamily & 2.9 & 0.044 & 0.015 \\
# 20 & 838 & IPR020846 & Major facilitator superfamily domain & 1.1 & 0.026 & 8.6e-19 \\
# 20 & 838 & IPR036259 & MFS transporter superfamily & 1.1 & 0.025 & 1.5e-29 \\
# 20 & 878 & IPR008271 & Serine/threonine-protein kinase, active site & 1.1 & 0.018 & 4.8e-32 \\
# 20 & 1276 & IPR029058 & Alpha/Beta hydrolase fold & 1.1 & 0.012 & 0 \\
# 20 & 2632 & IPR000073 & Alpha/beta hydrolase fold-1 & 3.3 & 0.035 & 0.00013 \\
# 20 & 2632 & IPR029058 & Alpha/Beta hydrolase fold & 2.1 & 0.027 & 6.1e-21 \\
# 20 & 3615 & IPR000073 & Alpha/beta hydrolase fold-1 & 2.3 & 0.041 & 0.00022 \\
# 20 & 3615 & IPR029058 & Alpha/Beta hydrolase fold & 2.1 & 0.031 & 4.1e-37 \\
# 20 & 3995 & IPR018202 & Serine carboxypeptidase, serine active site & 2.2 & 0.018 & 0.0041 \\
# 20 & 3995 & IPR001563 & Peptidase S10, serine carboxypeptidase & 2.4 & 0.017 & 1.2e-05 \\
# 20 & 3995 & IPR029058 & Alpha/Beta hydrolase fold & 1.1 & 0.013 & 0 \\
# 24 & 41 & IPR020846 & Major facilitator superfamily domain & 2.1 & 0.045 & 1.2e-16 \\
# 24 & 41 & IPR011701 & Major facilitator superfamily & 2 & 0.047 & 3.1e-11 \\
# 24 & 41 & IPR036259 & MFS transporter superfamily & 2.4 & 0.04 & 1.9e-26 \\
# 24 & 471 & IPR029044 & Nucleotide-diphospho-sugar transferases & 1.3 & 0.042 & 2.3e-26 \\
# 24 & 898 & IPR012338 & Beta-lactamase/transpeptidase-like & 1.6 & 0.049 & 0.00021 \\
# 24 & 1822 & IPR008271 & Serine/threonine-protein kinase, active site & 1.7 & 0.035 & 8.1e-28 \\
# 24 & 1822 & IPR017441 & Protein kinase, ATP binding site & 1.5 & 0.036 & 9.8e-26 \\
# 24 & 1822 & IPR000719 & Protein kinase domain & 1.6 & 0.034 & 4.1e-35 \\
# 24 & 1822 & IPR011009 & Protein kinase-like domain superfamily & 1.4 & 0.033 & 0 \\
# 24 & 3065 & IPR029058 & Alpha/Beta hydrolase fold & 1.4 & 0.047 & 1.7e-21 \\
# 24 & 3066 & IPR000073 & Alpha/beta hydrolase fold-1 & 1.4 & 0.032 & 0.00023 \\
# 24 & 3066 & IPR029058 & Alpha/Beta hydrolase fold & 1.7 & 0.024 & 0 \\
# 24 & 3196 & IPR033704 & dUTPase, trimeric & 1.1 & 0.037 & 0.00013 \\
# 24 & 3196 & IPR036157 & dUTPase-like superfamily & 1.1 & 0.037 & 0.00013 \\
# \bottomrule
# \end{tabular}
