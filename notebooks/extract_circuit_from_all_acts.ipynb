# %%
import sys
import os
import json
import torch

import pandas as pd
import numpy as np

from scipy.sparse import csr_matrix, save_npz, load_npz
from scipy.stats import mannwhitneyu

# %%
base_path = '/project/pi_annagreen_umass_edu/bryn/plm_circuit_enrichment/'

# %%
interpro_annotations_nonzero = pd.read_csv(base_path + "metadata/interpro_entry_list_mapping_nonzero.csv")
ptn_fam_nonzero_tensor = torch.load(base_path + "metadata/ptn_fam_tensor_nonzero.pt")

latents_family_effect_size = torch.load(base_path + "latents_family_effect_size_circuit.pt")
latents_family_pvals = torch.load(base_path + "latents_family_pvals_circuit.pt")
# Out:
# /tmp/ipykernel_158963/744292708.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ptn_fam_nonzero_tensor = torch.load(base_path + "metadata/ptn_fam_tensor_nonzero.pt")
# /tmp/ipykernel_158963/744292708.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   latents_family_effect_size = torch.load(base_path + "latents_family_effect_size_circuit.pt")
# /tmp/ipykernel_158963/744292708.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   latents_family_pvals = torch.load(base_path + "latents_family_pvals_circuit.pt")

# %%
print(f"Interpro Annotations: {interpro_annotations_nonzero.shape}")
print(f"ptn_fam_nonzero_tensor: {ptn_fam_nonzero_tensor.shape}")
print(f"Effect sizes: {latents_family_effect_size.shape}")
print(f"MWU pvals: {latents_family_pvals.shape}")
# Out:
# Interpro Annotations: (10096, 3)
# ptn_fam_nonzero_tensor: torch.Size([10000, 10096])
# Effect sizes: torch.Size([383, 10096, 4])
# MWU pvals: torch.Size([383, 10096])

# %%
interpro_annotations_nonzero.head()
# Out:
#     ENTRY_AC   ENTRY_TYPE                                         ENTRY_NAME
# 0  IPR000126  Active_site    Serine proteases, V8 family, serine active site
# 1  IPR000169  Active_site           Cysteine peptidase, cysteine active site
# 2  IPR000189  Active_site          Prokaryotic transglycosylase, active site
# 3  IPR001252  Active_site                  Malate dehydrogenase, active site
# 4  IPR001345  Active_site  Phosphoglycerate/bisphosphoglycerate mutase, a...

# %%
with open(base_path + "../../jatin/plm_circuits/layer_latent_dict_metx.json", 'r') as file:
    metx_latents = json.load(file)

with open(base_path + "../../jatin/plm_circuits/layer_latent_dict_top2.json", 'r') as file:
    top2_latents = json.load(file)

# %%
offsets = {k: i*4096 for i,k in enumerate(metx_latents.keys())}
full_indices_metx = [j+offsets[layer_id] for layer_id in metx_latents.keys() for j in metx_latents[layer_id]]
full_indices_top2 = [j+offsets[layer_id] for layer_id in top2_latents.keys() for j in top2_latents[layer_id]]
latent_ids_both_proteins = list(set(full_indices_top2+full_indices_metx))
latent_ids_both_proteins.sort()
len(latent_ids_both_proteins) # yes, only 383 unique
# Out:
# 383

# %%
n_tests = 28672*10096
epsilon = 1e-4
annotated_latents = []
for latent_i in range(latents_family_pvals.shape[0]):
    for family_j in range(latents_family_pvals.shape[1]):
        if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
            if latents_family_effect_size[latent_i,family_j,1] < 0.05:
                l2fc = np.log2((latents_family_effect_size[latent_i,family_j,0]+epsilon)/ (latents_family_effect_size[latent_i,family_j,1]+epsilon))
                if l2fc >= 4:  # latents_family_effect_size[latent_i,family_j,0] > 1.05: #
                    annotated_latents += [latent_ids_both_proteins[latent_i]]
                    # print(f"Latent {latent_ids_both_proteins[latent_i]} is sig assoc w family {family_j}")
                    # print(f"    Family {interpro_annotations_nonzero.iloc[family_j]["ENTRY_NAME"]}")
                    # print(f"    Mean in-family: {latents_family_effect_size[latent_i,family_j,0]}")
                    # print(f"    Mean out-of-family: {latents_family_effect_size[latent_i,family_j,1]}")
                    # print(f"    Log2FC: {np.log2(latents_family_effect_size[latent_i,family_j,0]+epsilon/latents_family_effect_size[latent_i,family_j,1]+epsilon)}")

# %%
ann_latents_list = list(set(annotated_latents))

# %%
metx_results_df_dict = {}
for latent_i in range(latents_family_pvals.shape[0]):
    for family_j in range(latents_family_pvals.shape[1]):
        if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
            if latents_family_effect_size[latent_i,family_j,1] < 0.05:
                ratio = (latents_family_effect_size[latent_i,family_j,0]+epsilon)/ (latents_family_effect_size[latent_i,family_j,1]+epsilon)
                l2fc = np.log2(ratio)
                if l2fc >= 4:  # latents_family_effect_size[latent_i,family_j,0] > 1.05:

                    df_id = str(latent_i)+"_"+str(family_j)
                    cur_lat_id = latent_ids_both_proteins[latent_i]
                    layer_id = ((cur_lat_id // 4096)+1)*4
                    lat_id = cur_lat_id % 4096

                    case_ptn = "MetX"
                    if latent_ids_both_proteins[latent_i] in full_indices_top2:
                        case_ptn="Top2"

                    metx_results_df_dict[df_id] = {
                        "Case": case_ptn,
                        "Layer": layer_id,
                        "Latent ID": lat_id,
                        "InterPro ID": interpro_annotations_nonzero.iloc[family_j]["ENTRY_AC"],
                        "InterPro Name": interpro_annotations_nonzero.iloc[family_j]["ENTRY_NAME"],
                        "A_in": float(latents_family_effect_size[latent_i,family_j,0]),
                        "A_out": float(latents_family_effect_size[latent_i,family_j,1]),
                        "L2FC": float(l2fc),
                        "Ratio": float(ratio),
                        "Bonferroni adj. p-value": float(latents_family_pvals[latent_i,family_j]*n_tests)
                    }

# %%
df_metx_results = pd.DataFrame.from_dict(metx_results_df_dict, orient='index')
df_metx_results.head()
# Out:
#          Case  Layer  Latent ID InterPro ID  \
# 13_3824  Top2      4       1297   IPR000473
# 13_5069  Top2      4       1297   IPR005996
# 13_9135  Top2      4       1297   IPR035977
# 46_128   Top2      4       3717   IPR018064
# 46_3724  Top2      4       3717   IPR000006
#
#                                              InterPro Name      A_in  \
# 13_3824               Large ribosomal subunit protein bL36  0.073116
# 13_5069  Large ribosomal subunit protein uL30, bacteria...  0.057346
# 13_9135   Large ribosomal subunit protein bL36 superfamily  0.073116
# 46_128     Metallothionein, vertebrate, metal binding site  0.040059
# 46_3724                        Metallothionein, vertebrate  0.040059
#
#             A_out      L2FC      Ratio  Bonferroni adj. p-value
# 13_3824  0.003320  4.419955  21.406178             6.988324e-07
# 13_5069  0.003392  4.040099  16.450954             7.427055e-05
# 13_9135  0.003320  4.419955  21.406178             6.988324e-07
# 46_128   0.001214  4.934134  30.571896             5.300378e-05
# 46_3724  0.001214  4.934134  30.571896             5.300378e-05

# %%
df_metx_results.query("Case == 'Top2' and L2FC > 6") # and A_in >= 0.1")#.sort_values(by="Bonferroni adj. p-value")
# Out:
#           Case  Layer  Latent ID InterPro ID  \
# 46_3824   Top2      4       3717   IPR000473
# 46_9135   Top2      4       3717   IPR035977
# 72_58     Top2     12       1204   IPR020003
# 72_274    Top2     12       1204   IPR014762
# 72_457    Top2     12       1204   IPR019805
# 72_672    Top2     12       1204   IPR000194
# 72_781    Top2     12       1204   IPR000793
# 72_1283   Top2     12       1204   IPR004100
# 72_2000   Top2     12       1204   IPR013507
# 72_2113   Top2     12       1204   IPR014790
# 72_2370   Top2     12       1204   IPR020575
# 72_2871   Top2     12       1204   IPR033732
# 72_4065   Top2     12       1204   IPR001404
# 72_4238   Top2     12       1204   IPR002099
# 72_4895   Top2     12       1204   IPR005294
# 72_6308   Top2     12       1204   IPR020667
# 72_7213   Top2     12       1204   IPR038973
# 72_9559   Top2     12       1204   IPR036890
# 72_9682   Top2     12       1204   IPR037196
# 72_9684   Top2     12       1204   IPR037198
# 72_9784   Top2     12       1204   IPR038376
# 72_9897   Top2     12       1204   IPR042120
# 72_9898   Top2     12       1204   IPR042121
# 77_457    Top2     12       1796   IPR019805
# 77_1229   Top2     12       1796   IPR003661
# 77_1324   Top2     12       1796   IPR004358
# 77_1401   Top2     12       1796   IPR005467
# 77_2370   Top2     12       1796   IPR020575
# 77_4065   Top2     12       1796   IPR001404
# 77_9193   Top2     12       1796   IPR036097
# 77_9559   Top2     12       1796   IPR036890
# 77_9682   Top2     12       1796   IPR037196
# 84_8834   Top2     12       2474   IPR016181
# 103_8654  Top2     12       3943   IPR011032
# 114_9559  Top2     16        631   IPR036890
# 116_9559  Top2     16        737   IPR036890
# 123_9559  Top2     16       1166   IPR036890
# 127_2370  Top2     16       1280   IPR020575
# 127_4065  Top2     16       1280   IPR001404
# 127_8865  Top2     16       1280   IPR020568
# 127_9559  Top2     16       1280   IPR036890
# 184_9052  Top2     20        659   IPR029046
# 214_669   Top2     20       1966   IPR000182
# 214_4765  Top2     20       1966   IPR004616
# 214_8834  Top2     20       1966   IPR016181
# 214_9910  Top2     20       1966   IPR042203
# 214_9912  Top2     20       1966   IPR042221
# 220_9559  Top2     20       2311   IPR036890
# 255_9559  Top2     20       3972   IPR036890
#
#                                               InterPro Name      A_in  \
# 46_3824                Large ribosomal subunit protein bL36  0.082034
# 46_9135    Large ribosomal subunit protein bL36 superfamily  0.082034
# 72_58     ATPase, alpha/beta subunit, nucleotide-binding...  0.276573
# 72_274                  DNA mismatch repair, conserved site  1.490237
# 72_457             Heat shock protein Hsp90, conserved site  1.455940
# 72_672    ATPase, F1/V1/A1 complex, alpha/beta subunit, ...  0.276573
# 72_781              ATP synthase, alpha subunit, C-terminal  0.297229
# 72_1283   ATPase, F1/V1/A1 complex, alpha/beta subunit, ...  0.275467
# 72_2000       DNA mismatch repair protein, S5 domain 2-like  1.490237
# 72_2113                      MutL, C-terminal, dimerisation  1.490237
# 72_2370                Heat shock protein Hsp90, N-terminal  1.424645
# 72_2871   ATP synthase, F1 complex, alpha subunit nucleo...  0.297229
# 72_4065                     Heat shock protein Hsp90 family  1.424645
# 72_4238            DNA mismatch repair protein MutL/Mlh/PMS  1.490237
# 72_4895             ATP synthase, F1 complex, alpha subunit  0.297229
# 72_6308                   DNA mismatch repair protein, MutL  1.490237
# 72_7213       DNA mismatch repair protein MutL/Mlh/Pms-like  1.490237
# 72_9559      Histidine kinase/HSP90-like ATPase superfamily  0.811589
# 72_9682                            HSP90, C-terminal domain  1.205773
# 72_9684                 MutL, C-terminal domain superfamily  1.490237
# 72_9784   ATP synthase, alpha subunit, C-terminal domain...  0.297229
# 72_9897     MutL, C-terminal domain, dimerisation subdomain  1.490237
# 72_9898       MutL, C-terminal domain, regulatory subdomain  1.490237
# 77_457             Heat shock protein Hsp90, conserved site  1.598966
# 77_1229   Signal transduction histidine kinase, dimerisa...  1.744758
# 77_1324   Signal transduction histidine kinase-related p...  1.785921
# 77_1401                             Histidine kinase domain  1.785921
# 77_2370                Heat shock protein Hsp90, N-terminal  1.562573
# 77_4065                     Heat shock protein Hsp90 family  1.562573
# 77_9193   Signal transduction histidine kinase, dimerisa...  1.785921
# 77_9559      Histidine kinase/HSP90-like ATPase superfamily  1.655666
# 77_9682                            HSP90, C-terminal domain  1.292645
# 84_8834                          Acyl-CoA N-acyltransferase  1.690485
# 103_8654                             GroES-like superfamily  0.484166
# 114_9559     Histidine kinase/HSP90-like ATPase superfamily  0.860373
# 116_9559     Histidine kinase/HSP90-like ATPase superfamily  1.781145
# 123_9559     Histidine kinase/HSP90-like ATPase superfamily  1.522638
# 127_2370               Heat shock protein Hsp90, N-terminal  5.745351
# 127_4065                    Heat shock protein Hsp90 family  5.745351
# 127_8865    Ribosomal protein uS5 domain 2-type superfamily  0.694470
# 127_9559     Histidine kinase/HSP90-like ATPase superfamily  3.101735
# 184_9052            Lipoprotein localisation LolA/LolB/LppX  2.129256
# 214_669                                         GNAT domain  3.190243
# 214_4765       Leucyl/phenylalanyl-tRNA-protein transferase  6.507967
# 214_8834                         Acyl-CoA N-acyltransferase  4.682979
# 214_9910  Leucyl/phenylalanyl-tRNA-protein transferase, ...  6.507967
# 214_9912  Leucyl/phenylalanyl-tRNA-protein transferase, ...  6.532168
# 220_9559     Histidine kinase/HSP90-like ATPase superfamily  2.126981
# 255_9559     Histidine kinase/HSP90-like ATPase superfamily  3.437108
#
#              A_out      L2FC       Ratio  Bonferroni adj. p-value
# 46_3824   0.001080  6.121716   69.633804             0.000000e+00
# 46_9135   0.001080  6.121716   69.633804             0.000000e+00
# 72_58     0.004105  6.039948   65.796936             0.000000e+00
# 72_274    0.004479  8.346327  325.457825             1.594212e-07
# 72_457    0.004206  8.401531  338.152710             2.943538e-13
# 72_672    0.004105  6.039948   65.796936             0.000000e+00
# 72_781    0.004520  6.008157   64.362862             0.000000e+00
# 72_1283   0.004137  6.023296   65.041840             0.000000e+00
# 72_2000   0.004479  8.346327  325.457825             1.594212e-07
# 72_2113   0.004479  8.346327  325.457825             1.594212e-07
# 72_2370   0.004086  8.411043  340.389496             3.936193e-16
# 72_2871   0.004520  6.008157   64.362862             0.000000e+00
# 72_4065   0.004086  8.411043  340.389496             3.936193e-16
# 72_4238   0.004479  8.346327  325.457825             1.594212e-07
# 72_4895   0.004520  6.008157   64.362862             0.000000e+00
# 72_6308   0.004479  8.346327  325.457825             1.594212e-07
# 72_7213   0.004479  8.346327  325.457825             1.594212e-07
# 72_9559   0.002715  8.171870  288.388489             0.000000e+00
# 72_9682   0.004381  8.072007  269.101593             3.014633e-13
# 72_9684   0.004479  8.346327  325.457825             1.594212e-07
# 72_9784   0.004520  6.008157   64.362862             0.000000e+00
# 72_9897   0.004479  8.346327  325.457825             1.594212e-07
# 72_9898   0.004479  8.346327  325.457825             1.594212e-07
# 77_457    0.008104  7.606666  194.910156             9.000002e-05
# 77_1229   0.008176  7.720000  210.839279             4.010378e-03
# 77_1324   0.007973  7.789401  221.229645             8.173953e-05
# 77_1401   0.007973  7.789401  221.229645             8.173953e-05
# 77_2370   0.007974  7.596510  193.542923             1.896858e-06
# 77_4065   0.007974  7.596510  193.542923             1.896858e-06
# 77_9193   0.007973  7.789401  221.229645             8.173953e-05
# 77_9559   0.004098  8.623631  394.431305             0.000000e+00
# 77_9682   0.008319  7.262627  153.556580             9.254814e-05
# 84_8834   0.019514  6.429508   86.193565             3.578099e-12
# 103_8654  0.007277  6.036601   65.644440             1.924977e-05
# 114_9559  0.012289  6.118029   69.456093             4.845783e-23
# 116_9559  0.020811  6.412501   85.183418             4.647273e-06
# 123_9559  0.010726  7.136023  140.655533             1.017908e-20
# 127_2370  0.011985  8.893061  475.420563             1.673163e-02
# 127_4065  0.011985  8.893061  475.420563             1.673163e-02
# 127_8865  0.007225  6.567117   94.819817             1.973771e-15
# 127_9559  0.006978  8.775578  438.240265             1.729629e-12
# 184_9052  0.027154  6.287828   78.131294             1.052378e-02
# 214_669   0.024109  7.041994  131.780609             5.667186e-09
# 214_4765  0.022721  8.155745  285.183136             9.995315e-04
# 214_8834  0.016242  8.162727  286.566772             2.976969e-26
# 214_9910  0.022721  8.155745  285.183136             9.995315e-04
# 214_9912  0.023353  8.121687  278.529663             2.191872e-02
# 220_9559  0.015656  7.076869  135.004990             1.698489e-15
# 255_9559  0.006915  8.936510  489.956604             2.450431e-19

# %%
print(df_metx_results.query("Case == 'Top2' and L2FC > 6").drop("Case", axis=1).to_latex(
    index=False, float_format="{:.2g}".format))
# Out:
# \begin{tabular}{rrllrrrrr}
# \toprule
# Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# 4 & 3717 & IPR000473 & Large ribosomal subunit protein bL36 & 0.082 & 0.0011 & 6.1 & 70 & 0 \\
# 4 & 3717 & IPR035977 & Large ribosomal subunit protein bL36 superfamily & 0.082 & 0.0011 & 6.1 & 70 & 0 \\
# 12 & 1204 & IPR020003 & ATPase, alpha/beta subunit, nucleotide-binding domain, active site & 0.28 & 0.0041 & 6 & 66 & 0 \\
# 12 & 1204 & IPR014762 & DNA mismatch repair, conserved site & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR019805 & Heat shock protein Hsp90, conserved site & 1.5 & 0.0042 & 8.4 & 3.4e+02 & 2.9e-13 \\
# 12 & 1204 & IPR000194 & ATPase, F1/V1/A1 complex, alpha/beta subunit, nucleotide-binding domain & 0.28 & 0.0041 & 6 & 66 & 0 \\
# 12 & 1204 & IPR000793 & ATP synthase, alpha subunit, C-terminal & 0.3 & 0.0045 & 6 & 64 & 0 \\
# 12 & 1204 & IPR004100 & ATPase, F1/V1/A1 complex, alpha/beta subunit, N-terminal domain & 0.28 & 0.0041 & 6 & 65 & 0 \\
# 12 & 1204 & IPR013507 & DNA mismatch repair protein, S5 domain 2-like & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR014790 & MutL, C-terminal, dimerisation & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR020575 & Heat shock protein Hsp90, N-terminal & 1.4 & 0.0041 & 8.4 & 3.4e+02 & 3.9e-16 \\
# 12 & 1204 & IPR033732 & ATP synthase, F1 complex, alpha subunit nucleotide-binding domain & 0.3 & 0.0045 & 6 & 64 & 0 \\
# 12 & 1204 & IPR001404 & Heat shock protein Hsp90 family & 1.4 & 0.0041 & 8.4 & 3.4e+02 & 3.9e-16 \\
# 12 & 1204 & IPR002099 & DNA mismatch repair protein MutL/Mlh/PMS & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR005294 & ATP synthase, F1 complex, alpha subunit & 0.3 & 0.0045 & 6 & 64 & 0 \\
# 12 & 1204 & IPR020667 & DNA mismatch repair protein, MutL & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR038973 & DNA mismatch repair protein MutL/Mlh/Pms-like & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 0.81 & 0.0027 & 8.2 & 2.9e+02 & 0 \\
# 12 & 1204 & IPR037196 & HSP90, C-terminal domain & 1.2 & 0.0044 & 8.1 & 2.7e+02 & 3e-13 \\
# 12 & 1204 & IPR037198 & MutL, C-terminal domain superfamily & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR038376 & ATP synthase, alpha subunit, C-terminal domain superfamily & 0.3 & 0.0045 & 6 & 64 & 0 \\
# 12 & 1204 & IPR042120 & MutL, C-terminal domain, dimerisation subdomain & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR042121 & MutL, C-terminal domain, regulatory subdomain & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1796 & IPR019805 & Heat shock protein Hsp90, conserved site & 1.6 & 0.0081 & 7.6 & 1.9e+02 & 9e-05 \\
# 12 & 1796 & IPR003661 & Signal transduction histidine kinase, dimerisation/phosphoacceptor domain & 1.7 & 0.0082 & 7.7 & 2.1e+02 & 0.004 \\
# 12 & 1796 & IPR004358 & Signal transduction histidine kinase-related protein, C-terminal & 1.8 & 0.008 & 7.8 & 2.2e+02 & 8.2e-05 \\
# 12 & 1796 & IPR005467 & Histidine kinase domain & 1.8 & 0.008 & 7.8 & 2.2e+02 & 8.2e-05 \\
# 12 & 1796 & IPR020575 & Heat shock protein Hsp90, N-terminal & 1.6 & 0.008 & 7.6 & 1.9e+02 & 1.9e-06 \\
# 12 & 1796 & IPR001404 & Heat shock protein Hsp90 family & 1.6 & 0.008 & 7.6 & 1.9e+02 & 1.9e-06 \\
# 12 & 1796 & IPR036097 & Signal transduction histidine kinase, dimerisation/phosphoacceptor domain superfamily & 1.8 & 0.008 & 7.8 & 2.2e+02 & 8.2e-05 \\
# 12 & 1796 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.7 & 0.0041 & 8.6 & 3.9e+02 & 0 \\
# 12 & 1796 & IPR037196 & HSP90, C-terminal domain & 1.3 & 0.0083 & 7.3 & 1.5e+02 & 9.3e-05 \\
# 12 & 2474 & IPR016181 & Acyl-CoA N-acyltransferase & 1.7 & 0.02 & 6.4 & 86 & 3.6e-12 \\
# 12 & 3943 & IPR011032 & GroES-like superfamily & 0.48 & 0.0073 & 6 & 66 & 1.9e-05 \\
# 16 & 631 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 0.86 & 0.012 & 6.1 & 69 & 4.8e-23 \\
# 16 & 737 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.8 & 0.021 & 6.4 & 85 & 4.6e-06 \\
# 16 & 1166 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.5 & 0.011 & 7.1 & 1.4e+02 & 1e-20 \\
# 16 & 1280 & IPR020575 & Heat shock protein Hsp90, N-terminal & 5.7 & 0.012 & 8.9 & 4.8e+02 & 0.017 \\
# 16 & 1280 & IPR001404 & Heat shock protein Hsp90 family & 5.7 & 0.012 & 8.9 & 4.8e+02 & 0.017 \\
# 16 & 1280 & IPR020568 & Ribosomal protein uS5 domain 2-type superfamily & 0.69 & 0.0072 & 6.6 & 95 & 2e-15 \\
# 16 & 1280 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 3.1 & 0.007 & 8.8 & 4.4e+02 & 1.7e-12 \\
# 20 & 659 & IPR029046 & Lipoprotein localisation LolA/LolB/LppX & 2.1 & 0.027 & 6.3 & 78 & 0.011 \\
# 20 & 1966 & IPR000182 & GNAT domain & 3.2 & 0.024 & 7 & 1.3e+02 & 5.7e-09 \\
# 20 & 1966 & IPR004616 & Leucyl/phenylalanyl-tRNA-protein transferase & 6.5 & 0.023 & 8.2 & 2.9e+02 & 0.001 \\
# 20 & 1966 & IPR016181 & Acyl-CoA N-acyltransferase & 4.7 & 0.016 & 8.2 & 2.9e+02 & 3e-26 \\
# 20 & 1966 & IPR042203 & Leucyl/phenylalanyl-tRNA-protein transferase, C-terminal & 6.5 & 0.023 & 8.2 & 2.9e+02 & 0.001 \\
# 20 & 1966 & IPR042221 & Leucyl/phenylalanyl-tRNA-protein transferase, N-terminal & 6.5 & 0.023 & 8.1 & 2.8e+02 & 0.022 \\
# 20 & 2311 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 2.1 & 0.016 & 7.1 & 1.4e+02 & 1.7e-15 \\
# 20 & 3972 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 3.4 & 0.0069 & 8.9 & 4.9e+02 & 2.5e-19 \\
# \bottomrule
# \end{tabular}

# %%
latex = (
    df_metx_results.query("Case == 'Top2' and A_out < 0.05 and A_in > 1.05")
    .drop(columns=["Case"])
    .to_latex(index=False, float_format="{:.2g}".format, escape=False)
)
latex = (
    r"\setlength{\tabcolsep}{4pt}\small" "\n"
    r"\resizebox{\linewidth}{!}{%" "\n" + latex + "\n}"
)
print(latex)
# Out:
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{%
# \begin{tabular}{rrllrrrrr}
# \toprule
# Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# 12 & 1204 & IPR014762 & DNA mismatch repair, conserved site & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR019805 & Heat shock protein Hsp90, conserved site & 1.5 & 0.0042 & 8.4 & 3.4e+02 & 2.9e-13 \\
# 12 & 1204 & IPR013507 & DNA mismatch repair protein, S5 domain 2-like & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR014790 & MutL, C-terminal, dimerisation & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR020575 & Heat shock protein Hsp90, N-terminal & 1.4 & 0.0041 & 8.4 & 3.4e+02 & 3.9e-16 \\
# 12 & 1204 & IPR001404 & Heat shock protein Hsp90 family & 1.4 & 0.0041 & 8.4 & 3.4e+02 & 3.9e-16 \\
# 12 & 1204 & IPR002099 & DNA mismatch repair protein MutL/Mlh/PMS & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR020667 & DNA mismatch repair protein, MutL & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR038973 & DNA mismatch repair protein MutL/Mlh/Pms-like & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR037196 & HSP90, C-terminal domain & 1.2 & 0.0044 & 8.1 & 2.7e+02 & 3e-13 \\
# 12 & 1204 & IPR037198 & MutL, C-terminal domain superfamily & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR042120 & MutL, C-terminal domain, dimerisation subdomain & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1204 & IPR042121 & MutL, C-terminal domain, regulatory subdomain & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# 12 & 1796 & IPR019805 & Heat shock protein Hsp90, conserved site & 1.6 & 0.0081 & 7.6 & 1.9e+02 & 9e-05 \\
# 12 & 1796 & IPR003661 & Signal transduction histidine kinase, dimerisation/phosphoacceptor domain & 1.7 & 0.0082 & 7.7 & 2.1e+02 & 0.004 \\
# 12 & 1796 & IPR004358 & Signal transduction histidine kinase-related protein, C-terminal & 1.8 & 0.008 & 7.8 & 2.2e+02 & 8.2e-05 \\
# 12 & 1796 & IPR005467 & Histidine kinase domain & 1.8 & 0.008 & 7.8 & 2.2e+02 & 8.2e-05 \\
# 12 & 1796 & IPR020575 & Heat shock protein Hsp90, N-terminal & 1.6 & 0.008 & 7.6 & 1.9e+02 & 1.9e-06 \\
# 12 & 1796 & IPR001404 & Heat shock protein Hsp90 family & 1.6 & 0.008 & 7.6 & 1.9e+02 & 1.9e-06 \\
# 12 & 1796 & IPR036097 & Signal transduction histidine kinase, dimerisation/phosphoacceptor domain superfamily & 1.8 & 0.008 & 7.8 & 2.2e+02 & 8.2e-05 \\
# 12 & 1796 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.7 & 0.0041 & 8.6 & 3.9e+02 & 0 \\
# 12 & 1796 & IPR037196 & HSP90, C-terminal domain & 1.3 & 0.0083 & 7.3 & 1.5e+02 & 9.3e-05 \\
# 12 & 2474 & IPR000182 & GNAT domain & 1.4 & 0.022 & 6 & 62 & 0.034 \\
# 12 & 2474 & IPR016181 & Acyl-CoA N-acyltransferase & 1.7 & 0.02 & 6.4 & 86 & 3.6e-12 \\
# 16 & 737 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.8 & 0.021 & 6.4 & 85 & 4.6e-06 \\
# 16 & 1166 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.5 & 0.011 & 7.1 & 1.4e+02 & 1e-20 \\
# 16 & 1280 & IPR020575 & Heat shock protein Hsp90, N-terminal & 5.7 & 0.012 & 8.9 & 4.8e+02 & 0.017 \\
# 16 & 1280 & IPR001404 & Heat shock protein Hsp90 family & 5.7 & 0.012 & 8.9 & 4.8e+02 & 0.017 \\
# 16 & 1280 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 3.1 & 0.007 & 8.8 & 4.4e+02 & 1.7e-12 \\
# 20 & 659 & IPR020097 & Pseudouridine synthase I, TruA, alpha/beta domain & 1.1 & 0.028 & 5.3 & 39 & 5e-06 \\
# 20 & 659 & IPR001406 & Pseudouridine synthase I, TruA & 1.1 & 0.028 & 5.3 & 39 & 5e-06 \\
# 20 & 659 & IPR020095 & Pseudouridine synthase I, TruA, C-terminal & 1.1 & 0.028 & 5.3 & 39 & 5e-06 \\
# 20 & 659 & IPR029046 & Lipoprotein localisation LolA/LolB/LppX & 2.1 & 0.027 & 6.3 & 78 & 0.011 \\
# 20 & 865 & IPR013025 & Large ribosomal subunit protein uL23-like & 1.1 & 0.046 & 4.6 & 25 & 2e-05 \\
# 20 & 865 & IPR012678 & Ribosomal protein uL23/eL15/eS24 core domain superfamily & 1.1 & 0.046 & 4.5 & 23 & 1.6e-05 \\
# 20 & 1966 & IPR000182 & GNAT domain & 3.2 & 0.024 & 7 & 1.3e+02 & 5.7e-09 \\
# 20 & 1966 & IPR002500 & Phosphoadenosine phosphosulphate reductase domain & 1.5 & 0.027 & 5.7 & 54 & 0.029 \\
# 20 & 1966 & IPR004616 & Leucyl/phenylalanyl-tRNA-protein transferase & 6.5 & 0.023 & 8.2 & 2.9e+02 & 0.001 \\
# 20 & 1966 & IPR008210 & Phosphoenolpyruvate carboxykinase, N-terminal & 1.1 & 0.027 & 5.4 & 43 & 3.3e-06 \\
# 20 & 1966 & IPR013035 & Phosphoenolpyruvate carboxykinase, C-terminal & 1.1 & 0.027 & 5.4 & 43 & 3.3e-06 \\
# 20 & 1966 & IPR016181 & Acyl-CoA N-acyltransferase & 4.7 & 0.016 & 8.2 & 2.9e+02 & 3e-26 \\
# 20 & 1966 & IPR042203 & Leucyl/phenylalanyl-tRNA-protein transferase, C-terminal & 6.5 & 0.023 & 8.2 & 2.9e+02 & 0.001 \\
# 20 & 1966 & IPR042221 & Leucyl/phenylalanyl-tRNA-protein transferase, N-terminal & 6.5 & 0.023 & 8.1 & 2.8e+02 & 0.022 \\
# 20 & 2311 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 2.1 & 0.016 & 7.1 & 1.4e+02 & 1.7e-15 \\
# 20 & 3972 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 3.4 & 0.0069 & 8.9 & 4.9e+02 & 2.5e-19 \\
# 24 & 2998 & IPR029044 & Nucleotide-diphospho-sugar transferases & 1.7 & 0.043 & 5.3 & 39 & 1.6e-23 \\
# \bottomrule
# \end{tabular}
#
# }

# %%
import numpy as np
import pandas as pd

def _normalize_pairs(layer_latents):
    """Accept {layer:[latents]} or [(layer, latent), ...] and return list of (layer, latent)."""
    if isinstance(layer_latents, dict):
        pairs = []
        for layer, lat_list in layer_latents.items():
            for lat in lat_list:
                pairs.append((int(layer), int(lat)))
        return pairs
    # assume iterable of tuples
    return [(int(l), int(z)) for (l, z) in layer_latents]

def get_top_interpro_for_latents(
    layer_latents,
    top_k=5,
    alpha=0.05,
    l2fc_min=1.0,
    aout_max=0.05,
    epsilon=1e-4,
    n_total_latents_for_bonferroni=28672  # matches your earlier n_tests = 28672 * 10096
):
    """
    For each (layer, latent) requested, return top-k InterPro annotations that pass:
      p < alpha / (n_total_latents_for_bonferroni * N_families), A_out < aout_max, L2FC >= l2fc_min.
    Two rankings per latent: by L2FC and by A_in.
    """
    pairs = _normalize_pairs(layer_latents)

    # Precompute constants/sets
    N_fams = latents_family_pvals.shape[1]
    n_tests = n_total_latents_for_bonferroni * N_fams
    bonf_thr = alpha / n_tests

    set_top2 = set(full_indices_top2)
    set_metx = set(full_indices_metx)

    # Consistent column order
    cols = [
        "Case", "Layer", "Latent ID", "InterPro ID", "InterPro Name",
        "A_in", "A_out", "L2FC", "Ratio", "Bonferroni adj. p-value"
    ]

    out = {}  # (layer, latent) -> {"by_l2fc": df, "by_ain": df}

    for layer, latent in pairs:
        flat_ind = offsets[str(layer)] + latent
        if flat_ind not in latent_ids_both_proteins:
            # Not in your 383-index universe—return empty tables
            out[(layer, latent)] = {
                "by_l2fc": pd.DataFrame(columns=cols),
                "by_ain": pd.DataFrame(columns=cols),
            }
            continue

        latent_i = latent_ids_both_proteins.index(flat_ind)
        rows = []

        for fam_j in range(N_fams):
            p = float(latents_family_pvals[latent_i, fam_j])
            if p >= bonf_thr:
                continue

            ain = float(latents_family_effect_size[latent_i, fam_j, 0])
            aout = float(latents_family_effect_size[latent_i, fam_j, 1])

            if aout_max is not None and not (aout < aout_max):
                continue

            ratio = (ain + epsilon) / (aout + epsilon)
            l2fc = float(np.log2(ratio))
            if l2fc_min is not None and not (l2fc >= l2fc_min):
                continue

            # Case label like your earlier code (Top2 if present there; otherwise MetX)
            if flat_ind in set_top2:
                case = "Top2"
            elif flat_ind in set_metx:
                case = "MetX"
            else:
                case = "Unknown"

            rows.append({
                "Case": case,
                "Layer": layer,
                "Latent ID": latent,
                "InterPro ID": interpro_annotations_nonzero.iloc[fam_j]["ENTRY_AC"],
                "InterPro Name": interpro_annotations_nonzero.iloc[fam_j]["ENTRY_NAME"],
                "A_in": ain,
                "A_out": aout,
                "L2FC": l2fc,
                "Ratio": float(ratio),
                "Bonferroni adj. p-value": float(p * n_tests),
            })

        df_all = pd.DataFrame(rows, columns=cols)

        if df_all.empty:
            out[(layer, latent)] = {
                "by_l2fc": df_all.copy(),
                "by_ain": df_all.copy(),
            }
        else:
            out[(layer, latent)] = {
                "by_l2fc": df_all.sort_values("L2FC", ascending=False).head(top_k).reset_index(drop=True),
                "by_ain": df_all.sort_values("A_in", ascending=False).head(top_k).reset_index(drop=True),
            }
    return out

# --- Example usage ---
# layer_latents = {12: [1256, 1204], 16: [631]}
# results = get_top_interpro_for_latents(layer_latents, top_k=5)
# for (layer, latent), tabs in results.items():
#     print(f"\nLayer {layer}, Latent {latent} — top by L2FC")
#     print(tabs["by_l2fc"].to_latex(index=False, float_format="{:.2g}".format, escape=False))
#     print(f"\nLayer {layer}, Latent {latent} — top by A_in")
#     print(tabs["by_ain"].to_latex(index=False, float_format="{:.2g}".format, escape=False))

# %%
feature_clusters = {
    # Layer 4 clusters
    4: {
        "direct_motif_detectors": {340: "FX'", 237: "FX'", 3788: "X'XI", 798: "D'XXGN", 1690: "X'XXF"},  # Example: specific (token, latent) pairs
        "indirect_motif_detectors": {2277: "G", 2311: "X'XM", 3634: "X'XXXG", 1682: "PXXXXXX'", 3326: "H"},
        "motif_detectors": {340: "FX'", 237: "FX'", 3788: "X'XI", 798: "D'XXGN", 1690: "X'XXF", 2277: "G", 2311: "X'XM", 3634: "X'XXXG", 1682: "PXXXXXX'", 3326: "H"}, 
    },
    
    # # Layer 8 clusters  
    8: {
        "annotated_domain_detector": {488:"AB_Hydrolase_fold"}, #, 2693: "AB_Hydrolase_fold", 1244:"AB_Hydrolase_fold"},
        "misc_domain_detector": {2677:"FAD/NAD", 2775:"Transketolase", 2166:"DHFR"},
        "motif_detectors": {488:"AB_Hydrolase_fold", 2677:"FAD/NAD", 2775:"Transketolase", 2166:"DHFR"}, #, 2693: "AB_Hydrolase_fold", 1244:"AB_Hydrolase_fold"},
    },
    
    # # Layer 12 clusters
    12: {
        "annotated_domain_detector": {2112: "AB_Hydrolase_fold"},
        "misc_domain_detector": {3536:"SAM_mtases", 1256: "FAM", 2797: "Aldolase", 3794: "SAM_mtases", 3035: "WD40"},
        "motif_detectors": {2112: "AB_Hydrolase_fold", 3536:"SAM_mtases", 1256: "FAM", 2797: "Aldolase", 3794: "SAM_mtases", 3035: "WD40"},
    },
    # Add more layers and clusters as needed...
}

feature_clusters_1pvg = {
    4: {
        "direct_motif_detectors": {1509:"E", 2511:"X'XQ", 2112:"YXX'", 3069: "GX'", 3544: "C", 2929: "N"},
        "indirect_motif_detectors": {3170: "X'N", 3717:"V", 527: "DX'", 3229: "IXX'", 1297: "I", 1468: "X'XXN", 1196: "D"},
        "motif_detectors": {1509:"E", 2511:"X'XQ", 2112:"YXX'", 3069: "GX'", 3544: "C", 2929: "N", 3170: "X'N", 3717:"V", 527: "DX'", 3229: "IXX'", 1297: "I", 1468: "X'XXN", 1196: "D"}
    },
    8: {
        # "direct_motif_detectors": {},
        # "indirect_motif_detectors": {1916: "NX'XXNA"},
        # "motif_detectors": {}, 
        "annotated_domain_detector": {2529:"Hatpase_C", 3159: "Hatpase_C", 3903: "Hatpase_C", 1055: "Hatpase_C", 2066: "Hatpase_C"},
    },
    12: {
        "annotated_domain_detector": {3943: "Hatpase_C", 1796: "Hatpase_C", 1204: "Hatpase_C", 1145:  "Hatpase_C"},
        "misc_domain_detector": {1082: "XPG-I", 2472: "Kinesin"},
        "domain_detectors": {3943: "Hatpase_C", 1796: "Hatpase_C", 1204: "Hatpase_C", 1145:  "Hatpase_C", 1082: "XPG-I", 2472: "Kinesin"},
    },
    16: {
        "annotated_domain_detector": {3077: "Hatpase_C", 1353: "Hatpase_C", 1597: "Hatpase_C", 1814: "Hatpase_C", 3994: "Ribosomal", 1166: "Hatpase_C"},
        # "misc_domain_detector": {},
        # "domain_detectors": {3077: "Hatpase_C", 1353: "Hatpase_C", 1597: "Hatpase_C", 1814: "Hatpase_C", 3994: "Ribosomal", 1166: "Hatpase_C"},
    }
}

# %%
feature_clusters_1pvg_onelevel = {    4: {1509:"E", 2511:"X'XQ", 2112:"YXX'", 3069: "GX'", 3544: "C", 2929: "N", 3170: "X'N", 3717:"V", 527: "DX'", 3229: "IXX'", 1297: "I", 1468: "X'XXN", 1196: "D"},
    8: {
        2529:"Hatpase_C", 3159: "Hatpase_C", 3903: "Hatpase_C", 1055: "Hatpase_C", 2066: "Hatpase_C"
    },
    12: {3943: "Hatpase_C", 1796: "Hatpase_C", 1204: "Hatpase_C", 1145:  "Hatpase_C", 1082: "XPG-I", 2472: "Kinesin"
    },
    16: {3077: "Hatpase_C", 1353: "Hatpase_C", 1597: "Hatpase_C", 1814: "Hatpase_C", 3994: "Ribosomal", 1166: "Hatpase_C"}}

feature_clusters_2b61_onelevel = {4: {340: "FX'", 237: "FX'", 3788: "X'XI", 798: "D'XXGN", 1690: "X'XXF", 2277: "G", 2311: "X'XM", 3634: "X'XXXG", 1682: "PXXXXXX'", 3326: "H"
    },
    8: {
        488:"AB_Hydrolase_fold", 2677:"FAD/NAD", 2775:"Transketolase", 2166:"DHFR"
    },
    12: {
        2112: "AB_Hydrolase_fold", 3536:"SAM_mtases", 1256: "FAM", 2797: "Aldolase", 3794: "SAM_mtases", 3035: "WD40"
    }}

# %%
feature_clusters_flat = {
    layer: list(set().union(*[latents.keys() for latents in clusters.values()]))
    for layer, clusters in feature_clusters.items()}

# Convert feature_clusters_1pvg dict to just layer: list of latents 
feature_clusters_1pvg_flat = {
    layer: list(set().union(*[latents.keys() for latents in clusters.values()]))
    for layer, clusters in feature_clusters_1pvg.items()}

# %%
feature_clusters_1pvg_flat
# Out:
# {4: [2112,
#   3170,
#   1509,
#   3717,
#   1196,
#   2511,
#   527,
#   2929,
#   1297,
#   3229,
#   3544,
#   1468,
#   3069],
#  8: [2529, 2066, 3903, 3159, 1055],
#  12: [1796, 3943, 2472, 1204, 1145, 1082],
#  16: [3077, 1353, 1166, 1814, 3994, 1597]}

# %%
feature_clusters_1pvg[4][]

# %%
def to_resized_latex(df, floatfmt="{:.2g}".format):
    s = df.to_latex(index=False, float_format=floatfmt, escape=False)
    s = s.replace("_", r"\_")  # escape underscores in headers/cells
    return (
        r"\setlength{\tabcolsep}{4pt}\small" "\n"
        r"\resizebox{\linewidth}{!}{" "\n" + s + "\n}"
    )

results = get_top_interpro_for_latents(feature_clusters_flat, top_k=5)

for (layer, latent), tabs in results.items():
    by_l2fc = tabs["by_l2fc"]
    by_ain  = tabs["by_ain"]

    if by_l2fc.empty and by_ain.empty:
        continue

    if not by_l2fc.empty:
        print(f"\nLayer {layer}, Latent {latent}, manual: {feature_clusters_2b61_onelevel[layer][latent]} — top by L2FC")
        print(to_resized_latex(by_l2fc))

    if not by_ain.empty:
        print(f"\nLayer {layer}, Latent {latent}, manual: {feature_clusters_2b61_onelevel[layer][latent]} — top by A\_in")
        print(to_resized_latex(by_ain))
# Out:
# Layer 4, Latent 3326, manual: H — top by L2FC
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 4 & 3326 & IPR036638 & Helix-loop-helix DNA-binding domain superfamily & 0.036 & 0.005 & 2.8 & 7.2 & 0.0032 \\
# MetX & 4 & 3326 & IPR001356 & Homeodomain & 0.035 & 0.0049 & 2.8 & 7 & 2.8e-09 \\
# MetX & 4 & 3326 & IPR011598 & Myc-type, basic helix-loop-helix (bHLH) domain & 0.035 & 0.005 & 2.8 & 6.9 & 0.0011 \\
# MetX & 4 & 3326 & IPR017970 & Homeobox, conserved site & 0.035 & 0.0049 & 2.8 & 6.9 & 0.00012 \\
# MetX & 4 & 3326 & IPR036236 & Zinc finger C2H2 superfamily & 0.035 & 0.0049 & 2.8 & 6.9 & 4.5e-10 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 4, Latent 3326, manual: H — top by A\_in
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 4 & 3326 & IPR036638 & Helix-loop-helix DNA-binding domain superfamily & 0.036 & 0.005 & 2.8 & 7.2 & 0.0032 \\
# MetX & 4 & 3326 & IPR011598 & Myc-type, basic helix-loop-helix (bHLH) domain & 0.035 & 0.005 & 2.8 & 6.9 & 0.0011 \\
# MetX & 4 & 3326 & IPR001356 & Homeodomain & 0.035 & 0.0049 & 2.8 & 7 & 2.8e-09 \\
# MetX & 4 & 3326 & IPR017970 & Homeobox, conserved site & 0.035 & 0.0049 & 2.8 & 6.9 & 0.00012 \\
# MetX & 4 & 3326 & IPR036236 & Zinc finger C2H2 superfamily & 0.035 & 0.0049 & 2.8 & 6.9 & 4.5e-10 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 4, Latent 798, manual: D'XXGN — top by L2FC
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 4 & 798 & IPR005745 & Large ribosomal subunit protein uL14, bacterial-type & 0.14 & 0.049 & 1.6 & 2.9 & 2.9e-08 \\
# MetX & 4 & 798 & IPR019972 & Large ribosomal subunit protein uL14, conserved site & 0.14 & 0.049 & 1.5 & 2.9 & 4.2e-07 \\
# MetX & 4 & 798 & IPR000218 & Large ribosomal subunit protein uL14 & 0.14 & 0.049 & 1.5 & 2.9 & 8.4e-09 \\
# MetX & 4 & 798 & IPR036853 & Large ribosomal subunit protein uL14 superfamily & 0.14 & 0.049 & 1.5 & 2.9 & 8.4e-09 \\
# MetX & 4 & 798 & IPR034704 & Large ribosomal subunit protein bL28/bL31-like superfamily & 0.14 & 0.049 & 1.5 & 2.8 & 1.5e-06 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 4, Latent 798, manual: D'XXGN — top by A\_in
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 4 & 798 & IPR005745 & Large ribosomal subunit protein uL14, bacterial-type & 0.14 & 0.049 & 1.6 & 2.9 & 2.9e-08 \\
# MetX & 4 & 798 & IPR019972 & Large ribosomal subunit protein uL14, conserved site & 0.14 & 0.049 & 1.5 & 2.9 & 4.2e-07 \\
# MetX & 4 & 798 & IPR000218 & Large ribosomal subunit protein uL14 & 0.14 & 0.049 & 1.5 & 2.9 & 8.4e-09 \\
# MetX & 4 & 798 & IPR036853 & Large ribosomal subunit protein uL14 superfamily & 0.14 & 0.049 & 1.5 & 2.9 & 8.4e-09 \\
# MetX & 4 & 798 & IPR034704 & Large ribosomal subunit protein bL28/bL31-like superfamily & 0.14 & 0.049 & 1.5 & 2.8 & 1.5e-06 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 8, Latent 488, manual: AB_Hydrolase_fold — top by L2FC
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 8 & 488 & IPR022742 & Serine aminopeptidase, S33 & 0.1 & 0.00035 & 7.8 & 2.3e+02 & 4.8e-19 \\
# MetX & 8 & 488 & IPR013094 & Alpha/beta hydrolase fold-3 & 0.068 & 0.00038 & 7.2 & 1.4e+02 & 4.4e-06 \\
# MetX & 8 & 488 & IPR045889 & Methylesterase/Alpha-hydroxynitrile lyase & 0.066 & 0.00038 & 7.1 & 1.4e+02 & 4.5e-06 \\
# MetX & 8 & 488 & IPR002925 & Dienelactone hydrolase & 0.062 & 0.00038 & 7 & 1.3e+02 & 4.6e-06 \\
# MetX & 8 & 488 & IPR050300 & GDXG lipolytic enzyme & 0.056 & 0.00038 & 6.9 & 1.2e+02 & 4.8e-06 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 8, Latent 488, manual: AB_Hydrolase_fold — top by A\_in
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 8 & 488 & IPR022742 & Serine aminopeptidase, S33 & 0.1 & 0.00035 & 7.8 & 2.3e+02 & 4.8e-19 \\
# MetX & 8 & 488 & IPR013094 & Alpha/beta hydrolase fold-3 & 0.068 & 0.00038 & 7.2 & 1.4e+02 & 4.4e-06 \\
# MetX & 8 & 488 & IPR045889 & Methylesterase/Alpha-hydroxynitrile lyase & 0.066 & 0.00038 & 7.1 & 1.4e+02 & 4.5e-06 \\
# MetX & 8 & 488 & IPR002925 & Dienelactone hydrolase & 0.062 & 0.00038 & 7 & 1.3e+02 & 4.6e-06 \\
# MetX & 8 & 488 & IPR050300 & GDXG lipolytic enzyme & 0.056 & 0.00038 & 6.9 & 1.2e+02 & 4.8e-06 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 8, Latent 2166, manual: DHFR — top by L2FC
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 8 & 2166 & IPR004368 & Translation initiation factor IF-1 & 0.15 & 0.0085 & 4.1 & 17 & 0.00038 \\
# MetX & 8 & 2166 & IPR006196 & RNA-binding domain, S1, IF1 type & 0.14 & 0.0085 & 4.1 & 17 & 2.9e-06 \\
# MetX & 8 & 2166 & IPR019979 & Small ribosomal subunit protein uS17, conserved site & 0.11 & 0.0085 & 3.6 & 13 & 0.0041 \\
# MetX & 8 & 2166 & IPR019984 & Small ribosomal subunit protein uS17, bacteria/chloroplast & 0.1 & 0.0085 & 3.6 & 12 & 3e-05 \\
# MetX & 8 & 2166 & IPR000266 & Small ribosomal subunit protein uS17 & 0.1 & 0.0085 & 3.5 & 12 & 0.00044 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 8, Latent 2166, manual: DHFR — top by A\_in
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 8 & 2166 & IPR004368 & Translation initiation factor IF-1 & 0.15 & 0.0085 & 4.1 & 17 & 0.00038 \\
# MetX & 8 & 2166 & IPR006196 & RNA-binding domain, S1, IF1 type & 0.14 & 0.0085 & 4.1 & 17 & 2.9e-06 \\
# MetX & 8 & 2166 & IPR019979 & Small ribosomal subunit protein uS17, conserved site & 0.11 & 0.0085 & 3.6 & 13 & 0.0041 \\
# MetX & 8 & 2166 & IPR019984 & Small ribosomal subunit protein uS17, bacteria/chloroplast & 0.1 & 0.0085 & 3.6 & 12 & 3e-05 \\
# MetX & 8 & 2166 & IPR000266 & Small ribosomal subunit protein uS17 & 0.1 & 0.0085 & 3.5 & 12 & 0.00044 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 12, Latent 2112, manual: AB_Hydrolase_fold — top by L2FC
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 12 & 2112 & IPR029058 & Alpha/Beta hydrolase fold & 0.56 & 0.0052 & 6.7 & 1.1e+02 & 0 \\
# MetX & 12 & 2112 & IPR000073 & Alpha/beta hydrolase fold-1 & 0.6 & 0.0078 & 6.3 & 77 & 3.1e-14 \\
# MetX & 12 & 2112 & IPR001563 & Peptidase S10, serine carboxypeptidase & 0.42 & 0.0083 & 5.6 & 50 & 3.5e-06 \\
# MetX & 12 & 2112 & IPR018202 & Serine carboxypeptidase, serine active site & 0.41 & 0.0084 & 5.6 & 49 & 0.0015 \\
# MetX & 12 & 2112 & IPR018101 & Translation elongation factor Ts, conserved site & 0.25 & 0.0084 & 4.9 & 29 & 3.8e-11 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 12, Latent 2112, manual: AB_Hydrolase_fold — top by A\_in
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 12 & 2112 & IPR000073 & Alpha/beta hydrolase fold-1 & 0.6 & 0.0078 & 6.3 & 77 & 3.1e-14 \\
# MetX & 12 & 2112 & IPR029058 & Alpha/Beta hydrolase fold & 0.56 & 0.0052 & 6.7 & 1.1e+02 & 0 \\
# MetX & 12 & 2112 & IPR001563 & Peptidase S10, serine carboxypeptidase & 0.42 & 0.0083 & 5.6 & 50 & 3.5e-06 \\
# MetX & 12 & 2112 & IPR018202 & Serine carboxypeptidase, serine active site & 0.41 & 0.0084 & 5.6 & 49 & 0.0015 \\
# MetX & 12 & 2112 & IPR018101 & Translation elongation factor Ts, conserved site & 0.25 & 0.0084 & 4.9 & 29 & 3.8e-11 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 12, Latent 1256, manual: FAM — top by L2FC
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 12 & 1256 & IPR031167 & OBG-type guanine nucleotide-binding (G) domain & 0.63 & 0.047 & 3.8 & 13 & 0.028 \\
# MetX & 12 & 1256 & IPR002048 & EF-hand domain & 0.56 & 0.047 & 3.6 & 12 & 2.5e-09 \\
# MetX & 12 & 1256 & IPR011992 & EF-hand domain pair & 0.54 & 0.046 & 3.5 & 12 & 1.4e-10 \\
# MetX & 12 & 1256 & IPR018247 & EF-Hand 1, calcium-binding site & 0.54 & 0.047 & 3.5 & 12 & 9.9e-05 \\
# MetX & 12 & 1256 & IPR034332 & Uracil phosphoribosyltransferase, bacterial-type & 0.49 & 0.047 & 3.4 & 10 & 0.027 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 12, Latent 1256, manual: FAM — top by A\_in
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 12 & 1256 & IPR031167 & OBG-type guanine nucleotide-binding (G) domain & 0.63 & 0.047 & 3.8 & 13 & 0.028 \\
# MetX & 12 & 1256 & IPR002048 & EF-hand domain & 0.56 & 0.047 & 3.6 & 12 & 2.5e-09 \\
# MetX & 12 & 1256 & IPR018247 & EF-Hand 1, calcium-binding site & 0.54 & 0.047 & 3.5 & 12 & 9.9e-05 \\
# MetX & 12 & 1256 & IPR011992 & EF-hand domain pair & 0.54 & 0.046 & 3.5 & 12 & 1.4e-10 \\
# MetX & 12 & 1256 & IPR005765 & Uracil phosphoribosyl transferase & 0.49 & 0.047 & 3.4 & 10 & 0.027 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 12, Latent 2797, manual: Aldolase — top by L2FC
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 12 & 2797 & IPR006062 & Histidine biosynthesis protein & 0.095 & 0.0041 & 4.5 & 22 & 8.7e-27 \\
# MetX & 12 & 2797 & IPR023016 & HisA/PriA & 0.096 & 0.0043 & 4.5 & 22 & 4.8e-11 \\
# MetX & 12 & 2797 & IPR044524 & Histidine biosynthesis, HisA-like & 0.096 & 0.0043 & 4.5 & 22 & 4.4e-12 \\
# MetX & 12 & 2797 & IPR006063 & HisA, bacterial & 0.095 & 0.0043 & 4.4 & 21 & 9.9e-06 \\
# MetX & 12 & 2797 & IPR004651 & Histidine biosynthesis, HisF & 0.093 & 0.0043 & 4.4 & 21 & 8.3e-08 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 12, Latent 2797, manual: Aldolase — top by A\_in
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 12 & 2797 & IPR023016 & HisA/PriA & 0.096 & 0.0043 & 4.5 & 22 & 4.8e-11 \\
# MetX & 12 & 2797 & IPR044524 & Histidine biosynthesis, HisA-like & 0.096 & 0.0043 & 4.5 & 22 & 4.4e-12 \\
# MetX & 12 & 2797 & IPR006063 & HisA, bacterial & 0.095 & 0.0043 & 4.4 & 21 & 9.9e-06 \\
# MetX & 12 & 2797 & IPR006062 & Histidine biosynthesis protein & 0.095 & 0.0041 & 4.5 & 22 & 8.7e-27 \\
# MetX & 12 & 2797 & IPR034291 & Thiamine phosphate synthase & 0.093 & 0.0044 & 4.4 & 21 & 0.016 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 12, Latent 3536, manual: SAM_mtases — top by L2FC
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 12 & 3536 & IPR036678 & MutS, connector domain superfamily & 0.23 & 0.022 & 3.4 & 10 & 8.7e-05 \\
# MetX & 12 & 3536 & IPR017261 & DNA mismatch repair protein MutS/MSH & 0.23 & 0.022 & 3.4 & 10 & 0.00044 \\
# MetX & 12 & 3536 & IPR007861 & DNA mismatch repair protein MutS, clamp & 0.23 & 0.022 & 3.3 & 10 & 0.00044 \\
# MetX & 12 & 3536 & IPR007860 & DNA mismatch repair protein MutS, connector domain & 0.23 & 0.022 & 3.3 & 10 & 0.00044 \\
# MetX & 12 & 3536 & IPR007695 & DNA mismatch repair protein MutS-like, N-terminal & 0.23 & 0.023 & 3.3 & 10 & 0.0022 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 12, Latent 3536, manual: SAM_mtases — top by A\_in
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 12 & 3536 & IPR036678 & MutS, connector domain superfamily & 0.23 & 0.022 & 3.4 & 10 & 8.7e-05 \\
# MetX & 12 & 3536 & IPR017261 & DNA mismatch repair protein MutS/MSH & 0.23 & 0.022 & 3.4 & 10 & 0.00044 \\
# MetX & 12 & 3536 & IPR007861 & DNA mismatch repair protein MutS, clamp & 0.23 & 0.022 & 3.3 & 10 & 0.00044 \\
# MetX & 12 & 3536 & IPR007860 & DNA mismatch repair protein MutS, connector domain & 0.23 & 0.022 & 3.3 & 10 & 0.00044 \\
# MetX & 12 & 3536 & IPR016151 & DNA mismatch repair protein MutS, N-terminal & 0.23 & 0.023 & 3.3 & 10 & 0.0022 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 12, Latent 3794, manual: SAM_mtases — top by L2FC
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 12 & 3794 & IPR002052 & DNA methylase, N-6 adenine-specific, conserved site & 0.18 & 0.014 & 3.7 & 13 & 0.02 \\
# MetX & 12 & 3794 & IPR020904 & Short-chain dehydrogenase/reductase, conserved site & 0.13 & 0.014 & 3.2 & 9.4 & 4.7e-05 \\
# MetX & 12 & 3794 & IPR002347 & Short-chain dehydrogenase/reductase SDR & 0.13 & 0.014 & 3.2 & 9.3 & 2.7e-11 \\
# MetX & 12 & 3794 & IPR029063 & S-adenosyl-L-methionine-dependent methyltransferase superfamily & 0.12 & 0.013 & 3.2 & 9.2 & 0 \\
# MetX & 12 & 3794 & IPR046346 & Aminoacid dehydrogenase-like, N-terminal domain superfamily & 0.12 & 0.014 & 3.1 & 8.4 & 2.2e-13 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 12, Latent 3794, manual: SAM_mtases — top by A\_in
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 12 & 3794 & IPR002052 & DNA methylase, N-6 adenine-specific, conserved site & 0.18 & 0.014 & 3.7 & 13 & 0.02 \\
# MetX & 12 & 3794 & IPR020904 & Short-chain dehydrogenase/reductase, conserved site & 0.13 & 0.014 & 3.2 & 9.4 & 4.7e-05 \\
# MetX & 12 & 3794 & IPR002347 & Short-chain dehydrogenase/reductase SDR & 0.13 & 0.014 & 3.2 & 9.3 & 2.7e-11 \\
# MetX & 12 & 3794 & IPR001557 & L-lactate/malate dehydrogenase & 0.12 & 0.014 & 3.1 & 8.4 & 9.8e-05 \\
# MetX & 12 & 3794 & IPR001236 & Lactate/malate dehydrogenase, N-terminal & 0.12 & 0.014 & 3.1 & 8.4 & 2e-05 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 12, Latent 3035, manual: WD40 — top by L2FC
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 12 & 3035 & IPR004368 & Translation initiation factor IF-1 & 0.54 & 0.023 & 4.6 & 24 & 0.0031 \\
# MetX & 12 & 3035 & IPR006196 & RNA-binding domain, S1, IF1 type & 0.51 & 0.022 & 4.5 & 23 & 3e-05 \\
# MetX & 12 & 3035 & IPR020472 & PAC1/LIS1-like, WD-40 repeat & 0.39 & 0.023 & 4.1 & 17 & 1e-07 \\
# MetX & 12 & 3035 & IPR019775 & WD40 repeat, conserved site & 0.38 & 0.022 & 4.1 & 17 & 4.8e-11 \\
# MetX & 12 & 3035 & IPR001680 & WD40 repeat & 0.33 & 0.022 & 3.9 & 15 & 2.6e-21 \\
# \bottomrule
# \end{tabular}
#
# }
#
# Layer 12, Latent 3035, manual: WD40 — top by A\_in
# \setlength{\tabcolsep}{4pt}\small
# \resizebox{\linewidth}{!}{
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A\_in & A\_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 12 & 3035 & IPR004368 & Translation initiation factor IF-1 & 0.54 & 0.023 & 4.6 & 24 & 0.0031 \\
# MetX & 12 & 3035 & IPR006196 & RNA-binding domain, S1, IF1 type & 0.51 & 0.022 & 4.5 & 23 & 3e-05 \\
# MetX & 12 & 3035 & IPR020472 & PAC1/LIS1-like, WD-40 repeat & 0.39 & 0.023 & 4.1 & 17 & 1e-07 \\
# MetX & 12 & 3035 & IPR019775 & WD40 repeat, conserved site & 0.38 & 0.022 & 4.1 & 17 & 4.8e-11 \\
# MetX & 12 & 3035 & IPR001680 & WD40 repeat & 0.33 & 0.022 & 3.9 & 15 & 2.6e-21 \\
# \bottomrule
# \end{tabular}
#
# }

# %%
results = get_top_interpro_for_latents(feature_clusters_1pvg_flat, top_k=5)
for (layer, latent), tabs in results.items():
    print(f"\nLayer {layer}, Latent {latent} — top by L2FC")
    print(tabs["by_l2fc"].to_latex(index=False, float_format="{:.2g}".format, escape=False))
    print(f"\nLayer {layer}, Latent {latent} — top by A_in")
    print(tabs["by_ain"].to_latex(index=False, float_format="{:.2g}".format, escape=False))
# Out:
# Layer 4, Latent 2112 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 2112 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 3170 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 3170 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 1509 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 1509 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 3717 — top by L2FC
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 4 & 3717 & IPR035977 & Large ribosomal subunit protein bL36 superfamily & 0.082 & 0.0011 & 6.1 & 70 & 0 \\
# Top2 & 4 & 3717 & IPR000473 & Large ribosomal subunit protein bL36 & 0.082 & 0.0011 & 6.1 & 70 & 0 \\
# Top2 & 4 & 3717 & IPR000221 & Protamine P1 & 0.048 & 0.0012 & 5.2 & 37 & 6.7e-07 \\
# Top2 & 4 & 3717 & IPR000006 & Metallothionein, vertebrate & 0.04 & 0.0012 & 4.9 & 31 & 5.3e-05 \\
# Top2 & 4 & 3717 & IPR023587 & Metallothionein domain superfamily, vertebrate & 0.04 & 0.0012 & 4.9 & 31 & 5.3e-05 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 3717 — top by A_in
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 4 & 3717 & IPR035977 & Large ribosomal subunit protein bL36 superfamily & 0.082 & 0.0011 & 6.1 & 70 & 0 \\
# Top2 & 4 & 3717 & IPR000473 & Large ribosomal subunit protein bL36 & 0.082 & 0.0011 & 6.1 & 70 & 0 \\
# Top2 & 4 & 3717 & IPR000221 & Protamine P1 & 0.048 & 0.0012 & 5.2 & 37 & 6.7e-07 \\
# Top2 & 4 & 3717 & IPR000006 & Metallothionein, vertebrate & 0.04 & 0.0012 & 4.9 & 31 & 5.3e-05 \\
# Top2 & 4 & 3717 & IPR023587 & Metallothionein domain superfamily, vertebrate & 0.04 & 0.0012 & 4.9 & 31 & 5.3e-05 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 1196 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 1196 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 2511 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 2511 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 527 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 527 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 2929 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 2929 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 1297 — top by L2FC
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 4 & 1297 & IPR000473 & Large ribosomal subunit protein bL36 & 0.073 & 0.0033 & 4.4 & 21 & 7e-07 \\
# Top2 & 4 & 1297 & IPR035977 & Large ribosomal subunit protein bL36 superfamily & 0.073 & 0.0033 & 4.4 & 21 & 7e-07 \\
# Top2 & 4 & 1297 & IPR005996 & Large ribosomal subunit protein uL30, bacterial-type & 0.057 & 0.0034 & 4 & 16 & 7.4e-05 \\
# Top2 & 4 & 1297 & IPR016082 & Large ribosomal subunit protein uL30-like, ferredoxin-like fold domain & 0.052 & 0.0034 & 3.9 & 15 & 0.0027 \\
# Top2 & 4 & 1297 & IPR036919 & Large ribosomal subunit protein uL30, ferredoxin-like fold domain superfamily & 0.052 & 0.0034 & 3.9 & 15 & 0.0027 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 1297 — top by A_in
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 4 & 1297 & IPR000473 & Large ribosomal subunit protein bL36 & 0.073 & 0.0033 & 4.4 & 21 & 7e-07 \\
# Top2 & 4 & 1297 & IPR035977 & Large ribosomal subunit protein bL36 superfamily & 0.073 & 0.0033 & 4.4 & 21 & 7e-07 \\
# Top2 & 4 & 1297 & IPR005996 & Large ribosomal subunit protein uL30, bacterial-type & 0.057 & 0.0034 & 4 & 16 & 7.4e-05 \\
# Top2 & 4 & 1297 & IPR016082 & Large ribosomal subunit protein uL30-like, ferredoxin-like fold domain & 0.052 & 0.0034 & 3.9 & 15 & 0.0027 \\
# Top2 & 4 & 1297 & IPR036919 & Large ribosomal subunit protein uL30, ferredoxin-like fold domain superfamily & 0.052 & 0.0034 & 3.9 & 15 & 0.0027 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 3229 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 3229 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 3544 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 3544 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 1468 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 1468 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 3069 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 4, Latent 3069 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 8, Latent 2529 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 8, Latent 2529 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 8, Latent 2066 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 8, Latent 2066 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 8, Latent 3903 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 8, Latent 3903 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 8, Latent 3159 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 8, Latent 3159 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 8, Latent 1055 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 8, Latent 1055 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 12, Latent 1796 — top by L2FC
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 12 & 1796 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.7 & 0.0041 & 8.6 & 3.9e+02 & 0 \\
# Top2 & 12 & 1796 & IPR036097 & Signal transduction histidine kinase, dimerisation/phosphoacceptor domain superfamily & 1.8 & 0.008 & 7.8 & 2.2e+02 & 8.2e-05 \\
# Top2 & 12 & 1796 & IPR005467 & Histidine kinase domain & 1.8 & 0.008 & 7.8 & 2.2e+02 & 8.2e-05 \\
# Top2 & 12 & 1796 & IPR004358 & Signal transduction histidine kinase-related protein, C-terminal & 1.8 & 0.008 & 7.8 & 2.2e+02 & 8.2e-05 \\
# Top2 & 12 & 1796 & IPR003661 & Signal transduction histidine kinase, dimerisation/phosphoacceptor domain & 1.7 & 0.0082 & 7.7 & 2.1e+02 & 0.004 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 12, Latent 1796 — top by A_in
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 12 & 1796 & IPR004358 & Signal transduction histidine kinase-related protein, C-terminal & 1.8 & 0.008 & 7.8 & 2.2e+02 & 8.2e-05 \\
# Top2 & 12 & 1796 & IPR036097 & Signal transduction histidine kinase, dimerisation/phosphoacceptor domain superfamily & 1.8 & 0.008 & 7.8 & 2.2e+02 & 8.2e-05 \\
# Top2 & 12 & 1796 & IPR005467 & Histidine kinase domain & 1.8 & 0.008 & 7.8 & 2.2e+02 & 8.2e-05 \\
# Top2 & 12 & 1796 & IPR003661 & Signal transduction histidine kinase, dimerisation/phosphoacceptor domain & 1.7 & 0.0082 & 7.7 & 2.1e+02 & 0.004 \\
# Top2 & 12 & 1796 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.7 & 0.0041 & 8.6 & 3.9e+02 & 0 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 12, Latent 3943 — top by L2FC
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 12 & 3943 & IPR011032 & GroES-like superfamily & 0.48 & 0.0073 & 6 & 66 & 1.9e-05 \\
# Top2 & 12 & 3943 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 0.27 & 0.0074 & 5.2 & 36 & 6.6e-20 \\
# Top2 & 12 & 3943 & IPR037143 & 4'-phosphopantetheinyl transferase domain superfamily & 0.26 & 0.0079 & 5 & 32 & 0.0023 \\
# Top2 & 12 & 3943 & IPR008278 & 4'-phosphopantetheinyl transferase domain & 0.26 & 0.0079 & 5 & 32 & 0.0023 \\
# Top2 & 12 & 3943 & IPR036286 & LexA/Signal peptidase-like superfamily & 0.071 & 0.0081 & 3.1 & 8.6 & 0.0039 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 12, Latent 3943 — top by A_in
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 12 & 3943 & IPR011032 & GroES-like superfamily & 0.48 & 0.0073 & 6 & 66 & 1.9e-05 \\
# Top2 & 12 & 3943 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 0.27 & 0.0074 & 5.2 & 36 & 6.6e-20 \\
# Top2 & 12 & 3943 & IPR037143 & 4'-phosphopantetheinyl transferase domain superfamily & 0.26 & 0.0079 & 5 & 32 & 0.0023 \\
# Top2 & 12 & 3943 & IPR008278 & 4'-phosphopantetheinyl transferase domain & 0.26 & 0.0079 & 5 & 32 & 0.0023 \\
# Top2 & 12 & 3943 & IPR036286 & LexA/Signal peptidase-like superfamily & 0.071 & 0.0081 & 3.1 & 8.6 & 0.0039 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 12, Latent 2472 — top by L2FC
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 12 & 2472 & IPR049261 & RecA-like, C-terminal & 0.68 & 0.017 & 5.4 & 41 & 7.8e-06 \\
# Top2 & 12 & 2472 & IPR049428 & RecA-like, N-terminal & 0.68 & 0.017 & 5.4 & 41 & 7.8e-06 \\
# Top2 & 12 & 2472 & IPR023400 & DNA recombination and repair protein RecA, C-terminal, superfamily & 0.68 & 0.017 & 5.4 & 41 & 7.8e-06 \\
# Top2 & 12 & 2472 & IPR013765 & DNA recombination and repair protein RecA & 0.68 & 0.017 & 5.4 & 41 & 7.8e-06 \\
# Top2 & 12 & 2472 & IPR020584 & DNA recombination/repair protein RecA, conserved site & 0.68 & 0.017 & 5.4 & 41 & 0.0011 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 12, Latent 2472 — top by A_in
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 12 & 2472 & IPR020584 & DNA recombination/repair protein RecA, conserved site & 0.68 & 0.017 & 5.4 & 41 & 0.0011 \\
# Top2 & 12 & 2472 & IPR049428 & RecA-like, N-terminal & 0.68 & 0.017 & 5.4 & 41 & 7.8e-06 \\
# Top2 & 12 & 2472 & IPR013765 & DNA recombination and repair protein RecA & 0.68 & 0.017 & 5.4 & 41 & 7.8e-06 \\
# Top2 & 12 & 2472 & IPR049261 & RecA-like, C-terminal & 0.68 & 0.017 & 5.4 & 41 & 7.8e-06 \\
# Top2 & 12 & 2472 & IPR023400 & DNA recombination and repair protein RecA, C-terminal, superfamily & 0.68 & 0.017 & 5.4 & 41 & 7.8e-06 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 12, Latent 1204 — top by L2FC
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 12 & 1204 & IPR001404 & Heat shock protein Hsp90 family & 1.4 & 0.0041 & 8.4 & 3.4e+02 & 3.9e-16 \\
# Top2 & 12 & 1204 & IPR020575 & Heat shock protein Hsp90, N-terminal & 1.4 & 0.0041 & 8.4 & 3.4e+02 & 3.9e-16 \\
# Top2 & 12 & 1204 & IPR019805 & Heat shock protein Hsp90, conserved site & 1.5 & 0.0042 & 8.4 & 3.4e+02 & 2.9e-13 \\
# Top2 & 12 & 1204 & IPR020667 & DNA mismatch repair protein, MutL & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# Top2 & 12 & 1204 & IPR014790 & MutL, C-terminal, dimerisation & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 12, Latent 1204 — top by A_in
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 12 & 1204 & IPR020667 & DNA mismatch repair protein, MutL & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# Top2 & 12 & 1204 & IPR042120 & MutL, C-terminal domain, dimerisation subdomain & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# Top2 & 12 & 1204 & IPR002099 & DNA mismatch repair protein MutL/Mlh/PMS & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# Top2 & 12 & 1204 & IPR037198 & MutL, C-terminal domain superfamily & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# Top2 & 12 & 1204 & IPR014790 & MutL, C-terminal, dimerisation & 1.5 & 0.0045 & 8.3 & 3.3e+02 & 1.6e-07 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 12, Latent 1145 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 12, Latent 1145 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 12, Latent 1082 — top by L2FC
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 12 & 1082 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 0.13 & 0.0061 & 4.4 & 21 & 2.8e-11 \\
# Top2 & 12 & 1082 & IPR002036 & Endoribonuclease YbeY & 0.11 & 0.0063 & 4.1 & 18 & 0.00091 \\
# Top2 & 12 & 1082 & IPR023091 & Metalloprotease catalytic domain superfamily, predicted & 0.11 & 0.0063 & 4.1 & 18 & 0.00091 \\
# Top2 & 12 & 1082 & IPR001406 & Pseudouridine synthase I, TruA & 0.11 & 0.0063 & 4.1 & 17 & 2.5e-05 \\
# Top2 & 12 & 1082 & IPR020097 & Pseudouridine synthase I, TruA, alpha/beta domain & 0.11 & 0.0063 & 4.1 & 17 & 2.5e-05 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 12, Latent 1082 — top by A_in
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 12 & 1082 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 0.13 & 0.0061 & 4.4 & 21 & 2.8e-11 \\
# Top2 & 12 & 1082 & IPR002036 & Endoribonuclease YbeY & 0.11 & 0.0063 & 4.1 & 18 & 0.00091 \\
# Top2 & 12 & 1082 & IPR023091 & Metalloprotease catalytic domain superfamily, predicted & 0.11 & 0.0063 & 4.1 & 18 & 0.00091 \\
# Top2 & 12 & 1082 & IPR001406 & Pseudouridine synthase I, TruA & 0.11 & 0.0063 & 4.1 & 17 & 2.5e-05 \\
# Top2 & 12 & 1082 & IPR020097 & Pseudouridine synthase I, TruA, alpha/beta domain & 0.11 & 0.0063 & 4.1 & 17 & 2.5e-05 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 16, Latent 3077 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 16, Latent 3077 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 16, Latent 1353 — top by L2FC
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 16 & 1353 & IPR001114 & Adenylosuccinate synthetase & 0.23 & 0.025 & 3.2 & 9.2 & 3.6e-05 \\
# Top2 & 16 & 1353 & IPR042111 & Adenylosuccinate synthetase, domain 3 & 0.23 & 0.025 & 3.2 & 9.2 & 3.6e-05 \\
# Top2 & 16 & 1353 & IPR042109 & Adenylosuccinate synthetase, domain 1 & 0.23 & 0.025 & 3.2 & 9.2 & 3.6e-05 \\
# Top2 & 16 & 1353 & IPR018220 & Adenylosuccinate synthase, GTP-binding site & 0.23 & 0.025 & 3.2 & 9.2 & 0.00017 \\
# Top2 & 16 & 1353 & IPR042110 & Adenylosuccinate synthetase, domain 2 & 0.23 & 0.025 & 3.2 & 9.2 & 0.00017 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 16, Latent 1353 — top by A_in
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 16 & 1353 & IPR018220 & Adenylosuccinate synthase, GTP-binding site & 0.23 & 0.025 & 3.2 & 9.2 & 0.00017 \\
# Top2 & 16 & 1353 & IPR042110 & Adenylosuccinate synthetase, domain 2 & 0.23 & 0.025 & 3.2 & 9.2 & 0.00017 \\
# Top2 & 16 & 1353 & IPR033128 & Adenylosuccinate synthase, active site & 0.23 & 0.025 & 3.2 & 9.2 & 0.00017 \\
# Top2 & 16 & 1353 & IPR001114 & Adenylosuccinate synthetase & 0.23 & 0.025 & 3.2 & 9.2 & 3.6e-05 \\
# Top2 & 16 & 1353 & IPR042111 & Adenylosuccinate synthetase, domain 3 & 0.23 & 0.025 & 3.2 & 9.2 & 3.6e-05 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 16, Latent 1166 — top by L2FC
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 16 & 1166 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.5 & 0.011 & 7.1 & 1.4e+02 & 1e-20 \\
# Top2 & 16 & 1166 & IPR016181 & Acyl-CoA N-acyltransferase & 0.47 & 0.014 & 5 & 32 & 1.1e-14 \\
# Top2 & 16 & 1166 & IPR000182 & GNAT domain & 0.43 & 0.015 & 4.8 & 28 & 0.00098 \\
# Top2 & 16 & 1166 & IPR020878 & Ribulose bisphosphate carboxylase, large chain, active site & 0.19 & 0.015 & 3.7 & 13 & 0.0069 \\
# Top2 & 16 & 1166 & IPR013765 & DNA recombination and repair protein RecA & 0.15 & 0.015 & 3.3 & 10 & 0.0014 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 16, Latent 1166 — top by A_in
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# Top2 & 16 & 1166 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.5 & 0.011 & 7.1 & 1.4e+02 & 1e-20 \\
# Top2 & 16 & 1166 & IPR016181 & Acyl-CoA N-acyltransferase & 0.47 & 0.014 & 5 & 32 & 1.1e-14 \\
# Top2 & 16 & 1166 & IPR000182 & GNAT domain & 0.43 & 0.015 & 4.8 & 28 & 0.00098 \\
# Top2 & 16 & 1166 & IPR020878 & Ribulose bisphosphate carboxylase, large chain, active site & 0.19 & 0.015 & 3.7 & 13 & 0.0069 \\
# Top2 & 16 & 1166 & IPR013765 & DNA recombination and repair protein RecA & 0.15 & 0.015 & 3.3 & 10 & 0.0014 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 16, Latent 1814 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 16, Latent 1814 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 16, Latent 3994 — top by L2FC
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 16 & 3994 & IPR050054 & Uracil phosphoribosyltransferase/Adenine phosphoribosyltransferase & 0.2 & 0.034 & 2.6 & 5.9 & 4.4e-09 \\
# MetX & 16 & 3994 & IPR014014 & RNA helicase, DEAD-box type, Q motif & 0.2 & 0.034 & 2.5 & 5.8 & 2.1e-11 \\
# MetX & 16 & 3994 & IPR020003 & ATPase, alpha/beta subunit, nucleotide-binding domain, active site & 0.19 & 0.034 & 2.5 & 5.7 & 2.6e-18 \\
# MetX & 16 & 3994 & IPR000194 & ATPase, F1/V1/A1 complex, alpha/beta subunit, nucleotide-binding domain & 0.19 & 0.034 & 2.5 & 5.7 & 2.6e-18 \\
# MetX & 16 & 3994 & IPR005294 & ATP synthase, F1 complex, alpha subunit & 0.19 & 0.034 & 2.5 & 5.7 & 6.3e-08 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 16, Latent 3994 — top by A_in
# \begin{tabular}{lrrllrrrrr}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# MetX & 16 & 3994 & IPR050054 & Uracil phosphoribosyltransferase/Adenine phosphoribosyltransferase & 0.2 & 0.034 & 2.6 & 5.9 & 4.4e-09 \\
# MetX & 16 & 3994 & IPR014014 & RNA helicase, DEAD-box type, Q motif & 0.2 & 0.034 & 2.5 & 5.8 & 2.1e-11 \\
# MetX & 16 & 3994 & IPR038376 & ATP synthase, alpha subunit, C-terminal domain superfamily & 0.19 & 0.034 & 2.5 & 5.7 & 6.3e-08 \\
# MetX & 16 & 3994 & IPR005294 & ATP synthase, F1 complex, alpha subunit & 0.19 & 0.034 & 2.5 & 5.7 & 6.3e-08 \\
# MetX & 16 & 3994 & IPR000793 & ATP synthase, alpha subunit, C-terminal & 0.19 & 0.034 & 2.5 & 5.7 & 6.3e-08 \\
# \bottomrule
# \end{tabular}
#
#
# Layer 16, Latent 1597 — top by L2FC
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}
#
#
# Layer 16, Latent 1597 — top by A_in
# \begin{tabular}{llllllllll}
# \toprule
# Case & Layer & Latent ID & InterPro ID & InterPro Name & A_in & A_out & L2FC & Ratio & Bonferroni adj. p-value \\
# \midrule
# \bottomrule
# \end{tabular}

# %%
def get_top_families_for_latents(layer_latent_pairs, 
                                latents_family_effect_size, 
                                latents_family_pvals, 
                                interpro_annotations_nonzero,
                                latent_ids_both_proteins,
                                n_tests,
                                top_k=5, 
                                require_pvalue=False, 
                                pvalue_threshold=0.05):
    """
    Get top K families for given layer-latent pairs based on both L2FC and raw activation.
    
    Parameters:
    -----------
    layer_latent_pairs : list of tuples
        List of (layer, latent_id) pairs. Layer should be the actual layer (4, 8, 12, etc.)
        and latent_id should be the latent index within that layer (0-4095).
    latents_family_effect_size : torch.Tensor
        Effect size tensor of shape (383, 10096, 4)
    latents_family_pvals : torch.Tensor  
        P-values tensor of shape (383, 10096)
    interpro_annotations_nonzero : pd.DataFrame
        DataFrame with InterPro annotations
    latent_ids_both_proteins : list
        Mapping from tensor indices to actual latent IDs
    n_tests : int
        Number of tests for Bonferroni correction
    top_k : int
        Number of top families to return (default 5)
    require_pvalue : bool
        Whether to filter by p-value threshold (default False)
    pvalue_threshold : float
        P-value threshold for Bonferroni correction (default 0.05)
    
    Returns:
    --------
    dict: Results for each latent with both L2FC and activation-based rankings
    """
    
    # Create mapping from actual latent ID to tensor index
    latent_id_to_index = {latent_id: i for i, latent_id in enumerate(latent_ids_both_proteins)}
    
    results = {}
    
    for layer, latent_id in layer_latent_pairs:
        # Convert layer and latent_id to actual latent ID used in the data
        actual_latent_id = ((layer // 4) - 1) * 4096 + latent_id
        
        # Check if this latent is in our data
        if actual_latent_id not in latent_id_to_index:
            print(f"Warning: Latent {actual_latent_id} (layer {layer}, latent {latent_id}) not found in data")
            continue
            
        latent_idx = latent_id_to_index[actual_latent_id]
        
        # Get data for this latent
        mean_in_family = latents_family_effect_size[latent_idx, :, 0].numpy()
        mean_out_family = latents_family_effect_size[latent_idx, :, 1].numpy()
        pvals = latents_family_pvals[latent_idx, :].numpy()
        
        # Calculate L2FC (with small epsilon to avoid division by zero)
        l2fc = np.log2(mean_in_family / (mean_out_family + 1e-8))
        
        # Create mask for families that pass p-value test if required
        if require_pvalue:
            bonf_corrected_pvals = pvals * n_tests
            pvalue_mask = bonf_corrected_pvals < pvalue_threshold
        else:
            pvalue_mask = np.ones_like(pvals, dtype=bool)
        
        # Get indices of families that pass the filter
        valid_families = np.where(pvalue_mask)[0]
        
        if len(valid_families) == 0:
            print(f"No families pass p-value threshold for latent {actual_latent_id}")
            results[f"layer_{layer}_latent_{latent_id}"] = {
                'actual_latent_id': actual_latent_id,
                'top_by_l2fc': [],
                'top_by_activation': []
            }
            continue
        
        # Method 1: Top families by L2FC
        l2fc_valid = l2fc[valid_families]
        l2fc_order = np.argsort(l2fc_valid)[::-1]  # Sort descending
        top_l2fc_indices = valid_families[l2fc_order[:top_k]]
        
        # Method 2: Top families by raw activation in family
        activation_valid = mean_in_family[valid_families]
        activation_order = np.argsort(activation_valid)[::-1]  # Sort descending
        top_activation_indices = valid_families[activation_order[:top_k]]
        
        # Create detailed results
        top_l2fc_details = []
        for idx in top_l2fc_indices:
            family_info = {
                'family_idx': int(idx),
                'interpro_id': interpro_annotations_nonzero.iloc[idx]['ENTRY_AC'],
                'interpro_name': interpro_annotations_nonzero.iloc[idx]['ENTRY_NAME'],
                'mean_in_family': float(mean_in_family[idx]),
                'mean_out_family': float(mean_out_family[idx]),
                'l2fc': float(l2fc[idx]),
                'pvalue': float(pvals[idx]),
                'bonf_pvalue': float(pvals[idx] * n_tests)
            }
            top_l2fc_details.append(family_info)
        
        top_activation_details = []
        for idx in top_activation_indices:
            family_info = {
                'family_idx': int(idx),
                'interpro_id': interpro_annotations_nonzero.iloc[idx]['ENTRY_AC'],
                'interpro_name': interpro_annotations_nonzero.iloc[idx]['ENTRY_NAME'],
                'mean_in_family': float(mean_in_family[idx]),
                'mean_out_family': float(mean_out_family[idx]),
                'l2fc': float(l2fc[idx]),
                'pvalue': float(pvals[idx]),
                'bonf_pvalue': float(pvals[idx] * n_tests)
            }
            top_activation_details.append(family_info)
        
        results[f"layer_{layer}_latent_{latent_id}"] = {
            'actual_latent_id': actual_latent_id,
            'top_by_l2fc': top_l2fc_details,
            'top_by_activation': top_activation_details
        }
    
    return results


def print_top_families_summary(results):
    """Print a nice summary of the results"""
    for latent_key, data in results.items():
        print(f"\n=== {latent_key.upper()} (Actual ID: {data['actual_latent_id']}) ===")
        
        print("\nTop 5 by L2FC:")
        for i, family in enumerate(data['top_by_l2fc'], 1):
            print(f"  {i}. {family['interpro_name']}")
            print(f"     ID: {family['interpro_id']}, L2FC: {family['l2fc']:.2f}")
            print(f"     In/Out: {family['mean_in_family']:.3f}/{family['mean_out_family']:.3f}")
            print(f"     Bonf p-val: {family['bonf_pvalue']:.2e}")
        
        print("\nTop 5 by Raw Activation:")
        for i, family in enumerate(data['top_by_activation'], 1):
            print(f"  {i}. {family['interpro_name']}")
            print(f"     ID: {family['interpro_id']}, Activation: {family['mean_in_family']:.3f}")
            print(f"     L2FC: {family['l2fc']:.2f}, Bonf p-val: {family['bonf_pvalue']:.2e}")


# Usage examples:
# Example 1: Get top families for specific layer-latent pairs without p-value filtering
layer_latent_pairs = [
    (12, 1204),  # Layer 12, latent 1204 
    (16, 1504),  # Layer 16, latent 1504
    (20, 142),   # Layer 20, latent 142
]

results_no_pval = get_top_families_for_latents(
    layer_latent_pairs=layer_latent_pairs,
    latents_family_effect_size=latents_family_effect_size,
    latents_family_pvals=latents_family_pvals,
    interpro_annotations_nonzero=interpro_annotations_nonzero,
    latent_ids_both_proteins=latent_ids_both_proteins,
    n_tests=n_tests,
    top_k=5,
    require_pvalue=False
)

print_top_families_summary(results_no_pval)


# Example 2: Get top families with p-value filtering
results_with_pval = get_top_families_for_latents(
    layer_latent_pairs=layer_latent_pairs,
    latents_family_effect_size=latents_family_effect_size,
    latents_family_pvals=latents_family_pvals,
    interpro_annotations_nonzero=interpro_annotations_nonzero,
    latent_ids_both_proteins=latent_ids_both_proteins,
    n_tests=n_tests,
    top_k=5,
    require_pvalue=True,
    pvalue_threshold=0.05
)

print("\n" + "="*80)
print("RESULTS WITH P-VALUE FILTERING:")
print("="*80)
print_top_families_summary(results_with_pval)


# Example 3: Convert to DataFrame for easier analysis
def results_to_dataframe(results, method='l2fc'):
    """Convert results to a pandas DataFrame"""
    rows = []
    for latent_key, data in results.items():
        layer = int(latent_key.split('_')[1])
        latent_id = int(latent_key.split('_')[3])
        
        method_key = 'top_by_l2fc' if method == 'l2fc' else 'top_by_activation'
        
        for rank, family in enumerate(data[method_key], 1):
            row = {
                'layer': layer,
                'latent_id': latent_id,
                'actual_latent_id': data['actual_latent_id'],
                'rank': rank,
                'interpro_id': family['interpro_id'],
                'interpro_name': family['interpro_name'],
                'mean_in_family': family['mean_in_family'],
                'mean_out_family': family['mean_out_family'],
                'l2fc': family['l2fc'],
                'pvalue': family['pvalue'],
                'bonf_pvalue': family['bonf_pvalue']
            }
            rows.append(row)
    
    return pd.DataFrame(rows)

# Create DataFrames
df_l2fc = results_to_dataframe(results_no_pval, method='l2fc')
df_activation = results_to_dataframe(results_no_pval, method='activation')

print("\nTop families by L2FC (DataFrame):")
print(df_l2fc.head(10))

print("\nTop families by activation (DataFrame):")
print(df_activation.head(10))
# Out:
# === LAYER_12_LATENT_1204 (Actual ID: 9396) ===
#
# Top 5 by L2FC:
#   1. Heat shock protein Hsp90, N-terminal
#      ID: IPR020575, L2FC: 8.45
#      In/Out: 1.425/0.004
#      Bonf p-val: 3.94e-16
#   2. Heat shock protein Hsp90 family
#      ID: IPR001404, L2FC: 8.45
#      In/Out: 1.425/0.004
#      Bonf p-val: 3.94e-16
#   3. Heat shock protein Hsp90, conserved site
#      ID: IPR019805, L2FC: 8.44
#      In/Out: 1.456/0.004
#      Bonf p-val: 2.94e-13
#   4. DNA mismatch repair protein MutL/Mlh/Pms-like
#      ID: IPR038973, L2FC: 8.38
#      In/Out: 1.490/0.004
#      Bonf p-val: 1.59e-07
#   5. DNA mismatch repair protein, MutL
#      ID: IPR020667, L2FC: 8.38
#      In/Out: 1.490/0.004
#      Bonf p-val: 1.59e-07
#
# Top 5 by Raw Activation:
#   1. MutL, C-terminal domain superfamily
#      ID: IPR037198, Activation: 1.490
#      L2FC: 8.38, Bonf p-val: 1.59e-07
#   2. DNA mismatch repair protein, MutL
#      ID: IPR020667, Activation: 1.490
#      L2FC: 8.38, Bonf p-val: 1.59e-07
#   3. DNA mismatch repair protein MutL/Mlh/Pms-like
#      ID: IPR038973, Activation: 1.490
#      L2FC: 8.38, Bonf p-val: 1.59e-07
#   4. DNA mismatch repair, conserved site
#      ID: IPR014762, Activation: 1.490
#      L2FC: 8.38, Bonf p-val: 1.59e-07
#   5. MutL, C-terminal domain, dimerisation subdomain
#      ID: IPR042120, Activation: 1.490
#      L2FC: 8.38, Bonf p-val: 1.59e-07
#
# === LAYER_16_LATENT_1504 (Actual ID: 13792) ===
#
# Top 5 by L2FC:
#   1. Dienelactone hydrolase-like enzyme
#      ID: IPR051049, L2FC: 6.64
#      In/Out: 2.796/0.028
#      Bonf p-val: 1.63e+07
#   2. Dienelactone hydrolase
#      ID: IPR002925, L2FC: 6.64
#      In/Out: 2.769/0.028
#      Bonf p-val: 2.01e+06
#   3. Platelet-activating factor acetylhydrolase-like, eukaryote
#      ID: IPR016715, L2FC: 6.59
#      In/Out: 2.700/0.028
#      Bonf p-val: 1.63e+07
#   4. Esterase-like
#      ID: IPR000801, L2FC: 6.47
#      In/Out: 2.488/0.028
#      Bonf p-val: 1.63e+07
#   5. S-formylglutathione hydrolase
#      ID: IPR014186, L2FC: 6.47
#      In/Out: 2.488/0.028
#      Bonf p-val: 1.63e+07
#
# Top 5 by Raw Activation:
#   1. Dienelactone hydrolase-like enzyme
#      ID: IPR051049, Activation: 2.796
#      L2FC: 6.64, Bonf p-val: 1.63e+07
#   2. Dienelactone hydrolase
#      ID: IPR002925, Activation: 2.769
#      L2FC: 6.64, Bonf p-val: 2.01e+06
#   3. Platelet-activating factor acetylhydrolase-like, eukaryote
#      ID: IPR016715, Activation: 2.700
#      L2FC: 6.59, Bonf p-val: 1.63e+07
#   4. Esterase-like
#      ID: IPR000801, Activation: 2.488
#      L2FC: 6.47, Bonf p-val: 1.63e+07
#   5. S-formylglutathione hydrolase
#      ID: IPR014186, Activation: 2.488
#      L2FC: 6.47, Bonf p-val: 1.63e+07
#
# === LAYER_20_LATENT_142 (Actual ID: 16526) ===
#
# Top 5 by L2FC:
#   1. Amino acid adenylation domain
#      ID: IPR010071, L2FC: 6.20
#      In/Out: 3.520/0.048
#      Bonf p-val: 1.98e+07
#   2. D-alanine--D-alanyl carrier protein ligase
#      ID: IPR010072, L2FC: 6.20
#      In/Out: 3.520/0.048
#      Bonf p-val: 1.98e+07
#   3. D-alanine:D-alanyl carrier protein ligase-like
#      ID: IPR044507, L2FC: 6.20
#      In/Out: 3.520/0.048
#      Bonf p-val: 1.98e+07
#   4. AMP-binding enzyme, C-terminal domain superfamily
#      ID: IPR045851, L2FC: 6.05
#      In/Out: 2.935/0.044
#      Bonf p-val: 1.54e-02
#   5. AMP-dependent synthetase/ligase domain
#      ID: IPR000873, L2FC: 6.05
#      In/Out: 2.935/0.044
#      Bonf p-val: 1.54e-02
#
# Top 5 by Raw Activation:
#   1. D-alanine--D-alanyl carrier protein ligase
#      ID: IPR010072, Activation: 3.520
#      L2FC: 6.20, Bonf p-val: 1.98e+07
#   2. Amino acid adenylation domain
#      ID: IPR010071, Activation: 3.520
#      L2FC: 6.20, Bonf p-val: 1.98e+07
#   3. D-alanine:D-alanyl carrier protein ligase-like
#      ID: IPR044507, Activation: 3.520
#      L2FC: 6.20, Bonf p-val: 1.98e+07
#   4. Oxalate--CoA ligase Pcs60-like
#      ID: IPR045310, Activation: 3.069
#      L2FC: 6.01, Bonf p-val: 1.99e+07
#   5. AMP-binding enzyme, C-terminal domain
#      ID: IPR025110, Activation: 2.966
#      L2FC: 6.05, Bonf p-val: 4.54e-01
#
# ================================================================================
# RESULTS WITH P-VALUE FILTERING:
# ================================================================================
#
# === LAYER_12_LATENT_1204 (Actual ID: 9396) ===
#
# Top 5 by L2FC:
#   1. Heat shock protein Hsp90, N-terminal
#      ID: IPR020575, L2FC: 8.45
#      In/Out: 1.425/0.004
#      Bonf p-val: 3.94e-16
#   2. Heat shock protein Hsp90 family
#      ID: IPR001404, L2FC: 8.45
#      In/Out: 1.425/0.004
#      Bonf p-val: 3.94e-16
#   3. Heat shock protein Hsp90, conserved site
#      ID: IPR019805, L2FC: 8.44
#      In/Out: 1.456/0.004
#      Bonf p-val: 2.94e-13
#   4. DNA mismatch repair protein, S5 domain 2-like
#      ID: IPR013507, L2FC: 8.38
#      In/Out: 1.490/0.004
#      Bonf p-val: 1.59e-07
#   5. DNA mismatch repair protein, MutL
#      ID: IPR020667, L2FC: 8.38
#      In/Out: 1.490/0.004
#      Bonf p-val: 1.59e-07
#
# Top 5 by Raw Activation:
#   1. MutL, C-terminal domain superfamily
#      ID: IPR037198, Activation: 1.490
#      L2FC: 8.38, Bonf p-val: 1.59e-07
#   2. MutL, C-terminal domain, dimerisation subdomain
#      ID: IPR042120, Activation: 1.490
#      L2FC: 8.38, Bonf p-val: 1.59e-07
#   3. DNA mismatch repair protein, MutL
#      ID: IPR020667, Activation: 1.490
#      L2FC: 8.38, Bonf p-val: 1.59e-07
#   4. DNA mismatch repair protein, S5 domain 2-like
#      ID: IPR013507, Activation: 1.490
#      L2FC: 8.38, Bonf p-val: 1.59e-07
#   5. DNA mismatch repair protein MutL/Mlh/PMS
#      ID: IPR002099, Activation: 1.490
#      L2FC: 8.38, Bonf p-val: 1.59e-07
#
# === LAYER_16_LATENT_1504 (Actual ID: 13792) ===
#
# Top 5 by L2FC:
#   1. Alpha/Beta hydrolase fold
#      ID: IPR029058, L2FC: 6.05
#      In/Out: 1.323/0.020
#      Bonf p-val: 0.00e+00
#   2. Alpha/beta hydrolase fold-1
#      ID: IPR000073, L2FC: 5.61
#      In/Out: 1.283/0.026
#      Bonf p-val: 8.71e-06
#   3. GroES-like superfamily
#      ID: IPR011032, L2FC: 3.74
#      In/Out: 0.368/0.028
#      Bonf p-val: 1.53e-04
#   4. Aminoacid dehydrogenase-like, N-terminal domain superfamily
#      ID: IPR046346, L2FC: 3.11
#      In/Out: 0.238/0.028
#      Bonf p-val: 3.03e-15
#   5. Tetrahydrofolate dehydrogenase/cyclohydrolase, catalytic domain
#      ID: IPR020630, L2FC: 2.97
#      In/Out: 0.219/0.028
#      Bonf p-val: 8.20e-05
#
# Top 5 by Raw Activation:
#   1. Alpha/Beta hydrolase fold
#      ID: IPR029058, Activation: 1.323
#      L2FC: 6.05, Bonf p-val: 0.00e+00
#   2. Alpha/beta hydrolase fold-1
#      ID: IPR000073, Activation: 1.283
#      L2FC: 5.61, Bonf p-val: 8.71e-06
#   3. GroES-like superfamily
#      ID: IPR011032, Activation: 0.368
#      L2FC: 3.74, Bonf p-val: 1.53e-04
#   4. Aminoacid dehydrogenase-like, N-terminal domain superfamily
#      ID: IPR046346, Activation: 0.238
#      L2FC: 3.11, Bonf p-val: 3.03e-15
#   5. Tetrahydrofolate dehydrogenase/cyclohydrolase, catalytic domain
#      ID: IPR020630, Activation: 0.219
#      L2FC: 2.97, Bonf p-val: 8.20e-05
#
# === LAYER_20_LATENT_142 (Actual ID: 16526) ===
#
# Top 5 by L2FC:
#   1. AMP-binding enzyme, C-terminal domain superfamily
#      ID: IPR045851, L2FC: 6.05
#      In/Out: 2.935/0.044
#      Bonf p-val: 1.54e-02
#   2. AMP-dependent synthetase/ligase domain
#      ID: IPR000873, L2FC: 6.05
#      In/Out: 2.935/0.044
#      Bonf p-val: 1.54e-02
#   3. Aldehyde/histidinol dehydrogenase
#      ID: IPR016161, L2FC: 5.86
#      In/Out: 2.456/0.042
#      Bonf p-val: 1.72e-10
#   4. Aldehyde dehydrogenase, N-terminal
#      ID: IPR016162, L2FC: 5.83
#      In/Out: 2.457/0.043
#      Bonf p-val: 1.39e-07
#   5. Aldehyde dehydrogenase, C-terminal
#      ID: IPR016163, L2FC: 5.83
#      In/Out: 2.457/0.043
#      Bonf p-val: 1.39e-07
#
# Top 5 by Raw Activation:
#   1. AMP-binding enzyme, C-terminal domain superfamily
#      ID: IPR045851, Activation: 2.935
#      L2FC: 6.05, Bonf p-val: 1.54e-02
#   2. AMP-dependent synthetase/ligase domain
#      ID: IPR000873, Activation: 2.935
#      L2FC: 6.05, Bonf p-val: 1.54e-02
#   3. Aldehyde dehydrogenase, N-terminal
#      ID: IPR016162, Activation: 2.457
#      L2FC: 5.83, Bonf p-val: 1.39e-07
#   4. Aldehyde dehydrogenase, C-terminal
#      ID: IPR016163, Activation: 2.457
#      L2FC: 5.83, Bonf p-val: 1.39e-07
#   5. Aldehyde dehydrogenase domain
#      ID: IPR015590, Activation: 2.457
#      L2FC: 5.83, Bonf p-val: 1.39e-07
#
# Top families by L2FC (DataFrame):
#    layer  latent_id  actual_latent_id  rank interpro_id  \
# 0     12       1204              9396     1   IPR020575
# 1     12       1204              9396     2   IPR001404
# 2     12       1204              9396     3   IPR019805
# 3     12       1204              9396     4   IPR038973
# 4     12       1204              9396     5   IPR020667
# 5     16       1504             13792     1   IPR051049
# 6     16       1504             13792     2   IPR002925
# 7     16       1504             13792     3   IPR016715
# 8     16       1504             13792     4   IPR000801
# 9     16       1504             13792     5   IPR014186
#
#                                        interpro_name  mean_in_family  \
# 0               Heat shock protein Hsp90, N-terminal        1.424645
# 1                    Heat shock protein Hsp90 family        1.424645
# 2           Heat shock protein Hsp90, conserved site        1.455940
# 3      DNA mismatch repair protein MutL/Mlh/Pms-like        1.490237
# 4                  DNA mismatch repair protein, MutL        1.490237
# 5                 Dienelactone hydrolase-like enzyme        2.795956
# 6                             Dienelactone hydrolase        2.768614
# 7  Platelet-activating factor acetylhydrolase-lik...        2.699578
# 8                                      Esterase-like        2.487814
# 9                      S-formylglutathione hydrolase        2.487814
#
#    mean_out_family      l2fc        pvalue   bonf_pvalue
# 0         0.004086  8.445825  1.359781e-24  3.936193e-16
# 1         0.004086  8.445825  1.359781e-24  3.936193e-16
# 2         0.004206  8.435329  1.016863e-21  2.943538e-13
# 3         0.004479  8.378081  5.507300e-16  1.594212e-07
# 4         0.004479  8.378081  5.507300e-16  1.594212e-07
# 5         0.027947  6.644495  5.623317e-02  1.627796e+07
# 6         0.027676  6.644395  6.932889e-03  2.006881e+06
# 7         0.027957  6.593390  5.633174e-02  1.630649e+07
# 8         0.027978  6.474442  5.638107e-02  1.632077e+07
# 9         0.027978  6.474442  5.638107e-02  1.632077e+07
#
# Top families by activation (DataFrame):
#    layer  latent_id  actual_latent_id  rank interpro_id  \
# 0     12       1204              9396     1   IPR037198
# 1     12       1204              9396     2   IPR020667
# 2     12       1204              9396     3   IPR038973
# 3     12       1204              9396     4   IPR014762
# 4     12       1204              9396     5   IPR042120
# 5     16       1504             13792     1   IPR051049
# 6     16       1504             13792     2   IPR002925
# 7     16       1504             13792     3   IPR016715
# 8     16       1504             13792     4   IPR000801
# 9     16       1504             13792     5   IPR014186
#
#                                        interpro_name  mean_in_family  \
# 0                MutL, C-terminal domain superfamily        1.490237
# 1                  DNA mismatch repair protein, MutL        1.490237
# 2      DNA mismatch repair protein MutL/Mlh/Pms-like        1.490237
# 3                DNA mismatch repair, conserved site        1.490237
# 4    MutL, C-terminal domain, dimerisation subdomain        1.490237
# 5                 Dienelactone hydrolase-like enzyme        2.795956
# 6                             Dienelactone hydrolase        2.768614
# 7  Platelet-activating factor acetylhydrolase-lik...        2.699578
# 8                                      Esterase-like        2.487814
# 9                      S-formylglutathione hydrolase        2.487814
#
#    mean_out_family      l2fc        pvalue   bonf_pvalue
# 0         0.004479  8.378081  5.507300e-16  1.594212e-07
# 1         0.004479  8.378081  5.507300e-16  1.594212e-07
# 2         0.004479  8.378081  5.507300e-16  1.594212e-07
# 3         0.004479  8.378081  5.507300e-16  1.594212e-07
# 4         0.004479  8.378081  5.507300e-16  1.594212e-07
# 5         0.027947  6.644495  5.623317e-02  1.627796e+07
# 6         0.027676  6.644395  6.932889e-03  2.006881e+06
# 7         0.027957  6.593390  5.633174e-02  1.630649e+07
# 8         0.027978  6.474442  5.638107e-02  1.632077e+07
# 9         0.027978  6.474442  5.638107e-02  1.632077e+07
# /tmp/ipykernel_158963/3159108707.py:62: RuntimeWarning: divide by zero encountered in log2
#   l2fc = np.log2(mean_in_family / (mean_out_family + 1e-8))

# %%
offsets
# Out:
# {'4': 0,
#  '8': 4096,
#  '12': 8192,
#  '16': 12288,
#  '20': 16384,
#  '24': 20480,
#  '28': 24576}

# %%
latent_ids_both_proteins[0:10]
# Out:
# [100, 181, 237, 340, 443, 495, 527, 601, 794, 798]

# %%
2112+8192
# Out:
# 10304

# %%
latent_ids_both_proteins
# Out:
# [100,
#  181,
#  237,
#  340,
#  443,
#  495,
#  527,
#  601,
#  794,
#  798,
#  963,
#  1096,
#  1196,
#  1297,
#  1374,
#  1468,
#  1474,
#  1509,
#  1682,
#  1690,
#  1712,
#  1807,
#  1949,
#  2005,
#  2112,
#  2277,
#  2311,
#  2340,
#  2443,
#  2511,
#  2850,
#  2929,
#  2947,
#  2983,
#  3069,
#  3153,
#  3170,
#  3177,
#  3229,
#  3326,
#  3351,
#  3544,
#  3612,
#  3634,
#  3651,
#  3701,
#  3717,
#  3764,
#  3788,
#  3832,
#  4527,
#  4584,
#  5671,
#  6262,
#  6582,
#  6758,
#  6773,
#  6871,
#  7415,
#  7480,
#  8017,
#  8403,
#  8531,
#  8757,
#  8859,
#  8861,
#  8990,
#  8995,
#  9091,
#  9096,
#  9274,
#  9313,
#  9396,
#  9448,
#  9569,
#  9606,
#  9710,
#  9988,
#  10010,
#  10249,
#  10304,
#  10342,
#  10494,
#  10664,
#  10666,
#  10669,
#  10670,
#  10704,
#  10820,
#  10989,
#  11037,
#  11227,
#  11431,
#  11690,
#  11728,
#  11735,
#  11749,
#  11790,
#  11818,
#  11943,
#  11986,
#  12000,
#  12041,
#  12135,
#  12152,
#  12211,
#  12236,
#  12334,
#  12445,
#  12645,
#  12675,
#  12679,
#  12768,
#  12894,
#  12919,
#  12996,
#  13025,
#  13088,
#  13099,
#  13146,
#  13216,
#  13356,
#  13363,
#  13454,
#  13491,
#  13497,
#  13524,
#  13568,
#  13641,
#  13668,
#  13676,
#  13687,
#  13735,
#  13737,
#  13740,
#  13748,
#  13792,
#  13801,
#  13885,
#  14016,
#  14076,
#  14124,
#  14128,
#  14168,
#  14215,
#  14463,
#  14511,
#  14629,
#  14700,
#  14734,
#  14738,
#  14824,
#  14837,
#  14876,
#  15124,
#  15166,
#  15380,
#  15395,
#  15429,
#  15553,
#  15585,
#  15681,
#  15742,
#  15746,
#  15801,
#  15851,
#  15953,
#  15954,
#  15967,
#  16051,
#  16053,
#  16167,
#  16282,
#  16443,
#  16470,
#  16520,
#  16521,
#  16526,
#  16571,
#  16816,
#  16825,
#  16846,
#  16880,
#  16978,
#  17043,
#  17106,
#  17138,
#  17173,
#  17214,
#  17222,
#  17235,
#  17249,
#  17262,
#  17282,
#  17292,
#  17314,
#  17396,
#  17492,
#  17651,
#  17660,
#  17689,
#  17779,
#  17889,
#  17917,
#  17924,
#  18128,
#  18140,
#  18144,
#  18147,
#  18167,
#  18183,
#  18184,
#  18191,
#  18344,
#  18350,
#  18359,
#  18405,
#  18407,
#  18587,
#  18645,
#  18695,
#  18706,
#  18708,
#  18711,
#  18750,
#  18785,
#  18879,
#  18884,
#  18922,
#  19016,
#  19105,
#  19107,
#  19122,
#  19145,
#  19332,
#  19351,
#  19428,
#  19780,
#  19794,
#  19846,
#  19874,
#  19951,
#  19964,
#  19981,
#  19999,
#  20000,
#  20023,
#  20061,
#  20112,
#  20116,
#  20159,
#  20171,
#  20308,
#  20336,
#  20338,
#  20356,
#  20379,
#  20384,
#  20442,
#  20444,
#  20494,
#  20521,
#  20558,
#  20568,
#  20590,
#  20660,
#  20700,
#  20711,
#  20808,
#  20910,
#  20926,
#  20951,
#  20971,
#  21085,
#  21164,
#  21211,
#  21378,
#  21409,
#  21430,
#  21452,
#  21456,
#  21476,
#  21493,
#  21524,
#  21549,
#  21555,
#  21577,
#  21629,
#  21635,
#  21743,
#  21780,
#  21879,
#  21887,
#  21901,
#  21907,
#  21985,
#  22174,
#  22302,
#  22308,
#  22338,
#  22345,
#  22373,
#  22389,
#  22401,
#  22528,
#  22530,
#  22533,
#  22543,
#  22686,
#  22689,
#  22733,
#  22734,
#  22801,
#  22829,
#  22830,
#  22878,
#  22915,
#  23013,
#  23025,
#  23066,
#  23089,
#  23107,
#  23112,
#  23133,
#  23219,
#  23226,
#  23264,
#  23328,
#  23478,
#  23496,
#  23532,
#  23545,
#  23546,
#  23597,
#  23651,
#  23676,
#  23744,
#  23782,
#  23807,
#  23810,
#  23838,
#  23917,
#  23919,
#  23940,
#  24098,
#  24113,
#  24159,
#  24187,
#  24266,
#  24337,
#  24345,
#  24352,
#  24375,
#  24426,
#  24439,
#  24476,
#  24548,
#  24692,
#  24745,
#  24789,
#  24910,
#  25063,
#  25234,
#  25238,
#  25306,
#  25393,
#  25438,
#  25472,
#  25642,
#  25671,
#  25998,
#  26455,
#  26468,
#  26546,
#  26607,
#  27528,
#  27895,
#  28023,
#  28331,
#  28482,
#  28526,
#  28597,
#  28651]

# %%
latent_ids_both_proteins.index(10304)
# Out:
# 80

# %%
latent_ids_both_proteins[80]
# Out:
# 10304

# %%
latents_family_pvals[80].shape
# Out:
# torch.Size([10096])

# %%
domain_annotations_threshold_3 = {}
domain_annotations_threshold_4 = {}
for pair in metx_latents.items():
    layer_ind = pair[0]
    for latent_ind in pair[1]:
        flat_ind = offsets[str(layer_ind)] + latent_ind
        epsilon = 1e-4
        latent_i = latent_ids_both_proteins.index(flat_ind)
        domain_annotations_threshold_3[f"{layer_ind}_{latent_ind}"] = []
        domain_annotations_threshold_4[f"{layer_ind}_{latent_ind}"] = []
        for family_j in range(latents_family_pvals.shape[1]):
            if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
                if latents_family_effect_size[latent_i,family_j,1] < 0.05 and latents_family_effect_size[latent_i,family_j,0] > 0.1:
                    l2fc = np.log2((latents_family_effect_size[latent_i,family_j,0]+epsilon)/(latents_family_effect_size[latent_i,family_j,1]+epsilon))
                    if l2fc > 3:
                        domain_annotations_threshold_3[f"{layer_ind}_{latent_ind}"] += [interpro_annotations_nonzero.iloc[family_j].ENTRY_NAME, latents_family_effect_size[latent_i,family_j,0].item(), latents_family_effect_size[latent_i,family_j,1].item(), l2fc.item()]
                    if l2fc > 4:
                        domain_annotations_threshold_4[f"{layer_ind}_{latent_ind}"] += [interpro_annotations_nonzero.iloc[family_j].ENTRY_NAME, latents_family_effect_size[latent_i,family_j,0].item(), latents_family_effect_size[latent_i,family_j,1].item(), l2fc.item()]

# %%
import json

# Save domain annotations with threshold 3 to JSON
with open('../results/domain_annotations_metx_threshold_3.json', 'w') as f:
    json.dump(domain_annotations_threshold_3, f, indent=2)

# Save domain annotations with threshold 4 to JSON 
with open('../results/domain_annotations_metx_threshold_4.json', 'w') as f:
    json.dump(domain_annotations_threshold_4, f, indent=2)

# %%
domain_annotations_threshold_3 = {}
domain_annotations_threshold_4 = {}
for pair in top2_latents.items():
    layer_ind = pair[0]
    for latent_ind in pair[1]:
        flat_ind = offsets[str(layer_ind)] + latent_ind
        epsilon = 1e-4
        latent_i = latent_ids_both_proteins.index(flat_ind)
        domain_annotations_threshold_3[f"{layer_ind}_{latent_ind}"] = []
        domain_annotations_threshold_4[f"{layer_ind}_{latent_ind}"] = []
        for family_j in range(latents_family_pvals.shape[1]):
            if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
                if latents_family_effect_size[latent_i,family_j,1] < 0.05 and latents_family_effect_size[latent_i,family_j,0] > 0.1:
                    l2fc = np.log2((latents_family_effect_size[latent_i,family_j,0]+epsilon)/(latents_family_effect_size[latent_i,family_j,1]+epsilon))
                    if l2fc > 3:
                        domain_annotations_threshold_3[f"{layer_ind}_{latent_ind}"] += [interpro_annotations_nonzero.iloc[family_j].ENTRY_NAME, latents_family_effect_size[latent_i,family_j,0].item(), latents_family_effect_size[latent_i,family_j,1].item(), l2fc.item()]
                    if l2fc > 4:
                        domain_annotations_threshold_4[f"{layer_ind}_{latent_ind}"] += [interpro_annotations_nonzero.iloc[family_j].ENTRY_NAME, latents_family_effect_size[latent_i,family_j,0].item(), latents_family_effect_size[latent_i,family_j,1].item(), l2fc.item()]

# %%
import json

# Save domain annotations with threshold 3 to JSON
with open('../results/domain_annotations_top2_threshold_3.json', 'w') as f:
    json.dump(domain_annotations_threshold_3, f, indent=2)

# Save domain annotations with threshold 4 to JSON 
with open('../results/domain_annotations_top2_threshold_4.json', 'w') as f:
    json.dump(domain_annotations_threshold_4, f, indent=2)

# %%
domain_annotations
# Out:
# {('4', 2443): [],
#  ('4', 3651): [],
#  ('4', 963): [],
#  ('4', 340): [],
#  ('4', 237): [],
#  ('4', 1474): [],
#  ('4', 794): [],
#  ('4', 443): [],
#  ('4', 2340): [],
#  ('4', 3788): [],
#  ('4', 3701): [],
#  ('4', 2311): [],
#  ('4', 2277): [],
#  ('4', 3153): [],
#  ('4', 798): [],
#  ('4', 3634): [],
#  ('4', 1682): [],
#  ('4', 1690): [],
#  ('4', 3764): [],
#  ('4', 3326): [],
#  ('4', 1096): [],
#  ('4', 3351): [],
#  ('4', 1712): [],
#  ('4', 181): [],
#  ('4', 3177): [],
#  ('4', 3832): [],
#  ('4', 1807): [],
#  ('4', 3612): [],
#  ('4', 495): [],
#  ('4',
#   1297): ['Large ribosomal subunit protein uL30-like, ferredoxin-like fold domain', tensor(0.0521), tensor(0.0034), tensor(3.9415), 'Large ribosomal subunit protein bL36', tensor(0.0731), tensor(0.0033), tensor(4.4604), 'Small ribosomal subunit protein uS14', tensor(0.0292), tensor(0.0034), tensor(3.0965), 'Large ribosomal subunit protein uL30, bacterial-type', tensor(0.0573), tensor(0.0034), tensor(4.0791), 'Large ribosomal subunit protein bL36 superfamily', tensor(0.0731), tensor(0.0033), tensor(4.4604), 'Large ribosomal subunit protein uL30, ferredoxin-like fold domain superfamily', tensor(0.0521), tensor(0.0034), tensor(3.9415)],
#  ('8', 488): ['Serine carboxypeptidase, serine active site',
#   tensor(0.0038),
#   tensor(0.0004),
#   tensor(3.2935),
#   'Carboxylesterase type B, active site',
#   tensor(0.0185),
#   tensor(0.0004),
#   tensor(5.5825),
#   'Glyceraldehyde 3-phosphate dehydrogenase, active site',
#   tensor(0.0057),
#   tensor(0.0004),
#   tensor(3.8780),
#   'Serine carboxypeptidases, histidine active site',
#   tensor(0.0034),
#   tensor(0.0004),
#   tensor(3.1364),
#   'Porphobilinogen deaminase, dipyrromethane cofactor binding site',
#   tensor(0.0061),
#   tensor(0.0004),
#   tensor(3.9709),
#   'AB hydrolase 4, conserved site',
#   tensor(0.0478),
#   tensor(0.0004),
#   tensor(6.9660),
#   'DNA methylase, N-6 adenine-specific, conserved site',
#   tensor(0.0050),
#   tensor(0.0004),
#   tensor(3.6975),
#   'Recombinase, conserved site',
#   tensor(0.0124),
#   tensor(0.0004),
#   tensor(4.9993),
#   'Malic enzyme, conserved site',
#   tensor(0.0039),
#   tensor(0.0004),
#   tensor(3.3214),
#   'ATP phosphoribosyltransferase, conserved site',
#   tensor(0.0045),
#   tensor(0.0004),
#   tensor(3.5351),
#   'Tetrahydrofolate dehydrogenase/cyclohydrolase, conserved site',
#   tensor(0.0033),
#   tensor(0.0004),
#   tensor(3.0683),
#   'Cutinase, aspartate and histidine active sites',
#   tensor(0.0095),
#   tensor(0.0004),
#   tensor(4.6136),
#   'Cutinase, serine active site',
#   tensor(0.0095),
#   tensor(0.0004),
#   tensor(4.6136),
#   'Ribosomal RNA large subunit methyltransferase K/L-like, conserved site',
#   tensor(0.0041),
#   tensor(0.0004),
#   tensor(3.3836),
#   'Alpha/beta hydrolase fold-1',
#   tensor(0.0371),
#   tensor(0.0003),
#   tensor(6.8011),
#   'Ribosomal RNA large subunit methyltransferase K/L-like, methyltransferase domain',
#   tensor(0.0039),
#   tensor(0.0004),
#   tensor(3.3196),
#   'THIF-type NAD/FAD binding fold',
#   tensor(0.0063),
#   tensor(0.0004),
#   tensor(4.0204),
#   'Peptidase S9, prolyl oligopeptidase, catalytic domain',
#   tensor(0.0258),
#   tensor(0.0004),
#   tensor(6.0772),
#   'Carboxylesterase, type B',
#   tensor(0.0080),
#   tensor(0.0004),
#   tensor(4.3613),
#   'Dipeptidylpeptidase IV, N-terminal domain',
#   tensor(0.0229),
#   tensor(0.0004),
#   tensor(5.8918),
#   'Dienelactone hydrolase',
#   tensor(0.0619),
#   tensor(0.0004),
#   tensor(7.3486),
#   'Small GTP-binding domain',
#   tensor(0.0033),
#   tensor(0.0004),
#   tensor(3.1997),
#   'Resolvase, N-terminal catalytic domain',
#   tensor(0.0116),
#   tensor(0.0004),
#   tensor(4.9046),
#   'Resolvase, HTH domain',
#   tensor(0.0124),
#   tensor(0.0004),
#   tensor(4.9993),
#   'Methyltransferase small domain',
#   tensor(0.0061),
#   tensor(0.0004),
#   tensor(3.9650),
#   'Flavodoxin/nitric oxide synthase',
#   tensor(0.0080),
#   tensor(0.0004),
#   tensor(4.3731),
#   'Propeptide, carboxypeptidase Y',
#   tensor(0.0032),
#   tensor(0.0004),
#   tensor(3.0225),
#   'Malic enzyme, N-terminal domain',
#   tensor(0.0039),
#   tensor(0.0004),
#   tensor(3.3214),
#   'Malic enzyme, NAD-binding',
#   tensor(0.0039),
#   tensor(0.0004),
#   tensor(3.3214),
#   'Alpha/beta hydrolase fold-3',
#   tensor(0.0685),
#   tensor(0.0004),
#   tensor(7.5007),
#   'Histidine biosynthesis HisG, C-terminal',
#   tensor(0.0079),
#   tensor(0.0004),
#   tensor(4.3541),
#   'Methyltransferase small, N-terminal',
#   tensor(0.0061),
#   tensor(0.0004),
#   tensor(3.9650),
#   'Lipase',
#   tensor(0.0063),
#   tensor(0.0004),
#   tensor(4.0170),
#   'ATP phosphoribosyltransferase, catalytic domain',
#   tensor(0.0059),
#   tensor(0.0004),
#   tensor(3.9389),
#   'Glyceraldehyde 3-phosphate dehydrogenase, NAD(P) binding domain',
#   tensor(0.0057),
#   tensor(0.0004),
#   tensor(3.8780),
#   'Glyceraldehyde 3-phosphate dehydrogenase, catalytic domain',
#   tensor(0.0057),
#   tensor(0.0004),
#   tensor(3.8780),
#   'Porphobilinogen deaminase, N-terminal',
#   tensor(0.0061),
#   tensor(0.0004),
#   tensor(3.9709),
#   'Porphobilinogen deaminase, C-terminal',
#   tensor(0.0061),
#   tensor(0.0004),
#   tensor(3.9709),
#   'Serine aminopeptidase, S33',
#   tensor(0.1024),
#   tensor(0.0003),
#   tensor(8.1890),
#   'Glycosyltransferase subfamily 4-like, N-terminal domain',
#   tensor(0.0055),
#   tensor(0.0004),
#   tensor(3.8035),
#   'EngB-type guanine nucleotide-binding (G) domain',
#   tensor(0.0047),
#   tensor(0.0004),
#   tensor(3.6178),
#   'Lipase, N-terminal',
#   tensor(0.0084),
#   tensor(0.0004),
#   tensor(4.4321),
#   'Cutinase/acetylxylan esterase',
#   tensor(0.0095),
#   tensor(0.0004),
#   tensor(4.6136),
#   'Triacylglycerol lipase family',
#   tensor(0.0063),
#   tensor(0.0004),
#   tensor(4.0170),
#   'Porphobilinogen deaminase',
#   tensor(0.0061),
#   tensor(0.0004),
#   tensor(3.9709),
#   'ATP phosphoribosyltransferase HisG',
#   tensor(0.0059),
#   tensor(0.0004),
#   tensor(3.9389),
#   'Peptidase S10, serine carboxypeptidase',
#   tensor(0.0040),
#   tensor(0.0004),
#   tensor(3.3498),
#   'Small GTPase',
#   tensor(0.0130),
#   tensor(0.0004),
#   tensor(5.1242),
#   'Glycosyl transferase, family 20',
#   tensor(0.0044),
#   tensor(0.0004),
#   tensor(3.4977),
#   'Malic oxidoreductase',
#   tensor(0.0039),
#   tensor(0.0004),
#   tensor(3.3214),
#   'Lumazine/riboflavin synthase',
#   tensor(0.0094),
#   tensor(0.0004),
#   tensor(4.6119),
#   'UDPGP family',
#   tensor(0.0053),
#   tensor(0.0004),
#   tensor(3.7677),
#   'Sugar-phosphate isomerase, RpiB/LacA/LacB family',
#   tensor(0.0110),
#   tensor(0.0004),
#   tensor(4.8319),
#   'Small GTPase Rho',
#   tensor(0.0114),
#   tensor(0.0004),
#   tensor(4.8752),
#   'Galactose-6-phosphate isomerase subunit LacB',
#   tensor(0.0147),
#   tensor(0.0004),
#   tensor(5.2470),
#   'Phosphoglycolate phosphatase',
#   tensor(0.0077),
#   tensor(0.0004),
#   tensor(4.2934),
#   'Glyceraldehyde-3-phosphate dehydrogenase, type I',
#   tensor(0.0086),
#   tensor(0.0004),
#   tensor(4.4632),
#   'Small GTPase superfamily, ARF/SAR type',
#   tensor(0.0239),
#   tensor(0.0004),
#   tensor(5.9664),
#   'Uncharacterised protein family UPF0229',
#   tensor(0.0088),
#   tensor(0.0004),
#   tensor(4.4972),
#   'Homoserine/serine acetyltransferase MetX-like',
#   tensor(0.0324),
#   tensor(0.0004),
#   tensor(6.4195),
#   'TPMT family',
#   tensor(0.0091),
#   tensor(0.0004),
#   tensor(4.5479),
#   'Uncharacterised protein family UPF0227/Esterase YqiA',
#   tensor(0.0537),
#   tensor(0.0004),
#   tensor(7.1390),
#   'Flavoprotein WrbA-like',
#   tensor(0.0142),
#   tensor(0.0004),
#   tensor(5.1911),
#   'Esterase FrsA-like',
#   tensor(0.0294),
#   tensor(0.0004),
#   tensor(6.2606),
#   'Cutinase, monofunctional',
#   tensor(0.0095),
#   tensor(0.0004),
#   tensor(4.6136),
#   'AB hydrolase 4 family',
#   tensor(0.0478),
#   tensor(0.0004),
#   tensor(6.9660),
#   'GTP-binding protein, ribosome biogenesis, YsxC',
#   tensor(0.0047),
#   tensor(0.0004),
#   tensor(3.6178),
#   'ATP phosphoribosyltransferase HisG, long form',
#   tensor(0.0079),
#   tensor(0.0004),
#   tensor(4.3541),
#   'Glyceraldehyde/Erythrose phosphate dehydrogenase family',
#   tensor(0.0057),
#   tensor(0.0004),
#   tensor(3.8780),
#   'Small GTPase, Ras-type',
#   tensor(0.0093),
#   tensor(0.0004),
#   tensor(4.5708),
#   'Thiopurine S-methyltransferase, Se/Te detoxification',
#   tensor(0.0091),
#   tensor(0.0004),
#   tensor(4.5479),
#   'Uncharacterised protein family UPF0227',
#   tensor(0.0537),
#   tensor(0.0004),
#   tensor(7.1390),
#   'rRNA small subunit methyltransferase C',
#   tensor(0.0061),
#   tensor(0.0004),
#   tensor(3.9650),
#   'Small GTPase superfamily, ARF type',
#   tensor(0.0256),
#   tensor(0.0004),
#   tensor(6.0509),
#   'Thiopurine S-methyltransferase',
#   tensor(0.0091),
#   tensor(0.0004),
#   tensor(4.5479),
#   'Lumazine synthase',
#   tensor(0.0094),
#   tensor(0.0004),
#   tensor(4.6119),
#   'NAD(P)H dehydrogenase (quinone), prokaryotic',
#   tensor(0.0142),
#   tensor(0.0004),
#   tensor(5.1911),
#   'UDP-sugar pyrophosphorylase',
#   tensor(0.0053),
#   tensor(0.0004),
#   tensor(3.7677),
#   'Esterase FrsA',
#   tensor(0.0294),
#   tensor(0.0004),
#   tensor(6.2606),
#   'ThiF/MoeB/HesA family',
#   tensor(0.0063),
#   tensor(0.0004),
#   tensor(4.0204),
#   'Methylesterase/Alpha-hydroxynitrile lyase',
#   tensor(0.0660),
#   tensor(0.0004),
#   tensor(7.4451),
#   'rRNA (guanine-N(2)-)-methyltransferase RsmC/RlmG',
#   tensor(0.0061),
#   tensor(0.0004),
#   tensor(3.9650),
#   'Zinc-containing alcohol dehydrogenase',
#   tensor(0.0051),
#   tensor(0.0004),
#   tensor(3.7138),
#   'Glycosyltransferase group 1',
#   tensor(0.0055),
#   tensor(0.0004),
#   tensor(3.8035),
#   'FrsA esterase',
#   tensor(0.0312),
#   tensor(0.0004),
#   tensor(6.3614),
#   'AB hydrolase superfamily',
#   tensor(0.0295),
#   tensor(0.0004),
#   tensor(6.2541),
#   'Serine protease S9B/DPPIV',
#   tensor(0.0229),
#   tensor(0.0004),
#   tensor(5.8918),
#   'GDXG lipolytic enzyme',
#   tensor(0.0556),
#   tensor(0.0004),
#   tensor(7.1888),
#   'Small GTPase superfamily, Rab',
#   tensor(0.0232),
#   tensor(0.0004),
#   tensor(5.9048),
#   'Type-B Carboxylesterase/Lipase',
#   tensor(0.0080),
#   tensor(0.0004),
#   tensor(4.3613),
#   'Site-specific recombinase resolvase',
#   tensor(0.0124),
#   tensor(0.0004),
#   tensor(4.9993),
#   'AB hydrolase superfamily, subfamily 4',
#   tensor(0.0478),
#   tensor(0.0004),
#   tensor(6.9660),
#   'Monoacylglycerol and Diacylglycerol Lipase',
#   tensor(0.0550),
#   tensor(0.0004),
#   tensor(7.1747),
#   'Nitrogen regulatory PII-like, alpha/beta',
#   tensor(0.0053),
#   tensor(0.0004),
#   tensor(3.7688),
#   'Nitrogen regulatory protein PII/ATP phosphoribosyltransferase, C-terminal',
#   tensor(0.0048),
#   tensor(0.0004),
#   tensor(3.6167),
#   'Alpha/Beta hydrolase fold',
#   tensor(0.0321),
#   tensor(0.0002),
#   tensor(7.3992),
#   'Ubiquitin-activating enzyme-like',
#   tensor(0.0063),
#   tensor(0.0004),
#   tensor(4.0204),
#   'Resolvase-like, N-terminal catalytic domain superfamily',
#   tensor(0.0116),
#   tensor(0.0004),
#   tensor(4.9046),
#   'Lumazine/riboflavin synthase superfamily',
#   tensor(0.0094),
#   tensor(0.0004),
#   tensor(4.6119),
#   'Sugar-phosphate isomerase, RpiB/LacA/LacB superfamily',
#   tensor(0.0110),
#   tensor(0.0004),
#   tensor(4.8319),
#   'Porphobilinogen deaminase, C-terminal domain superfamily',
#   tensor(0.0061),
#   tensor(0.0004),
#   tensor(3.9709),
#   'Malic enzyme, N-terminal domain superfamily',
#   tensor(0.0039),
#   tensor(0.0004),
#   tensor(3.3214)],
#  ('8', 2677): [],
#  ('8', 2775): [],
#  ('8', 2486): [],
#  ('8', 3384): ['DnaJ domain, conserved site',
#   tensor(0.0679),
#   tensor(0.0053),
#   tensor(3.6742),
#   'Large ribosomal subunit protein bL34, conserved site',
#   tensor(0.0851),
#   tensor(0.0053),
#   tensor(4.0022),
#   'Large ribosomal subunit protein bL20, conserved site',
#   tensor(0.0531),
#   tensor(0.0054),
#   tensor(3.3024),
#   'Heat shock protein DnaJ, cysteine-rich domain',
#   tensor(0.0785),
#   tensor(0.0053),
#   tensor(3.8825),
#   'DnaJ domain',
#   tensor(0.0540),
#   tensor(0.0053),
#   tensor(3.3457),
#   'Chaperone DnaJ, C-terminal',
#   tensor(0.0744),
#   tensor(0.0053),
#   tensor(3.8044),
#   'Zinc finger C2H2-type',
#   tensor(0.0597),
#   tensor(0.0053),
#   tensor(3.4923),
#   'UDP-3-O-[3-hydroxymyristoyl] glucosamine N-acyltransferase, non-repeat region',
#   tensor(0.0630),
#   tensor(0.0054),
#   tensor(3.5399),
#   'Protamine P1',
#   tensor(0.1301),
#   tensor(0.0054),
#   tensor(4.5999),
#   'Large ribosomal subunit protein bL34',
#   tensor(0.0851),
#   tensor(0.0053),
#   tensor(4.0022),
#   'Large ribosomal subunit protein bL20',
#   tensor(0.0531),
#   tensor(0.0054),
#   tensor(3.3024),
#   'ATP synthase, F0 complex, subunit b, bacterial',
#   tensor(0.0618),
#   tensor(0.0054),
#   tensor(3.5102),
#   'UDP-3-O-[3-hydroxymyristoyl] glucosamine N-acyltransferase LpxD',
#   tensor(0.0630),
#   tensor(0.0054),
#   tensor(3.5399),
#   'Chaperone DnaJ',
#   tensor(0.0785),
#   tensor(0.0053),
#   tensor(3.8825),
#   'HSP40/DnaJ peptide-binding',
#   tensor(0.0744),
#   tensor(0.0053),
#   tensor(3.8044),
#   'F-type ATP synthase subunit B-like, membrane domain superfamily',
#   tensor(0.0543),
#   tensor(0.0054),
#   tensor(3.3249),
#   'Ribosomal protein bL20, C-terminal',
#   tensor(0.0531),
#   tensor(0.0054),
#   tensor(3.3024),
#   'Zinc finger C2H2 superfamily',
#   tensor(0.0632),
#   tensor(0.0053),
#   tensor(3.5742),
#   'Heat shock protein DnaJ, cysteine-rich domain superfamily',
#   tensor(0.0785),
#   tensor(0.0053),
#   tensor(3.8825),
#   'Chaperone J-domain superfamily',
#   tensor(0.0516),
#   tensor(0.0053),
#   tensor(3.2829),
#   'Collagen triple helix repeat',
#   tensor(0.1583),
#   tensor(0.0054),
#   tensor(4.8836)],
#  ('8', 431): [],
#  ('8', 1575): [],
#  ('8', 2166): ['Large ribosomal subunit protein uL3, conserved site',
#   tensor(0.0890),
#   tensor(0.0086),
#   tensor(3.3739),
#   'Small ribosomal subunit protein uS17, conserved site',
#   tensor(0.1078),
#   tensor(0.0085),
#   tensor(3.6605),
#   'RNA-binding domain, S1, IF1 type',
#   tensor(0.1423),
#   tensor(0.0085),
#   tensor(4.0722),
#   'Small ribosomal subunit protein uS17',
#   tensor(0.1001),
#   tensor(0.0085),
#   tensor(3.5586),
#   'Large ribosomal subunit protein uL3',
#   tensor(0.0861),
#   tensor(0.0086),
#   tensor(3.3275),
#   'Translation initiation factor IF-1',
#   tensor(0.1463),
#   tensor(0.0085),
#   tensor(4.1059),
#   'Large ribosomal subunit protein uL3, bacterial/organelle-type',
#   tensor(0.0909),
#   tensor(0.0086),
#   tensor(3.4058),
#   'Small ribosomal subunit protein uS17, bacteria/chloroplast',
#   tensor(0.1049),
#   tensor(0.0085),
#   tensor(3.6258)],
#  ('8', 3921): ['Zinc finger C2H2-type',
#   tensor(0.4861),
#   tensor(0.0304),
#   tensor(4.0012),
#   'Zinc finger C2H2 superfamily',
#   tensor(0.4966),
#   tensor(0.0304),
#   tensor(4.0291)],
#  ('8', 3319): ['Homeobox, conserved site',
#   tensor(0.1724),
#   tensor(0.0185),
#   tensor(3.2204),
#   'Homeodomain',
#   tensor(0.1690),
#   tensor(0.0184),
#   tensor(3.2016)],
#  ('12', 2112): ['Phosphoglycerate/bisphosphoglycerate mutase, active site',
#   tensor(0.0936),
#   tensor(0.0086),
#   tensor(3.4396),
#   'Serine carboxypeptidase, serine active site',
#   tensor(0.4119),
#   tensor(0.0084),
#   tensor(5.6165),
#   'Translation elongation factor Ts, conserved site',
#   tensor(0.2486),
#   tensor(0.0084),
#   tensor(4.8904),
#   'Small ribosomal subunit protein bS18, conserved site',
#   tensor(0.1239),
#   tensor(0.0086),
#   tensor(3.8499),
#   'Amidase, conserved site',
#   tensor(0.1738),
#   tensor(0.0085),
#   tensor(4.3617),
#   'Short-chain dehydrogenase/reductase, conserved site',
#   tensor(0.1276),
#   tensor(0.0085),
#   tensor(3.9058),
#   'UDP-glycosyltransferase family, conserved site',
#   tensor(0.0978),
#   tensor(0.0086),
#   tensor(3.5055),
#   'Alpha/beta hydrolase fold-1',
#   tensor(0.6045),
#   tensor(0.0078),
#   tensor(6.2829),
#   'Phosphoribosyltransferase domain',
#   tensor(0.1116),
#   tensor(0.0082),
#   tensor(3.7723),
#   'Survival protein SurE-like phosphatase/nucleotidase',
#   tensor(0.1045),
#   tensor(0.0086),
#   tensor(3.6028),
#   'Glycosyltransferase family 28, N-terminal domain',
#   tensor(0.0829),
#   tensor(0.0086),
#   tensor(3.2619),
#   'Glycosyl transferase, family 28, C-terminal',
#   tensor(0.0778),
#   tensor(0.0086),
#   tensor(3.1710),
#   'Acetyl-coenzyme A carboxyltransferase, C-terminal',
#   tensor(0.0774),
#   tensor(0.0086),
#   tensor(3.1636),
#   'Translation elongation factor EFTs/EF1B, dimerisation',
#   tensor(0.2341),
#   tensor(0.0084),
#   tensor(4.8039),
#   'Amidase signature domain',
#   tensor(0.1746),
#   tensor(0.0084),
#   tensor(4.3715),
#   'Amidase',
#   tensor(0.1746),
#   tensor(0.0084),
#   tensor(4.3715),
#   'Acetyl-CoA carboxylase, alpha subunit',
#   tensor(0.0774),
#   tensor(0.0086),
#   tensor(3.1636),
#   'Peptidase S10, serine carboxypeptidase',
#   tensor(0.4207),
#   tensor(0.0083),
#   tensor(5.6625),
#   'Small ribosomal subunit protein bS18',
#   tensor(0.1214),
#   tensor(0.0086),
#   tensor(3.8239),
#   'Translation elongation factor EFTs/EF1B',
#   tensor(0.2341),
#   tensor(0.0084),
#   tensor(4.8039),
#   'UDP-glucuronosyl/UDP-glucosyltransferase',
#   tensor(0.0972),
#   tensor(0.0086),
#   tensor(3.4996),
#   'Short-chain dehydrogenase/reductase SDR',
#   tensor(0.1289),
#   tensor(0.0084),
#   tensor(3.9386),
#   'Glutamyl-tRNA(Gln) amidotransferase A subunit',
#   tensor(0.1750),
#   tensor(0.0085),
#   tensor(4.3718),
#   'Adenine phosphoribosyl transferase',
#   tensor(0.1691),
#   tensor(0.0085),
#   tensor(4.3096),
#   'Uracil phosphoribosyl transferase',
#   tensor(0.0805),
#   tensor(0.0086),
#   tensor(3.2227),
#   'Phosphoglycerate mutase 1',
#   tensor(0.0916),
#   tensor(0.0086),
#   tensor(3.4077),
#   'N-acetylglucosaminyltransferase, MurG',
#   tensor(0.0829),
#   tensor(0.0086),
#   tensor(3.2619),
#   'Histidine phosphatase superfamily, clade-1',
#   tensor(0.0927),
#   tensor(0.0086),
#   tensor(3.4281),
#   'Ferredoxin--NADP reductase, type 2',
#   tensor(0.0768),
#   tensor(0.0087),
#   tensor(3.1482),
#   'Survival protein SurE',
#   tensor(0.1045),
#   tensor(0.0086),
#   tensor(3.6028),
#   'Uracil phosphoribosyltransferase, bacterial-type',
#   tensor(0.0805),
#   tensor(0.0086),
#   tensor(3.2227),
#   'Uracil phosphoribosyltransferase/Adenine phosphoribosyltransferase',
#   tensor(0.1214),
#   tensor(0.0084),
#   tensor(3.8484),
#   'Ferredoxin--NADP reductase type 2',
#   tensor(0.0726),
#   tensor(0.0087),
#   tensor(3.0678),
#   'UBA-like superfamily',
#   tensor(0.1756),
#   tensor(0.0084),
#   tensor(4.3882),
#   'Histidine phosphatase superfamily',
#   tensor(0.0835),
#   tensor(0.0086),
#   tensor(3.2775),
#   'ClpP/crotonase-like domain superfamily',
#   tensor(0.0774),
#   tensor(0.0084),
#   tensor(3.1948),
#   'Phosphoribosyltransferase-like',
#   tensor(0.1116),
#   tensor(0.0082),
#   tensor(3.7723),
#   'Alpha/Beta hydrolase fold',
#   tensor(0.5598),
#   tensor(0.0052),
#   tensor(6.7434),
#   'Elongation factor Ts, dimerisation domain superfamily',
#   tensor(0.2341),
#   tensor(0.0084),
#   tensor(4.8039),
#   'SurE-like phosphatase/nucleotidase superfamily',
#   tensor(0.0965),
#   tensor(0.0086),
#   tensor(3.4872),
#   'Small ribosomal subunit protein bS18 superfamily',
#   tensor(0.1214),
#   tensor(0.0086),
#   tensor(3.8239),
#   'Amidase signature (AS) superfamily',
#   tensor(0.1746),
#   tensor(0.0084),
#   tensor(4.3715)],
#  ('12', 3751): [],
#  ('12', 3536): ['DNA mismatch repair protein MutS, C-terminal',
#   tensor(0.2246),
#   tensor(0.0224),
#   tensor(3.3260),
#   'DNA mismatch repair protein MutS-like, N-terminal',
#   tensor(0.2273),
#   tensor(0.0225),
#   tensor(3.3357),
#   'DNA mismatch repair protein MutS, core',
#   tensor(0.2246),
#   tensor(0.0224),
#   tensor(3.3260),
#   'DNA mismatch repair protein MutS, connector domain',
#   tensor(0.2300),
#   tensor(0.0225),
#   tensor(3.3540),
#   'DNA mismatch repair protein MutS, clamp',
#   tensor(0.2300),
#   tensor(0.0225),
#   tensor(3.3540),
#   'DNA mismatch repair protein MutS',
#   tensor(0.2273),
#   tensor(0.0225),
#   tensor(3.3357),
#   'DNA mismatch repair protein MutS/MSH',
#   tensor(0.2309),
#   tensor(0.0225),
#   tensor(3.3596),
#   'DNA mismatch repair MutS',
#   tensor(0.2246),
#   tensor(0.0224),
#   tensor(3.3260),
#   'DNA mismatch repair protein MutS, N-terminal',
#   tensor(0.2273),
#   tensor(0.0225),
#   tensor(3.3357),
#   'DNA mismatch repair protein MutS, core domain superfamily',
#   tensor(0.2246),
#   tensor(0.0224),
#   tensor(3.3260),
#   'MutS, connector domain superfamily',
#   tensor(0.2336),
#   tensor(0.0225),
#   tensor(3.3783)],
#  ('12', 1256): ['EF-Hand 1, calcium-binding site',
#   tensor(0.5439),
#   tensor(0.0468),
#   tensor(3.5399),
#   'Phosphoribosyltransferase domain',
#   tensor(0.3951),
#   tensor(0.0460),
#   tensor(3.1022),
#   'EF-hand domain',
#   tensor(0.5556),
#   tensor(0.0465),
#   tensor(3.5779),
#   'OBG-type guanine nucleotide-binding (G) domain',
#   tensor(0.6348),
#   tensor(0.0470),
#   tensor(3.7545),
#   'Small GTPase',
#   tensor(0.3918),
#   tensor(0.0473),
#   tensor(3.0501),
#   'Uracil phosphoribosyl transferase',
#   tensor(0.4899),
#   tensor(0.0472),
#   tensor(3.3745),
#   'Uracil phosphoribosyltransferase, bacterial-type',
#   tensor(0.4899),
#   tensor(0.0472),
#   tensor(3.3745),
#   'Uracil phosphoribosyltransferase/Adenine phosphoribosyltransferase',
#   tensor(0.4784),
#   tensor(0.0467),
#   tensor(3.3557),
#   'EF-hand domain pair',
#   tensor(0.5414),
#   tensor(0.0465),
#   tensor(3.5423),
#   'Phosphoribosyltransferase-like',
#   tensor(0.3951),
#   tensor(0.0460),
#   tensor(3.1022)],
#  ('12', 2797): ["Orotidine 5'-phosphate decarboxylase, active site",
#   tensor(0.0538),
#   tensor(0.0044),
#   tensor(3.6190),
#   'Tryptophan synthase, alpha chain, active site',
#   tensor(0.0725),
#   tensor(0.0044),
#   tensor(4.0513),
#   'Transaldolase, active site',
#   tensor(0.0368),
#   tensor(0.0044),
#   tensor(3.0626),
#   'Schiff base-forming aldolase, active site',
#   tensor(0.0669),
#   tensor(0.0043),
#   tensor(3.9511),
#   'Triosephosphate isomerase, active site',
#   tensor(0.0504),
#   tensor(0.0044),
#   tensor(3.5296),
#   'Ribulose bisphosphate carboxylase, large chain, active site',
#   tensor(0.0371),
#   tensor(0.0044),
#   tensor(3.0761),
#   'Dihydroorotate dehydrogenase, conserved site',
#   tensor(0.0599),
#   tensor(0.0044),
#   tensor(3.7779),
#   'Indole-3-glycerol phosphate synthase, conserved site',
#   tensor(0.0759),
#   tensor(0.0044),
#   tensor(4.1201),
#   'Phosphoglycerate kinase, conserved site',
#   tensor(0.0359),
#   tensor(0.0044),
#   tensor(3.0252),
#   'Large ribosomal subunit protein uL29, conserved site',
#   tensor(0.0442),
#   tensor(0.0044),
#   tensor(3.3303),
#   'Schiff base-forming aldolase, conserved site',
#   tensor(0.0671),
#   tensor(0.0044),
#   tensor(3.9420),
#   'UDP-glycosyltransferase family, conserved site',
#   tensor(0.0485),
#   tensor(0.0044),
#   tensor(3.4676),
#   'Alpha/beta hydrolase fold-1',
#   tensor(0.0365),
#   tensor(0.0044),
#   tensor(3.0569),
#   'Uroporphyrinogen decarboxylase (URO-D)',
#   tensor(0.0428),
#   tensor(0.0044),
#   tensor(3.2871),
#   'Ribulose bisphosphate carboxylase, large subunit, C-terminal',
#   tensor(0.0360),
#   tensor(0.0044),
#   tensor(3.0345),
#   "Orotidine 5'-phosphate decarboxylase domain",
#   tensor(0.0529),
#   tensor(0.0044),
#   tensor(3.5966),
#   'tRNA-guanine(15) transglycosylase-like',
#   tensor(0.0381),
#   tensor(0.0044),
#   tensor(3.1176),
#   'Dihydroorotate dehydrogenase, catalytic',
#   tensor(0.0588),
#   tensor(0.0044),
#   tensor(3.7482),
#   'Biotin and thiamin synthesis-associated domain',
#   tensor(0.0369),
#   tensor(0.0044),
#   tensor(3.0711),
#   'Indole-3-glycerol phosphate synthase domain',
#   tensor(0.0728),
#   tensor(0.0044),
#   tensor(4.0621),
#   'Thiamine phosphate synthase/TenI',
#   tensor(0.0934),
#   tensor(0.0044),
#   tensor(4.4233),
#   'Triosephosphate isomerase',
#   tensor(0.0504),
#   tensor(0.0044),
#   tensor(3.5296),
#   'Peptidase S10, serine carboxypeptidase',
#   tensor(0.0393),
#   tensor(0.0044),
#   tensor(3.1595),
#   'Phosphoglycerate kinase',
#   tensor(0.0358),
#   tensor(0.0044),
#   tensor(3.0251),
#   'Transaldolase/Fructose-6-phosphate aldolase',
#   tensor(0.0368),
#   tensor(0.0044),
#   tensor(3.0626),
#   'Large ribosomal subunit protein uL29',
#   tensor(0.0435),
#   tensor(0.0044),
#   tensor(3.3105),
#   'Tryptophan synthase, alpha chain',
#   tensor(0.0725),
#   tensor(0.0044),
#   tensor(4.0513),
#   'UDP-glucuronosyl/UDP-glucosyltransferase',
#   tensor(0.0475),
#   tensor(0.0044),
#   tensor(3.4415),
#   'DapA-like',
#   tensor(0.0666),
#   tensor(0.0043),
#   tensor(3.9464),
#   'Biotin synthase/Biotin biosynthesis bifunctional protein BioAB',
#   tensor(0.0369),
#   tensor(0.0044),
#   tensor(3.0711),
#   'Histidine biosynthesis, HisF',
#   tensor(0.0929),
#   tensor(0.0043),
#   tensor(4.4288),
#   'tRNA-guanine transglycosylase',
#   tensor(0.0380),
#   tensor(0.0044),
#   tensor(3.1136),
#   '4-hydroxy-tetrahydrodipicolinate synthase, DapA',
#   tensor(0.0669),
#   tensor(0.0043),
#   tensor(3.9511),
#   'Histidine biosynthesis protein',
#   tensor(0.0945),
#   tensor(0.0041),
#   tensor(4.5105),
#   'HisA, bacterial',
#   tensor(0.0948),
#   tensor(0.0043),
#   tensor(4.4529),
#   'Uroporphyrinogen decarboxylase HemE',
#   tensor(0.0428),
#   tensor(0.0044),
#   tensor(3.2871),
#   "Orotidine 5'-phosphate decarboxylase",
#   tensor(0.0538),
#   tensor(0.0044),
#   tensor(3.6190),
#   'Triosephosphate isomerase, bacterial/eukaryotic',
#   tensor(0.0489),
#   tensor(0.0044),
#   tensor(3.4828),
#   'HisA/PriA',
#   tensor(0.0962),
#   tensor(0.0043),
#   tensor(4.4912),
#   'Biotin synthase',
#   tensor(0.0369),
#   tensor(0.0044),
#   tensor(3.0711),
#   'Thiamine phosphate synthase',
#   tensor(0.0934),
#   tensor(0.0044),
#   tensor(4.4233),
#   'Histidine biosynthesis, HisA-like',
#   tensor(0.0958),
#   tensor(0.0043),
#   tensor(4.4873),
#   'Indole-3-glycerol phosphate synthase',
#   tensor(0.0759),
#   tensor(0.0044),
#   tensor(4.1201),
#   'Universal ribosomal protein uL29',
#   tensor(0.0435),
#   tensor(0.0044),
#   tensor(3.3105),
#   'Imidazole glycerol phosphate synthase HisA/HisF',
#   tensor(0.0922),
#   tensor(0.0043),
#   tensor(4.4210),
#   'Dihydroorotate dehydrogenase',
#   tensor(0.0588),
#   tensor(0.0044),
#   tensor(3.7482),
#   'Archaeosine Synthase Type 1/Queuine TRNA-Ribosyltransferase',
#   tensor(0.0380),
#   tensor(0.0044),
#   tensor(3.1136),
#   'Ribulose-phosphate binding barrel',
#   tensor(0.0795),
#   tensor(0.0039),
#   tensor(4.3639),
#   'Aldolase-type TIM barrel',
#   tensor(0.0550),
#   tensor(0.0032),
#   tensor(4.1195),
#   'Phosphoglycerate kinase, N-terminal',
#   tensor(0.0358),
#   tensor(0.0044),
#   tensor(3.0251),
#   'Flavoprotein-like superfamily',
#   tensor(0.0441),
#   tensor(0.0044),
#   tensor(3.3310),
#   'Alpha/Beta hydrolase fold',
#   tensor(0.0382),
#   tensor(0.0042),
#   tensor(3.1758),
#   'Triosephosphate isomerase superfamily',
#   tensor(0.0504),
#   tensor(0.0044),
#   tensor(3.5296),
#   'Phosphoglycerate kinase superfamily',
#   tensor(0.0358),
#   tensor(0.0044),
#   tensor(3.0251),
#   'Large ribosomal subunit protein uL29 superfamily',
#   tensor(0.0435),
#   tensor(0.0044),
#   tensor(3.3105),
#   'Thiamin phosphate synthase superfamily',
#   tensor(0.0934),
#   tensor(0.0044),
#   tensor(4.4233),
#   'Ribulose bisphosphate carboxylase, large subunit, C-terminal domain superfamily',
#   tensor(0.0360),
#   tensor(0.0044),
#   tensor(3.0345),
#   'Queuine tRNA-ribosyltransferase-like',
#   tensor(0.0381),
#   tensor(0.0044),
#   tensor(3.1176),
#   'UROD/MetE-like superfamily',
#   tensor(0.0397),
#   tensor(0.0044),
#   tensor(3.1794),
#   'Pyruvate kinase-like domain superfamily',
#   tensor(0.0399),
#   tensor(0.0044),
#   tensor(3.1909)],
#  ('12', 3239): [],
#  ('12', 3794): ['DNA methylase, N-6 adenine-specific, conserved site',
#   tensor(0.1820),
#   tensor(0.0142),
#   tensor(3.6779),
#   'Ribosomal RNA adenine methylase transferase, conserved site',
#   tensor(0.1168),
#   tensor(0.0143),
#   tensor(3.0310),
#   'Short-chain dehydrogenase/reductase, conserved site',
#   tensor(0.1350),
#   tensor(0.0142),
#   tensor(3.2456),
#   'Lactate/malate dehydrogenase, N-terminal',
#   tensor(0.1199),
#   tensor(0.0142),
#   tensor(3.0736),
#   'Ribosomal RNA adenine methylase transferase, N-terminal',
#   tensor(0.1168),
#   tensor(0.0143),
#   tensor(3.0310),
#   'Lactate/malate dehydrogenase, C-terminal',
#   tensor(0.1199),
#   tensor(0.0142),
#   tensor(3.0736),
#   'L-lactate/malate dehydrogenase',
#   tensor(0.1201),
#   tensor(0.0143),
#   tensor(3.0744),
#   'Ribosomal RNA adenine methyltransferase KsgA/Erm',
#   tensor(0.1168),
#   tensor(0.0143),
#   tensor(3.0310),
#   'Short-chain dehydrogenase/reductase SDR',
#   tensor(0.1324),
#   tensor(0.0141),
#   tensor(3.2282),
#   'Lactate dehydrogenase/glycoside hydrolase, family 4, C-terminal',
#   tensor(0.1171),
#   tensor(0.0142),
#   tensor(3.0390),
#   'rRNA adenine dimethylase-like, C-terminal',
#   tensor(0.1168),
#   tensor(0.0143),
#   tensor(3.0310),
#   'S-adenosyl-L-methionine-dependent methyltransferase superfamily',
#   tensor(0.1160),
#   tensor(0.0126),
#   tensor(3.2046),
#   'Aminoacid dehydrogenase-like, N-terminal domain superfamily',
#   tensor(0.1194),
#   tensor(0.0141),
#   tensor(3.0794)],
#  ('12', 3035): ['WD40 repeat, conserved site',
#   tensor(0.3777),
#   tensor(0.0224),
#   tensor(4.0743),
#   'RNA-binding domain, S1, IF1 type',
#   tensor(0.5107),
#   tensor(0.0225),
#   tensor(4.5044),
#   'Translation initiation factor IF-1',
#   tensor(0.5357),
#   tensor(0.0226),
#   tensor(4.5666),
#   'GroES-like superfamily',
#   tensor(0.2660),
#   tensor(0.0229),
#   tensor(3.5387),
#   'WD40/YVTN repeat-like-containing domain superfamily',
#   tensor(0.2763),
#   tensor(0.0219),
#   tensor(3.6554),
#   'WD40-repeat-containing domain superfamily',
#   tensor(0.3218),
#   tensor(0.0221),
#   tensor(3.8629),
#   'WD40 repeat',
#   tensor(0.3272),
#   tensor(0.0221),
#   tensor(3.8903),
#   'PAC1/LIS1-like, WD-40 repeat',
#   tensor(0.3855),
#   tensor(0.0226),
#   tensor(4.0938)],
#  ('12', 3626): ['Short-chain dehydrogenase/reductase, conserved site',
#   tensor(0.3489),
#   tensor(0.0430),
#   tensor(3.0204),
#   'Large ribosomal subunit protein bL27',
#   tensor(0.5371),
#   tensor(0.0428),
#   tensor(3.6484)],
#  ('12', 3598): [],
#  ('12', 565): ['ClpP, Ser active site',
#   tensor(0.7669),
#   tensor(0.0450),
#   tensor(4.0902),
#   'ClpP, histidine active site',
#   tensor(0.7635),
#   tensor(0.0450),
#   tensor(4.0838),
#   'Short-chain dehydrogenase/reductase, conserved site',
#   tensor(0.6035),
#   tensor(0.0451),
#   tensor(3.7426),
#   'Alpha/beta hydrolase fold-1',
#   tensor(0.3703),
#   tensor(0.0455),
#   tensor(3.0243),
#   'ATP-dependent Clp protease proteolytic subunit',
#   tensor(0.7633),
#   tensor(0.0449),
#   tensor(4.0880),
#   'Short-chain dehydrogenase/reductase SDR',
#   tensor(0.6004),
#   tensor(0.0446),
#   tensor(3.7511),
#   'Clp protease proteolytic subunit /Translocation-enhancing protein TepA',
#   tensor(0.7633),
#   tensor(0.0449),
#   tensor(4.0880),
#   'Alkaline-phosphatase-like, core domain superfamily',
#   tensor(0.7370),
#   tensor(0.0450),
#   tensor(4.0339),
#   'Histidine phosphatase superfamily',
#   tensor(0.6827),
#   tensor(0.0451),
#   tensor(3.9208),
#   'ClpP/crotonase-like domain superfamily',
#   tensor(0.8376),
#   tensor(0.0429),
#   tensor(4.2860),
#   'Alpha/Beta hydrolase fold',
#   tensor(0.4031),
#   tensor(0.0438),
#   tensor(3.2029)],
#  ('12', 904): ['Uracil phosphoribosyl transferase',
#   tensor(0.4797),
#   tensor(0.0543),
#   tensor(3.1434),
#   'Uracil phosphoribosyltransferase, bacterial-type',
#   tensor(0.4797),
#   tensor(0.0543),
#   tensor(3.1434),
#   'Acyl-CoA N-acyltransferase',
#   tensor(0.4375),
#   tensor(0.0539),
#   tensor(3.0201)],
#  ('12', 3960): ['Cytochrome P450, conserved site',
#   tensor(0.4008),
#   tensor(0.0120),
#   tensor(5.0594),
#   'Small ribosomal subunit protein uS9, conserved site',
#   tensor(0.1817),
#   tensor(0.0132),
#   tensor(3.7830),
#   'GPCR, rhodopsin-like, 7TM',
#   tensor(0.3129),
#   tensor(0.0122),
#   tensor(4.6756),
#   'G protein-coupled receptor, rhodopsin-like',
#   tensor(0.3160),
#   tensor(0.0123),
#   tensor(4.6841),
#   'Small ribosomal subunit protein uS9',
#   tensor(0.1817),
#   tensor(0.0132),
#   tensor(3.7830),
#   'Cytochrome P450',
#   tensor(0.4266),
#   tensor(0.0118),
#   tensor(5.1812),
#   'UDP-glucuronosyl/UDP-glucosyltransferase',
#   tensor(0.1521),
#   tensor(0.0132),
#   tensor(3.5240),
#   'Cytochrome P450, E-class, group I',
#   tensor(0.4557),
#   tensor(0.0120),
#   tensor(5.2420),
#   'Cytochrome P450 monooxygenase',
#   tensor(0.3420),
#   tensor(0.0130),
#   tensor(4.7147),
#   'Cytochrome P450 superfamily',
#   tensor(0.4266),
#   tensor(0.0118),
#   tensor(5.1812)],
#  ('12', 899): ['Argininosuccinate synthase, conserved site',
#   tensor(0.3535),
#   tensor(0.0238),
#   tensor(3.8949),
#   'GMP synthase, C-terminal',
#   tensor(0.2525),
#   tensor(0.0239),
#   tensor(3.3992),
#   'GMP synthase, glutamine amidotransferase',
#   tensor(0.2525),
#   tensor(0.0239),
#   tensor(3.3992),
#   'NAD/GMP synthase',
#   tensor(0.2470),
#   tensor(0.0239),
#   tensor(3.3724),
#   'GMP synthetase ATP pyrophosphatase domain',
#   tensor(0.2525),
#   tensor(0.0239),
#   tensor(3.3992),
#   'Arginosuccinate synthase-like, N-terminal domain',
#   tensor(0.3535),
#   tensor(0.0238),
#   tensor(3.8949),
#   'Arginosuccinate synthase C-terminal domain',
#   tensor(0.3535),
#   tensor(0.0238),
#   tensor(3.8949),
#   'Argininosuccinate synthase',
#   tensor(0.3535),
#   tensor(0.0238),
#   tensor(3.8949),
#   'UDP-glucuronosyl/UDP-glucosyltransferase',
#   tensor(0.2515),
#   tensor(0.0239),
#   tensor(3.3933),
#   'Argininosuccinate synthase, type 1 subfamily',
#   tensor(0.3535),
#   tensor(0.0238),
#   tensor(3.8949),
#   'Argininosuccinate synthetase, catalytic/multimerisation domain body',
#   tensor(0.3535),
#   tensor(0.0238),
#   tensor(3.8949)],
#  ('12', 1121): ['Short-chain dehydrogenase/reductase, conserved site',
#   tensor(0.7056),
#   tensor(0.0353),
#   tensor(4.3202),
#   'Phosphopantetheine binding ACP domain',
#   tensor(0.3174),
#   tensor(0.0360),
#   tensor(3.1409),
#   'Short-chain dehydrogenase/reductase SDR',
#   tensor(0.6978),
#   tensor(0.0347),
#   tensor(4.3283),
#   'Acyl carrier protein',
#   tensor(0.3174),
#   tensor(0.0360),
#   tensor(3.1409),
#   'ACP-like superfamily',
#   tensor(0.3174),
#   tensor(0.0360),
#   tensor(3.1409)],
#  ('12', 339): ['Small ribosomal subunit protein uS3, conserved site',
#   tensor(0.2952),
#   tensor(0.0237),
#   tensor(3.6417),
#   'Small ribosomal subunit protein uS3, C-terminal',
#   tensor(0.2952),
#   tensor(0.0237),
#   tensor(3.6417),
#   'Small ribosomal subunit protein uS3, bacterial-type',
#   tensor(0.2952),
#   tensor(0.0237),
#   tensor(3.6417),
#   'Ribosomal protein S3, C-terminal domain superfamily',
#   tensor(0.2952),
#   tensor(0.0237),
#   tensor(3.6417)],
#  ('12', 1818): [],
#  ('12',
#   798): ['ATPase, alpha/beta subunit, nucleotide-binding domain, active site', tensor(0.2829), tensor(0.0186), tensor(3.9258), 'ATPase, F1/V1/A1 complex, alpha/beta subunit, nucleotide-binding domain', tensor(0.2829), tensor(0.0186), tensor(3.9258), 'ATP synthase, alpha subunit, C-terminal', tensor(0.2822), tensor(0.0191), tensor(3.8874), 'ATPase, F1/V1/A1 complex, alpha/beta subunit, N-terminal domain', tensor(0.2795), tensor(0.0187), tensor(3.9051), 'ATP synthase, F1 complex, alpha subunit nucleotide-binding domain', tensor(0.2822), tensor(0.0191), tensor(3.8874), 'ATP synthase A/B type, C-terminal domain', tensor(0.2839), tensor(0.0192), tensor(3.8828), 'ATP synthase, F1 complex, alpha subunit', tensor(0.2822), tensor(0.0191), tensor(3.8874), 'ATP synthase subunit alpha, N-terminal domain-like superfamily', tensor(0.2649), tensor(0.0190), tensor(3.7988), 'ATPase, F1/V1 complex, beta/alpha subunit, C-terminal', tensor(0.2819), tensor(0.0193), tensor(3.8683), 'ATPase, F1/V1/A1 complex, alpha/beta subunit, N-terminal domain superfamily', tensor(0.2784), tensor(0.0187), tensor(3.8954), 'ATP synthase, alpha subunit, C-terminal domain superfamily', tensor(0.2822), tensor(0.0191), tensor(3.8874)],
#  ('12', 803): [],
#  ('12', 2512): [],
#  ('12', 2477): ['WD40 repeat, conserved site',
#   tensor(0.2278),
#   tensor(0.0073),
#   tensor(4.9678),
#   'Small GTPase',
#   tensor(0.0647),
#   tensor(0.0078),
#   tensor(3.0539),
#   'Molybdate/tungstate binding, C-terminal',
#   tensor(0.0715),
#   tensor(0.0078),
#   tensor(3.2020),
#   'WD40/YVTN repeat-like-containing domain superfamily',
#   tensor(0.2078),
#   tensor(0.0067),
#   tensor(4.9482),
#   'WD40-repeat-containing domain superfamily',
#   tensor(0.2123),
#   tensor(0.0070),
#   tensor(4.9196),
#   'WD40 repeat',
#   tensor(0.2116),
#   tensor(0.0070),
#   tensor(4.9187),
#   'PAC1/LIS1-like, WD-40 repeat',
#   tensor(0.2295),
#   tensor(0.0074),
#   tensor(4.9575)],
#  ('12', 2628): [],
#  ('12', 1518): [],
#  ('12', 2302): ['AMP-binding, conserved site',
#   tensor(0.0569),
#   tensor(0.0034),
#   tensor(4.0631),
#   'AMP-dependent synthetase/ligase domain',
#   tensor(0.0560),
#   tensor(0.0034),
#   tensor(4.0436),
#   'Enolpyruvate transferase domain',
#   tensor(0.1813),
#   tensor(0.0032),
#   tensor(5.8264),
#   'Oxoglutarate/iron-dependent dioxygenase domain',
#   tensor(0.0463),
#   tensor(0.0034),
#   tensor(3.7669),
#   'AMP-binding enzyme, C-terminal domain',
#   tensor(0.0585),
#   tensor(0.0034),
#   tensor(4.1030),
#   'UDP-N-acetylglucosamine 1-carboxyvinyltransferase',
#   tensor(0.2038),
#   tensor(0.0033),
#   tensor(5.9564),
#   'Beta-hydroxyacyl-(acyl-carrier-protein) dehydratase FabZ',
#   tensor(0.5495),
#   tensor(0.0029),
#   tensor(7.5581),
#   'Beta-hydroxydecanoyl thiol ester dehydrase, FabA/FabZ',
#   tensor(0.5653),
#   tensor(0.0027),
#   tensor(7.6934),
#   'UDP-N-acetylglucosamine 1-carboxyvinyltransferase MurA subfamily',
#   tensor(0.2038),
#   tensor(0.0033),
#   tensor(5.9564),
#   "RNA 3'-terminal phosphate cyclase/enolpyruvate transferase, alpha/beta",
#   tensor(0.1700),
#   tensor(0.0032),
#   tensor(5.7331),
#   'HotDog domain superfamily',
#   tensor(0.4657),
#   tensor(0.0026),
#   tensor(7.4686),
#   'Enolpyruvate transferase domain superfamily',
#   tensor(0.1813),
#   tensor(0.0032),
#   tensor(5.8264),
#   'ANL, N-terminal domain',
#   tensor(0.0560),
#   tensor(0.0034),
#   tensor(4.0420),
#   'AMP-binding enzyme, C-terminal domain superfamily',
#   tensor(0.0560),
#   tensor(0.0034),
#   tensor(4.0436)],
#  ('12', 1377): ['Argininosuccinate synthase, conserved site',
#   tensor(0.6243),
#   tensor(0.0734),
#   tensor(3.0879),
#   'Short-chain dehydrogenase/reductase, conserved site',
#   tensor(0.6617),
#   tensor(0.0733),
#   tensor(3.1751),
#   'Lactate/malate dehydrogenase, N-terminal',
#   tensor(0.5949),
#   tensor(0.0733),
#   tensor(3.0204),
#   'Lactate/malate dehydrogenase, C-terminal',
#   tensor(0.5949),
#   tensor(0.0733),
#   tensor(3.0204),
#   'FAD/NAD(P)-binding domain',
#   tensor(1.1319),
#   tensor(0.0727),
#   tensor(3.9613),
#   'Arginosuccinate synthase-like, N-terminal domain',
#   tensor(0.6243),
#   tensor(0.0734),
#   tensor(3.0879),
#   'Arginosuccinate synthase C-terminal domain',
#   tensor(0.6243),
#   tensor(0.0734),
#   tensor(3.0879),
#   'Argininosuccinate synthase',
#   tensor(0.6243),
#   tensor(0.0734),
#   tensor(3.0879),
#   'L-lactate/malate dehydrogenase',
#   tensor(0.6212),
#   tensor(0.0733),
#   tensor(3.0828),
#   'Short-chain dehydrogenase/reductase SDR',
#   tensor(0.6411),
#   tensor(0.0728),
#   tensor(3.1390),
#   'Argininosuccinate synthase, type 1 subfamily',
#   tensor(0.6243),
#   tensor(0.0734),
#   tensor(3.0879),
#   'Lactate dehydrogenase/glycoside hydrolase, family 4, C-terminal',
#   tensor(0.5896),
#   tensor(0.0733),
#   tensor(3.0083),
#   'Argininosuccinate synthetase, catalytic/multimerisation domain body',
#   tensor(0.6243),
#   tensor(0.0734),
#   tensor(3.0879),
#   'FAD/NAD(P)-binding domain superfamily',
#   tensor(0.6443),
#   tensor(0.0699),
#   tensor(3.2035)],
#  ('12', 667): [],
#  ('12', 3498): [],
#  ('12', 4044): ['ClpP, Ser active site',
#   tensor(0.0150),
#   tensor(0.0013),
#   tensor(3.5718),
#   'ClpP, histidine active site',
#   tensor(0.0149),
#   tensor(0.0013),
#   tensor(3.5636),
#   'ATP-dependent RNA helicase DEAD-box, conserved site',
#   tensor(0.0101),
#   tensor(0.0013),
#   tensor(3.0187),
#   'Aminoacyl-tRNA synthetase, class I, conserved site',
#   tensor(0.0172),
#   tensor(0.0012),
#   tensor(3.8969),
#   'Metallo-beta-lactamase',
#   tensor(0.0108),
#   tensor(0.0012),
#   tensor(3.1161),
#   'Aminoacyl-tRNA synthetase, class Ia',
#   tensor(0.0332),
#   tensor(0.0012),
#   tensor(4.7894),
#   'Methionyl-tRNA synthetase, beta subunit, C-terminal',
#   tensor(0.0234),
#   tensor(0.0013),
#   tensor(4.2232),
#   'NADH:ubiquinone oxidoreductase-like, 20kDa subunit',
#   tensor(0.0104),
#   tensor(0.0013),
#   tensor(3.0368),
#   'Zinc finger, FPG/IleRS-type',
#   tensor(0.0312),
#   tensor(0.0012),
#   tensor(4.6678),
#   'Acetyl-coenzyme A carboxyltransferase, N-terminal',
#   tensor(0.0271),
#   tensor(0.0013),
#   tensor(4.4249),
#   'Acetyl-coenzyme A carboxyltransferase, C-terminal',
#   tensor(0.0330),
#   tensor(0.0012),
#   tensor(4.7276),
#   'Methionyl/Valyl/Leucyl/Isoleucyl-tRNA synthetase, anticodon-binding',
#   tensor(0.0307),
#   tensor(0.0012),
#   tensor(4.6767),
#   'RNA helicase, DEAD-box type, Q motif',
#   tensor(0.0101),
#   tensor(0.0013),
#   tensor(3.0185),
#   'Cysteinyl-tRNA synthetase, class Ia, DALR',
#   tensor(0.0252),
#   tensor(0.0012),
#   tensor(4.3327),
#   'Methionyl/Leucyl tRNA synthetase',
#   tensor(0.0192),
#   tensor(0.0012),
#   tensor(3.9568),
#   'Glutamyl/glutaminyl-tRNA synthetase, class Ib, catalytic domain',
#   tensor(0.0154),
#   tensor(0.0013),
#   tensor(3.6150),
#   'EngB-type guanine nucleotide-binding (G) domain',
#   tensor(0.0266),
#   tensor(0.0012),
#   tensor(4.4128),
#   'Hydroxyacylglutathione hydrolase, C-terminal domain',
#   tensor(0.0154),
#   tensor(0.0013),
#   tensor(3.6053),
#   'tRNA synthetases class I, catalytic domain',
#   tensor(0.0248),
#   tensor(0.0012),
#   tensor(4.3239),
#   'Isoleucyl tRNA synthetase type 1, anticodon-binding domain',
#   tensor(0.0477),
#   tensor(0.0012),
#   tensor(5.2847),
#   'Glutamyl-tRNA synthetase',
#   tensor(0.0164),
#   tensor(0.0013),
#   tensor(3.6947),
#   'Methioninyl-tRNA synthetase core domain',
#   tensor(0.0266),
#   tensor(0.0012),
#   tensor(4.4183),
#   'Hydroxyacylglutathione hydrolase, MBL domain',
#   tensor(0.0154),
#   tensor(0.0013),
#   tensor(3.6053),
#   'Methionyl-tRNA synthetase, anticodon-binding domain',
#   tensor(0.0271),
#   tensor(0.0012),
#   tensor(4.4446),
#   'Aminoacyl-tRNA synthetase, class I, anticodon-binding',
#   tensor(0.0164),
#   tensor(0.0013),
#   tensor(3.6947),
#   'Cysteinyl-tRNA ligase, anticodon binding domain',
#   tensor(0.0233),
#   tensor(0.0013),
#   tensor(4.2088),
#   'Acetyl-CoA carboxylase carboxyl transferase, beta subunit',
#   tensor(0.0271),
#   tensor(0.0013),
#   tensor(4.4249),
#   'Glutamyl/glutaminyl-tRNA synthetase',
#   tensor(0.0154),
#   tensor(0.0013),
#   tensor(3.6150),
#   'Acetyl-CoA carboxylase, alpha subunit',
#   tensor(0.0330),
#   tensor(0.0012),
#   tensor(4.7276),
#   'Small GTPase',
#   tensor(0.0109),
#   tensor(0.0013),
#   tensor(3.1086),
#   'ATP-dependent Clp protease proteolytic subunit',
#   tensor(0.0145),
#   tensor(0.0013),
#   tensor(3.5238),
#   'Mitochondrial carrier protein',
#   tensor(0.0125),
#   tensor(0.0013),
#   tensor(3.2995),
#   'Isoleucine-tRNA ligase',
#   tensor(0.0477),
#   tensor(0.0012),
#   tensor(5.2847),
#   "Tetraacyldisaccharide 4'-kinase",
#   tensor(0.0232),
#   tensor(0.0013),
#   tensor(4.2001),
#   'S-ribosylhomocysteinase (LuxS)',
#   tensor(0.0118),
#   tensor(0.0013),
#   tensor(3.2097),
#   'Glutamate-tRNA ligase, bacterial/mitochondrial',
#   tensor(0.0164),
#   tensor(0.0013),
#   tensor(3.6947),
#   'NADH-ubiquinone oxidoreductase, 20 Kd subunit',
#   tensor(0.0108),
#   tensor(0.0013),
#   tensor(3.0871),
#   'Ribonuclease Z/BN',
#   tensor(0.0116),
#   tensor(0.0013),
#   tensor(3.1836),
#   'Methionyl-tRNA synthetase',
#   tensor(0.0266),
#   tensor(0.0012),
#   tensor(4.4183),
#   'Cysteine-tRNA ligase',
#   tensor(0.0256),
#   tensor(0.0012),
#   tensor(4.3596),
#   'Hydroxyacylglutathione hydrolase',
#   tensor(0.0154),
#   tensor(0.0013),
#   tensor(3.6053),
#   'GTP-binding protein, ribosome biogenesis, YsxC',
#   tensor(0.0266),
#   tensor(0.0012),
#   tensor(4.4128),
#   'Methionine-tRNA ligase, type 1',
#   tensor(0.0290),
#   tensor(0.0012),
#   tensor(4.5382),
#   'Clp protease proteolytic subunit /Translocation-enhancing protein TepA',
#   tensor(0.0145),
#   tensor(0.0013),
#   tensor(3.5238),
#   'Isoleucine-tRNA ligase, type 1',
#   tensor(0.0477),
#   tensor(0.0012),
#   tensor(5.2847),
#   'Cysteinyl-tRNA synthetase/mycothiol ligase',
#   tensor(0.0251),
#   tensor(0.0012),
#   tensor(4.3402),
#   'Glutamyl-Q tRNA(Asp) synthetase/Glutamate--tRNA ligase',
#   tensor(0.0170),
#   tensor(0.0013),
#   tensor(3.7587),
#   'DEAD box RNA helicase',
#   tensor(0.0124),
#   tensor(0.0013),
#   tensor(3.2881),
#   'Isoleucine--tRNA ligase',
#   tensor(0.0477),
#   tensor(0.0012),
#   tensor(5.2847),
#   'Glyoxalase II family hydroxyacylglutathione hydrolases',
#   tensor(0.0163),
#   tensor(0.0013),
#   tensor(3.6894),
#   'Aminoacyl-tRNA synthetase, class I, anticodon-binding superfamily',
#   tensor(0.0160),
#   tensor(0.0013),
#   tensor(3.6620),
#   'Valyl/Leucyl/Isoleucyl-tRNA synthetase, editing domain',
#   tensor(0.0311),
#   tensor(0.0012),
#   tensor(4.6946),
#   'Aminoacyl-tRNA synthetase, class Ia, anticodon-binding',
#   tensor(0.0231),
#   tensor(0.0011),
#   tensor(4.3537),
#   'Metalloenzyme, LuxS/M16 peptidase-like',
#   tensor(0.0104),
#   tensor(0.0013),
#   tensor(3.0397),
#   'Rossmann-like alpha/beta/alpha sandwich fold',
#   tensor(0.0087),
#   tensor(0.0011),
#   tensor(3.0155),
#   'Aminoacyl-tRNA synthetase, class I, anticodon-binding domain, subdomain 2',
#   tensor(0.0160),
#   tensor(0.0013),
#   tensor(3.6620),
#   'Mitochondrial carrier protein domain superfamily',
#   tensor(0.0111),
#   tensor(0.0013),
#   tensor(3.1276),
#   'Methionyl-tRNA synthetase, Zn-domain',
#   tensor(0.0290),
#   tensor(0.0012),
#   tensor(4.5382),
#   'ClpP/crotonase-like domain superfamily',
#   tensor(0.0203),
#   tensor(0.0012),
#   tensor(4.0750),
#   'Ribonuclease Z/Hydroxyacylglutathione hydrolase-like',
#   tensor(0.0107),
#   tensor(0.0012),
#   tensor(3.0988),
#   'S-ribosylhomocysteinase (LuxS) superfamily',
#   tensor(0.0118),
#   tensor(0.0013),
#   tensor(3.2097),
#   'Mitochondrial carrier protein, transmembrane region',
#   tensor(0.0111),
#   tensor(0.0013),
#   tensor(3.1276)],
#  ('12', 669): ['Lactate/malate dehydrogenase, N-terminal',
#   tensor(0.6757),
#   tensor(0.0740),
#   tensor(3.1915),
#   'Lactate/malate dehydrogenase, C-terminal',
#   tensor(0.6757),
#   tensor(0.0740),
#   tensor(3.1915),
#   'L-lactate/malate dehydrogenase',
#   tensor(0.6861),
#   tensor(0.0740),
#   tensor(3.2125),
#   '6-phosphogluconate dehydrogenase-like, C-terminal domain superfamily',
#   tensor(0.6598),
#   tensor(0.0732),
#   tensor(3.1714),
#   '6-phosphogluconate dehydrogenase, domain 2',
#   tensor(0.6404),
#   tensor(0.0742),
#   tensor(3.1094),
#   'Lactate dehydrogenase/glycoside hydrolase, family 4, C-terminal',
#   tensor(0.6780),
#   tensor(0.0739),
#   tensor(3.1975)],
#  ('12', 3543): ['ABC transporter-like, conserved site',
#   tensor(0.0534),
#   tensor(0.0059),
#   tensor(3.1694),
#   'ABC transporter-like, ATP-binding domain',
#   tensor(0.0541),
#   tensor(0.0059),
#   tensor(3.1909),
#   'Acyl-CoA N-acyltransferase',
#   tensor(0.0809),
#   tensor(0.0061),
#   tensor(3.7404)],
#  ('12', 4019): ['Aspartate/glutamate/uridylate kinase',
#   tensor(1.0724),
#   tensor(0.0502),
#   tensor(4.4155),
#   'Exoribonuclease, phosphorolytic domain 1',
#   tensor(0.6229),
#   tensor(0.0523),
#   tensor(3.5730),
#   'Exoribonuclease, phosphorolytic domain 2',
#   tensor(0.6257),
#   tensor(0.0525),
#   tensor(3.5749),
#   'Polyribonucleotide nucleotidyltransferase, RNA-binding domain',
#   tensor(0.6382),
#   tensor(0.0529),
#   tensor(3.5914),
#   'Glutamate/acetylglutamate kinase',
#   tensor(0.9992),
#   tensor(0.0523),
#   tensor(4.2555),
#   'Large ribosomal subunit protein uL10',
#   tensor(0.4675),
#   tensor(0.0532),
#   tensor(3.1352),
#   'Polyribonucleotide nucleotidyltransferase',
#   tensor(0.6382),
#   tensor(0.0529),
#   tensor(3.5914),
#   'PNPase/RNase PH domain superfamily',
#   tensor(0.6229),
#   tensor(0.0523),
#   tensor(3.5730),
#   'Exoribonuclease, PH domain 2 superfamily',
#   tensor(0.6229),
#   tensor(0.0523),
#   tensor(3.5730),
#   'Acetylglutamate kinase-like superfamily',
#   tensor(1.0724),
#   tensor(0.0502),
#   tensor(4.4155),
#   'Large ribosomal subunit protein uL10-like domain superfamily',
#   tensor(0.4675),
#   tensor(0.0532),
#   tensor(3.1352)],
#  ('12', 3808): ['Aminoacyl-tRNA synthetase, class Ia',
#   tensor(0.0286),
#   tensor(0.0025),
#   tensor(3.5028),
#   'Zinc finger, FPG/IleRS-type',
#   tensor(0.0317),
#   tensor(0.0025),
#   tensor(3.6447),
#   'Methionyl/Valyl/Leucyl/Isoleucyl-tRNA synthetase, anticodon-binding',
#   tensor(0.0261),
#   tensor(0.0025),
#   tensor(3.3695),
#   'Isoleucyl tRNA synthetase type 1, anticodon-binding domain',
#   tensor(0.0449),
#   tensor(0.0025),
#   tensor(4.1452),
#   'Isoleucine-tRNA ligase',
#   tensor(0.0449),
#   tensor(0.0025),
#   tensor(4.1452),
#   'Fluoride-specific ion channel FluC',
#   tensor(0.0207),
#   tensor(0.0026),
#   tensor(3.0134),
#   'Isoleucine-tRNA ligase, type 1',
#   tensor(0.0449),
#   tensor(0.0025),
#   tensor(4.1452),
#   'Isoleucine--tRNA ligase',
#   tensor(0.0449),
#   tensor(0.0025),
#   tensor(4.1452),
#   'Valyl/Leucyl/Isoleucyl-tRNA synthetase, editing domain',
#   tensor(0.0269),
#   tensor(0.0025),
#   tensor(3.4168),
#   'Nucleotide-diphospho-sugar transferases',
#   tensor(0.0228),
#   tensor(0.0025),
#   tensor(3.1956)],
#  ('16', 1880): ['Alpha/beta hydrolase fold-1',
#   tensor(1.1776),
#   tensor(0.0636),
#   tensor(4.2116),
#   'Phosphoribosyltransferase domain',
#   tensor(0.7095),
#   tensor(0.0619),
#   tensor(3.5184),
#   'Uracil phosphoribosyl transferase',
#   tensor(0.6770),
#   tensor(0.0645),
#   tensor(3.3921),
#   'Uracil phosphoribosyltransferase, bacterial-type',
#   tensor(0.6770),
#   tensor(0.0645),
#   tensor(3.3921),
# ...
#   tensor(0.1897),
#   tensor(0.0210),
#   tensor(3.1771),
#   'Ankyrin repeat',
#   tensor(0.4019),
#   tensor(0.0204),
#   tensor(4.2982)],
#  ('24', 3264): [],
#  ('24', 3996): [],
#  ('24', 1155): [],
#  ('24',
#   1097): ['Serine hydroxymethyltransferase, pyridoxal phosphate binding site', tensor(0.2223), tensor(0.0237), tensor(3.2320), 'Polyribonucleotide nucleotidyltransferase, RNA-binding domain', tensor(0.2051), tensor(0.0237), tensor(3.1127), 'GPCR, rhodopsin-like, 7TM', tensor(0.2225), tensor(0.0232), tensor(3.2615), 'Major facilitator superfamily domain', tensor(0.4553), tensor(0.0225), tensor(4.3411), 'Serine hydroxymethyltransferase-like domain', tensor(0.2223), tensor(0.0237), tensor(3.2320), 'G protein-coupled receptor, rhodopsin-like', tensor(0.2192), tensor(0.0233), tensor(3.2367), 'Serine hydroxymethyltransferase', tensor(0.2223), tensor(0.0237), tensor(3.2320), 'Major facilitator superfamily', tensor(0.4869), tensor(0.0227), tensor(4.4211), 'Polyribonucleotide nucleotidyltransferase', tensor(0.2051), tensor(0.0237), tensor(3.1127), 'Serine hydroxymethyltransferase-like', tensor(0.2223), tensor(0.0237), tensor(3.2320), 'MFS transporter superfamily', tensor(0.4016), tensor(0.0221), tensor(4.1849)],
#  ('24', 1858): ['ATP synthase, F0 complex, subunit A, active site',
#   tensor(0.2291),
#   tensor(0.0189),
#   tensor(3.5969),
#   'Hexapeptide transferase, conserved site',
#   tensor(0.2139),
#   tensor(0.0189),
#   tensor(3.4974),
#   'ATP synthase, F0 complex, subunit A',
#   tensor(0.2291),
#   tensor(0.0189),
#   tensor(3.5969),
#   'Trimeric LpxA-like superfamily',
#   tensor(0.1958),
#   tensor(0.0187),
#   tensor(3.3915),
#   'Leucine-rich repeat domain superfamily',
#   tensor(0.5854),
#   tensor(0.0178),
#   tensor(5.0379),
#   'ATP synthase, F0 complex, subunit A superfamily',
#   tensor(0.2291),
#   tensor(0.0189),
#   tensor(3.5969),
#   'Hexapeptide repeat',
#   tensor(0.2124),
#   tensor(0.0188),
#   tensor(3.5015),
#   'Leucine-rich repeat',
#   tensor(0.5738),
#   tensor(0.0181),
#   tensor(4.9886),
#   'Leucine-rich repeat, typical subtype',
#   tensor(0.7508),
#   tensor(0.0183),
#   tensor(5.3552)],
#  ('24', 231): ['WD40 repeat, conserved site',
#   tensor(0.4373),
#   tensor(0.0273),
#   tensor(4.0038),
#   'WD40/YVTN repeat-like-containing domain superfamily',
#   tensor(0.4319),
#   tensor(0.0260),
#   tensor(4.0514),
#   'WD40-repeat-containing domain superfamily',
#   tensor(0.4122),
#   tensor(0.0267),
#   tensor(3.9459),
#   'WD40 repeat',
#   tensor(0.4233),
#   tensor(0.0267),
#   tensor(3.9890),
#   'PAC1/LIS1-like, WD-40 repeat',
#   tensor(0.4378),
#   tensor(0.0275),
#   tensor(3.9949)],
#  ('24', 3196): ['dUTPase, trimeric',
#   tensor(1.0888),
#   tensor(0.0369),
#   tensor(4.8846),
#   'dUTPase-like superfamily',
#   tensor(1.0888),
#   tensor(0.0369),
#   tensor(4.8846)],
#  ('24', 3895): ['Large ribosomal subunit protein bL35, conserved site',
#   tensor(1.4886),
#   tensor(0.0800),
#   tensor(4.2179),
#   'Large ribosomal subunit protein bL34, conserved site',
#   tensor(0.7062),
#   tensor(0.0817),
#   tensor(3.1120),
#   'Large ribosomal subunit protein bL20, conserved site',
#   tensor(0.7584),
#   tensor(0.0818),
#   tensor(3.2128),
#   'Large ribosomal subunit protein bL34',
#   tensor(0.7062),
#   tensor(0.0817),
#   tensor(3.1120),
#   'Large ribosomal subunit protein bL35',
#   tensor(1.4886),
#   tensor(0.0800),
#   tensor(4.2179),
#   'Large ribosomal subunit protein bL20',
#   tensor(0.7584),
#   tensor(0.0818),
#   tensor(3.2128),
#   'Large ribosomal subunit protein bL35-like',
#   tensor(1.4886),
#   tensor(0.0800),
#   tensor(4.2179),
#   'Ribosomal protein bL20, C-terminal',
#   tensor(0.7584),
#   tensor(0.0818),
#   tensor(3.2128),
#   'Large ribosomal subunit protein bL35 superfamily',
#   tensor(1.4886),
#   tensor(0.0800),
#   tensor(4.2179)],
#  ('24', 3171): [],
#  ('24', 220): [],
#  ('24', 328): [],
#  ('24', 2253): [],
#  ('24', 2627): [],
#  ('24', 3052): [],
#  ('24', 2586): ['Hexapeptide transferase, conserved site',
#   tensor(0.4226),
#   tensor(0.0188),
#   tensor(4.4918),
#   'Fumarate lyase, conserved site',
#   tensor(0.2425),
#   tensor(0.0191),
#   tensor(3.6638),
#   'Fumarate lyase, N-terminal',
#   tensor(0.2425),
#   tensor(0.0191),
#   tensor(3.6638),
#   'Fumarate lyase family',
#   tensor(0.2425),
#   tensor(0.0191),
#   tensor(3.6638),
#   'L-Aspartase-like',
#   tensor(0.2076),
#   tensor(0.0191),
#   tensor(3.4442),
#   'Trimeric LpxA-like superfamily',
#   tensor(0.3605),
#   tensor(0.0183),
#   tensor(4.3017),
#   'Fumarase/histidase, N-terminal',
#   tensor(0.2076),
#   tensor(0.0191),
#   tensor(3.4442),
#   'Hexapeptide repeat',
#   tensor(0.4276),
#   tensor(0.0184),
#   tensor(4.5412)],
#  ('24', 78): [],
#  ('24', 976): [],
#  ('24', 3117): [],
#  ('24', 1427): ['Leucine-rich repeat domain superfamily',
#   tensor(0.4743),
#   tensor(0.0537),
#   tensor(3.1421),
#   'Leucine-rich repeat',
#   tensor(0.4709),
#   tensor(0.0539),
#   tensor(3.1273)],
#  ('24', 929): ['Large ribosomal subunit protein bL35, conserved site',
#   tensor(0.3264),
#   tensor(0.0327),
#   tensor(3.3209),
#   'Large ribosomal subunit protein uL3, conserved site',
#   tensor(0.4192),
#   tensor(0.0327),
#   tensor(3.6818),
#   'Small ribosomal subunit protein uS15',
#   tensor(0.5151),
#   tensor(0.0324),
#   tensor(3.9895),
#   'Large ribosomal subunit protein uL3',
#   tensor(0.4149),
#   tensor(0.0326),
#   tensor(3.6680),
#   'Large ribosomal subunit protein bL33',
#   tensor(0.2960),
#   tensor(0.0328),
#   tensor(3.1726),
#   'Large ribosomal subunit protein bL35',
#   tensor(0.3264),
#   tensor(0.0327),
#   tensor(3.3209),
#   'Large ribosomal subunit protein uL10',
#   tensor(0.3831),
#   tensor(0.0327),
#   tensor(3.5493),
#   'Large ribosomal subunit protein uL4',
#   tensor(0.6273),
#   tensor(0.0323),
#   tensor(4.2797),
#   'Large ribosomal subunit protein uL4-like',
#   tensor(0.6263),
#   tensor(0.0324),
#   tensor(4.2720),
#   'Large ribosomal subunit protein uL3, bacterial/organelle-type',
#   tensor(0.4213),
#   tensor(0.0327),
#   tensor(3.6889),
#   'Large ribosomal subunit protein bL35-like',
#   tensor(0.3264),
#   tensor(0.0327),
#   tensor(3.3209),
#   'Large ribosomal subunit protein bL32, bacterial type',
#   tensor(0.3120),
#   tensor(0.0328),
#   tensor(3.2483),
#   'uS15/NS1, RNA-binding domain superfamily',
#   tensor(0.4875),
#   tensor(0.0324),
#   tensor(3.9101),
#   'Zinc-binding ribosomal protein',
#   tensor(0.2714),
#   tensor(0.0322),
#   tensor(3.0744),
#   'Large ribosomal subunit protein uL4 domain superfamily',
#   tensor(0.6273),
#   tensor(0.0323),
#   tensor(4.2797),
#   'Large ribosomal subunit protein bL35 superfamily',
#   tensor(0.3264),
#   tensor(0.0327),
#   tensor(3.3209),
#   'Large ribosomal subunit protein bL33 superfamily',
#   tensor(0.2960),
#   tensor(0.0328),
#   tensor(3.1726),
#   'Large ribosomal subunit protein uL10-like domain superfamily',
#   tensor(0.3831),
#   tensor(0.0327),
#   tensor(3.5493)],
#  ('24', 3016): [],
#  ('24', 491): [],
#  ('24', 41): ['Major facilitator superfamily domain',
#   tensor(2.0615),
#   tensor(0.0451),
#   tensor(5.5144),
#   'Major facilitator superfamily',
#   tensor(1.9933),
#   tensor(0.0469),
#   tensor(5.4094),
#   'MFS transporter superfamily',
#   tensor(2.3735),
#   tensor(0.0405),
#   tensor(5.8732)],
#  ('24', 2848): ['Serine/threonine-protein kinase, active site',
#   tensor(0.5309),
#   tensor(0.0360),
#   tensor(3.8838),
#   'Protein kinase, ATP binding site',
#   tensor(0.4845),
#   tensor(0.0363),
#   tensor(3.7367),
#   'Protein kinase domain',
#   tensor(0.5019),
#   tensor(0.0356),
#   tensor(3.8175),
#   'Protein kinase-like domain superfamily',
#   tensor(0.4605),
#   tensor(0.0352),
#   tensor(3.7088)],
#  ('24', 1822): ['Serine/threonine-protein kinase, active site',
#   tensor(1.7407),
#   tensor(0.0348),
#   tensor(5.6436),
#   'Protein kinase, ATP binding site',
#   tensor(1.5485),
#   tensor(0.0363),
#   tensor(5.4155),
#   'Protein kinase domain',
#   tensor(1.6119),
#   tensor(0.0337),
#   tensor(5.5778),
#   'Small GTPase',
#   tensor(0.7695),
#   tensor(0.0425),
#   tensor(4.1775),
#   'Protein kinase-like domain superfamily',
#   tensor(1.3632),
#   tensor(0.0333),
#   tensor(5.3545)],
#  ('24', 2321): [],
#  ('24', 1909): [],
#  ('24', 1300): [],
#  ('24', 1893): ['Schiff base-forming aldolase, active site',
#   tensor(0.1836),
#   tensor(0.0202),
#   tensor(3.1857),
#   'ATP synthase, F0 complex, subunit C, DCCD-binding site',
#   tensor(0.2599),
#   tensor(0.0201),
#   tensor(3.6948),
#   'ABC transporter-like, conserved site',
#   tensor(0.1677),
#   tensor(0.0195),
#   tensor(3.1037),
#   'V-ATPase proteolipid subunit C-like domain',
#   tensor(0.2454),
#   tensor(0.0201),
#   tensor(3.6122),
#   'ABC transporter-like, ATP-binding domain',
#   tensor(0.1694),
#   tensor(0.0195),
#   tensor(3.1210),
#   'GPCR, rhodopsin-like, 7TM',
#   tensor(0.3355),
#   tensor(0.0192),
#   tensor(4.1240),
#   'Major facilitator superfamily domain',
#   tensor(0.1679),
#   tensor(0.0200),
#   tensor(3.0724),
#   'Ribosome recycling factor domain',
#   tensor(0.1786),
#   tensor(0.0202),
#   tensor(3.1446),
#   'G protein-coupled receptor, rhodopsin-like',
#   tensor(0.3320),
#   tensor(0.0193),
#   tensor(4.1033),
#   'ATP synthase, F0 complex, subunit C',
#   tensor(0.2599),
#   tensor(0.0201),
#   tensor(3.6948),
#   "ATP synthase, F0 complex, subunit b/b', bacterial/chloroplast",
#   tensor(0.2827),
#   tensor(0.0201),
#   tensor(3.8116),
#   'DapA-like',
#   tensor(0.1822),
#   tensor(0.0202),
#   tensor(3.1756),
#   'Ribosome recycling factor',
#   tensor(0.1786),
#   tensor(0.0202),
#   tensor(3.1446),
#   '4-hydroxy-tetrahydrodipicolinate synthase, DapA',
#   tensor(0.1836),
#   tensor(0.0202),
#   tensor(3.1857),
#   'ATP synthase, F0 complex, subunit C, bacterial/chloroplast',
#   tensor(0.2751),
#   tensor(0.0201),
#   tensor(3.7733),
#   'Major facilitator superfamily',
#   tensor(0.1620),
#   tensor(0.0201),
#   tensor(3.0109),
#   'F/V-ATP synthase subunit C superfamily',
#   tensor(0.2454),
#   tensor(0.0201),
#   tensor(3.6122),
#   'RRF superfamily',
#   tensor(0.1786),
#   tensor(0.0202),
#   tensor(3.1446),
#   'F1F0 ATP synthase subunit C superfamily',
#   tensor(0.2577),
#   tensor(0.0201),
#   tensor(3.6772)],
#  ('24', 898): ['Small ribosomal subunit protein uS11, conserved site',
#   tensor(0.6128),
#   tensor(0.0509),
#   tensor(3.5893),
#   'Amidase, conserved site',
#   tensor(0.4316),
#   tensor(0.0515),
#   tensor(3.0659),
#   'Amidase signature domain',
#   tensor(0.4274),
#   tensor(0.0515),
#   tensor(3.0526),
#   'Cytochrome b/b6, N-terminal domain, eukaryotic/bacterial',
#   tensor(0.4104),
#   tensor(0.0511),
#   tensor(3.0052),
#   'Amidase',
#   tensor(0.4274),
#   tensor(0.0515),
#   tensor(3.0526),
#   'Small ribosomal subunit protein uS11',
#   tensor(0.6145),
#   tensor(0.0508),
#   tensor(3.5964),
#   'Glutamyl-tRNA(Gln) amidotransferase A subunit',
#   tensor(0.4295),
#   tensor(0.0515),
#   tensor(3.0585),
#   'Small ribosomal subunit protein uS11, bacterial-type',
#   tensor(0.6160),
#   tensor(0.0510),
#   tensor(3.5938),
#   'Beta-lactamase/transpeptidase-like',
#   tensor(1.6191),
#   tensor(0.0495),
#   tensor(5.0320),
#   'Amidase signature (AS) superfamily',
#   tensor(0.4274),
#   tensor(0.0515),
#   tensor(3.0526),
#   'Small ribosomal subunit protein uS11 superfamily',
#   tensor(0.6145),
#   tensor(0.0508),
#   tensor(3.5964)],
#  ('24', 3330): [],
#  ('24', 471): ['Nucleotide-diphospho-sugar transferases',
#   tensor(1.2872),
#   tensor(0.0418),
#   tensor(4.9451)],
#  ('24', 1263): ['Large ribosomal subunit protein uL14, conserved site',
#   tensor(0.8352),
#   tensor(0.0948),
#   tensor(3.1386),
#   'Large ribosomal subunit protein uL14',
#   tensor(0.8268),
#   tensor(0.0946),
#   tensor(3.1270),
#   'Large ribosomal subunit protein uL14, bacterial-type',
#   tensor(0.8334),
#   tensor(0.0947),
#   tensor(3.1376),
#   'Large ribosomal subunit protein uL14 superfamily',
#   tensor(0.8268),
#   tensor(0.0946),
#   tensor(3.1270)],
#  ('24', 3327): [],
#  ('24', 3302): ['ATP synthase, F0 complex, subunit C, DCCD-binding site',
#   tensor(0.5728),
#   tensor(0.0358),
#   tensor(3.9988),
#   'V-ATPase proteolipid subunit C-like domain',
#   tensor(0.5556),
#   tensor(0.0358),
#   tensor(3.9558),
#   'ATP synthase, F0 complex, subunit C',
#   tensor(0.5728),
#   tensor(0.0358),
#   tensor(3.9988),
#   'ATP synthase, F0 complex, subunit C, bacterial/chloroplast',
#   tensor(0.5910),
#   tensor(0.0360),
#   tensor(4.0385),
#   'Armadillo-like helical',
#   tensor(0.6590),
#   tensor(0.0354),
#   tensor(4.2198),
#   'Armadillo-type fold',
#   tensor(0.6163),
#   tensor(0.0353),
#   tensor(4.1239),
#   'F/V-ATP synthase subunit C superfamily',
#   tensor(0.5556),
#   tensor(0.0358),
#   tensor(3.9558),
#   'F1F0 ATP synthase subunit C superfamily',
#   tensor(0.5761),
#   tensor(0.0360),
#   tensor(4.0009)],
#  ('24', 2048): [],
#  ('24', 2653): [],
#  ('24', 446): [],
#  ('24', 2533): [],
#  ('24', 3460): ['tRNA synthetases class I, catalytic domain',
#   tensor(0.2850),
#   tensor(0.0303),
#   tensor(3.2342),
#   'Cysteine-tRNA ligase',
#   tensor(0.2958),
#   tensor(0.0303),
#   tensor(3.2850),
#   'Cysteinyl-tRNA synthetase/mycothiol ligase',
#   tensor(0.2974),
#   tensor(0.0303),
#   tensor(3.2954),
#   'Histidine kinase/HSP90-like ATPase superfamily',
#   tensor(0.2614),
#   tensor(0.0300),
#   tensor(3.1232)],
#  ('24', 2206): ['D-aminoacyl-tRNA deacylase DTD',
#   tensor(1.3089),
#   tensor(0.1594),
#   tensor(3.0375),
#   'D-aminoacyl-tRNA deacylase-like superfamily',
#   tensor(1.3089),
#   tensor(0.1594),
#   tensor(3.0375)],
#  ('24', 3865): ['Uracil-DNA glycosylase-like',
#   tensor(0.3759),
#   tensor(0.0352),
#   tensor(3.4175),
#   'Alkaline-phosphatase-like, core domain superfamily',
#   tensor(0.7317),
#   tensor(0.0346),
#   tensor(4.4019),
#   'Histidine phosphatase superfamily',
#   tensor(0.5041),
#   tensor(0.0350),
#   tensor(3.8503),
#   'Uracil-DNA glycosylase-like domain superfamily',
#   tensor(0.3759),
#   tensor(0.0352),
#   tensor(3.4175)],
#  ('24', 2435): [],
#  ('24', 3707): ['ClpP, Ser active site',
#   tensor(0.2225),
#   tensor(0.0167),
#   tensor(3.7390),
#   'ClpP, histidine active site',
#   tensor(0.2235),
#   tensor(0.0167),
#   tensor(3.7455),
#   'Large ribosomal subunit protein uL6, conserved site',
#   tensor(0.3442),
#   tensor(0.0165),
#   tensor(4.3806),
#   'Hexapeptide transferase, conserved site',
#   tensor(0.7382),
#   tensor(0.0156),
#   tensor(5.5598),
#   'Large ribosomal subunit protein uL6, alpha-beta domain',
#   tensor(0.3430),
#   tensor(0.0165),
#   tensor(4.3784),
#   'Large ribosomal subunit protein uL6-like',
#   tensor(0.3430),
#   tensor(0.0165),
#   tensor(4.3784),
#   'ATP-dependent Clp protease proteolytic subunit',
#   tensor(0.2218),
#   tensor(0.0166),
#   tensor(3.7378),
#   'Large ribosomal subunit protein uL6, bacterial-type',
#   tensor(0.3442),
#   tensor(0.0165),
#   tensor(4.3806),
#   'Clp protease proteolytic subunit /Translocation-enhancing protein TepA',
#   tensor(0.2218),
#   tensor(0.0166),
#   tensor(3.7378),
#   'Trimeric LpxA-like superfamily',
#   tensor(0.6753),
#   tensor(0.0146),
#   tensor(5.5341),
#   'Large ribosomal subunit protein uL6-like, alpha-beta domain superfamily',
#   tensor(0.3430),
#   tensor(0.0165),
#   tensor(4.3784),
#   'Hexapeptide repeat',
#   tensor(0.7518),
#   tensor(0.0149),
#   tensor(5.6583)],
#  ('24', 1044): [],
#  ('24', 684): ['Adenylate kinase, conserved site',
#   tensor(0.4883),
#   tensor(0.0454),
#   tensor(3.4268),
#   'Uracil-DNA glycosylase-like',
#   tensor(0.6010),
#   tensor(0.0455),
#   tensor(3.7245),
#   'Adenylate kinase/UMP-CMP kinase',
#   tensor(0.4874),
#   tensor(0.0454),
#   tensor(3.4255),
#   'Adenylate kinase subfamily',
#   tensor(0.4862),
#   tensor(0.0455),
#   tensor(3.4176),
#   'Uracil-DNA glycosylase-like domain superfamily',
#   tensor(0.6010),
#   tensor(0.0455),
#   tensor(3.7245)],
#  ('24', 1865): ['Short-chain dehydrogenase/reductase, conserved site',
#   tensor(0.9886),
#   tensor(0.0627),
#   tensor(3.9783),
#   'Alpha/beta hydrolase fold-1',
#   tensor(1.3444),
#   tensor(0.0622),
#   tensor(4.4329),
#   'Short-chain dehydrogenase/reductase SDR',
#   tensor(0.9646),
#   tensor(0.0619),
#   tensor(3.9608),
#   'Alpha/Beta hydrolase fold',
#   tensor(1.2189),
#   tensor(0.0570),
#   tensor(4.4191)],
#  ('28', 817): [],
#  ('28', 896): [],
#  ('28', 3755): [],
#  ('28', 487): [],
#  ('28', 1095): [],
#  ('28', 1879): ['Alpha/beta hydrolase fold-1',
#   tensor(0.7432),
#   tensor(0.0894),
#   tensor(3.0559),
#   'FAD/NAD(P)-binding domain',
#   tensor(0.8246),
#   tensor(0.0893),
#   tensor(3.2067),
#   'Alpha/Beta hydrolase fold',
#   tensor(0.7666),
#   tensor(0.0861),
#   tensor(3.1539)],
#  ('28', 334): [],
#  ('28', 116): [],
#  ('28', 213): [],
#  ('28', 2031): [],
#  ('28', 1970): [],
#  ('28', 1066): [],
#  ('28', 862): [],
#  ('28', 658): [],
#  ('28', 4021): []}

# %%
n_tests = 28672*10096

layer_ind = 12
latent_ind = 1256   
flat_ind = offsets[str(layer_ind)] + latent_ind
epsilon = 1e-6
latent_i = latent_ids_both_proteins.index(flat_ind) #80
annotated_latents = []
print(layer_ind, latent_ind)
for family_j in range(latents_family_pvals.shape[1]):
    if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
        if latents_family_effect_size[latent_i,family_j,1] < 0.2:
            l2fc = np.log2((latents_family_effect_size[latent_i,family_j,0]+epsilon)/(latents_family_effect_size[latent_i,family_j,1]+epsilon))
            # print(f"L2FC: {l2fc}")
            if l2fc > 3: #if latents_family_effect_size[latent_i,family_j,0] > 0.3:
                annotated_latents += [latent_ids_both_proteins[latent_i]]
                print(f"Latent {latent_ids_both_proteins[latent_i]} is sig assoc w family {family_j}")
                print(f"    Family {interpro_annotations_nonzero.iloc[family_j].ENTRY_NAME}")
                print(f"    Mean in-family: {latents_family_effect_size[latent_i,family_j,0]}")
                print(f"    Mean out-of-family: {latents_family_effect_size[latent_i,family_j,1]}")
                print(f"    Log2FC: {np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])}")
# Out:
# 12 1256
# Latent 9448 is sig assoc w family 134
#     Family EF-Hand 1, calcium-binding site
#     Mean in-family: 0.5439120531082153
#     Mean out-of-family: 0.04676192253828049
#     Log2FC: 3.5399672985076904
# Latent 9448 is sig assoc w family 787
#     Family Phosphoribosyltransferase domain
#     Mean in-family: 0.39505958557128906
#     Mean out-of-family: 0.04600566625595093
#     Log2FC: 3.102186918258667
# Latent 9448 is sig assoc w family 1010
#     Family EF-hand domain
#     Mean in-family: 0.5556498765945435
#     Mean out-of-family: 0.04653194919228554
#     Log2FC: 3.577882766723633
# Latent 9448 is sig assoc w family 2727
#     Family OBG-type guanine nucleotide-binding (G) domain
#     Mean in-family: 0.6347910761833191
#     Mean out-of-family: 0.04703279212117195
#     Log2FC: 3.7545430660247803
# Latent 9448 is sig assoc w family 4162
#     Family Small GTPase
#     Mean in-family: 0.3918114900588989
#     Mean out-of-family: 0.047304440289735794
#     Log2FC: 3.050112247467041
# Latent 9448 is sig assoc w family 4991
#     Family Uracil phosphoribosyl transferase
#     Mean in-family: 0.4898849129676819
#     Mean out-of-family: 0.04723594710230827
#     Log2FC: 3.374485731124878
# Latent 9448 is sig assoc w family 7126
#     Family Uracil phosphoribosyltransferase, bacterial-type
#     Mean in-family: 0.4898849129676819
#     Mean out-of-family: 0.04723594710230827
#     Log2FC: 3.374485731124878
# Latent 9448 is sig assoc w family 7657
#     Family Uracil phosphoribosyltransferase/Adenine phosphoribosyltransferase
#     Mean in-family: 0.47842341661453247
#     Mean out-of-family: 0.04673326015472412
#     Log2FC: 3.355766534805298
# Latent 9448 is sig assoc w family 8699
#     Family EF-hand domain pair
#     Mean in-family: 0.5414069890975952
#     Mean out-of-family: 0.04646982625126839
#     Log2FC: 3.5423474311828613
# Latent 9448 is sig assoc w family 9058
#     Family Phosphoribosyltransferase-like
#     Mean in-family: 0.39505958557128906
#     Mean out-of-family: 0.04600566625595093
#     Log2FC: 3.102186918258667

# %%
n_tests = 28672*10096

layer_ind = 12
latent_ind = 1256   
flat_ind = offsets[str(layer_ind)] + latent_ind
epsilon = 1e-6
latent_i = latent_ids_both_proteins.index(flat_ind) #80
annotated_latents = []
print(layer_ind, latent_ind)
for family_j in range(latents_family_pvals.shape[1]):
    if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
        if latents_family_effect_size[latent_i,family_j,1] < 0.2:
            l2fc = np.log2((latents_family_effect_size[latent_i,family_j,0]+epsilon)/(latents_family_effect_size[latent_i,family_j,1]+epsilon))
            # print(f"L2FC: {l2fc}")
            if l2fc > 3: #if latents_family_effect_size[latent_i,family_j,0] > 0.3:
                annotated_latents += [latent_ids_both_proteins[latent_i]]
                print(f"Latent {latent_ids_both_proteins[latent_i]} is sig assoc w family {family_j}")
                print(f"    Family {interpro_annotations_nonzero.iloc[family_j].ENTRY_NAME}")
                print(f"    Mean in-family: {latents_family_effect_size[latent_i,family_j,0]}")
                print(f"    Mean out-of-family: {latents_family_effect_size[latent_i,family_j,1]}")
                print(f"    Log2FC: {np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])}")
# Out:
# 12 1256
# Latent 9448 is sig assoc w family 134
#     Family EF-Hand 1, calcium-binding site
#     Mean in-family: 0.5439120531082153
#     Mean out-of-family: 0.04676192253828049
#     Log2FC: 3.5399672985076904
# Latent 9448 is sig assoc w family 787
#     Family Phosphoribosyltransferase domain
#     Mean in-family: 0.39505958557128906
#     Mean out-of-family: 0.04600566625595093
#     Log2FC: 3.102186918258667
# Latent 9448 is sig assoc w family 1010
#     Family EF-hand domain
#     Mean in-family: 0.5556498765945435
#     Mean out-of-family: 0.04653194919228554
#     Log2FC: 3.577882766723633
# Latent 9448 is sig assoc w family 2727
#     Family OBG-type guanine nucleotide-binding (G) domain
#     Mean in-family: 0.6347910761833191
#     Mean out-of-family: 0.04703279212117195
#     Log2FC: 3.7545430660247803
# Latent 9448 is sig assoc w family 4162
#     Family Small GTPase
#     Mean in-family: 0.3918114900588989
#     Mean out-of-family: 0.047304440289735794
#     Log2FC: 3.050112247467041
# Latent 9448 is sig assoc w family 4991
#     Family Uracil phosphoribosyl transferase
#     Mean in-family: 0.4898849129676819
#     Mean out-of-family: 0.04723594710230827
#     Log2FC: 3.374485731124878
# Latent 9448 is sig assoc w family 7126
#     Family Uracil phosphoribosyltransferase, bacterial-type
#     Mean in-family: 0.4898849129676819
#     Mean out-of-family: 0.04723594710230827
#     Log2FC: 3.374485731124878
# Latent 9448 is sig assoc w family 7657
#     Family Uracil phosphoribosyltransferase/Adenine phosphoribosyltransferase
#     Mean in-family: 0.47842341661453247
#     Mean out-of-family: 0.04673326015472412
#     Log2FC: 3.355766534805298
# Latent 9448 is sig assoc w family 8699
#     Family EF-hand domain pair
#     Mean in-family: 0.5414069890975952
#     Mean out-of-family: 0.04646982625126839
#     Log2FC: 3.5423474311828613
# Latent 9448 is sig assoc w family 9058
#     Family Phosphoribosyltransferase-like
#     Mean in-family: 0.39505958557128906
#     Mean out-of-family: 0.04600566625595093
#     Log2FC: 3.102186918258667

# %%
n_tests = 28672*10096

layer_ind = 12
latent_ind = 1256   
flat_ind = offsets[str(layer_ind)] + latent_ind
epsilon = 1e-6
latent_i = latent_ids_both_proteins.index(flat_ind) #80
annotated_latents = []
print(layer_ind, latent_ind)
for family_j in range(latents_family_pvals.shape[1]):
    if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
        if latents_family_effect_size[latent_i,family_j,1] < 0.2:
            l2fc = np.log2((latents_family_effect_size[latent_i,family_j,0]+epsilon)/(latents_family_effect_size[latent_i,family_j,1]+epsilon))
            # print(f"L2FC: {l2fc}")
            if l2fc > 3: #if latents_family_effect_size[latent_i,family_j,0] > 0.3:
                annotated_latents += [latent_ids_both_proteins[latent_i]]
                print(f"Latent {latent_ids_both_proteins[latent_i]} is sig assoc w family {family_j}")
                print(f"    Family {interpro_annotations_nonzero.iloc[family_j].ENTRY_NAME}")
                print(f"    Mean in-family: {latents_family_effect_size[latent_i,family_j,0]}")
                print(f"    Mean out-of-family: {latents_family_effect_size[latent_i,family_j,1]}")
                print(f"    Log2FC: {np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])}")
# Out:
# 12 1256
# Latent 9448 is sig assoc w family 134
#     Family EF-Hand 1, calcium-binding site
#     Mean in-family: 0.5439120531082153
#     Mean out-of-family: 0.04676192253828049
#     Log2FC: 3.5399672985076904
# Latent 9448 is sig assoc w family 787
#     Family Phosphoribosyltransferase domain
#     Mean in-family: 0.39505958557128906
#     Mean out-of-family: 0.04600566625595093
#     Log2FC: 3.102186918258667
# Latent 9448 is sig assoc w family 1010
#     Family EF-hand domain
#     Mean in-family: 0.5556498765945435
#     Mean out-of-family: 0.04653194919228554
#     Log2FC: 3.577882766723633
# Latent 9448 is sig assoc w family 2727
#     Family OBG-type guanine nucleotide-binding (G) domain
#     Mean in-family: 0.6347910761833191
#     Mean out-of-family: 0.04703279212117195
#     Log2FC: 3.7545430660247803
# Latent 9448 is sig assoc w family 4162
#     Family Small GTPase
#     Mean in-family: 0.3918114900588989
#     Mean out-of-family: 0.047304440289735794
#     Log2FC: 3.050112247467041
# Latent 9448 is sig assoc w family 4991
#     Family Uracil phosphoribosyl transferase
#     Mean in-family: 0.4898849129676819
#     Mean out-of-family: 0.04723594710230827
#     Log2FC: 3.374485731124878
# Latent 9448 is sig assoc w family 7126
#     Family Uracil phosphoribosyltransferase, bacterial-type
#     Mean in-family: 0.4898849129676819
#     Mean out-of-family: 0.04723594710230827
#     Log2FC: 3.374485731124878
# Latent 9448 is sig assoc w family 7657
#     Family Uracil phosphoribosyltransferase/Adenine phosphoribosyltransferase
#     Mean in-family: 0.47842341661453247
#     Mean out-of-family: 0.04673326015472412
#     Log2FC: 3.355766534805298
# Latent 9448 is sig assoc w family 8699
#     Family EF-hand domain pair
#     Mean in-family: 0.5414069890975952
#     Mean out-of-family: 0.04646982625126839
#     Log2FC: 3.5423474311828613
# Latent 9448 is sig assoc w family 9058
#     Family Phosphoribosyltransferase-like
#     Mean in-family: 0.39505958557128906
#     Mean out-of-family: 0.04600566625595093
#     Log2FC: 3.102186918258667

# %%
n_tests = 28672*10096

layer_ind = 12
latent_ind = 1256   
flat_ind = offsets[str(layer_ind)] + latent_ind
epsilon = 1e-6
latent_i = latent_ids_both_proteins.index(flat_ind) #80
annotated_latents = []
print(layer_ind, latent_ind)
for family_j in range(latents_family_pvals.shape[1]):
    if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
        if latents_family_effect_size[latent_i,family_j,1] < 0.2:
            l2fc = np.log2((latents_family_effect_size[latent_i,family_j,0]+epsilon)/(latents_family_effect_size[latent_i,family_j,1]+epsilon))
            # print(f"L2FC: {l2fc}")
            if l2fc > 3: #if latents_family_effect_size[latent_i,family_j,0] > 0.3:
                annotated_latents += [latent_ids_both_proteins[latent_i]]
                print(f"Latent {latent_ids_both_proteins[latent_i]} is sig assoc w family {family_j}")
                print(f"    Family {interpro_annotations_nonzero.iloc[family_j].ENTRY_NAME}")
                print(f"    Mean in-family: {latents_family_effect_size[latent_i,family_j,0]}")
                print(f"    Mean out-of-family: {latents_family_effect_size[latent_i,family_j,1]}")
                print(f"    Log2FC: {np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])}")
# Out:
# 12 1256
# Latent 9448 is sig assoc w family 134
#     Family EF-Hand 1, calcium-binding site
#     Mean in-family: 0.5439120531082153
#     Mean out-of-family: 0.04676192253828049
#     Log2FC: 3.5399672985076904
# Latent 9448 is sig assoc w family 787
#     Family Phosphoribosyltransferase domain
#     Mean in-family: 0.39505958557128906
#     Mean out-of-family: 0.04600566625595093
#     Log2FC: 3.102186918258667
# Latent 9448 is sig assoc w family 1010
#     Family EF-hand domain
#     Mean in-family: 0.5556498765945435
#     Mean out-of-family: 0.04653194919228554
#     Log2FC: 3.577882766723633
# Latent 9448 is sig assoc w family 2727
#     Family OBG-type guanine nucleotide-binding (G) domain
#     Mean in-family: 0.6347910761833191
#     Mean out-of-family: 0.04703279212117195
#     Log2FC: 3.7545430660247803
# Latent 9448 is sig assoc w family 4162
#     Family Small GTPase
#     Mean in-family: 0.3918114900588989
#     Mean out-of-family: 0.047304440289735794
#     Log2FC: 3.050112247467041
# Latent 9448 is sig assoc w family 4991
#     Family Uracil phosphoribosyl transferase
#     Mean in-family: 0.4898849129676819
#     Mean out-of-family: 0.04723594710230827
#     Log2FC: 3.374485731124878
# Latent 9448 is sig assoc w family 7126
#     Family Uracil phosphoribosyltransferase, bacterial-type
#     Mean in-family: 0.4898849129676819
#     Mean out-of-family: 0.04723594710230827
#     Log2FC: 3.374485731124878
# Latent 9448 is sig assoc w family 7657
#     Family Uracil phosphoribosyltransferase/Adenine phosphoribosyltransferase
#     Mean in-family: 0.47842341661453247
#     Mean out-of-family: 0.04673326015472412
#     Log2FC: 3.355766534805298
# Latent 9448 is sig assoc w family 8699
#     Family EF-hand domain pair
#     Mean in-family: 0.5414069890975952
#     Mean out-of-family: 0.04646982625126839
#     Log2FC: 3.5423474311828613
# Latent 9448 is sig assoc w family 9058
#     Family Phosphoribosyltransferase-like
#     Mean in-family: 0.39505958557128906
#     Mean out-of-family: 0.04600566625595093
#     Log2FC: 3.102186918258667

# %%
n_tests = 28672*10096

layer_ind = 12
latent_ind = 1256   
flat_ind = offsets[str(layer_ind)] + latent_ind
epsilon = 1e-6
latent_i = latent_ids_both_proteins.index(flat_ind) #80
annotated_latents = []
print(layer_ind, latent_ind)
for family_j in range(latents_family_pvals.shape[1]):
    if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
        if latents_family_effect_size[latent_i,family_j,1] < 0.2:
            l2fc = np.log2((latents_family_effect_size[latent_i,family_j,0]+epsilon)/(latents_family_effect_size[latent_i,family_j,1]+epsilon))
            # print(f"L2FC: {l2fc}")
            if l2fc > 3: #if latents_family_effect_size[latent_i,family_j,0] > 0.3:
                annotated_latents += [latent_ids_both_proteins[latent_i]]
                print(f"Latent {latent_ids_both_proteins[latent_i]} is sig assoc w family {family_j}")
                print(f"    Family {interpro_annotations_nonzero.iloc[family_j].ENTRY_NAME}")
                print(f"    Mean in-family: {latents_family_effect_size[latent_i,family_j,0]}")
                print(f"    Mean out-of-family: {latents_family_effect_size[latent_i,family_j,1]}")
                print(f"    Log2FC: {np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])}")
# Out:
# 12 1256
# Latent 9448 is sig assoc w family 134
#     Family EF-Hand 1, calcium-binding site
#     Mean in-family: 0.5439120531082153
#     Mean out-of-family: 0.04676192253828049
#     Log2FC: 3.5399672985076904
# Latent 9448 is sig assoc w family 787
#     Family Phosphoribosyltransferase domain
#     Mean in-family: 0.39505958557128906
#     Mean out-of-family: 0.04600566625595093
#     Log2FC: 3.102186918258667
# Latent 9448 is sig assoc w family 1010
#     Family EF-hand domain
#     Mean in-family: 0.5556498765945435
#     Mean out-of-family: 0.04653194919228554
#     Log2FC: 3.577882766723633
# Latent 9448 is sig assoc w family 2727
#     Family OBG-type guanine nucleotide-binding (G) domain
#     Mean in-family: 0.6347910761833191
#     Mean out-of-family: 0.04703279212117195
#     Log2FC: 3.7545430660247803
# Latent 9448 is sig assoc w family 4162
#     Family Small GTPase
#     Mean in-family: 0.3918114900588989
#     Mean out-of-family: 0.047304440289735794
#     Log2FC: 3.050112247467041
# Latent 9448 is sig assoc w family 4991
#     Family Uracil phosphoribosyl transferase
#     Mean in-family: 0.4898849129676819
#     Mean out-of-family: 0.04723594710230827
#     Log2FC: 3.374485731124878
# Latent 9448 is sig assoc w family 7126
#     Family Uracil phosphoribosyltransferase, bacterial-type
#     Mean in-family: 0.4898849129676819
#     Mean out-of-family: 0.04723594710230827
#     Log2FC: 3.374485731124878
# Latent 9448 is sig assoc w family 7657
#     Family Uracil phosphoribosyltransferase/Adenine phosphoribosyltransferase
#     Mean in-family: 0.47842341661453247
#     Mean out-of-family: 0.04673326015472412
#     Log2FC: 3.355766534805298
# Latent 9448 is sig assoc w family 8699
#     Family EF-hand domain pair
#     Mean in-family: 0.5414069890975952
#     Mean out-of-family: 0.04646982625126839
#     Log2FC: 3.5423474311828613
# Latent 9448 is sig assoc w family 9058
#     Family Phosphoribosyltransferase-like
#     Mean in-family: 0.39505958557128906
#     Mean out-of-family: 0.04600566625595093
#     Log2FC: 3.102186918258667

# %%
n_tests = 28672*10096

layer_ind = 12
latent_ind = 1256   
flat_ind = offsets[str(layer_ind)] + latent_ind
epsilon = 1e-6
latent_i = latent_ids_both_proteins.index(flat_ind) #80
annotated_latents = []
print(layer_ind, latent_ind)
for family_j in range(latents_family_pvals.shape[1]):
    if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
        if latents_family_effect_size[latent_i,family_j,1] < 0.2:
            l2fc = np.log2((latents_family_effect_size[latent_i,family_j,0]+epsilon)/(latents_family_effect_size[latent_i,family_j,1]+epsilon))
            # print(f"L2FC: {l2fc}")
            if l2fc > 3: #if latents_family_effect_size[latent_i,family_j,0] > 0.3:
                annotated_latents += [latent_ids_both_proteins[latent_i]]
                print(f"Latent {latent_ids_both_proteins[latent_i]} is sig assoc w family {family_j}")
                print(f"    Family {interpro_annotations_nonzero.iloc[family_j].ENTRY_NAME}")
                print(f"    Mean in-family: {latents_family_effect_size[latent_i,family_j,0]}")
                print(f"    Mean out-of-family: {latents_family_effect_size[latent_i,family_j,1]}")
                print(f"    Log2FC: {np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])}")
# Out:
# 12 1256
# Latent 9448 is sig assoc w family 134
#     Family EF-Hand 1, calcium-binding site
#     Mean in-family: 0.5439120531082153
#     Mean out-of-family: 0.04676192253828049
#     Log2FC: 3.5399672985076904
# Latent 9448 is sig assoc w family 787
#     Family Phosphoribosyltransferase domain
#     Mean in-family: 0.39505958557128906
#     Mean out-of-family: 0.04600566625595093
#     Log2FC: 3.102186918258667
# Latent 9448 is sig assoc w family 1010
#     Family EF-hand domain
#     Mean in-family: 0.5556498765945435
#     Mean out-of-family: 0.04653194919228554
#     Log2FC: 3.577882766723633
# Latent 9448 is sig assoc w family 2727
#     Family OBG-type guanine nucleotide-binding (G) domain
#     Mean in-family: 0.6347910761833191
#     Mean out-of-family: 0.04703279212117195
#     Log2FC: 3.7545430660247803
# Latent 9448 is sig assoc w family 4162
#     Family Small GTPase
#     Mean in-family: 0.3918114900588989
#     Mean out-of-family: 0.047304440289735794
#     Log2FC: 3.050112247467041
# Latent 9448 is sig assoc w family 4991
#     Family Uracil phosphoribosyl transferase
#     Mean in-family: 0.4898849129676819
#     Mean out-of-family: 0.04723594710230827
#     Log2FC: 3.374485731124878
# Latent 9448 is sig assoc w family 7126
#     Family Uracil phosphoribosyltransferase, bacterial-type
#     Mean in-family: 0.4898849129676819
#     Mean out-of-family: 0.04723594710230827
#     Log2FC: 3.374485731124878
# Latent 9448 is sig assoc w family 7657
#     Family Uracil phosphoribosyltransferase/Adenine phosphoribosyltransferase
#     Mean in-family: 0.47842341661453247
#     Mean out-of-family: 0.04673326015472412
#     Log2FC: 3.355766534805298
# Latent 9448 is sig assoc w family 8699
#     Family EF-hand domain pair
#     Mean in-family: 0.5414069890975952
#     Mean out-of-family: 0.04646982625126839
#     Log2FC: 3.5423474311828613
# Latent 9448 is sig assoc w family 9058
#     Family Phosphoribosyltransferase-like
#     Mean in-family: 0.39505958557128906
#     Mean out-of-family: 0.04600566625595093
#     Log2FC: 3.102186918258667

# %%
import numpy as np

mu_out = latents_family_effect_size[:, :, 1]
mask = mu_out < 0.05

num_true = int(np.count_nonzero(mask))
total = int(mask.size)
print(f"{num_true} / {total} ({num_true/total:.2%}) latent–family pairs with mu_out < 0.05")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 8
#       4 mask = mu_out < 0.05
#       7 num_true = int(np.count_nonzero(mask))
# ----> 8 total = int(mask.size)
#       9 print(f"{num_true} / {total} ({num_true/total:.2%}) latent–family pairs with mu_out < 0.05")
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'builtin_function_or_method'

# %%
import numpy as np
import pandas as pd

# Assumes:
# - latents_family_effect_size shape: [num_latents, num_families, 2]
#   [:, :, 0] = in-family mean, [:, :, 1] = out-of-family mean
# - latents_family_pvals shape: [num_latents, num_families]
# - latent_ids_both_proteins is a list mapping latent index -> global latent id
# - interpro_annotations_nonzero has column 'ENTRY_NAME' indexed by family_j

mu_in  = latents_family_effect_size[:, :, 0]
mu_out = latents_family_effect_size[:, :, 1]

# Filter on out-of-family mean < 0.05
mask = mu_out < 0.05

# Optional: small epsilon to avoid inf when mu_out≈0; set to 0.0 for exact ratios
eps = 0.0  # e.g., use 1e-6 if you prefer stabilization

ratio = (mu_in + eps) / (mu_out + eps)
l2fc  = np.log2(ratio)

rows = []
ii, jj = np.where(mask)
for i, j in zip(ii, jj):
    rows.append({
        "latent_idx": int(i),
        "latent_id": int(latent_ids_both_proteins[i]) if i < len(latent_ids_both_proteins) else i,
        "family_idx": int(j),
        "family_name": str(interpro_annotations_nonzero.iloc[j].ENTRY_NAME) if hasattr(interpro_annotations_nonzero.iloc[j], "ENTRY_NAME") else j,
        "mu_in": float(mu_in[i, j]),
        "mu_out": float(mu_out[i, j]),
        "ratio": float(ratio[i, j]),
        "log2fc": float(l2fc[i, j]),
        "pval": float(latents_family_pvals[i, j]) if 'latents_family_pvals' in globals() else np.nan,
    })

df_ratios = pd.DataFrame(rows).sort_values(["ratio", "log2fc"], ascending=[False, False]).reset_index(drop=True)
df_ratios.head(20)
# Out:
# /tmp/ipykernel_72712/3796616251.py:21: RuntimeWarning: divide by zero encountered in log2
#   l2fc  = np.log2(ratio)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 34
#      24 ii, jj = np.where(mask)
#      25 for i, j in zip(ii, jj):
#      26     rows.append({
#      27         "latent_idx": int(i),
#      28         "latent_id": int(latent_ids_both_proteins[i]) if i < len(latent_ids_both_proteins) else i,
#      29         "family_idx": int(j),
#      30         "family_name": str(interpro_annotations_nonzero.iloc[j].ENTRY_NAME) if hasattr(interpro_annotations_nonzero.iloc[j], "ENTRY_NAME") else j,
#      31         "mu_in": float(mu_in[i, j]),
#      32         "mu_out": float(mu_out[i, j]),
#      33         "ratio": float(ratio[i, j]),
# ---> 34         "log2fc": float(l2fc[i, j]),
#      35         "pval": float(latents_family_pvals[i, j]) if 'latents_family_pvals' in globals() else np.nan,
#      36     })
#      38 df_ratios = pd.DataFrame(rows).sort_values(["ratio", "log2fc"], ascending=[False, False]).reset_index(drop=True)
#      39 df_ratios.head(20)
#
# KeyboardInterrupt:

# %%
n_tests
# Out:
# 289472512

# %%
np.argmin(latents_family_pvals[0])
# Out:
# tensor(8760)

# %%
for latent_i in range(latents_family_pvals.shape[0]):
    print(latent_i)
    break
# Out:
# 0

# %%
latents_family_pvals.shape
# Out:
# torch.Size([383, 10096])

# %%
annotated_latents = []
for latent_i in range(latents_family_pvals.shape[0]):
    for family_j in range(latents_family_pvals.shape[1]):
        if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
            if latents_family_effect_size[latent_i,family_j,1] < 0.05:
                l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])
                if latents_family_effect_size[latent_i,family_j,0] > 1.05:
                    annotated_latents += [latent_ids_both_proteins[latent_i]]
                    print(f"Latent {latent_ids_both_proteins[latent_i]} is sig assoc w family {family_j}")
                    print(f"    Family {interpro_annotations_nonzero.iloc[family_j]["ENTRY_NAME"]}")
                    print(f"    Mean in-family: {latents_family_effect_size[latent_i,family_j,0]}")
                    print(f"    Mean out-of-family: {latents_family_effect_size[latent_i,family_j,1]}")
                    print(f"    Log2FC: {np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])}")
# Out:
# /tmp/ipykernel_7694/3019213309.py:6: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])
# /tmp/ipykernel_7694/3019213309.py:6: RuntimeWarning: divide by zero encountered in log2
#   l2fc = np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])
# Latent 9396 is sig assoc w family 274
#     Family DNA mismatch repair, conserved site
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 457
#     Family Heat shock protein Hsp90, conserved site
#     Mean in-family: 1.4559404850006104
#     Mean out-of-family: 0.00420586671680212
#     Log2FC: 8.435332298278809
# Latent 9396 is sig assoc w family 2000
#     Family DNA mismatch repair protein, S5 domain 2-like
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 2113
#     Family MutL, C-terminal, dimerisation
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 2370
#     Family Heat shock protein Hsp90, N-terminal
#     Mean in-family: 1.4246454238891602
#     Mean out-of-family: 0.004085632972419262
#     Log2FC: 8.44582748413086
# Latent 9396 is sig assoc w family 4065
#     Family Heat shock protein Hsp90 family
#     Mean in-family: 1.4246454238891602
#     Mean out-of-family: 0.004085632972419262
#     Log2FC: 8.44582748413086
# Latent 9396 is sig assoc w family 4238
#     Family DNA mismatch repair protein MutL/Mlh/PMS
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 6308
#     Family DNA mismatch repair protein, MutL
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 7213
#     Family DNA mismatch repair protein MutL/Mlh/Pms-like
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 9682
#     Family HSP90, C-terminal domain
#     Mean in-family: 1.2057727575302124
#     Mean out-of-family: 0.004381106235086918
#     Log2FC: 8.104447364807129
# Latent 9396 is sig assoc w family 9684
#     Family MutL, C-terminal domain superfamily
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 9897
#     Family MutL, C-terminal domain, dimerisation subdomain
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# Latent 9396 is sig assoc w family 9898
#     Family MutL, C-terminal domain, regulatory subdomain
#     Mean in-family: 1.4902369976043701
#     Mean out-of-family: 0.004479201976209879
#     Log2FC: 8.378084182739258
# /tmp/ipykernel_7694/3019213309.py:13: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"    Log2FC: {np.log2(latents_family_effect_size[latent_i,family_j,0]/latents_family_effect_size[latent_i,family_j,1])}")
# Latent 9988 is sig assoc w family 457
#     Family Heat shock protein Hsp90, conserved site
#     Mean in-family: 1.5989656448364258
#     Mean out-of-family: 0.008104116655886173
#     Log2FC: 7.624268054962158
# Latent 9988 is sig assoc w family 1229
#     Family Signal transduction histidine kinase, dimerisation/phosphoacceptor domain
#     Mean in-family: 1.7447575330734253
#     Mean out-of-family: 0.008175770752131939
#     Log2FC: 7.737456321716309
# Latent 9988 is sig assoc w family 1324
#     Family Signal transduction histidine kinase-related protein, C-terminal
#     Mean in-family: 1.785921335220337
#     Mean out-of-family: 0.007973155938088894
#     Log2FC: 7.807301998138428
# Latent 9988 is sig assoc w family 1401
#     Family Histidine kinase domain
#     Mean in-family: 1.785921335220337
#     Mean out-of-family: 0.007973155938088894
#     Log2FC: 7.807301998138428
# Latent 9988 is sig assoc w family 2370
#     Family Heat shock protein Hsp90, N-terminal
#     Mean in-family: 1.5625734329223633
#     Mean out-of-family: 0.007974040694534779
#     Log2FC: 7.6143975257873535
# Latent 9988 is sig assoc w family 4065
#     Family Heat shock protein Hsp90 family
#     Mean in-family: 1.5625734329223633
#     Mean out-of-family: 0.007974040694534779
#     Log2FC: 7.6143975257873535
# Latent 9988 is sig assoc w family 9193
#     Family Signal transduction histidine kinase, dimerisation/phosphoacceptor domain superfamily
#     Mean in-family: 1.785921335220337
#     Mean out-of-family: 0.007973155938088894
#     Log2FC: 7.807301998138428
# Latent 9988 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 1.6556663513183594
#     Mean out-of-family: 0.004097857512533665
#     Log2FC: 8.658326148986816
# Latent 9988 is sig assoc w family 9682
#     Family HSP90, C-terminal domain
#     Mean in-family: 1.2926454544067383
#     Mean out-of-family: 0.00831869151443243
#     Log2FC: 7.279754161834717
# Latent 10666 is sig assoc w family 669
#     Family GNAT domain
#     Mean in-family: 1.381739616394043
#     Mean out-of-family: 0.02205962873995304
#     Log2FC: 5.968933582305908
# Latent 10666 is sig assoc w family 8834
#     Family Acyl-CoA N-acyltransferase
#     Mean in-family: 1.6904847621917725
#     Mean out-of-family: 0.019513817504048347
#     Log2FC: 6.436797142028809
# Latent 13025 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 1.7811452150344849
#     Mean out-of-family: 0.020810704678297043
#     Log2FC: 6.41933536529541
# Latent 13454 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 1.5226376056671143
#     Mean out-of-family: 0.010726005770266056
#     Log2FC: 7.14931583404541
# Latent 13568 is sig assoc w family 2370
#     Family Heat shock protein Hsp90, N-terminal
#     Mean in-family: 5.7453508377075195
#     Mean out-of-family: 0.011984986253082752
#     Log2FC: 8.905022621154785
# Latent 13568 is sig assoc w family 4065
#     Family Heat shock protein Hsp90 family
#     Mean in-family: 5.7453508377075195
#     Mean out-of-family: 0.011984986253082752
#     Log2FC: 8.905022621154785
# Latent 13568 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 3.1017351150512695
#     Mean out-of-family: 0.0069779325276613235
#     Log2FC: 8.796060562133789
# Latent 13792 is sig assoc w family 659
#     Family Alpha/beta hydrolase fold-1
#     Mean in-family: 1.2832716703414917
#     Mean out-of-family: 0.026212679222226143
#     Log2FC: 5.613418102264404
# Latent 13792 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 1.3233450651168823
#     Mean out-of-family: 0.020012982189655304
#     Log2FC: 6.047109127044678
# Latent 14463 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 1.5610861778259277
#     Mean out-of-family: 0.022779107093811035
#     Log2FC: 6.098695278167725
# Latent 15124 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 1.3250720500946045
#     Mean out-of-family: 0.04500913992524147
#     Log2FC: 4.879708766937256
# Latent 16053 is sig assoc w family 4594
#     Family Undecaprenyl-diphosphatase UppP
#     Mean in-family: 1.1321523189544678
#     Mean out-of-family: 0.032732706516981125
#     Log2FC: 5.112191200256348
# Latent 16526 is sig assoc w family 797
#     Family AMP-dependent synthetase/ligase domain
#     Mean in-family: 2.935063600540161
#     Mean out-of-family: 0.04430416598916054
#     Log2FC: 6.049805641174316
# Latent 16526 is sig assoc w family 2169
#     Family Aldehyde dehydrogenase domain
#     Mean in-family: 2.456920862197876
#     Mean out-of-family: 0.04323478043079376
#     Log2FC: 5.82851505279541
# Latent 16526 is sig assoc w family 8825
#     Family Aldehyde/histidinol dehydrogenase
#     Mean in-family: 2.4557204246520996
#     Mean out-of-family: 0.04226987063884735
#     Log2FC: 5.860373020172119
# Latent 16526 is sig assoc w family 8826
#     Family Aldehyde dehydrogenase, N-terminal
#     Mean in-family: 2.456920862197876
#     Mean out-of-family: 0.04323478043079376
#     Log2FC: 5.82851505279541
# Latent 16526 is sig assoc w family 8827
#     Family Aldehyde dehydrogenase, C-terminal
#     Mean in-family: 2.456920862197876
#     Mean out-of-family: 0.04323478043079376
#     Log2FC: 5.82851505279541
# Latent 16526 is sig assoc w family 9990
#     Family AMP-binding enzyme, C-terminal domain superfamily
#     Mean in-family: 2.935063600540161
#     Mean out-of-family: 0.04430416598916054
#     Log2FC: 6.049805641174316
# Latent 17043 is sig assoc w family 2353
#     Family Pseudouridine synthase I, TruA, alpha/beta domain
#     Mean in-family: 1.0848681926727295
#     Mean out-of-family: 0.027880394831299782
#     Log2FC: 5.282124996185303
# Latent 17043 is sig assoc w family 4067
#     Family Pseudouridine synthase I, TruA
#     Mean in-family: 1.0848681926727295
#     Mean out-of-family: 0.027880394831299782
#     Log2FC: 5.282124996185303
# Latent 17043 is sig assoc w family 8863
#     Family Pseudouridine synthase I, TruA, C-terminal
#     Mean in-family: 1.0848681926727295
#     Mean out-of-family: 0.027880394831299782
#     Log2FC: 5.282124996185303
# Latent 17043 is sig assoc w family 9052
#     Family Lipoprotein localisation LolA/LolB/LppX
#     Mean in-family: 2.129256248474121
#     Mean out-of-family: 0.027153562754392624
#     Log2FC: 6.293064117431641
# Latent 17222 is sig assoc w family 2393
#     Family Major facilitator superfamily domain
#     Mean in-family: 1.1007509231567383
#     Mean out-of-family: 0.026311714202165604
#     Log2FC: 5.38663911819458
# Latent 17222 is sig assoc w family 9263
#     Family MFS transporter superfamily
#     Mean in-family: 1.1193487644195557
#     Mean out-of-family: 0.02459850162267685
#     Log2FC: 5.507945537567139
# Latent 17249 is sig assoc w family 5810
#     Family Large ribosomal subunit protein uL23-like
#     Mean in-family: 1.124653697013855
#     Mean out-of-family: 0.04555756226181984
#     Log2FC: 4.625646591186523
# Latent 17249 is sig assoc w family 8719
#     Family Ribosomal protein uL23/eL15/eS24 core domain superfamily
#     Mean in-family: 1.0681434869766235
#     Mean out-of-family: 0.04555702209472656
#     Log2FC: 4.55128812789917
# Latent 17262 is sig assoc w family 21
#     Family Serine/threonine-protein kinase, active site
#     Mean in-family: 1.0674089193344116
#     Mean out-of-family: 0.018165400251746178
#     Log2FC: 5.876776218414307
# Latent 17660 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 1.106537103652954
#     Mean out-of-family: 0.01177440769970417
#     Log2FC: 6.554253578186035
# Latent 18350 is sig assoc w family 669
#     Family GNAT domain
#     Mean in-family: 3.1902425289154053
#     Mean out-of-family: 0.024109497666358948
#     Log2FC: 7.0479207038879395
# Latent 18350 is sig assoc w family 1058
#     Family Phosphoadenosine phosphosulphate reductase domain
#     Mean in-family: 1.451269268989563
#     Mean out-of-family: 0.026911810040473938
#     Log2FC: 5.752932071685791
# Latent 18350 is sig assoc w family 4765
#     Family Leucyl/phenylalanyl-tRNA-protein transferase
#     Mean in-family: 6.507966995239258
#     Mean out-of-family: 0.022720659151673317
#     Log2FC: 8.16205883026123
# Latent 18350 is sig assoc w family 8548
#     Family Phosphoenolpyruvate carboxykinase, N-terminal
#     Mean in-family: 1.1466498374938965
#     Mean out-of-family: 0.026788996532559395
#     Log2FC: 5.41964054107666
# Latent 18350 is sig assoc w family 8720
#     Family Phosphoenolpyruvate carboxykinase, C-terminal
#     Mean in-family: 1.1466498374938965
#     Mean out-of-family: 0.026788996532559395
#     Log2FC: 5.41964054107666
# Latent 18350 is sig assoc w family 8834
#     Family Acyl-CoA N-acyltransferase
#     Mean in-family: 4.682978630065918
#     Mean out-of-family: 0.01624201610684395
#     Log2FC: 8.171551704406738
# Latent 18350 is sig assoc w family 9910
#     Family Leucyl/phenylalanyl-tRNA-protein transferase, C-terminal
#     Mean in-family: 6.507966995239258
#     Mean out-of-family: 0.022720659151673317
#     Log2FC: 8.16205883026123
# Latent 18350 is sig assoc w family 9912
#     Family Leucyl/phenylalanyl-tRNA-protein transferase, N-terminal
#     Mean in-family: 6.532168388366699
#     Mean out-of-family: 0.023352686315774918
#     Log2FC: 8.127829551696777
# Latent 18695 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 2.126980781555176
#     Mean out-of-family: 0.015655571594834328
#     Log2FC: 7.085987091064453
# Latent 19016 is sig assoc w family 659
#     Family Alpha/beta hydrolase fold-1
#     Mean in-family: 3.2683162689208984
#     Mean out-of-family: 0.03483063727617264
#     Log2FC: 6.552046775817871
# Latent 19016 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 2.0970373153686523
#     Mean out-of-family: 0.02696274220943451
#     Log2FC: 6.281241416931152
# Latent 19999 is sig assoc w family 659
#     Family Alpha/beta hydrolase fold-1
#     Mean in-family: 2.274716377258301
#     Mean out-of-family: 0.040920011699199677
#     Log2FC: 5.796736240386963
# Latent 19999 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 2.1130309104919434
#     Mean out-of-family: 0.03137968108057976
#     Log2FC: 6.073339462280273
# Latent 20356 is sig assoc w family 9559
#     Family Histidine kinase/HSP90-like ATPase superfamily
#     Mean in-family: 3.437107801437378
#     Mean out-of-family: 0.00691533088684082
#     Log2FC: 8.957180976867676
# Latent 20379 is sig assoc w family 38
#     Family Serine carboxypeptidase, serine active site
#     Mean in-family: 2.240122079849243
#     Mean out-of-family: 0.018040232360363007
#     Log2FC: 6.956215858459473
# Latent 20379 is sig assoc w family 4096
#     Family Peptidase S10, serine carboxypeptidase
#     Mean in-family: 2.3884708881378174
#     Mean out-of-family: 0.01744687557220459
#     Log2FC: 7.096974849700928
# Latent 20379 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 1.093358039855957
#     Mean out-of-family: 0.013011718168854713
#     Log2FC: 6.392810821533203
# Latent 20521 is sig assoc w family 2393
#     Family Major facilitator superfamily domain
#     Mean in-family: 2.061525583267212
#     Mean out-of-family: 0.04509911313652992
#     Log2FC: 5.514469623565674
# Latent 20521 is sig assoc w family 5666
#     Family Major facilitator superfamily
#     Mean in-family: 1.9933199882507324
#     Mean out-of-family: 0.04690127447247505
#     Log2FC: 5.409402370452881
# Latent 20521 is sig assoc w family 9263
#     Family MFS transporter superfamily
#     Mean in-family: 2.3734781742095947
#     Mean out-of-family: 0.04049167037010193
#     Log2FC: 5.873233795166016
# Latent 20951 is sig assoc w family 9050
#     Family Nucleotide-diphospho-sugar transferases
#     Mean in-family: 1.2871720790863037
#     Mean out-of-family: 0.04178468510508537
#     Log2FC: 4.94508695602417
# Latent 21378 is sig assoc w family 8706
#     Family Beta-lactamase/transpeptidase-like
#     Mean in-family: 1.6190625429153442
#     Mean out-of-family: 0.04948509484529495
#     Log2FC: 5.0320210456848145
# Latent 22302 is sig assoc w family 21
#     Family Serine/threonine-protein kinase, active site
#     Mean in-family: 1.740713357925415
#     Mean out-of-family: 0.034819893538951874
#     Log2FC: 5.643622875213623
# Latent 22302 is sig assoc w family 126
#     Family Protein kinase, ATP binding site
#     Mean in-family: 1.548477053642273
#     Mean out-of-family: 0.03628077730536461
#     Log2FC: 5.415500640869141
# Latent 22302 is sig assoc w family 767
#     Family Protein kinase domain
#     Mean in-family: 1.6119248867034912
#     Mean out-of-family: 0.03374802693724632
#     Log2FC: 5.5778374671936035
# Latent 22302 is sig assoc w family 8644
#     Family Protein kinase-like domain superfamily
#     Mean in-family: 1.3631665706634521
#     Mean out-of-family: 0.03331771492958069
#     Log2FC: 5.354528427124023
# Latent 23478 is sig assoc w family 9050
#     Family Nucleotide-diphospho-sugar transferases
#     Mean in-family: 1.6834858655929565
#     Mean out-of-family: 0.04261191189289093
#     Log2FC: 5.304050922393799
# Latent 23545 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 1.3932600021362305
#     Mean out-of-family: 0.046924397349357605
#     Log2FC: 4.891982555389404
# Latent 23546 is sig assoc w family 659
#     Family Alpha/beta hydrolase fold-1
#     Mean in-family: 1.384918212890625
#     Mean out-of-family: 0.0320814847946167
#     Log2FC: 5.431916236877441
# Latent 23546 is sig assoc w family 9059
#     Family Alpha/Beta hydrolase fold
#     Mean in-family: 1.7029019594192505
#     Mean out-of-family: 0.02366684004664421
#     Log2FC: 6.168984413146973
# Latent 23676 is sig assoc w family 2860
#     Family dUTPase, trimeric
#     Mean in-family: 1.088760256767273
#     Mean out-of-family: 0.03685624524950981
#     Log2FC: 4.884633541107178
# Latent 23676 is sig assoc w family 9220
#     Family dUTPase-like superfamily
#     Mean in-family: 1.088760256767273
#     Mean out-of-family: 0.03685624524950981
#     Log2FC: 4.884633541107178

# %%
ann_latents_list = list(set(annotated_latents))

# %%
len(ann_latents_list)
# Out:
# 30

# %%
len(set(full_indices_metx))
# Out:
# 273

# %%
len(set(full_indices_metx).intersection(ann_latents_list))
# Out:
# 18

# %%
len(set(full_indices_top2))
# Out:
# 134

# %%
len(set(full_indices_top2).intersection(ann_latents_list))
# Out:
# 12

# %%
# For a table:
# Layer | Latent ID (#) | IntroPro ID | InterPro Name | out-of-family | in-family | Bonf p-value

# %%
metx_results_df_dict = {}
for latent_i in range(latents_family_pvals.shape[0]):
    for family_j in range(latents_family_pvals.shape[1]):
        if latents_family_pvals[latent_i,family_j] < (0.05/n_tests):
            if latents_family_effect_size[latent_i,family_j,1] < 0.05:
                if latents_family_effect_size[latent_i,family_j,0] > 1.05:

                    df_id = str(latent_i)+"_"+str(family_j)
                    cur_lat_id = latent_ids_both_proteins[latent_i]
                    layer_id = (cur_lat_id // 4096)*4
                    lat_id = cur_lat_id % 4096

                    case_ptn = "MetX"
                    if latent_ids_both_proteins[latent_i] in full_indices_top2:
                        case_ptn="Top2"

                    metx_results_df_dict[df_id] = {
                        "Case": case_ptn,
                        "Layer": layer_id,
                        "Latent ID": lat_id,
                        "InterPro ID": interpro_annotations_nonzero.iloc[family_j]["ENTRY_AC"],
                        "InterPro Name": interpro_annotations_nonzero.iloc[family_j]["ENTRY_NAME"],
                        "Activation w/ domain": float(latents_family_effect_size[latent_i,family_j,0]),
                        "Activation w/o domain": float(latents_family_effect_size[latent_i,family_j,1]),
                        "Bonferroni adj. p-value": float(latents_family_pvals[latent_i,family_j]*n_tests)
                    }

# %%
df_metx_results = pd.DataFrame.from_dict(metx_results_df_dict, orient='index')
df_metx_results.head()
# Out:
#          Case  Layer  Latent ID InterPro ID  \
# 72_274   Top2      8       1204   IPR014762
# 72_457   Top2      8       1204   IPR019805
# 72_2000  Top2      8       1204   IPR013507
# 72_2113  Top2      8       1204   IPR014790
# 72_2370  Top2      8       1204   IPR020575
#
#                                          InterPro Name  Activation w/ domain  \
# 72_274             DNA mismatch repair, conserved site              1.490237
# 72_457        Heat shock protein Hsp90, conserved site              1.455940
# 72_2000  DNA mismatch repair protein, S5 domain 2-like              1.490237
# 72_2113                 MutL, C-terminal, dimerisation              1.490237
# 72_2370           Heat shock protein Hsp90, N-terminal              1.424645
#
#          Activation w/o domain  Bonferroni adj. p-value
# 72_274                0.004479             1.594212e-07
# 72_457                0.004206             2.943538e-13
# 72_2000               0.004479             1.594212e-07
# 72_2113               0.004479             1.594212e-07
# 72_2370               0.004086             3.936193e-16

# %%
df_metx_results.query("Case == 'MetX'") #.sort_values(by="Bonferroni adj. p-value")
# Out:
#           Case  Layer  Latent ID InterPro ID  \
# 136_659   MetX     12       1504   IPR000073
# 136_9059  MetX     12       1504   IPR029058
# 145_9059  MetX     12       2175   IPR029058
# 154_9059  MetX     12       2836   IPR029058
# 170_4594  MetX     12       3765   IPR003824
# 177_797   MetX     16        142   IPR000873
# 177_2169  MetX     16        142   IPR015590
# 177_8825  MetX     16        142   IPR016161
# 177_8826  MetX     16        142   IPR016162
# 177_8827  MetX     16        142   IPR016163
# 177_9990  MetX     16        142   IPR045851
# 189_2393  MetX     16        838   IPR020846
# 189_9263  MetX     16        838   IPR036259
# 192_21    MetX     16        878   IPR008271
# 199_9059  MetX     16       1276   IPR029058
# 229_659   MetX     16       2632   IPR000073
# 229_9059  MetX     16       2632   IPR029058
# 244_659   MetX     16       3615   IPR000073
# 244_9059  MetX     16       3615   IPR029058
# 256_38    MetX     16       3995   IPR018202
# 256_4096  MetX     16       3995   IPR001563
# 256_9059  MetX     16       3995   IPR029058
# 261_2393  MetX     20         41   IPR020846
# 261_5666  MetX     20         41   IPR011701
# 261_9263  MetX     20         41   IPR036259
# 271_9050  MetX     20        471   IPR029044
# 276_8706  MetX     20        898   IPR012338
# 297_21    MetX     20       1822   IPR008271
# 297_126   MetX     20       1822   IPR017441
# 297_767   MetX     20       1822   IPR000719
# 297_8644  MetX     20       1822   IPR011009
# 331_9059  MetX     20       3065   IPR029058
# 332_659   MetX     20       3066   IPR000073
# 332_9059  MetX     20       3066   IPR029058
# 335_2860  MetX     20       3196   IPR033704
# 335_9220  MetX     20       3196   IPR036157
#
#                                               InterPro Name  \
# 136_659                         Alpha/beta hydrolase fold-1
# 136_9059                          Alpha/Beta hydrolase fold
# 145_9059                          Alpha/Beta hydrolase fold
# 154_9059                          Alpha/Beta hydrolase fold
# 170_4594                    Undecaprenyl-diphosphatase UppP
# 177_797              AMP-dependent synthetase/ligase domain
# 177_2169                      Aldehyde dehydrogenase domain
# 177_8825                  Aldehyde/histidinol dehydrogenase
# 177_8826                 Aldehyde dehydrogenase, N-terminal
# 177_8827                 Aldehyde dehydrogenase, C-terminal
# 177_9990  AMP-binding enzyme, C-terminal domain superfamily
# 189_2393               Major facilitator superfamily domain
# 189_9263                        MFS transporter superfamily
# 192_21         Serine/threonine-protein kinase, active site
# 199_9059                          Alpha/Beta hydrolase fold
# 229_659                         Alpha/beta hydrolase fold-1
# 229_9059                          Alpha/Beta hydrolase fold
# 244_659                         Alpha/beta hydrolase fold-1
# 244_9059                          Alpha/Beta hydrolase fold
# 256_38          Serine carboxypeptidase, serine active site
# 256_4096             Peptidase S10, serine carboxypeptidase
# 256_9059                          Alpha/Beta hydrolase fold
# 261_2393               Major facilitator superfamily domain
# 261_5666                      Major facilitator superfamily
# 261_9263                        MFS transporter superfamily
# 271_9050            Nucleotide-diphospho-sugar transferases
# 276_8706                 Beta-lactamase/transpeptidase-like
# 297_21         Serine/threonine-protein kinase, active site
# 297_126                    Protein kinase, ATP binding site
# 297_767                               Protein kinase domain
# 297_8644             Protein kinase-like domain superfamily
# 331_9059                          Alpha/Beta hydrolase fold
# 332_659                         Alpha/beta hydrolase fold-1
# 332_9059                          Alpha/Beta hydrolase fold
# 335_2860                                  dUTPase, trimeric
# 335_9220                           dUTPase-like superfamily
#
#           Activation w/ domain  Activation w/o domain  Bonferroni adj. p-value
# 136_659               1.283272               0.026213             8.708278e-06
# 136_9059              1.323345               0.020013             0.000000e+00
# 145_9059              1.561086               0.022779             0.000000e+00
# 154_9059              1.325072               0.045009             3.001717e-35
# 170_4594              1.132152               0.032733             2.038676e-06
# 177_797               2.935064               0.044304             1.535564e-02
# 177_2169              2.456921               0.043235             1.386195e-07
# 177_8825              2.455720               0.042270             1.722333e-10
# 177_8826              2.456921               0.043235             1.386195e-07
# 177_8827              2.456921               0.043235             1.386195e-07
# 177_9990              2.935064               0.044304             1.535564e-02
# 189_2393              1.100751               0.026312             8.563810e-19
# 189_9263              1.119349               0.024599             1.460178e-29
# 192_21                1.067409               0.018165             4.822177e-32
# 199_9059              1.106537               0.011774             0.000000e+00
# 229_659               3.268316               0.034831             1.250094e-04
# 229_9059              2.097037               0.026963             6.118074e-21
# 244_659               2.274716               0.040920             2.239325e-04
# 244_9059              2.113031               0.031380             4.056374e-37
# 256_38                2.240122               0.018040             4.092521e-03
# 256_4096              2.388471               0.017447             1.195451e-05
# 256_9059              1.093358               0.013012             0.000000e+00
# 261_2393              2.061526               0.045099             1.203750e-16
# 261_5666              1.993320               0.046901             3.062357e-11
# 261_9263              2.373478               0.040492             1.909631e-26
# 271_9050              1.287172               0.041785             2.254630e-26
# 276_8706              1.619063               0.049485             2.095319e-04
# 297_21                1.740713               0.034820             8.078916e-28
# 297_126               1.548477               0.036281             9.803431e-26
# 297_767               1.611925               0.033748             4.096938e-35
# 297_8644              1.363167               0.033318             0.000000e+00
# 331_9059              1.393260               0.046924             1.695742e-21
# 332_659               1.384918               0.032081             2.296502e-04
# 332_9059              1.702902               0.023667             0.000000e+00
# 335_2860              1.088760               0.036856             1.285796e-04
# 335_9220              1.088760               0.036856             1.285796e-04

# %%
df_metx_results.query("Case == 'Top2'") #.sort_values(by="Bonferroni adj. p-value")
# Out:
#           Case  Layer  Latent ID InterPro ID  \
# 72_274    Top2      8       1204   IPR014762
# 72_457    Top2      8       1204   IPR019805
# 72_2000   Top2      8       1204   IPR013507
# 72_2113   Top2      8       1204   IPR014790
# 72_2370   Top2      8       1204   IPR020575
# 72_4065   Top2      8       1204   IPR001404
# 72_4238   Top2      8       1204   IPR002099
# 72_6308   Top2      8       1204   IPR020667
# 72_7213   Top2      8       1204   IPR038973
# 72_9682   Top2      8       1204   IPR037196
# 72_9684   Top2      8       1204   IPR037198
# 72_9897   Top2      8       1204   IPR042120
# 72_9898   Top2      8       1204   IPR042121
# 77_457    Top2      8       1796   IPR019805
# 77_1229   Top2      8       1796   IPR003661
# 77_1324   Top2      8       1796   IPR004358
# 77_1401   Top2      8       1796   IPR005467
# 77_2370   Top2      8       1796   IPR020575
# 77_4065   Top2      8       1796   IPR001404
# 77_9193   Top2      8       1796   IPR036097
# 77_9559   Top2      8       1796   IPR036890
# 77_9682   Top2      8       1796   IPR037196
# 84_669    Top2      8       2474   IPR000182
# 84_8834   Top2      8       2474   IPR016181
# 116_9559  Top2     12        737   IPR036890
# 123_9559  Top2     12       1166   IPR036890
# 127_2370  Top2     12       1280   IPR020575
# 127_4065  Top2     12       1280   IPR001404
# 127_9559  Top2     12       1280   IPR036890
# 184_2353  Top2     16        659   IPR020097
# 184_4067  Top2     16        659   IPR001406
# 184_8863  Top2     16        659   IPR020095
# 184_9052  Top2     16        659   IPR029046
# 191_5810  Top2     16        865   IPR013025
# 191_8719  Top2     16        865   IPR012678
# 214_669   Top2     16       1966   IPR000182
# 214_1058  Top2     16       1966   IPR002500
# 214_4765  Top2     16       1966   IPR004616
# 214_8548  Top2     16       1966   IPR008210
# 214_8720  Top2     16       1966   IPR013035
# 214_8834  Top2     16       1966   IPR016181
# 214_9910  Top2     16       1966   IPR042203
# 214_9912  Top2     16       1966   IPR042221
# 220_9559  Top2     16       2311   IPR036890
# 255_9559  Top2     16       3972   IPR036890
# 328_9050  Top2     20       2998   IPR029044
#
#                                               InterPro Name  \
# 72_274                  DNA mismatch repair, conserved site
# 72_457             Heat shock protein Hsp90, conserved site
# 72_2000       DNA mismatch repair protein, S5 domain 2-like
# 72_2113                      MutL, C-terminal, dimerisation
# 72_2370                Heat shock protein Hsp90, N-terminal
# 72_4065                     Heat shock protein Hsp90 family
# 72_4238            DNA mismatch repair protein MutL/Mlh/PMS
# 72_6308                   DNA mismatch repair protein, MutL
# 72_7213       DNA mismatch repair protein MutL/Mlh/Pms-like
# 72_9682                            HSP90, C-terminal domain
# 72_9684                 MutL, C-terminal domain superfamily
# 72_9897     MutL, C-terminal domain, dimerisation subdomain
# 72_9898       MutL, C-terminal domain, regulatory subdomain
# 77_457             Heat shock protein Hsp90, conserved site
# 77_1229   Signal transduction histidine kinase, dimerisa...
# 77_1324   Signal transduction histidine kinase-related p...
# 77_1401                             Histidine kinase domain
# 77_2370                Heat shock protein Hsp90, N-terminal
# 77_4065                     Heat shock protein Hsp90 family
# 77_9193   Signal transduction histidine kinase, dimerisa...
# 77_9559      Histidine kinase/HSP90-like ATPase superfamily
# 77_9682                            HSP90, C-terminal domain
# 84_669                                          GNAT domain
# 84_8834                          Acyl-CoA N-acyltransferase
# 116_9559     Histidine kinase/HSP90-like ATPase superfamily
# 123_9559     Histidine kinase/HSP90-like ATPase superfamily
# 127_2370               Heat shock protein Hsp90, N-terminal
# 127_4065                    Heat shock protein Hsp90 family
# 127_9559     Histidine kinase/HSP90-like ATPase superfamily
# 184_2353  Pseudouridine synthase I, TruA, alpha/beta domain
# 184_4067                     Pseudouridine synthase I, TruA
# 184_8863         Pseudouridine synthase I, TruA, C-terminal
# 184_9052            Lipoprotein localisation LolA/LolB/LppX
# 191_5810          Large ribosomal subunit protein uL23-like
# 191_8719  Ribosomal protein uL23/eL15/eS24 core domain s...
# 214_669                                         GNAT domain
# 214_1058  Phosphoadenosine phosphosulphate reductase domain
# 214_4765       Leucyl/phenylalanyl-tRNA-protein transferase
# 214_8548      Phosphoenolpyruvate carboxykinase, N-terminal
# 214_8720      Phosphoenolpyruvate carboxykinase, C-terminal
# 214_8834                         Acyl-CoA N-acyltransferase
# 214_9910  Leucyl/phenylalanyl-tRNA-protein transferase, ...
# 214_9912  Leucyl/phenylalanyl-tRNA-protein transferase, ...
# 220_9559     Histidine kinase/HSP90-like ATPase superfamily
# 255_9559     Histidine kinase/HSP90-like ATPase superfamily
# 328_9050            Nucleotide-diphospho-sugar transferases
#
#           Activation w/ domain  Activation w/o domain  Bonferroni adj. p-value
# 72_274                1.490237               0.004479             1.594212e-07
# 72_457                1.455940               0.004206             2.943538e-13
# 72_2000               1.490237               0.004479             1.594212e-07
# 72_2113               1.490237               0.004479             1.594212e-07
# 72_2370               1.424645               0.004086             3.936193e-16
# 72_4065               1.424645               0.004086             3.936193e-16
# 72_4238               1.490237               0.004479             1.594212e-07
# 72_6308               1.490237               0.004479             1.594212e-07
# 72_7213               1.490237               0.004479             1.594212e-07
# 72_9682               1.205773               0.004381             3.014633e-13
# 72_9684               1.490237               0.004479             1.594212e-07
# 72_9897               1.490237               0.004479             1.594212e-07
# 72_9898               1.490237               0.004479             1.594212e-07
# 77_457                1.598966               0.008104             9.000002e-05
# 77_1229               1.744758               0.008176             4.010378e-03
# 77_1324               1.785921               0.007973             8.173953e-05
# 77_1401               1.785921               0.007973             8.173953e-05
# 77_2370               1.562573               0.007974             1.896858e-06
# 77_4065               1.562573               0.007974             1.896858e-06
# 77_9193               1.785921               0.007973             8.173953e-05
# 77_9559               1.655666               0.004098             0.000000e+00
# 77_9682               1.292645               0.008319             9.254814e-05
# 84_669                1.381740               0.022060             3.420647e-02
# 84_8834               1.690485               0.019514             3.578099e-12
# 116_9559              1.781145               0.020811             4.647273e-06
# 123_9559              1.522638               0.010726             1.017908e-20
# 127_2370              5.745351               0.011985             1.673163e-02
# 127_4065              5.745351               0.011985             1.673163e-02
# 127_9559              3.101735               0.006978             1.729629e-12
# 184_2353              1.084868               0.027880             5.024589e-06
# 184_4067              1.084868               0.027880             5.024589e-06
# 184_8863              1.084868               0.027880             5.024589e-06
# 184_9052              2.129256               0.027154             1.052378e-02
# 191_5810              1.124654               0.045558             1.956427e-05
# 191_8719              1.068143               0.045557             1.574326e-05
# 214_669               3.190243               0.024109             5.667186e-09
# 214_1058              1.451269               0.026912             2.879986e-02
# 214_4765              6.507967               0.022721             9.995315e-04
# 214_8548              1.146650               0.026789             3.273330e-06
# 214_8720              1.146650               0.026789             3.273330e-06
# 214_8834              4.682979               0.016242             2.976969e-26
# 214_9910              6.507967               0.022721             9.995315e-04
# 214_9912              6.532168               0.023353             2.191872e-02
# 220_9559              2.126981               0.015656             1.698489e-15
# 255_9559              3.437108               0.006915             2.450431e-19
# 328_9050              1.683486               0.042612             1.554031e-23

# %%
df_metx_results.to_csv('circuit_domain_detectors.csv', index=False)

# %%
print(df_metx_results.query("Case == 'Top2'").drop("Case", axis=1).to_latex(
    index=False, float_format="{:.2g}".format))
# Out:
# \begin{tabular}{rrllrrr}
# \toprule
# Layer & Latent ID & InterPro ID & InterPro Name & Activation w/ domain & Activation w/o domain & Bonferroni adj. p-value \\
# \midrule
# 8 & 1204 & IPR014762 & DNA mismatch repair, conserved site & 1.5 & 0.0045 & 1.6e-07 \\
# 8 & 1204 & IPR019805 & Heat shock protein Hsp90, conserved site & 1.5 & 0.0042 & 2.9e-13 \\
# 8 & 1204 & IPR013507 & DNA mismatch repair protein, S5 domain 2-like & 1.5 & 0.0045 & 1.6e-07 \\
# 8 & 1204 & IPR014790 & MutL, C-terminal, dimerisation & 1.5 & 0.0045 & 1.6e-07 \\
# 8 & 1204 & IPR020575 & Heat shock protein Hsp90, N-terminal & 1.4 & 0.0041 & 3.9e-16 \\
# 8 & 1204 & IPR001404 & Heat shock protein Hsp90 family & 1.4 & 0.0041 & 3.9e-16 \\
# 8 & 1204 & IPR002099 & DNA mismatch repair protein MutL/Mlh/PMS & 1.5 & 0.0045 & 1.6e-07 \\
# 8 & 1204 & IPR020667 & DNA mismatch repair protein, MutL & 1.5 & 0.0045 & 1.6e-07 \\
# 8 & 1204 & IPR038973 & DNA mismatch repair protein MutL/Mlh/Pms-like & 1.5 & 0.0045 & 1.6e-07 \\
# 8 & 1204 & IPR037196 & HSP90, C-terminal domain & 1.2 & 0.0044 & 3e-13 \\
# 8 & 1204 & IPR037198 & MutL, C-terminal domain superfamily & 1.5 & 0.0045 & 1.6e-07 \\
# 8 & 1204 & IPR042120 & MutL, C-terminal domain, dimerisation subdomain & 1.5 & 0.0045 & 1.6e-07 \\
# 8 & 1204 & IPR042121 & MutL, C-terminal domain, regulatory subdomain & 1.5 & 0.0045 & 1.6e-07 \\
# 8 & 1796 & IPR019805 & Heat shock protein Hsp90, conserved site & 1.6 & 0.0081 & 9e-05 \\
# 8 & 1796 & IPR003661 & Signal transduction histidine kinase, dimerisation/phosphoacceptor domain & 1.7 & 0.0082 & 0.004 \\
# 8 & 1796 & IPR004358 & Signal transduction histidine kinase-related protein, C-terminal & 1.8 & 0.008 & 8.2e-05 \\
# 8 & 1796 & IPR005467 & Histidine kinase domain & 1.8 & 0.008 & 8.2e-05 \\
# 8 & 1796 & IPR020575 & Heat shock protein Hsp90, N-terminal & 1.6 & 0.008 & 1.9e-06 \\
# 8 & 1796 & IPR001404 & Heat shock protein Hsp90 family & 1.6 & 0.008 & 1.9e-06 \\
# 8 & 1796 & IPR036097 & Signal transduction histidine kinase, dimerisation/phosphoacceptor domain superfamily & 1.8 & 0.008 & 8.2e-05 \\
# 8 & 1796 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.7 & 0.0041 & 0 \\
# 8 & 1796 & IPR037196 & HSP90, C-terminal domain & 1.3 & 0.0083 & 9.3e-05 \\
# 8 & 2474 & IPR000182 & GNAT domain & 1.4 & 0.022 & 0.034 \\
# 8 & 2474 & IPR016181 & Acyl-CoA N-acyltransferase & 1.7 & 0.02 & 3.6e-12 \\
# 12 & 737 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.8 & 0.021 & 4.6e-06 \\
# 12 & 1166 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 1.5 & 0.011 & 1e-20 \\
# 12 & 1280 & IPR020575 & Heat shock protein Hsp90, N-terminal & 5.7 & 0.012 & 0.017 \\
# 12 & 1280 & IPR001404 & Heat shock protein Hsp90 family & 5.7 & 0.012 & 0.017 \\
# 12 & 1280 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 3.1 & 0.007 & 1.7e-12 \\
# 16 & 659 & IPR020097 & Pseudouridine synthase I, TruA, alpha/beta domain & 1.1 & 0.028 & 5e-06 \\
# 16 & 659 & IPR001406 & Pseudouridine synthase I, TruA & 1.1 & 0.028 & 5e-06 \\
# 16 & 659 & IPR020095 & Pseudouridine synthase I, TruA, C-terminal & 1.1 & 0.028 & 5e-06 \\
# 16 & 659 & IPR029046 & Lipoprotein localisation LolA/LolB/LppX & 2.1 & 0.027 & 0.011 \\
# 16 & 865 & IPR013025 & Large ribosomal subunit protein uL23-like & 1.1 & 0.046 & 2e-05 \\
# 16 & 865 & IPR012678 & Ribosomal protein uL23/eL15/eS24 core domain superfamily & 1.1 & 0.046 & 1.6e-05 \\
# 16 & 1966 & IPR000182 & GNAT domain & 3.2 & 0.024 & 5.7e-09 \\
# 16 & 1966 & IPR002500 & Phosphoadenosine phosphosulphate reductase domain & 1.5 & 0.027 & 0.029 \\
# 16 & 1966 & IPR004616 & Leucyl/phenylalanyl-tRNA-protein transferase & 6.5 & 0.023 & 0.001 \\
# 16 & 1966 & IPR008210 & Phosphoenolpyruvate carboxykinase, N-terminal & 1.1 & 0.027 & 3.3e-06 \\
# 16 & 1966 & IPR013035 & Phosphoenolpyruvate carboxykinase, C-terminal & 1.1 & 0.027 & 3.3e-06 \\
# 16 & 1966 & IPR016181 & Acyl-CoA N-acyltransferase & 4.7 & 0.016 & 3e-26 \\
# 16 & 1966 & IPR042203 & Leucyl/phenylalanyl-tRNA-protein transferase, C-terminal & 6.5 & 0.023 & 0.001 \\
# 16 & 1966 & IPR042221 & Leucyl/phenylalanyl-tRNA-protein transferase, N-terminal & 6.5 & 0.023 & 0.022 \\
# 16 & 2311 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 2.1 & 0.016 & 1.7e-15 \\
# 16 & 3972 & IPR036890 & Histidine kinase/HSP90-like ATPase superfamily & 3.4 & 0.0069 & 2.5e-19 \\
# 20 & 2998 & IPR029044 & Nucleotide-diphospho-sugar transferases & 1.7 & 0.043 & 1.6e-23 \\
# \bottomrule
# \end{tabular}

# %%
print(df_metx_results.query("Case == 'MetX'").drop("Case", axis=1).to_latex(
    index=False, float_format="{:.2g}".format))
# Out:
# \begin{tabular}{rrllrrr}
# \toprule
# Layer & Latent ID & InterPro ID & InterPro Name & Activation w/ domain & Activation w/o domain & Bonferroni adj. p-value \\
# \midrule
# 12 & 1504 & IPR000073 & Alpha/beta hydrolase fold-1 & 1.3 & 0.026 & 8.7e-06 \\
# 12 & 1504 & IPR029058 & Alpha/Beta hydrolase fold & 1.3 & 0.02 & 0 \\
# 12 & 2175 & IPR029058 & Alpha/Beta hydrolase fold & 1.6 & 0.023 & 0 \\
# 12 & 2836 & IPR029058 & Alpha/Beta hydrolase fold & 1.3 & 0.045 & 3e-35 \\
# 12 & 3765 & IPR003824 & Undecaprenyl-diphosphatase UppP & 1.1 & 0.033 & 2e-06 \\
# 16 & 142 & IPR000873 & AMP-dependent synthetase/ligase domain & 2.9 & 0.044 & 0.015 \\
# 16 & 142 & IPR015590 & Aldehyde dehydrogenase domain & 2.5 & 0.043 & 1.4e-07 \\
# 16 & 142 & IPR016161 & Aldehyde/histidinol dehydrogenase & 2.5 & 0.042 & 1.7e-10 \\
# 16 & 142 & IPR016162 & Aldehyde dehydrogenase, N-terminal & 2.5 & 0.043 & 1.4e-07 \\
# 16 & 142 & IPR016163 & Aldehyde dehydrogenase, C-terminal & 2.5 & 0.043 & 1.4e-07 \\
# 16 & 142 & IPR045851 & AMP-binding enzyme, C-terminal domain superfamily & 2.9 & 0.044 & 0.015 \\
# 16 & 838 & IPR020846 & Major facilitator superfamily domain & 1.1 & 0.026 & 8.6e-19 \\
# 16 & 838 & IPR036259 & MFS transporter superfamily & 1.1 & 0.025 & 1.5e-29 \\
# 16 & 878 & IPR008271 & Serine/threonine-protein kinase, active site & 1.1 & 0.018 & 4.8e-32 \\
# 16 & 1276 & IPR029058 & Alpha/Beta hydrolase fold & 1.1 & 0.012 & 0 \\
# 16 & 2632 & IPR000073 & Alpha/beta hydrolase fold-1 & 3.3 & 0.035 & 0.00013 \\
# 16 & 2632 & IPR029058 & Alpha/Beta hydrolase fold & 2.1 & 0.027 & 6.1e-21 \\
# 16 & 3615 & IPR000073 & Alpha/beta hydrolase fold-1 & 2.3 & 0.041 & 0.00022 \\
# 16 & 3615 & IPR029058 & Alpha/Beta hydrolase fold & 2.1 & 0.031 & 4.1e-37 \\
# 16 & 3995 & IPR018202 & Serine carboxypeptidase, serine active site & 2.2 & 0.018 & 0.0041 \\
# 16 & 3995 & IPR001563 & Peptidase S10, serine carboxypeptidase & 2.4 & 0.017 & 1.2e-05 \\
# 16 & 3995 & IPR029058 & Alpha/Beta hydrolase fold & 1.1 & 0.013 & 0 \\
# 20 & 41 & IPR020846 & Major facilitator superfamily domain & 2.1 & 0.045 & 1.2e-16 \\
# 20 & 41 & IPR011701 & Major facilitator superfamily & 2 & 0.047 & 3.1e-11 \\
# 20 & 41 & IPR036259 & MFS transporter superfamily & 2.4 & 0.04 & 1.9e-26 \\
# 20 & 471 & IPR029044 & Nucleotide-diphospho-sugar transferases & 1.3 & 0.042 & 2.3e-26 \\
# 20 & 898 & IPR012338 & Beta-lactamase/transpeptidase-like & 1.6 & 0.049 & 0.00021 \\
# 20 & 1822 & IPR008271 & Serine/threonine-protein kinase, active site & 1.7 & 0.035 & 8.1e-28 \\
# 20 & 1822 & IPR017441 & Protein kinase, ATP binding site & 1.5 & 0.036 & 9.8e-26 \\
# 20 & 1822 & IPR000719 & Protein kinase domain & 1.6 & 0.034 & 4.1e-35 \\
# 20 & 1822 & IPR011009 & Protein kinase-like domain superfamily & 1.4 & 0.033 & 0 \\
# 20 & 3065 & IPR029058 & Alpha/Beta hydrolase fold & 1.4 & 0.047 & 1.7e-21 \\
# 20 & 3066 & IPR000073 & Alpha/beta hydrolase fold-1 & 1.4 & 0.032 & 0.00023 \\
# 20 & 3066 & IPR029058 & Alpha/Beta hydrolase fold & 1.7 & 0.024 & 0 \\
# 20 & 3196 & IPR033704 & dUTPase, trimeric & 1.1 & 0.037 & 0.00013 \\
# 20 & 3196 & IPR036157 & dUTPase-like superfamily & 1.1 & 0.037 & 0.00013 \\
# \bottomrule
# \end{tabular}
